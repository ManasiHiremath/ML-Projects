# %% [markdown]
# ### DOMAIN: Smartphone, Electronics
# #### CONTEXT:
#  India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across India in the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web by smartphone users across Asia Pacific. The combination of very high sales volumes and the average smartphone consumer behaviour has made India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when they are buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at the right place, there are 90% chances that user will enquire for the same.
#
# #### This Case Study is targeted to build a recommendation system based on individual consumer’s behaviour or choice.
#
# ### DATA DESCRIPTION:
# 1. author : name of the person who gave the ratingcountry
# 2. country the person who gave the rating belongs to
# 3. data : date of the rating
# 4. domain: website from which the rating was taken from
# 5. extract: rating content
# 6. language: language in which the rating was given
# 7. product: name of the product/mobile phone for which the rating was given
# 8. score: average rating for the phone
# 9. score_max: highest rating given for the phone
# 10. source: source from where the rating was taken
# *Data source:
# #### PROJECT OBJECTIVE: We will build a recommendation system using popularity based and collaborative filtering methods to recommend mobile phones to a user which are most popular and personalised respectively..

# %% [markdown]
# #### step 1: Import the necessary libraries and read the provided CSVs as a data frame and perform the below steps.

# %%
#import libraries
import pandas as pd
import numpy as np
import os
from os import listdir

# %% [markdown]
# #### step 2: Merge the provided CSVs into one data-frame.

# %%
# import sys
path=os.getcwd()+"\Data\Data Set\\"
filenames = listdir(path)
x=[filename for filename in filenames if filename.endswith( ".csv" )]

d1=pd.concat([pd.read_csv(path+ x,encoding='latin1') for x in x], axis=0)
#d1=pd.concat([pd.read_csv(path+ x,encoding='ISO-8859-1') for x in x], axis=0)
d1.shape
# Out:
# (1415133, 11)

# %%
## Check a few observations and shape of the data-frame.
d1.sample(3)
# Out:
#                                               phone_url        date lang  \
# 169763  /cellphones/samsung-galaxy-j1-2016-4-5-sm-j120/   7/18/2016   en
# 141341                          /cellphones/cubot-s308/  12/27/2014   de
# 117933               /cellphones/samsung-wave-ii-s8530/   9/16/2011   es
#
#        country  source      domain  score  score_max  \
# 169763      us  Amazon  amazon.com   10.0       10.0
# 141341      de  Amazon   amazon.de   10.0       10.0
# 117933      es    Ciao     ciao.es   10.0       10.0
#
#                                                   extract  \
# 169763                  I love this phone. It works great
# 141341  artikel wie beschrieben, nur fÃ¼r ein 5 zoler ...
# 117933  Una estetica elegante, pedazo de movil y parec...
#
#                               author  \
# 169763               Amazon Customer
# 141341  !!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 117933                      abuquina
#
#                                                   product
# 169763  Samsung Galaxy Express 3 AT&T Prepaid (U.S. Wa...
# 141341  Cubot 5 '' CUBOT S308 IPS HD Display 3G Smartp...
# 117933                              Samsung S8530 Wave II

# %% [markdown]
# #### step 3 : data preprocessing and exploration

# %%
##Round off scores to the nearest integers
df=d1.copy()
df['score']=df['score'].round()
df['score_max']=df['score_max'].round()

# %%
## Check for missing values. Impute the missing values if there is any
df.isnull().mean()*100
# Out:
# phone_url    0.000000
# date         0.000000
# lang         0.000000
# country      0.000000
# source       0.000000
# domain       0.000000
# score        4.486433
# score_max    4.486433
# extract      1.368140
# author       4.466153
# product      0.000071
# dtype: float64

# %%
#missing value imputation
df['score']= df['score'].replace(np.nan, 0)
df['score_max']= df['score_max'].replace(np.nan, 0)
df['extract']= df['extract'].replace(np.nan,'no captured')
df['author']= df['author'].replace(np.nan,'no captured')
df['product']= df['product'].replace(np.nan,'no captured')

# %%
#Check for duplicate values and remove them if there is any
if len(df[df.duplicated()]) > 0:
    print('Data has duplicate rows')
    df_temp1=df.drop_duplicates()
    print('Number of rows dropped', len(df)-len(df_temp1))
    print(df_temp1.shape)
else :
    print('Data does not have duplicate rows')
    df_temp1=df.copy()
    print(df_temp1.shape)
    print('Number of rows dropped', len(df)-len(df_temp1))
# Out:
# Data has duplicate rows
# Number of rows dropped 6436
# (1408697, 11)

# %%
## highest rating given for the phone
df_temp1['score_max'].value_counts()
# Out:
# 10.0    1345604
# 0.0       63093
# Name: score_max, dtype: int64

# %%
len(df_temp1['lang'].value_counts())
# Out:
# 22

# %%
df_temp1[df_temp1['lang']=='ar'].sample(2)
# Out:
#                                               phone_url       date lang  \
# 61385                       /cellphones/huawei-p9-plus/  7/14/2016   ar
# 169811  /cellphones/samsung-galaxy-j1-2016-4-5-sm-j120/  5/10/2017   ar
#
#        country source        domain  score  score_max  \
# 61385       ae   Souq  uae.souq.com   10.0       10.0
# 169811      ae   Souq  uae.souq.com   10.0       10.0
#
#                                                   extract      author  \
# 61385                                            Ø´ÙØ±Ø§   mahdi1408
# 169811  ÙÙØ§Ø³Ù Ø§Ù ÙØ°Ù ÙÙ Ø§ÙÙ
# Ø±Ù Ø§ÙØ«Ø...  melody1989
#
#                                                   product
# 61385   ÙØ§ÙØ§ÙÙ P9 Ø¨ÙÙØ³ - 64 Ø¬ÙØ¬Ø§Ø¨Ø§ÙØª...
# 169811  Ø³Ø§Ù
# Ø³ÙÙØ¬ Ø¬Ø§ÙÙØ³Ù J1 2016 SM-J120H -...

# %% [markdown]
# #### Summary :
# 1. maximum score 0-10 and there is a data in 22 launganges with some in non readable format/ non english format
# 2. Above data is not adding any value, as this is not in readable format with english

# %%
## Drop irrelevant features. Keep features like Author, Product, and Score
drop_col_list=['phone_url','date','country','domain','source','extract','score_max', 'lang']
df_temp1_sub=df_temp1.drop(drop_col_list, axis=1)
df_temp1_sub.sample(2)
# Out:
#         score              author                                  product
# 265063   10.0  Kurt C. Anchorstar  Apple iPhone 6, Space Gray, 16GB (AT&T)
# 221618    9.0        Tazzymama71      Samsung Galaxy S4 Active 16GB (AT&T)

# %%
##Keep only 1000000 data samples. Use random state=612.
df_sampled = df_temp1_sub.sample(n=1000000 ,random_state=612)
df_sampled.shape
# Out:
# (1000000, 3)

# %%
df_sampled.head(2)
# Out:
#        score                  author  \
# 55265    8.0  Vinod Kumar Chengespur
# 97318    2.0                  Sharon
#
#                                                  product
# 55265                   Lenovo Vibe K4 Note (White,16GB)
# 97318  HTC Desire 816 Black (Virgin mobile) - 5.5 inc...

# %%
#identify most rated feature

# %% [markdown]
# #### step 3.1: processing on data frame column

# %%
import re
import string
df_sampled['product']= df_sampled['product'].map(lambda x: x.lower())
df_sampled['author']= df_sampled['author'].map(lambda x: x.lower())
df_sampled['prod_details']=df_sampled['product'].map(lambda x: ' '.join(x.split()[:3]))
df_sampled['prod_details1']= df_sampled['prod_details'].map(lambda x: ' '.join(re.split(r'\W+', x)[:3]))
df_sampled['nonalpha']=df_sampled['prod_details1'].map(lambda x: re.sub("[^a-zA-Z0-9]+", "1",x))
df_sampled['authornonalpha']=df_sampled['author'].map(lambda x: re.sub("[^a-zA-Z0-9]+", "1",x))
df_sampled.sample(2)
# Out:
#         score    author                                            product  \
# 304936    4.0  la tommi  asus zenfone 2 smartphone 4gb 32gb android 5.0...
# 280755    8.0      sqej   ð¡ð¾ñð¾ð²ñð¹ ñðµð»ðµñð¾ð½ nokia 206 dual sim
#
#                                prod_details   prod_details1        nonalpha  \
# 304936                       asus zenfone 2  asus zenfone 2  asus1zenfone12
# 280755  ð¡ð¾ñð¾ð²ñð¹ ñðµð»ðµñð¾ð½ nokia     ð ð¾ñ ð¾ð²ñ               1
#
#        authornonalpha
# 304936       la1tommi
# 280755           sqej

# %% [markdown]
# #### step 3.2: getting readable data from product and user data

# %%
df_sampled_eng=df_sampled[df_sampled['nonalpha']!="1"]
df_sampled_eng.shape

df_sampled_auteng=df_sampled[df_sampled['authornonalpha']!="1"]
df_sampled_auteng.shape
df_sampled_auteng['author'].unique().tolist()
# Out:
# ['vinod kumar chengespur',
#  'sharon',
#  'an sionnach',
#  'jomine jose',
#  'walter',
#  'cliente amazon',
#  'hjkage',
#  'egornesterenko2009',
#  'no captured',
#  'chads3010',
#  'hitesh malhotra',
#  'luis del rã\xado',
#  'w kessing',
#  'elgringo_221',
#  'viktoria-o',
#  'amazon customer',
#  'josef',
#  'hussainn',
#  'alessio t.',
#  'amigo-vulnerable',
#  'merendeiro',
#  'lucas',
#  'scorpionne666',
#  'j. cerquera',
#  'anonymous',
#  'r. o. davis',
#  'phobia',
#  'dennis kee',
#  'stuart gosney',
#  'lynneb',
#  'maribel',
#  'dilemma21',
#  'vlad',
#  'adam',
#  'nino',
#  'mk',
#  'farooque ahmed',
#  'elke kaiser',
#  'i. palmer',
#  'aaabadtec ',
#  'josemanuel',
#  'rdraper',
#  'marie-pierre',
#  'frank westphal',
#  'john',
#  'raymond ong a kwien',
#  'ja-topograf',
#  'molux',
#  'dominik',
#  'claude',
#  'irinags2009',
#  'marcato mauro',
#  'oc1905',
#  'felivrin',
#  'killingjoke',
#  'ajai mohan',
#  'iomar lemes barbosa',
#  'chris p',
#  'pravin',
#  'leorock65',
#  'b210bl',
#  'annette barrett',
#  'roticbeatz',
#  'ramires',
#  'lypssos',
#  'andfri80',
#  'netmax',
#  'n. n. kaonga',
#  'sm',
#  'cj "chefjeff"',
#  'w.phone. pourri.',
#  'rahul kumar',
#  'k. oder',
#  'wilton sergio',
#  'mr. ninja',
#  'kazane',
#  'itai shemesh',
#  'riccardo b.',
#  'lucinda10',
#  'demetr1o',
#  'morgana1966',
#  'huliye',
#  'jacques',
#  'shantanu m. dahale',
#  'kung_keno',
#  'oksi-0409',
#  "client d'amazon",
#  'matthew timms',
#  'harold',
#  'lucas franã§a meirelles',
#  'webalby',
#  'nick_h',
#  "ram's c7",
#  'july',
#  'avshnika',
#  'coineandude ',
#  'lauriwjr',
#  'naptown2',
#  'michael aust',
#  'katharina szynal',
#  'eduardo',
#  'faimix',
#  'paulthab',
#  'fran',
#  'edgar k.',
#  'norporter',
#  '50mbyte',
#  'james mccarthy',
#  'abhishek trivedi',
#  'tilevi',
#  'liooghnj',
#  'jaybee',
#  'misscricri',
#  'gian',
#  'meloparedes',
#  'william cardinali',
#  'ã§akil',
#  'cristian nascimento miguel',
#  'dr d',
#  'abin',
#  'gadgetgeek',
#  'dazmack',
#  'terumi',
#  'shubham',
#  'manu',
#  'lucky907',
#  'n.nusrat',
#  'paul wesely',
#  'jlv smeets',
#  'harmony83',
#  'sathish',
#  'arik',
#  'chismoso',
#  '????c?????????????? ?????????\x80???? ?????\x80???????????? ',
#  'rb98',
#  'amazon kunde',
#  'merely',
#  'nick',
#  'marco',
#  'alejandra rodriguez yanez',
#  'unknown',
#  'ashvinkumar dave',
#  'coento',
#  'rkty ',
#  'natali',
#  'k rajesh kumar',
#  'grams',
#  'meister',
#  'heiko',
#  'c. felske',
#  'kurt endrikat',
#  'marciley',
#  'ederlyn4f ',
#  'luis quesada',
#  'crashmaker',
#  'meneseslea2010',
#  'ibrahim perdigon',
#  'kyef',
#  'e-bit',
#  'gabriel kaiser',
#  'luca tommasi',
#  'samouss35',
#  'matthieu',
#  'fedor tsybulin',
#  '1delarosa1',
#  'elly "le petite ours"',
#  'vilma 34',
#  'motogustavo',
#  'frayed',
#  'khidhir brahmendra vinukonda',
#  'ky mi',
#  'me sandrine',
#  'mendes200',
#  'gadget mom',
#  'lansing9999',
#  'jlh34',
#  'marie-louise noã«l',
#  'juan roa',
#  'kaagsa',
#  'prettycoolmom ',
#  'anne',
#  'terrance',
#  'pasquale977-2',
#  'chiranjivi girish thuse',
#  'neuli',
#  'elisabeth krumme',
#  'martynoviktor',
#  'lindaa01',
#  'mahern2011',
#  'martin',
#  'saransh bhavsar',
#  'e. strobel',
#  'zamackie',
#  'ahof',
#  'ferhat',
#  'aurkene pã©rezrosado',
#  'sara curtarelli',
#  'mauro maranto',
#  'marinettedu59',
#  'abhi',
#  'isabella',
#  'bs265172',
#  'alfredo wallis',
#  'jian-guo ren',
#  'gururaja s.',
#  'cjduran',
#  'benjoy',
#  'sudipta gupta',
#  'juan sebastian caparros',
#  'fathima',
#  'mao13',
#  'fedorovmb',
#  'astrid polivka',
#  'edge140392',
#  'bernard',
#  'paolo',
#  'hltechie',
#  'daniele moriello',
#  'perryjonsson',
#  'barzogh',
#  'justpablo666',
#  'jaxon0521',
#  'erikku',
#  'claris',
#  'hayrettin',
#  'tia0896',
#  'moises',
#  'sunil',
#  'dima19',
#  'john h.',
#  'dilpreet',
#  'christian',
#  'cronos',
#  'rynofilms',
#  'pabloylola',
#  'juju49700',
#  'a. h.',
#  'johan ranson',
#  'lilafee',
#  'tony rourke',
#  'bitz',
#  'ggiden',
#  'pratik kumar',
#  'chitra saxena',
#  'francisco lamolda alvarez',
#  'ricodjoko',
#  'spã¤nemacher',
#  'sreekar',
#  'dario_1320',
#  'erhancam',
#  'nidam',
#  'g.tuenker',
#  'tropical phil',
#  'trekgeek',
#  'mart8365',
#  'liant_16',
#  'elsacbl',
#  'radchenko viktor',
#  'mika',
#  'henry osborne',
#  'oliveriri ',
#  'richie defrates',
#  'vol8',
#  'dylan k.',
#  'samson e.',
#  'morisato-kun',
#  'marc',
#  'caglarceritli',
#  'feldkamp',
#  'amine41',
#  'roshan jain',
#  'dhtroy',
#  'pyykinpesija ',
#  'lolely',
#  'marcio fenix',
#  'patrinc02',
#  'jaclarus',
#  'renepapa',
#  'ernst august',
#  'onkonk',
#  'christine suleyman',
#  'jeni',
#  'dd ss',
#  'girard',
#  'spiroux arnaud',
#  'guri singh',
#  'emerson',
#  'hercule',
#  'chalapathi',
#  'isabel llorente',
#  'kaliblade',
#  'mr w t cassidy',
#  'delicate',
#  'raghu',
#  'k.harish',
#  'marie-rose muller',
#  'beatriz aparecida vieira martins',
#  'igor a',
#  'mark',
#  'massimo pergolini',
#  'tiger230178',
#  'lparlitanu',
#  'carolina',
#  'manokanta saraf',
#  'm. kolias',
#  'yusenka',
#  'nico',
#  'cillaw',
#  'jean callaghan',
#  'mystikchick17',
#  'martin k.',
#  'c. becker',
#  'detrie',
#  'angel160',
#  'fparejo',
#  'vik',
#  'xarry',
#  'misafir',
#  'shashank',
#  'vladyan',
#  'salsa',
#  'marcia rose',
#  'gertrud',
#  'guillermohector',
#  'gabihrs',
#  'vivek paidi',
#  'umesh nawale',
#  'kevin ramirez',
#  'jaewoo kim',
#  'patricio g.',
#  'jojo',
#  'lance f.',
#  'kevkev215 ',
#  'sasha mason',
#  'gabriel mat',
#  'djgom',
#  'theoneman',
#  'leila wes',
#  'chichi',
#  'gianluca',
#  'charlie pendl',
#  'jennifer',
#  'luv2playffl ',
#  'josue sanchez',
#  'tim bearden',
#  'animesh ghosh',
#  'jawan',
#  'roberto carletti',
#  'dora',
#  'andre',
#  'jhath',
#  'obaidur rehman',
#  'prbabu85',
#  'ed loohuis',
#  'optimierungspartner',
#  'empresspirate11',
#  'niels de b',
#  'curtis w carver',
#  'birkullanici',
#  'ronnie2boys',
#  'vishal tiwari',
#  'mersedesslk',
#  'aubi',
#  'bartboris',
#  's-ivaschenko',
#  'phone',
#  'abdul',
#  'jinfenggoh',
#  'magnusvs',
#  'thomas s.',
#  'jacobmart',
#  'minikiny',
#  'sabyasachi mandal',
#  'revtotheredline',
#  'yeahlau',
#  'ninja',
#  'msprivat',
#  'nekoosarocks ',
#  'blaze',
#  'javier r.',
#  'barbara f.',
#  'chris elias',
#  'marp',
#  'estheria',
#  'eugenio b.',
#  'jf',
#  'condemnation-84',
#  'mountain dew man',
#  'rolf',
#  'nieke',
#  'jiå\x99ã\xad, jablonec nad nisou',
#  'berdosana',
#  'connectednow ',
#  'mason reynolds',
#  'cotes',
#  'bhaskarkumar',
#  'kevin',
#  'jamesbond2000',
#  'leonard',
#  'piloulip',
#  'dmvanderreep',
#  'avinash887',
#  'arijit ray',
#  'kennyken',
#  'expertcustomer',
#  'mp78',
#  'grisu100',
#  'alexander struck',
#  '5v3r',
#  'dr. singh',
#  'vladislaw.nizelsky',
#  'gast',
#  'tapan',
#  'marlboro81',
#  'kirduk88',
#  'qantas',
#  'abiola',
#  'lory',
#  'ihsin',
#  'astino',
#  'boro',
#  'chris',
#  'tbakabaka',
#  'rene v.',
#  'quillec gilles',
#  'ddavid2001',
#  'marcela',
#  'spresso',
#  'imotion83',
#  'jarbas correia',
#  'raffaele',
#  'janina12',
#  'bart',
#  'joel gardner',
#  'heiderã¶schen',
#  'yurbansssr',
#  'familyoffour',
#  'suat',
#  'twan',
#  'pack solenn',
#  'l. jones',
#  'enemy1986',
#  'kristen4galxreview ',
#  'cyndie p.',
#  'ua tuahine kekipi',
#  'lem',
#  'lancerv8',
#  'happydog',
#  'bal8469',
#  'colonelredkite',
#  'zzero',
#  'the fiddler',
#  'bernd k..',
#  'jordi',
#  'paul g',
#  'b. shive',
#  'sia',
#  'wetbear',
#  'javier g.',
#  'rj diaz "rj"',
#  'donald charlton',
#  'geannee lizardo',
#  'kent',
#  'budbud ',
#  'ralf',
#  'janssens',
#  'koushik das',
#  'rxb',
#  'denis de grenoble',
#  'rimpa saha',
#  'rojo3s ',
#  'glenndcruz24',
#  'roberto arantes',
#  'pratiek',
#  'rã³sula',
#  'ladia330 ',
#  'armando',
#  'sandeep goswamy',
#  'sanek',
#  'sabaht',
#  'ludovico',
#  'leyster',
#  'stefano',
#  '19-jun',
#  'sam l.',
#  'dennisdilara',
#  'carlo',
#  'pastor les',
#  'chillinpape',
#  'lemospie',
#  'genius-to-be',
#  'shreyas waje',
#  'shailendra kumar yadav',
#  'ukraine-us',
#  'harvey orlando steinbach',
#  'chris prettejohn',
#  'n. barth',
#  'eden_shii',
#  'anoop kumar',
#  'jako66 ',
#  'mordecai',
#  'niko_will',
#  'ottonormalverbraucher',
#  'fransou19',
#  'anthony s.',
#  'arma abbas',
#  'ben',
#  'ian r "ianr"',
#  'giovanni benedetto',
#  'samsufi',
#  'felipe5903',
#  'joseph t.',
#  'megalamozz',
#  'jmbd1206',
#  'ashish patel',
#  'loui',
#  'zaxes',
#  'rui afonso stracke "nozama"',
#  'sandip kumar',
#  'everlin',
#  'mallika singh',
#  'keyboarder',
#  'hello',
#  'anna-dv',
#  'sasikumar c',
#  'giovanni',
#  'man',
#  'thomas kahle "black-jay"',
#  'marko7533333',
#  'arina_92',
#  'shiv kumar rai',
#  'bernhard',
#  'snooziewoozie ',
#  'mehmet eken',
#  'dominiekk',
#  'kishan s.',
#  'mohamed nishan jaleel',
#  'marvin',
#  'gui lee',
#  'einem kunden',
#  'g. mehmet',
#  'lyubas_aa',
#  'berlinfun',
#  'gaste',
#  'jã¼rgen',
#  'gaburri',
#  'alkesh r patel',
#  'vineet singhal',
#  'kubiata',
#  'b. rogers',
#  'veronica',
#  'thiago lima',
#  '11jart',
#  'pepito grillo',
#  'paul tanniou',
#  'aksisey',
#  'oetz2000',
#  'ruby ann embestro',
#  'lbro',
#  'charan',
#  'francesco',
#  'thorsson',
#  'douglas alexandre dias barbosa',
#  'q. ulhaq',
#  'sc1928',
#  'tiagoam',
#  'stefaniasantoriello',
#  'paolotamagni',
#  'sonyericssonk500i',
#  'dinesh j.',
#  'marylin lopez',
#  'randyalex',
#  'sadik',
#  'hejje',
#  'mahesh tm',
#  'briguy16 ',
#  'noknok1971',
#  'tim',
#  'f. diefenbach',
#  'anonymous ',
#  'madara',
#  'mauricio',
#  'ollie205',
#  'defosseux',
#  'sebastian',
#  'mike der einkauf-junkie "der tag kann nur bes...',
#  'ignacio',
#  'anita s.',
#  'alex ossevoort',
#  'michisfootball',
#  'phartsmone lover',
#  'spencer177',
#  'ccaryahoo ',
#  'ftv25',
#  'reiner hofmann',
#  'deezaster',
#  'joseph h.',
#  'ssmithapco',
#  'herick',
#  'gabriel',
#  'phoenix ',
#  'miatamania',
#  'scott s.',
#  'fred',
#  'ms. marie j. h. koenig',
#  'von helga a. (barby)',
#  'torben',
#  'nofreephones',
#  'guy',
#  'carlos gutierrez',
#  'brian cheek',
#  'sjotty',
#  'nitin',
#  'haleysmom94 ',
#  'cantu',
#  'jon e. hutcherson "bookman"',
#  'wamafe',
#  'kris',
#  'mummy1',
#  'ela',
#  'sharon blaylock',
#  'joe',
#  'adilson dos santos',
#  'jlslemmons',
#  'claudio',
#  'vivek sheel',
#  'berne',
#  'kaja',
#  'nelly',
#  'pamie haynes',
#  'fairdinand',
#  'mr n.laulkar',
#  'anne1111',
#  'tigertornado',
#  'martausa ',
#  'fc',
#  'patrick wynants',
#  'rezultat',
#  'angi',
#  'emalys',
#  'juline21',
#  'kirarecommends',
#  'c. greene',
#  'century',
#  'consult',
#  'david k.rooney',
#  'flavio',
#  'black',
#  'ag010',
#  'noah merz',
#  'claudio patti',
#  'marimeri',
#  'chief.mirono2010',
#  'joshua kirkland',
#  'gio58',
#  'elaine l. woodward',
#  'matthew',
#  'tishuu "tishuu"',
#  'mareatta',
#  'pankaj suthar',
#  'deboraakbulut',
#  'delgis',
#  'tonyblack',
#  'paolo ghedina',
#  'r. bowman',
#  'almas',
#  'lizomar santos',
#  'cosimo',
#  'stiing',
#  'disgruntledmb',
#  'jong',
#  'jairo andres novoa mantilla',
#  'za8999',
#  'holly clearwater',
#  'naresh begavath',
#  'veraspb2008',
#  'dave',
#  'damian cannamela',
#  'inigotodaro',
#  'p. buttler',
#  'michael preuss',
#  'laura',
#  'arantyr',
#  'rohan c.',
#  'erwan01',
#  'romana mã¼ller',
#  'giã²',
#  'sandy manglos',
#  'dannysin1 ',
#  'stephan',
#  'yuji',
#  'tania and camilo',
#  'newssmarttech.com',
#  'tejas',
#  'fernando',
#  'txen',
#  'sueli',
#  'nicokine002',
#  'feliciano damico',
#  'giorgio vago',
#  'ronleon',
#  'maxime h',
#  'chris utech',
#  'oges_timsi',
#  'rogers3712',
#  'dj_mixhouse',
#  'pseudonyme',
#  'erkocali',
#  'davidino123',
#  'theewizard',
#  'hugo_peters',
#  'centuries',
#  'h. ansel',
#  'c??sar arrieta',
#  'einer kundin',
#  'hariprasath',
#  'thebveis',
#  'fabios1976',
#  'nath',
#  'elisha',
#  'beanface',
#  'jasmine riley',
#  'lafon',
#  'kamalesh',
#  'richard',
#  'lowry1309 ',
#  'jamessmith500',
#  'pallus',
#  'ana',
#  'hl',
#  'patrice',
#  'rodrigo de freitas tannãºs',
#  'teilsmit',
#  'roschin-v-y',
#  'stefano beccalli',
#  'kiwo',
#  'brandom hernandez',
#  'asesino667',
#  'risingstar',
#  'korbendallas',
#  'k. brandst',
#  'georg_re',
#  'ajay kashyap',
#  'supervegetox',
#  'hypostasis',
#  'katiitas',
#  'raman chhagan chaudhari',
#  'rami',
#  'pietdl',
#  'rahul',
#  'mad3line',
#  'marika',
#  'yevgeniy mironyuk-leykine',
#  'naitik patel',
#  'raoul61',
#  'jandyr pereira filho',
#  'xzzzzz',
#  'marco94',
#  'karen knembel',
#  'victor w hendrix',
#  'ramius1521',
#  'zipped',
#  'diaman1234',
#  'sely a',
#  'powershihab',
#  'ingwarr',
#  'frits2016',
#  'jaquie',
#  'n-gager',
#  'liloute',
#  'oh ghee',
#  'merola nello',
#  'von waldemar r. (nersingen)',
#  'mustafa',
#  'laurence57270',
#  'andre jose',
#  'harun t.',
#  'ani',
#  'andrã©a',
#  'sircynic',
#  'terry smith',
#  'angelo mazzafera',
#  'r. mack',
#  'silvia marcia rocha de souza',
#  'patrick',
#  'daniel enrique rivera zelaya',
#  'anton stehouwer',
#  'dany',
#  'eagle_wolf',
#  'amazon kundenrezensionen',
#  'dp',
#  'minouche',
#  'ceddy710 ',
#  'abc-post',
#  'canon alsup',
#  'stefy_88',
#  'jesãºs',
#  'gbladdha',
#  'alessandro deathwalker',
#  'constantinopoli',
#  'david',
#  'mtsc2008',
#  'clo',
#  'renel',
#  'adrimap',
#  'ramakrishna behera',
#  'davemock ',
#  'primis2008',
#  'wolf1661 ',
#  'wendy soyer',
#  'travel geschã¤ftsmann',
#  'renek',
#  'vorga',
#  'carmen j. fernendez de f.',
#  'henk liewes',
#  'stefano pettinelli',
#  'marco s.',
#  'arias817 ',
#  'outfitter ',
#  'juliofernandez',
#  'nena',
#  'orlangor',
#  'thestikman',
#  'jean c.',
#  'vicsic',
#  'toverbal',
#  'scorpion',
#  'joejoe90 ',
#  'andy',
#  'lgg3',
#  'cjsantiago2005 ',
#  'e_v_g_e_n_87',
#  'holger rentsch',
#  'lezanch',
#  'mabelkia',
#  'stynema',
#  'vincenzo coti',
#  'jayeybee',
#  'the-razmes',
#  'cahudson ',
#  'vgondim',
#  'rmadrid7 ',
#  'tasha brilliant',
#  'retkit',
#  'tataru marius',
#  'pierre',
#  'carlos perez',
#  'bart van de venne',
#  'gasmolinarich',
#  'm. schneider',
#  'mixerblade',
#  'phsycho',
#  'roxanelle',
#  'carmen margarida kunrath',
#  'amy s.',
#  'mariachico',
#  'crispin_gatieza',
#  'michael r. tellup',
#  'samlover420 ',
#  'anish jose',
#  'davidprobertson',
#  'ere',
#  'lapin mies',
#  'robert mckenzie',
#  'server2333',
#  'nimmerland',
#  'mara',
#  'gary',
#  'feliciano',
#  'ceren2006',
#  'daniel almã©rida',
#  'bandone90',
#  'chus fran',
#  'bruno barbosa',
#  'redd31 ',
#  'krishna',
#  'crpycrt',
#  'fabio',
#  'jagdeesh',
#  'melissa',
#  'barbiella',
#  'petitbonheur',
#  'louis schwartz',
#  'mercury10000',
#  'burak',
#  'aidar212',
#  'achille scaramella',
#  'antonio ruggieri',
#  'saif mohammad',
#  'klaus -. dieter fleischmann',
#  'jani',
#  'francisco',
#  'banane',
#  'gimpel',
#  'eb',
#  'very disappointed',
#  'r. evans',
#  'gennaro',
#  'thomas reisinger',
#  '_lady_lina_',
#  'cheremuhi',
#  'diddy',
#  'minireaper99',
#  'maurilio zucatelli junior',
#  'samuel',
#  'b. savage',
#  'yr',
#  'kaktusz',
#  'missb90',
#  'torrano giuseppe',
#  'wings ',
#  'banderne',
#  'ulrich',
#  'mr j r hartley',
#  'aziz',
#  "rach'",
#  'dinosaur',
#  'tigerjim',
#  'florian stiedl',
#  'biswarup kundu',
#  'koushik rana',
#  'rafaeltc',
#  'wal-rs',
#  'ljs',
#  'chintan barot',
#  'andrea frigo',
#  'tashh',
#  'storm owner 08',
#  'white',
#  'x. li',
#  'nam00',
#  'dsc29a',
#  'adrianarosa2014',
#  'justin',
#  'milie 972',
#  'ravi shankar',
#  'figaro',
#  'dalep',
#  'sheldima',
#  'sudarshan pal',
#  'sergi',
#  'marchi52',
#  'vasiliy0410',
#  'jose manuel jimenez',
#  'dave c',
#  'cherry1618',
#  'coolvie',
#  'cuccinella',
#  'kitty_b0220',
#  'chunlol',
#  'alfredo v.',
#  'mattia',
#  'nimesh a.',
#  'michele',
#  'vlart7',
#  'martha ellis',
#  'antonello',
#  'claire',
#  'samsungliker',
#  'aludwynne ',
#  'alejandro paradis',
#  'hopeless',
#  'grischa',
#  'kim',
#  '8688346741',
#  'sagar kamranii',
#  'irida',
#  'lorenzo alziati',
#  'augusto',
#  'jan mã¶ller',
#  'sara1304',
#  'isabel',
#  'ademoglu1982',
#  'wayner',
#  'emelieostoya',
#  'luca',
#  'tolyanwp',
#  'nabil jouini',
#  'michelangelo',
#  'xenios',
#  'sgtjey ',
#  'tony',
#  'robson soares',
#  'vincent',
#  'dr. johnson c. philip "author of over 100 books and 10,000 articles"',
#  'stefangelo',
#  'zã¡kaznã\xadk',
#  'dj_deano',
#  'krzysztof j.',
#  'chasseurdetigrou',
#  'alessandro vasco',
#  'lauren williamson',
#  'ravencrowgoth91',
#  'wch',
#  'aravind r',
#  'nellys torres',
#  'alan hoang',
#  'dimka500',
#  'rafa21 ',
#  'd.john',
#  ...]

# %%
## most rated product
prod=df_sampled.groupby(['prod_details1']).size().reset_index(name='counts')
prod.sort_values('counts',ascending=False)[0:5]
# Out:
#            prod_details1  counts
# 14162  samsung galaxy s6   19578
# 14163  samsung galaxy s7   19015
# 14152   samsung galaxy s   14071
# 14155  samsung galaxy s4   13487
# 14156  samsung galaxy s5   12425

# %% [markdown]
# #### Data frame Prod will give most rated products, above is the list of top 5 products which has recived maximum reviews

# %%
df_sampled.groupby('prod_details1')['score'].agg(['mean','size']).sort_values(['mean','size'],ascending=False).head(10).reset_index()
# Out:
#               prod_details1  mean  size
# 0    apple smartphone libre  10.0    22
# 1            iphone 6s 16gb  10.0    16
# 2  samsung smartphone libre  10.0    16
# 3             lg optimus gj  10.0    15
# 4           samsung note ii  10.0    13
# 5            iphone 6s 64gb  10.0    12
# 6         coque sony xperia  10.0    11
# 7     seminovo apple iphone  10.0    11
# 8      blackberry dtek50 16  10.0    10
# 9            htc p4550 tytn  10.0    10

# %% [markdown]
# Summary : Above is the top 10 highest rated products based on ratings and size

# %%
prod_rd=df_sampled_eng.groupby(['prod_details1']).size().reset_index(name='counts')
print(df_sampled_eng.groupby('prod_details1')['score'].agg(['mean','size']).sort_values(['mean','size'], ascending=False).head(2))  
prod_rd_gt50_rate_list=prod_rd[prod_rd['counts']>50]['prod_details1']
prod_rd_gt50_rate_list[0:2]
# Out:
#                         mean  size
# prod_details1
# apple smartphone libre  10.0    22
# iphone 6s 16gb          10.0    16
# 3          apple
# 16     envios da
# Name: prod_details1, dtype: object

# %% [markdown]
# Summary: Since this data has non readable characters, removing them and above is list of only readable highest rating products

# %%
## authors with most reviews
author=df_sampled.groupby(['author']).size().reset_index(name='counts')
author.sort_values('counts',ascending=False)[0:10]
# Out:
#                  author  counts
# 26747   amazon customer   54605
# 375541      no captured   43809
# 99693    cliente amazon   13674
# 140909            e-bit    5959
# 99668   client d'amazon    5496
# 27077      amazon kunde    3283
# 39136         anonymous    2067
# 145533     einer kundin    1890
# 145530     einem kunden    1350
# 518385          unknown    1225

# %% [markdown]
# Summary : Above is the list of authors with maximum reviews

# %%
## authors names too have junk data so checking list of authors whose names are readable
## authors with most reviews
author_rd=df_sampled_auteng.groupby(['author']).size().reset_index(name='counts')
author_rd.sort_values('counts',ascending=False)[0:2]
author_rd_gt50_rate_list=author_rd[author_rd['counts']>50]['author'].to_list()
author_rd_gt50_rate_list[0:3]
# Out:
# ['a', 'aaron', 'abhishek']

# %% [markdown]
# Summary : Above is the list of authors with maximum reviews with authors name in readble format

# %%
## Select the data with products having more than 50 ratings
prod_gt50_rate_list=prod[prod['counts']>50]['prod_details1']
prod_gt50_rate_list[0:4]
# Out:
# 3          apple
# 16     envios da
# 19           htc
# 28        huawei
# Name: prod_details1, dtype: object

# %%
## users who have given more than 50 ratings.
author=df_sampled.groupby(['author']).size().reset_index(name='counts')
author_gt50_rate_list=author[author['counts']>50]['author'].to_list()
author_gt50_rate_list[0:2]
# Out:
# ['#', '????????']

# %%
df_final=df_sampled[(df_sampled['prod_details'].isin(prod_gt50_rate_list)) & (df_sampled['author'].isin(author_gt50_rate_list))]
df_final.shape
# Out:
# (174326, 7)

# %% [markdown]
# ## populatrity based recommondation

# %%
df_final1=df_final.drop_duplicates()
print(df_final1.shape)
df_final.groupby('prod_details1')['score'].agg(['size','mean']).sort_values(['mean','size'], ascending=False)[0:5]
# Out:
# (89069, 7)
#                      size  mean
# prod_details1
# blackberry oem z10     12  10.0
# blackberry passport    12  10.0
# samsung e1150 handy     9  10.0
# nokia n8 sim            8  10.0
# iphone 6 16             6  10.0

# %% [markdown]
# #### Summary : above are 5 products recommoded based on popularity/ratings from users.
# These products have high rating but these products have been recommonded by very less users. products with high reviwes are not appraring in top list

# %%
df_final_v1=df_sampled[(df_sampled['prod_details'].isin(prod_rd_gt50_rate_list)) & (df_sampled['author'].isin(author_rd_gt50_rate_list))]
df_final_v1.shape
df_final_v1=df_final_v1.drop_duplicates()

###Summary : this data has less noise,

# %%
df_final_v1.groupby('prod_details1')['score'].agg(['mean','size']).sort_values(['mean','size'],ascending=False).head(5)
# Out:
#                      mean  size
# prod_details1
# blackberry oem z10   10.0     9
# samsung e1150 handy  10.0     9
# blackberry passport  10.0     8
# nokia n8 sim         10.0     8
# sony ericsson arc    10.0     5

# %% [markdown]
# Summary: data with less noise too produce same list of products based on popularity

# %% [markdown]
# ## Build a collaborative filtering model using SVD.

# %%
from surprise import SVD, KNNWithMeans
from surprise import accuracy
from surprise import Dataset,Reader

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(df_final1[['author', 'prod_details1', 'score']], reader)

# Split data to train and test
from surprise.model_selection import train_test_split
trainset, testset = train_test_split(data, test_size=.25,random_state=123)

print(trainset.to_raw_iid(0))

svd_model = SVD(n_factors=5,biased=False)
svd_model.fit(trainset)

test_pred = svd_model.test(testset)

# compute RMSE
print(accuracy.rmse(test_pred))
pred = pd.DataFrame(test_pred)
# # pred[pred['uid'] == 'amazon customer'][['iid', 'r_ui','est']].sort_values(by = 'r_ui',ascending = False).head(10)
# pred[['uid','uid','iid', 'r_ui','est']].sort_values(by = ['uid','r_ui','est'],ascending = False).head(10)
# Out:
# htc incredible s
# RMSE: 2.9514
# 2.9513655907437624

# %%
from collections import defaultdict
def get_top_n(predictions, n=10):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %% [markdown]
# ### New product recommendation for user

# %%
top_n = get_top_n(test_pred, n=10)
# pred.sort_values(['uid','r_ui','est'],ascending=False).head(10)
top_n
# Out:
# defaultdict(list,
#             {'alexander': [('huawei ascend g600', 10),
#               ('htc one smartphone', 9.556021453405585),
#               ('huawei ascend mate', 9.425918521969589),
#               ('asus computer zenfone', 9.083667572781483),
#               ('sony xperia s', 9.032531882250506),
#               ('samsung s5230 star', 8.91584944079047),
#               ('honor 7 smartphone', 8.639872568266167),
#               ('htc one x', 8.534793979834358),
#               ('lenovo motorola moto', 8.320956781191608),
#               ('sony ericsson k750i', 8.297947151611009)],
#              'juan carlos': [('sony xperia z5', 9.22362311479064),
#               ('bq aquaris e5', 8.993835718545952),
#               ('lg l bello', 8.953404624477994),
#               ('apple iphone 5s', 8.934542845367217),
#               ('samsung galaxy note', 8.878961035375392),
#               ('samsung galaxy s3', 8.779275442592148),
#               ('samsung galaxy s3', 8.779275442592148),
#               ('galaxy samsung galaxy', 8.621429162923306),
#               ('huawei p9 lite', 8.504919627542918),
#               ('samsung galaxy ace', 8.445360451599617)],
#              'maria': [('huawei ascend g750', 9.87258997611236),
#               ('samsung galaxy s4', 9.741765148396633),
#               ('sim free samsung', 9.717782957262749),
#               ('lg optimus l9', 9.603181787642653),
#               ('huawei ascend mate', 9.508958388982105),
#               ('lenovo moto g4', 9.471126734703331),
#               ('elephone p6000 pro', 9.460545447593317),
#               ('sim free apple', 9.419170764128076),
#               ('samsung korea samsung', 9.203286426398611),
#               ('sony xperia z1', 9.16211257642135)],
#              'alex': [('microsoft nokia 100', 10),
#               ('samsung s5360 galaxy', 10),
#               ('lg g5 h850', 10),
#               ('samsung ativ s', 10),
#               ('lg p500 optimus', 10),
#               ('lg electronics g2d802', 9.71680353593015),
#               ('samsung galaxy s', 9.710910403058037),
#               ('samsung galaxy s', 9.710910403058037),
#               ('samsung galaxy s', 9.710910403058037),
#               ('sony xperia tx', 9.708063245741526)],
#              'francesco': [('sony xperia x', 10),
#               ('asus zenfone max', 9.956563568871648),
#               ('asus zenfone 2', 9.720675166670006),
#               ('asus zenfone 2', 9.720675166670006),
#               ('samsung j510 galaxy', 9.679305594757405),
#               ('wiko fever 4g', 9.477452415569257),
#               ('nokia lumia 625', 9.4001575689327),
#               ('oukitel k10000 smartphone', 9.39573272100046),
#               ('lg k10 smartphone', 9.367589983402555),
#               ('lg d802 g2', 9.339072552085419)],
#              'ð\x98ñ\x80ð¸ð½ð°': [('sony xperia z1', 10),
#               ('sony xperia z1', 10),
#               ('sony xperia t2', 9.703242554462653),
#               ('samsung galaxy a3', 9.327147901995684),
#               ('samsung galaxy a3', 9.327147901995684),
#               ('samsung galaxy s4', 9.223297750482445),
#               ('nokia 5230 navigation', 9.046365350283887),
#               ('samsung i9082 galaxy', 9.014652475630827),
#               ('samsung i9082 galaxy', 9.014652475630827),
#               ('samsung i9082 galaxy', 9.014652475630827)],
#              'anna': [('samsung n9005 galaxy', 9.514270377915768),
#               ('huawei smartphone honor', 9.212866741337269),
#               ('huawei ascend y550', 9.197750695406821),
#               ('cubot note s', 9.03397268256894),
#               ('cubot note s', 9.03397268256894),
#               ('huawei ascend p7', 8.690686750043918),
#               ('samsung g900 galaxy', 8.669005339692891),
#               ('nokia 105 telefono', 8.62982082448436),
#               ('samsung galaxy j5', 8.615184883895278),
#               ('zte blade v6', 8.572802660745396)],
#              'kim': [('apple iphone 5c', 9.919925070918861),
#               ('apple iphone 6', 9.340192031944534),
#               ('apple iphone 6', 9.340192031944534),
#               ('htc flyer 7', 9.260559077405755),
#               ('sony xperia z1', 9.11735506519517),
#               ('samsung galaxy grand', 8.964409573516269),
#               ('huawei p8 grijs', 8.644315618973419),
#               ('huawei p8lite zwart', 8.419973230923958),
#               ('huawei p8lite zwart', 8.419973230923958),
#               ('ee alcatel one', 8.317704443991056)],
#              'ð\x92ð°ð»ðµñ\x80ð¸ð¹': [('htc nexus one', 7.998886674995624),
#               ('samsung galaxy s7', 7.417812597937344),
#               ('samsung galaxy s4', 6.860273497066908),
#               ('samsung galaxy s5', 6.717262652046314),
#               ('sony xperia sp', 6.50998857187126),
#               ('apple iphone 5s', 6.439883705209132),
#               ('samsung i8150 galaxy', 6.1933268361129885),
#               ('sony xperia c', 5.028934338700273),
#               ('sony xperia c', 5.028934338700273)],
#              'chris': [('sim free apple', 10),
#               ('huawei smartphone honor', 9.781082668827633),
#               ('microsoft nokia 808', 9.728583753105042),
#               ('cubot note s', 9.68224437912145),
#               ('cubot note s', 9.68224437912145),
#               ('sim free motorola', 9.664779559665643),
#               ('sim free motorola', 9.664779559665643),
#               ('lenovo moto g4', 9.48870429733848),
#               ('lg electronics g2', 9.478644267874383),
#               ('samsung rugby 2', 9.454537796461086)],
#              'kevin': [('htc one m9', 10),
#               ('lenovo moto g4', 9.642497503112866),
#               ('sony ericsson arc', 9.60180752423688),
#               ('huawei ascend p7', 9.172818793448249),
#               ('sim free apple', 9.086601287384166),
#               ('honor 7 smartphone', 9.022159954051727),
#               ('honor 7 smartphone', 9.022159954051727),
#               ('samsung galaxy s4', 8.928588174086283),
#               ('samsung galaxy s4', 8.928588174086283),
#               ('motorola moto x', 8.927710276846511)],
#              'markus': [('cubot note s', 10),
#               ('samsung galaxy s4', 9.61200433243826),
#               ('lg electronics p500', 9.490584358418953),
#               ('sony ericsson w595', 9.408787311395916),
#               ('honor 6 smartphone', 9.362517441017905),
#               ('sony xperia z5', 9.295879666939609),
#               ('sony xperia z1', 9.192026280527829),
#               ('sony xperia sp', 9.17592388677114),
#               ('motorola nexus 6', 9.160711807617409),
#               ('microsoft lumia 640', 9.036517846955103)],
#              'silvia': [('zte axon 7', 9.036942692426106),
#               ('samsung ativ s', 8.854016521093017),
#               ('alcatel onetouch pop', 8.675546121996344),
#               ('alcatel one touch', 8.482823963749999),
#               ('apple iphone se', 8.456123779836503),
#               ('samsung i9105p galaxy', 8.427682811735027),
#               ('lenovo motorola moto', 8.29397353894652),
#               ('lenovo motorola moto', 8.29397353894652),
#               ('lenovo motorola moto', 8.29397353894652),
#               ('samsung galaxy a3', 8.240410334302366)],
#              'david': [('lg electronics l7', 10),
#               ('vodafone huawei ascend', 9.886557939308414),
#               ('huawei mate 9', 9.766051162522249),
#               ('huawei mate 9', 9.766051162522249),
#               ('huawei ascend mate', 9.56563279962685),
#               ('motorola google nexus', 9.51422642457976),
#               ('sony xperia z5', 9.478552641301192),
#               ('cubot note s', 9.436059592943277),
#               ('huawei ascend y330', 9.196224701054952),
#               ('nokia 6210', 9.165064802368416)],
#              'ð\x93ð¾ñ\x81ñ\x82ñ\x8c': [('htc windows phone',
#                8.143493497861222),
#               ('sony ericsson xperia', 8.082289691781735),
#               ('sony ericsson x10', 8.045333179703128),
#               ('nokia 5130 xpressmusic', 7.702821763135589),
#               ('samsung galaxy j7', 7.588066602671963),
#               ('nokia 5530 xpressmusic', 7.570389094264134),
#               ('nokia 6303i classic', 6.891829006586564),
#               ('nokia 6303i classic', 6.891829006586564),
#               ('nokia 5800', 6.744294103435639),
#               ('nokia 5800', 6.744294103435639)],
#              'salvatore': [('htc one max', 10),
#               ('doogee x6 pro', 10),
#               ('huawei mate 8', 9.76236394355886),
#               ('huawei ascend g700', 9.542723219961808),
#               ('huawei ascend y550', 9.542332002031944),
#               ('huawei p9 lite', 9.427178114746278),
#               ('nokia 105 telefono', 9.285388291673513),
#               ('lg h410 wine', 9.26653586532171),
#               ('lenovo motorola moto', 9.224266825586103),
#               ('nokia lumia 1320', 9.089359215038513)],
#              'no captured': [('microsoft lumia 950', 10),
#               ('lenovo s860', 10),
#               ('sony ericsson w700i', 10),
#               ('lg google nexus', 10),
#               ('sony ericsson c903', 10),
#               ('acer liquid e3', 10),
#               ('htc one dual', 10),
#               ('asus zenfone 3', 10),
#               ('lenovo s860', 10),
#               ('motorola rokr e8', 10)],
#              'amazon customer': [('lg x power', 10),
#               ('doogee dagger dg550', 10),
#               ('samsung galaxy gs7', 9.728614150089246),
#               ('samsung galaxy gs7', 9.728614150089246),
#               ('honor holly 3g', 9.664453441958237),
#               ('motorola tundra va76r', 9.449226100444388),
#               ('motorola tundra va76r', 9.449226100444388),
#               ('lg electronics p710', 9.397353192812616),
#               ('cubot p9 unlocked', 9.341291390400292),
#               ('samsung j510 galaxy', 9.331959130098781)],
#              'marie': [('htc incredible s', 10),
#               ('samsung galaxy a3', 9.379899134938213),
#               ('huawei p8lite zwart', 9.213380054465187),
#               ('apple iphone 4s', 9.183377515632898),
#               ('apple iphone 7', 9.133186521030261),
#               ('samsung galaxy s3', 8.943163638965133),
#               ('samsung galaxy a5', 8.942418696359972),
#               ('samsung galaxy mega', 8.9376468339657),
#               ('kit me out', 8.890810976208435),
#               ('apple iphone 6s', 8.77380590392442)],
#              'james': [('sim free apple', 9.967488399087841),
#               ('huawei honor 8', 9.44448675689616),
#               ('nokia lumia 930', 9.413193409582629),
#               ('sim free motorola', 9.370692933644971),
#               ('motorola moto x', 9.142577290669522),
#               ('motorola moto x', 9.142577290669522),
#               ('htc droid dna', 9.11203556166458),
#               ('apple iphone 7', 9.025638801245902),
#               ('apple iphone 7', 9.025638801245902),
#               ('zte axon 7', 8.921408069181798)],
#              'pascal': [('samsung e1190 sim', 10),
#               ('nokia lumia 625', 9.709233192288071),
#               ('samsung galaxy a3', 9.273093009011138),
#               ('alcatel one touch', 9.189302470513942),
#               ('alcatel one touch', 9.189302470513942),
#               ('samsung galaxy j5', 9.149591683395304),
#               ('tech armor samsung', 8.955602713561836),
#               ('sony xperia ion', 8.951134516659769),
#               ('htc one m8s', 8.819323699193578),
#               ('apple iphone 5s', 8.683495071197598)],
#              'valentina': [('samsung galaxy j5', 9.99253582423982),
#               ('samsung a500 galaxy', 9.902404623260306),
#               ('nokia 105 telefono', 9.707896270146577),
#               ('apple iphone 4s', 9.663332021247657),
#               ('lg g4 smartphone', 9.648952789601042),
#               ('samsung s7580 galaxy', 9.644252858151848),
#               ('samsung i9082 galaxy', 9.470494622803093),
#               ('wiko lenny 3', 9.456475417565532),
#               ('samsung a300 galaxy', 9.396654571797836),
#               ('huawei p8 lite', 9.311690736441502)],
#              'sabrina': [('smartphone asus zenfone', 9.84787916554571),
#               ('motorola moto g', 9.628742275986893),
#               ('samsung star s5230', 9.216828449217054),
#               ('samsung i9301 galaxy', 9.21489839835921),
#               ('apple iphone 4s', 9.135688157961281),
#               ('samsung galaxy y', 9.088353599749988),
#               ('lg d722 g3', 8.93867193449861),
#               ('huawei ascend p6', 8.05397124377873),
#               ('sony ericsson k770i', 7.994041908473774),
#               ('samsung galaxy s5', 7.787223270773718)],
#              'simone': [('honor 6x smartphone', 10),
#               ('asus zenfone 3', 10),
#               ('lg k10 smartphone', 10),
#               ('motorola moto g', 9.711009219758559),
#               ('huawei ascend p1', 9.683096045618099),
#               ('asus zenfone 2', 9.656926550072061),
#               ('wiko fever 4g', 9.591730268775947),
#               ('huawei mate s', 9.352190217456906),
#               ('huawei ascend y330', 9.301666370145696),
#               ('sony smartphone sony', 9.179024138883836)],
#              'amazon kunde': [('sony xperia x', 9.834663469045287),
#               ('apple iphone 7', 9.132058736025195),
#               ('apple iphone 7', 9.132058736025195),
#               ('apple iphone 7', 9.132058736025195),
#               ('yota yotaphone 2', 9.046518330776545),
#               ('honor 8 smartphone', 8.596390201848406),
#               ('blackberry passport smartphone', 8.331715631114717),
#               ('cat b15 smartphone', 8.279412020898645),
#               ('lg electronics g2', 8.179272032302187),
#               ('apple iphone se', 8.09086534106708)],
#              'jean': [('htc sensation sim', 9.663324075957373),
#               ('sony xperia z2', 9.286435945563582),
#               ('samsung galaxy mini', 9.137992348306236),
#               ('nokia lumia 625', 8.99528815141553),
#               ('lg optimus g', 8.904991862597628),
#               ('celular lg t375', 8.878456971962342),
#               ('nokia asha 302', 8.815673675429302),
#               ('microsoft lumia 640', 8.769952527105907),
#               ('smartphone motorola moto', 8.639005786298435),
#               ('sony mobile xperia', 8.533121677360477)],
#              'valerio': [('samsung ativ s', 9.198640073549496),
#               ('asus zenfone 2', 9.147316845979532),
#               ('asus zenfone 2', 9.147316845979532),
#               ('huawei p9 plus', 9.095365784063171),
#               ('samsung galaxy j5', 8.97784733002499),
#               ('lenovo motorola moto', 8.959763242520403),
#               ('samsung galaxy a3', 8.803936479622925),
#               ('sony xperia x', 8.729139404509908),
#               ('samsung galaxy note', 8.531157052391913),
#               ('xiaomi hongmi 1s', 8.363168067832731)],
#              'zã¡kaznã\xadk': [('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('nokia lumia 625', 10),
#               ('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('nokia lumia 625', 10),
#               ('samsung galaxy s3', 9.9220184582622),
#               ('samsung galaxy s3', 9.9220184582622),
#               ('htc desire 820', 9.8529234073104)],
#              'john': [('doogee dagger dg550', 10),
#               ('blackberry z10 smartphone', 9.586155141736873),
#               ('huawei ascend mate', 9.567227673290796),
#               ('huawei mate 9', 9.486133540503154),
#               ('sim free samsung', 9.390176660721952),
#               ('sim free samsung', 9.390176660721952),
#               ('samsung galaxy grand', 9.329271830051795),
#               ('sim free apple', 9.311670718197385),
#               ('sony xperia z2', 9.198158200991259),
#               ('doro liberto 820', 9.16745891330388)],
#              'manish': [('micromax canvas turbo', 7.985785545544736),
#               ('motorola moto g', 7.681976002305081),
#               ('huawei honor 5x', 7.657135026481374),
#               ('huawei honor 8', 7.5805086820712715),
#               ('samsung galaxy a8', 7.374026633922229),
#               ('samsung galaxy j2', 7.348059987241749),
#               ('apple iphone 5s', 7.287940713355981),
#               ('lenovo k900 32gb', 7.268045778999102),
#               ('huawei nexus 6p', 7.260941073738928),
#               ('lenovo vibe k5', 6.889903063302759)],
#              'angel': [('nokia lumia 625', 9.24277931894828),
#               ('lg optimus g', 9.224511832530045),
#               ('sony xperia arc', 9.136191834624135),
#               ('microsoft lumia 640', 9.109052699491349),
#               ('lg voyager', 9.067202398470878),
#               ('samsung galaxy ace', 9.030341020563506),
#               ('samsung galaxy ace', 9.030341020563506),
#               ('sony xperia go', 9.019734734842034),
#               ('sony xperia xz', 9.003890868301323),
#               ('lg nexus 5x', 8.948706078679134)],
#              'sandy': [('lg google nexus', 8.645466328137925),
#               ('samsung galaxy s3', 8.589594291999827),
#               ('samsung galaxy s3', 8.589594291999827),
#               ('nokia n9 unlocked', 8.538602818646693),
#               ('samsung galaxy alpha', 8.377347826600682),
#               ('tech armor galaxy', 8.279865324950519),
#               ('sony xperia z5', 8.272958686269584),
#               ('apple iphone 5s', 8.203506660543027),
#               ('lenovo vibe k4', 8.201349646436954),
#               ('samsung galaxy s7', 8.130250510946741)],
#              'angelo': [('wiko fever 4g', 9.856870919505706),
#               ('samsung n9005 galaxy', 9.790718820763672),
#               ('samsung g920 galaxy', 9.768257225353107),
#               ('lg k10 smartphone', 9.70921168751921),
#               ('huawei ascend g610', 9.492792168483447),
#               ('samsung c3590 telefono', 9.393383712100148),
#               ('sony ericsson xperia', 9.29187081939979),
#               ('huawei p8 lite', 9.220993318649214),
#               ('meizu m2 note', 9.195304649911034),
#               ('lg h410 wine', 9.174619299556948)],
#              'prashant': [('asus zenfone max', 8.41539446432572),
#               ('sony xperia t2', 8.317643148950168),
#               ('samsung galaxy s6', 8.291015649195986),
#               ('htc desire 816', 8.123542757676766),
#               ('motorola moto g', 8.102031559656691),
#               ('lenovo vibe x3', 7.824253950037059),
#               ('google nexus 5', 7.527208100286251),
#               ('samsung galaxy j7', 7.027398399866252),
#               ('hp slate 6', 7.00211754584009),
#               ('blackberry bold 9790', 6.815127913037289)],
#              'ð\x92ð¸ðºñ\x82ð¾ñ\x80ð¸ñ\x8f': [('samsung galaxy s4',
#                8.36392456725562),
#               ('samsung galaxy s5', 7.569089533981385),
#               ('samsung galaxy s5', 7.569089533981385),
#               ('samsung galaxy s5', 7.569089533981385),
#               ('samsung galaxy s5', 7.569089533981385),
#               ('samsung i9082 galaxy', 7.2822080738772925),
#               ('sony xperia m', 7.259278202360106),
#               ('sony xperia sp', 6.811034050884001),
#               ('sony xperia sp', 6.811034050884001),
#               ('samsung n7100 galaxy', 6.2150521039034885)],
#              'eli': [('doogee dagger dg550', 9.781661814828636),
#               ('smartphone lg l90', 9.378865073348344),
#               ('asus zenfone 2', 9.034442918877783),
#               ('huawei p8 lite', 8.501222351941749),
#               ('nokia lumia 800', 8.490409506050733),
#               ('samsung galaxy core', 8.044777405663305),
#               ('samsung galaxy s7', 7.981240388604884),
#               ('samsung t404g prepaid', 6.836990750845448),
#               ('motorola verizon motorola', 6.571643641170816)],
#              'andrea': [('samsung galaxy s4', 9.583198459707509),
#               ('samsung galaxy s4', 9.583198459707509),
#               ('apple iphone 7', 9.47328905905716),
#               ('asus zenfone max', 9.39262685844524),
#               ('huawei ascend g750', 9.389866179131868),
#               ('htc one m8', 9.296714406219778),
#               ('htc one m8', 9.296714406219778),
#               ('asus zenfone 2', 9.149641043919447),
#               ('asus zenfone 2', 9.149641043919447),
#               ('asus zenfone 2', 9.149641043919447)],
#              'ð\x90ð»ðµðºñ\x81ð°ð½ð´ñ\x80': [('samsung s7270 galaxy',
#                9.539015901382355),
#               ('samsung c5212 duos', 9.055453820415392),
#               ('nokia c3', 8.99336573610102),
#               ('samsung s5660 galaxy', 8.94099673476257),
#               ('samsung s5570 galaxy', 8.853610739353238),
#               ('sony xperia zr', 8.826845984972454),
#               ('sony xperia zr', 8.826845984972454),
#               ('sony xperia zr', 8.826845984972454),
#               ('sony xperia sp', 8.644417640350142),
#               ('samsung galaxy core', 8.600523946266968)],
#              'anonymous': [('samsung galaxy j5', 10),
#               ('samsung galaxy nexus', 10),
#               ('apple iphone 4s', 10),
#               ('samsung galaxy nexus', 10),
#               ('htc one v', 10),
#               ('sim free iphone', 9.966746767950719),
#               ('nokia 2690', 9.698642258042579),
#               ('iphone 5s 16', 9.618640497820568),
#               ('iphone 5s 16', 9.618640497820568),
#               ('motorola v197 unlocked', 9.49598785315337)],
#              'alexandre': [('smartphone lg l90', 9.234836989748725),
#               ('smartphone samsung galaxy', 8.727347076936036),
#               ('lg a290', 8.600317423566452),
#               ('samsung galaxy s', 8.46174070529387),
#               ('nokia lumia 520', 8.350586717861603),
#               ('samsung galaxy s6', 7.872046287056255),
#               ('nokia lumia 530', 7.742285362194088),
#               ('microsoft lumia 435', 7.628290293881058),
#               ('samsung galaxy ace', 7.571005620114055),
#               ('samsung wave m', 7.296461105278798)],
#              'eva': [('htc desire 500', 7.979051370108163),
#               ('sony xperia sp', 7.752138625351237),
#               ('motorola moto g', 7.732145526518526),
#               ('htc windows phone', 7.594661287107379),
#               ('samsung galaxy note', 7.495395902060118),
#               ('samsung galaxy s7', 7.399050883573577),
#               ('huawei ascend y201', 7.331803123450092),
#               ('microsoft lumia 640', 7.328041395828647),
#               ('alcatel onetouch idol', 7.2456273383618015),
#               ('asus zenfone go', 6.886477948739129)],
#              'cliente amazon': [('lg x power', 8.50494564008459),
#               ('samsung j510 galaxy', 8.339211170101965),
#               ('samsung j510 galaxy', 8.339211170101965),
#               ('samsung j510 galaxy', 8.339211170101965),
#               ('alcatel pop c7', 8.23181877823497),
#               ('sony xperia sp', 8.135916728663474),
#               ('samsung ativ s', 8.129007676412728),
#               ('samsung ativ s', 8.129007676412728),
#               ('motorola nexus 6', 8.107622998128235),
#               ('acer liquid z520', 8.051293942104605)],
#              'nicolas': [('htc 8x unlocked', 9.748743479859545),
#               ('nokia lumia 930', 9.512576271609184),
#               ('htc one m8', 9.507049386311541),
#               ('samsung i9105p galaxy', 9.21687682822894),
#               ('apple iphone 4s', 8.878565712157695),
#               ('nokia lumia 925', 8.820672845625436),
#               ('huawei p8 lite', 8.797964504119236),
#               ('huawei p8 lite', 8.797964504119236),
#               ('samsung galaxy mega', 8.711120844908692),
#               ('lg optimus l5', 8.618656850523804)],
#              'mike': [('sony xperia x', 10),
#               ('sim free apple', 10),
#               ('samsung galaxy s8', 10),
#               ('spigen neo hybrid', 10),
#               ('microsoft nokia 2710', 10),
#               ('sim free apple', 10),
#               ('motorola moto g', 9.763995575763863),
#               ('samsung galaxy j5', 9.624562621972487),
#               ('samsung galaxy j5', 9.624562621972487),
#               ('microsoft nokia c5', 9.480018684758374)],
#              'andreas': [('htc one dual', 10),
#               ('honor 8 smartphone', 9.88986926234013),
#               ('huawei ascend g700', 9.75231472526063),
#               ('honor 6 smartphone', 9.591330459376648),
#               ('sony xperia s', 9.51323566173985),
#               ('sony xperia z2', 9.062237317147826),
#               ('samsung galaxy a5', 9.015927882809278),
#               ('sony ericsson xperia', 9.001500056544037),
#               ('sony ericsson xperia', 9.001500056544037),
#               ('samsung galaxy j5', 8.986316527099094)],
#              'stefan': [('lenovo moto g4', 9.642551684644243),
#               ('microsoft nokia 100', 9.295197568022772),
#               ('htc 10 32gb', 9.254375370119394),
#               ('huawei p9 lite', 9.248720619344489),
#               ('lenovo motorola razr', 9.247584633661113),
#               ('sony xperia z1', 9.076087727845971),
#               ('sony xperia z1', 9.076087727845971),
#               ('samsung galaxy s3', 9.056103299974126),
#               ('lg electronics e400', 8.98006916959518),
#               ('samsung galaxy s4', 8.82552940878588)],
#              'ð\x9fð¾ð»ñ\x8cð·ð¾ð²ð°ñ\x82ðµð»ñ\x8c ñ\x81ðºñ\x80ñ\x8bð» ñ\x81ð²ð¾ð¸ ð´ð°ð½ð½ñ\x8bðµ': [('blackberry passport',
#                9.38140141232478),
#               ('alcatel idol 4', 8.615644836852958),
#               ('apple iphone 7', 8.270497851711928),
#               ('apple iphone 7', 8.270497851711928),
#               ('samsung galaxy j5', 8.174249435437302),
#               ('asus zenfone 3', 8.171873134026463),
#               ('microsoft lumia 950', 8.134437830788116),
#               ('microsoft lumia 950', 8.134437830788116),
#               ('apple iphone 6s', 8.110114270972268),
#               ('apple iphone 6s', 8.110114270972268)],
#              'jose': [('lg g5 h850', 9.133303603630939),
#               ('asus zenfone 2', 8.836561069735975),
#               ('sim free motorola', 8.66372241613602),
#               ('meizu m3s 16gb', 8.483598040024035),
#               ('motorola moto x', 8.44729027682894),
#               ('sony xperia z2', 8.330733933181651),
#               ('smartphone nokia lumia', 8.31504843735232),
#               ('lg g2 d802', 8.285596831314535),
#               ('smartphone moto e', 8.216402662694374),
#               ('bq aquaris e5', 8.174045926405833)],
#              'antonio': [('lg d802 g2', 10),
#               ('lg d802 g2', 10),
#               ('apple iphone 7', 9.883047843862734),
#               ('samsung a5 2016', 9.776121668485398),
#               ('samsung n9005 galaxy', 9.759679118581259),
#               ('smartphone lg g2', 9.730407310893977),
#               ('apple iphone 6s', 9.594061290083697),
#               ('asus zenfone 2', 9.588319622253623),
#               ('asus zenfone 2', 9.588319622253623),
#               ('samsung a500 galaxy', 9.582435610389552)],
#              'anonieme bezoeker': [('samsung galaxy s', 8.751419095928428),
#               ('sony xperia t', 8.666540611437346),
#               ('apple iphone 5', 8.367272921532733),
#               ('apple iphone 5', 8.367272921532733),
#               ('nokia lumia 920', 8.238274851346143),
#               ('samsung i9100 galaxy', 7.934885389948937),
#               ('samsung i9100 galaxy', 7.934885389948937),
#               ('lg e610 optimus', 7.84407698874134),
#               ('htc desire x', 7.774908668480208),
#               ('huawei ascend g510', 7.736741876331618)],
#              'toni': [('sim free samsung', 9.88351045545153),
#               ('samsung i9301 galaxy', 9.569464803355704),
#               ('nokia lumia 625', 9.415285626585),
#               ('samsung galaxy s', 9.101952141401028),
#               ('samsung galaxy s', 9.101952141401028),
#               ('zte axon 7', 9.078972748358975),
#               ('sony xperia p', 8.872899650918251),
#               ('huawei ascend mate', 8.754209580797799),
#               ('samsung galaxy note', 8.674501250320766),
#               ('sony xperia sp', 8.559569276885949)],
#              'lukas': [('htc one smartphone', 9.684909716296556),
#               ('huawei u8860 smartphone', 9.611664771146613),
#               ('samsung galaxy a5', 9.1808381205159),
#               ('samsung galaxy s6', 9.131424881507876),
#               ('xiaomi redmi note', 8.987251746503054),
#               ('motorola moto g', 8.94739044181257),
#               ('microsoft lumia 640', 8.825885599143962),
#               ('huawei p8 champagne', 8.73107910625398),
#               ('samsung galaxy note', 8.230572006013285),
#               ('samsung galaxy note', 8.230572006013285)],
#              'anthony': [('apple iphone 7', 10),
#               ('apple iphone 6s', 10),
#               ('apple iphone 7', 10),
#               ('apple iphone 7', 10),
#               ('apple iphone 7', 10),
#               ('sony xperia x', 10),
#               ('apple iphone 7', 10),
#               ('motorola moto g', 9.378043090422459),
#               ('apple iphone 5s', 8.823328845090458),
#               ('samsung transform ultra', 8.798455610215017)],
#              'pedro': [('htc one m8', 10),
#               ('asus zenfone 2', 9.907923057555099),
#               ('lg google nexus', 9.825238897122192),
#               ('huawei ascend p1', 9.712736376248479),
#               ('huawei ascend y330', 9.436881117000096),
#               ('lg optimus g', 9.191083604827256),
#               ('cubot note s', 9.149691816737798),
#               ('motorola moto g', 9.030570801894767),
#               ('motorola moto g', 9.030570801894767),
#               ('motorola moto g', 9.030570801894767)],
#              'ð\xa0ð¾ð¼ð°ð½': [('nokia lumia 720', 9.524268866449997),
#               ('motorola defy', 9.228196809657033),
#               ('sony xperia tx', 9.21207382627896),
#               ('lg nexus 4', 8.874148112656044),
#               ('sony xperia c', 8.818088266163649),
#               ('sony xperia c', 8.818088266163649),
#               ('sony xperia sp', 8.461591579881095),
#               ('sony xperia sp', 8.461591579881095),
#               ('sony ericsson vivaz', 8.436152430315577),
#               ('nokia 6700 classic', 8.309953616926983)],
#              'jack': [('lg g5 h850', 10),
#               ('apple iphone 7', 10),
#               ('sony ericsson p900', 10),
#               ('sony sony xperia', 9.652769851216295),
#               ('samsung galaxy j2', 9.437582105511197),
#               ('samsung galaxy j5', 9.067976006923132),
#               ('sony xperia z5', 9.06680090730994),
#               ('huawei ascend mate', 8.66681341389504),
#               ('nokia lumia 520', 8.07656801070239),
#               ('huawei p8 grijs', 8.070685671733436)],
#              'pasquale': [('lg d802 g2', 10),
#               ('motorola moto g', 10),
#               ('huawei ascend y550', 9.818277259043),
#               ('asus zenfone 2', 9.635086882051802),
#               ('nokia lumia 520', 9.477808229596752),
#               ('lenovo motorola moto', 9.420138887256902),
#               ('huawei p8 lite', 9.165452102193655),
#               ('alcatel one touch', 9.082870162338635),
#               ('samsung a700 galaxy', 8.956872376137687),
#               ('asus zenfone 3', 8.545295239491853)],
#              'mar': [('sony xperia zr', 8.70237675617749),
#               ('samsung galaxy j5', 8.624914821948858),
#               ('motorola moto g', 8.265779994951782),
#               ('huawei p8 lite', 8.176415451457629),
#               ('bq aquaris x5', 7.85439025153426),
#               ('huawei ascend g730', 7.735852666826003),
#               ('samsung galaxy s7', 7.641092561909334),
#               ('lg optimus f3', 7.457238581751495),
#               ('motorola droid 3', 6.894538572916825),
#               ('htc evo 4g', 6.646460373902607)],
#              'philipp': [('nokia 3250', 8.366733921586789),
#               ('blackberry q5 smartphone', 8.304886458291069),
#               ('huawei ascend p6', 8.271360026678407),
#               ('honor 7 smartphone', 8.233053944064697),
#               ('acer liquid e1', 8.114405689978131),
#               ('sony ericsson xperia', 7.545344567579457),
#               ('sony ericsson s500i', 6.984007572081782),
#               ('apple iphone 4', 6.832337251268494),
#               ('samsung galaxy s5', 6.590653723391851),
#               ('microsoft lumia 550', 6.123496878135871)],
#              'paul': [('zte axon 7', 10),
#               ('apple iphone 4s', 10),
#               ('nokia 1208 sim', 10),
#               ('sim free apple', 10),
#               ('sim free iphone', 10),
#               ('apple iphone 4s', 10),
#               ('samsung galaxy a3', 10),
#               ('microsoft lumia 650', 10),
#               ('samsung galaxy j5', 10),
#               ('microsoft nokia 100', 10)],
#              'roberto': [('alcatel pop c7', 10),
#               ('samsung s7580 galaxy', 10),
#               ('smartphone samsung galaxy', 9.697650189859411),
#               ('nokia lumia 930', 9.697128517026675),
#               ('huawei ascend g620s', 9.623183864318635),
#               ('motorola moto g', 9.593862284065104),
#               ('huawei p9 plus', 9.533574001307898),
#               ('meizu pro 5', 9.527011480782761),
#               ('asus zenfone 2', 9.508532323203454),
#               ('huawei ascend mate', 9.372867368652166)],
#              'wendy': [('apple iphone 5', 9.818390692780223),
#               ('apple iphone 5', 9.818390692780223),
#               ('samsung galaxy s', 9.648525871941878),
#               ('lenovo motorola razr', 9.288140033940023),
#               ('htc wildfire s', 8.956384439383243),
#               ('leagoo easysmx leagoo', 8.820550019817563),
#               ('huawei p8 lite', 8.73662089498893),
#               ('samsung tocco lite', 8.613717623027934),
#               ('samsung galaxy note', 8.533428752418216),
#               ('samsung galaxy note', 8.533428752418216)],
#              'ð\x90ð½ð´ñ\x80ðµð¹': [('lg optimus l4', 10),
#               ('samsung galaxy a5', 9.298473483590914),
#               ('samsung galaxy a5', 9.298473483590914),
#               ('sony xperia sp', 9.27877033137623),
#               ('sony xperia sp', 9.27877033137623),
#               ('sony xperia sp', 9.27877033137623),
#               ('samsung n9005 galaxy', 9.267435387724689),
#               ('sony xperia z1', 9.175229583688393),
#               ('sony xperia z1', 9.175229583688393),
#               ('sony xperia z1', 9.175229583688393)],
#              'fernando': [('huawei ascend g300', 9.77374437444795),
#               ('smartphone asus zenfone', 9.694713000432724),
#               ('nokia lumia 625', 9.525880653049132),
#               ('zte axon 7', 9.41825595335216),
#               ('smartphone sony xperia', 9.277242076140194),
#               ('lg electronics g2', 9.243479879364891),
#               ('smartphone samsung galaxy', 9.158307715023758),
#               ('smartphone samsung galaxy', 9.158307715023758),
#               ('smartphone samsung galaxy', 9.158307715023758),
#               ('smartphone lenovo vibe', 9.12707675011077)],
#              'mark': [('samsung galaxy s', 10),
#               ('huawei honor 8', 10),
#               ('sim free sony', 10),
#               ('apple iphone 4s', 10),
#               ('zte axon 7', 9.909598082007083),
#               ('zte axon 7', 9.909598082007083),
#               ('samsung galaxy a3', 9.776261017790384),
#               ('motorola google nexus', 9.76278955953049),
#               ('nokia lumia 920', 9.665783975978433),
#               ('blackberry passport factory', 9.597925403396376)],
#              'rachel': [('asus zenfone max', 9.90326879274448),
#               ('sim free iphone', 9.843305490770359),
#               ('htc desire 816', 9.809191818613117),
#               ('smartphone lg l90', 9.538099131207101),
#               ('samsung galaxy s3', 9.262307638902033),
#               ('apple iphone 6s', 9.070461072671744),
#               ('microsoft lumia 435', 8.806597810433974),
#               ('samsung galaxy s5', 8.792849247590814),
#               ('samsung galaxy s5', 8.792849247590814),
#               ('lenovo motorola moto', 8.580389513344533)],
#              'laura': [('lg k10 smartphone', 10),
#               ('huawei p9 lite', 9.978506620063161),
#               ('sim free samsung', 9.64736793501765),
#               ('huawei ascend p8', 9.366117834050861),
#               ('samsung galaxy s3', 9.32937230358483),
#               ('asus zenfone max', 9.327319718550706),
#               ('asus zenfone max', 9.327319718550706),
#               ('lg cosmos vn250', 9.289094757224095),
#               ('lg g5 h860', 9.266648811921737),
#               ('samsung galaxy s4', 9.1443640624197)],
#              'incesaz': [('nokia n97 mini', 1),
#               ('apple iphone 3g', 1),
#               ('nokia 2630 cep', 1),
#               ('nokia 6500 slide', 1),
#               ('sony ericsson k850i', 1),
#               ('sony ericsson w995', 1),
#               ('samsung e250 cep', 1)],
#              'wolfgang': [('blackberry passport smartphone',
#                9.281289754988787),
#               ('lg electronics l40', 7.750239548088722),
#               ('microsoft nokia lumia', 7.485422666083566),
#               ('lenovo moto z', 7.4104181984875455),
#               ('honor 6 smartphone', 7.40556100617613),
#               ('samsung galaxy mega', 7.400223554889426),
#               ('samsung galaxy j5', 7.211186888673707),
#               ('microsoft nokia 5230', 7.160746723920321),
#               ('microsoft nokia e51', 7.12696938986826),
#               ('samsung galaxy s', 7.0526289247965295)],
#              'manu': [('samsung galaxy j5', 9.54634787543005),
#               ('wiko fever 4g', 9.319822063695508),
#               ('sony ericsson k800i', 9.059022401889392),
#               ('lg nexus 5x', 8.588206052105953),
#               ('sony xperia s', 8.576614279029359),
#               ('nokia 5130 xpressmusic', 8.562922021943402),
#               ('nokia asha 210', 8.365680707321758),
#               ('htc wildfire s', 8.344976161912331),
#               ('sony ericsson xperia', 8.100425343277267),
#               ('lenovo motorola moto', 8.027922570708732)],
#              'rick2809': [('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone microsoft lumia', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone motorola moto', 9.863483738767616)],
#              'gianfranco': [('huawei p9 lite', 9.767522920491917),
#               ('huawei p9 lite', 9.767522920491917),
#               ('honor 7 smartphone', 9.539309574326207),
#               ('alcatel one touch', 9.32346589055299),
#               ('sony e5603 xperia', 9.19014665235174),
#               ('alcatel pixi 4', 8.845420775490696),
#               ('alcatel pixi 4', 8.845420775490696),
#               ('nokia asha 501', 8.15476669029507),
#               ('nokia asha 305', 8.029560297050585),
#               ('lenovo zuk z1', 7.921463536798852)],
#              "client d'amazon": [('meizu pro 5', 9.33735732511761),
#               ('baas nokia lumia', 9.220939221153102),
#               ('blackberry priv smartphone', 8.813946972934065),
#               ('acer liquid e3', 8.620589172890966),
#               ('spigen coque samsung', 8.618083719622291),
#               ('asus zenfone 3', 8.450831057105983),
#               ('asus zenfone 3', 8.450831057105983),
#               ('asus zenfone 3', 8.450831057105983),
#               ('huawei p9 plus', 8.34915754613503),
#               ('lg g2 smartphone', 8.334964418093502)],
#              'juan': [('apple iphone 5c', 8.94524078086286),
#               ('huawei honor 5x', 8.727967804288753),
#               ('samsung galaxy s3', 8.621393504369921),
#               ('lg g3 d855', 8.505689516854527),
#               ('motorola moto g', 8.283310302853941),
#               ('samsung galaxy young', 8.23654869480249),
#               ('elephone p6000 pro', 8.12330849122543),
#               ('lenovo motorola moto', 8.037153282920139),
#               ('samsung galaxy grand', 7.951846389438928),
#               ('huawei ascend p6', 7.893398615075856)],
#              'sergio': [('lenovo moto g4', 9.510573821423767),
#               ('lg d802 g2', 9.217041758429355),
#               ('huawei ascend p7', 8.898058022685934),
#               ('huawei ascend g615', 8.722852544195707),
#               ('motorola moto g', 8.691593140439961),
#               ('sony xperia s', 8.651285814990471),
#               ('meizu m3 note', 8.61613642791332),
#               ('samsung galaxy s7', 8.540560194383524),
#               ('samsung galaxy s7', 8.540560194383524),
#               ('samsung s7582 galaxy', 8.526481836831236)],
#              'charlie': [('motorola moto g', 9.486013997041477),
#               ('samsung galaxy a3', 9.431620768295584),
#               ('apple iphone 5s', 8.88706493571827),
#               ('apple iphone 5', 8.647429397820035),
#               ('nokia asha 302', 8.542024932237794),
#               ('lg electronics nexus', 8.508615508032523),
#               ('samsung galaxy y', 8.439830188875682),
#               ('samsung galaxy j7', 8.399595904728194),
#               ('apple iphone 7', 7.820747846452797),
#               ('lg 530g prepaid', 7.788142855012888)],
#              'nicole': [('archos 50 helium', 9.287274842672918),
#               ('samsung galaxy alpha', 9.268865965626016),
#               ('sony xperia zl', 9.216598534496937),
#               ('samsung galaxy s4', 8.632280284774474),
#               ('lenovo motorola moto', 8.464330382559089),
#               ('huawei nexus 6p', 8.279510230894227),
#               ('lg electronics t385', 8.074181717147201),
#               ('samsung galaxy j7', 8.019720072914783),
#               ('apple iphone 5c', 8.016332914124684),
#               ('samsung galaxy j1', 7.371231275428278)],
#              'ð\x95ð²ð³ðµð½ð¸ñ\x8f': [('sony xperia z1', 9.75577855426409),
#               ('sony xperia z1', 9.75577855426409),
#               ('samsung galaxy a5', 9.450088311738703),
#               ('samsung galaxy s4', 8.632589320450162),
#               ('samsung galaxy s4', 8.632589320450162),
#               ('sony xperia m', 8.49679985870633),
#               ('samsung galaxy note', 8.370445730187251),
#               ('sony xperia e1', 8.301941734021486),
#               ('samsung galaxy s5', 8.288893671389689),
#               ('samsung n7100 galaxy', 8.02897302363854)],
#              'ð\x94ð¸ð¼ð°': [('samsung galaxy a3', 9.97790293461893),
#               ('htc desire s', 9.937556538794835),
#               ('sony xperia z1', 9.68765239438809),
#               ('samsung galaxy s4', 9.197201121523754),
#               ('samsung galaxy ace', 9.191768385957849),
#               ('samsung i8190 galaxy', 8.816729854728958),
#               ('sony xperia l', 8.437214965335654),
#               ('sony xperia l', 8.437214965335654),
#               ('samsung n7100 galaxy', 8.423789202325457),
#               ('samsung i5800 galaxy', 8.37866381476944)],
#              'rpv': [('nokia lumia 720', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 720', 10),
#               ('htc nexus one', 10),
#               ('nokia lumia 920', 9.734251774470206),
#               ('nokia lumia 920', 9.734251774470206),
#               ('nokia lumia 920', 9.734251774470206),
#               ('samsung galaxy note', 9.675023656779214),
#               ('samsung galaxy note', 9.675023656779214),
#               ('samsung galaxy note', 9.675023656779214)],
#              'ana': [('motorola moto g', 9.257185787584294),
#               ('motorola moto g', 9.257185787584294),
#               ('lg google nexus', 8.774057888239968),
#               ('smartphone moto e', 8.753068770913767),
#               ('smartphone samsung galaxy', 8.665511408060034),
#               ('smartphone samsung galaxy', 8.665511408060034),
#               ('smartphone samsung galaxy', 8.665511408060034),
#               ('smartphone samsung galaxy', 8.665511408060034),
#               ('apple iphone 5s', 8.630721842125979),
#               ('lg nexus 5', 8.551345771789666)],
#              'ð\x90ð½ð°ñ\x81ñ\x82ð°ñ\x81ð¸ñ\x8f': [('sony xperia z1',
#                9.765757292489907),
#               ('samsung galaxy s4', 9.149387297679356),
#               ('samsung galaxy a7', 8.63130010639523),
#               ('sony xperia t2', 8.24766908470596),
#               ('samsung i9082 galaxy', 7.871199107349619),
#               ('sony xperia m', 7.8586642187143525),
#               ('sony xperia m', 7.8586642187143525),
#               ('samsung galaxy a3', 7.777156311206509),
#               ('apple iphone 5s', 7.047808957022564),
#               ('apple iphone 5s', 7.047808957022564)],
#              'gary': [('huawei mate 9', 10),
#               ('lg g2 sprint', 10),
#               ('samsung i9100 galaxy', 9.64840726220145),
#               ('lg g2 mini', 9.529517467884862),
#               ('apple iphone se', 9.101517000334091),
#               ('samsung galaxy j5', 9.014010846774084),
#               ('samsung galaxy a3', 8.945103967872726),
#               ('samsung note 2', 8.577237996331213),
#               ('nokia lumia 635', 8.390107856092936),
#               ('lg verizon lg', 8.366548671750605)],
#              'mary': [('apple iphone 7', 10),
#               ('motorola moto g', 9.664618852374472),
#               ('nokia lumia 520', 9.151925394481625),
#               ('samsung a157 gophone', 9.040654838315131),
#               ('samsung i9082 galaxy', 9.026325482304603),
#               ('huawei smartphone honor', 8.954437277225317),
#               ('samsung galaxy s6', 8.930628611877871),
#               ('samsung galaxy s3', 8.92664031352755),
#               ('huawei honor 5x', 8.765845768953579),
#               ('samsung factory unlocked', 8.63948958973642)],
#              'mario': [('asus zenfone 3', 10),
#               ('htc one m8', 10),
#               ('asus zenfone 2', 9.673649751891045),
#               ('asus zenfone 2', 9.673649751891045),
#               ('asus zenfone 2', 9.673649751891045),
#               ('sim free apple', 9.588194136929939),
#               ('lg google nexus', 9.481173248461175),
#               ('smartphone lg l90', 9.442089437855076),
#               ('wiko fever 4g', 9.191051962605188),
#               ('samsung galaxy s4', 9.184181596557362)],
#              'caroline': [('sim free apple', 9.266614400119455),
#               ('smartphone asus zenfone', 9.21981930065455),
#               ('apple iphone 7', 8.824797624203182),
#               ('samsung galaxy j5', 8.688586560183671),
#               ('samsung galaxy j5', 8.688586560183671),
#               ('motorola moto g', 8.68034051875394),
#               ('lenovo moto g4', 8.565292026191166),
#               ('ringke asus zenfone', 8.42105192591484),
#               ('smartphone samsung galaxy', 8.135945563164597),
#               ('samsung smartphone samsung', 7.912477890294946)],
#              'kindle customer': [('samsung s425g prepaid', 9.379628155440926),
#               ('samsung s425g prepaid', 9.379628155440926),
#               ('nokia lumia 720', 9.007620809866015),
#               ('nokia lumia 720', 9.007620809866015),
#               ('sony ericsson w890i', 8.866036048991951),
#               ('samsung galaxy s2', 8.700337380249719),
#               ('htc one 32gb', 8.634165334426028),
#               ('samsung e1200 sim', 8.379268296723069),
#               ('lg a275 black', 8.378488983293202),
#               ('huawei honor 8', 8.232136132269577)],
#              'frank': [('huawei ascend d1', 9.405646643958026),
#               ('blackberry q5 smartphone', 9.237890142611548),
#               ('samsung galaxy s', 9.131626777047535),
#               ('nokia lumia 830', 8.947327590097979),
#               ('huawei p8 champagne', 8.93796386624857),
#               ('samsung e2550 monte', 8.91823286551983),
#               ('samsung i9192 galaxy', 8.761936100860215),
#               ('honor holly smartphone', 8.721791594019905),
#               ('apple iphone 5s', 8.717906497387403),
#               ('apple iphone 5s', 8.717906497387403)],
#              '????????': [('sony xperia s', 9.629900653465663),
# ...
#               ('asus zenfone 5', 7.9653058286548655),
#               ('samsung galaxy note', 7.649232935122118),
#               ('sony xperia c3', 7.576972823418105),
#               ('samsung galaxy a9', 7.344332926809984)],
#              'natalia': [('ee alcatel one', 10),
#               ('sony xperia s', 9.99349429903465),
#               ('samsung galaxy s6', 9.849128560590103),
#               ('lenovo motorola moto', 9.18844099612989),
#               ('alcatel one touch', 8.7698499919631),
#               ('huawei ascend g510', 8.727778200293535),
#               ('sony xperia z3', 7.912356309868681),
#               ('sony xperia tipo', 7.423523194210496),
#               ('samsung galaxy star', 6.974303215914002)],
#              'ciklet': [('nokia e90 cep', 1),
#               ('nokia 5310 cep', 1),
#               ('nokia n70 cep', 1)],
#              'thierry': [('nokia lumia 830', 9.850310332045618),
#               ('zte axon 7', 9.791767150096481),
#               ('zte axon 7', 9.791767150096481),
#               ('zte axon 7', 9.791767150096481),
#               ('honor 4x smartphone', 9.40411532902006),
#               ('samsung galaxy a5', 9.18846539713157),
#               ('samsung galaxy s', 9.053267829945414),
#               ('samsung galaxy s', 9.053267829945414),
#               ('alcatel one touch', 8.980144328784672),
#               ('lg g3 smartphone', 8.663907361276056)],
#              'mel': [('huawei ascend mate', 8.894508308959933),
#               ('tech armor galaxy', 8.705684267951654),
#               ('microsoft lumia 640', 8.503936237815495),
#               ('motorola rokr e1', 6.796462787010427),
#               ('motorola mb300 backflip', 4.611368289862314)],
#              'bianca': [('huawei p8 grijs', 8.895775902258695),
#               ('samsung galaxy s6', 8.879252943828009),
#               ('samsung galaxy s4', 8.488614202545167),
#               ('smartphone motorola defy', 8.277742156328584),
#               ('apple iphone 5c', 8.127497623138474),
#               ('sony xperia z5', 7.917430708690253),
#               ('sony ericsson c', 7.049360243389643),
#               ('sony ericsson s500i', 6.9154412591989844)],
#              'marion': [('apple iphone 7', 9.586710728948987),
#               ('emporia elegance handy', 9.28078646840727),
#               ('lenovo motorola moto', 8.973494962731596),
#               ('doro matra phone', 8.08341634538111),
#               ('buyus etui housse', 7.958421473271096),
#               ('sony xperia m4', 6.075876184495463)],
#              'simona': [('asus ze550kl zenfone', 9.586944921322761),
#               ('huawei ascend p7', 9.489587142041762),
#               ('huawei ascend g7', 9.355893398929545),
#               ('lg g2 mini', 9.261496594430602),
#               ('samsung galaxy j5', 9.030280151777486),
#               ('lenovo motorola moto', 8.54112953891116),
#               ('htc desire 816', 8.52522341017093),
#               ('huawei p8 lite', 8.367369449257025),
#               ('apple iphone 5s', 8.259049705467815),
#               ('blackberry curve 9320', 7.7900423136799155)],
#              'enzo': [('lg k10 smartphone', 9.415930965108114),
#               ('huawei p9 lite', 9.013326198910631),
#               ('apple iphone 5s', 8.908949470119408),
#               ('huawei p8 lite', 8.890465998324826),
#               ('lenovo motorola moto', 8.869351960238522),
#               ('lenovo motorola moto', 8.869351960238522),
#               ('sony e6653 xperia', 8.62138341491042),
#               ('doogee valencia2 y100', 8.579408180496532),
#               ('samsung g355 galaxy', 8.481956704344805),
#               ('samsung smartphone galaxy', 8.131693744539254)],
#              'karadag60': [('sony ericsson w610i', 1),
#               ('sony ericsson w910i', 1),
#               ('sony ericsson c903', 1),
#               ('sony ericsson w995', 1),
#               ('palm treo pro', 1),
#               ('sony ericsson z310i', 1)],
#              'adriana': [('smartphone motorola moto', 8.253738678038335),
#               ('samsung galaxy note', 7.665861558157543),
#               ('samsung galaxy y', 7.385239368815755),
#               ('sony xperia l', 6.750587623622019),
#               ('samsung i9060i galaxy', 6.728666865248291),
#               ('huawei ascend y300', 5.709894673626673),
#               ('blackberry bold 9000', 5.385986114008162),
#               ('palm pre plus', 3.8822360477746174),
#               ('motorola xt390', 3.017865700845416)],
#              'francis': [('apple iphone 7', 8.843493580952526),
#               ('motorola moto g', 8.020558642487154),
#               ('samsung galaxy grand', 6.93613383585759),
#               ('blackberry bold 9900', 6.756604579812581),
#               ('doogee x5 max', 6.6929639510609595),
#               ('samsung galaxy s7', 6.512667529836081),
#               ('samsung galaxy s7', 6.512667529836081),
#               ('samsung s5230 player', 6.5117646479175795),
#               ('apple iphone 5', 6.062324604359915),
#               ('lg gt540', 5.031255958708897)],
#              'delicate': [('nokia 2730 classic', 1),
#               ('palm treo 750', 1),
#               ('nokia 6600i slide', 1),
#               ('apple iphone 3gs', 1),
#               ('palm treo 650', 1),
#               ('nokia e52', 1)],
#              'flavio': [('asus zenfone 2', 9.279646205713632),
#               ('apple iphone 5s', 8.896284952681953),
#               ('lg d855 g3', 8.761309323191082),
#               ('huawei ascend p8', 8.745043200498083),
#               ('lg optimus l5', 8.536273147743808),
#               ('huawei nexus 6p', 8.420489312018013),
#               ('alcatel one touch', 8.411138820272965),
#               ('smartphone lg optimus', 8.104136671720617),
#               ('huawei ascend y530', 7.84831784961545),
#               ('doogee x5 max', 7.2623297313070525)],
#              'santiago': [('samsung galaxy s6', 9.569145662059457),
#               ('nokia lumia 1320', 9.279470072951264),
#               ('lenovo motorola moto', 9.256509712365718),
#               ('microsoft lumia 640', 9.061031185609565),
#               ('huawei smartphone huawei', 8.676688007065584),
#               ('motorola moto e', 8.633385786415872),
#               ('bq aquaris x5', 8.305885988402128),
#               ('samsung galaxy s', 8.234120969206048),
#               ('sony xperia z', 7.952647698642221),
#               ('sony xperia p', 5.983611631118573)],
#              'emanetcan': [('apple iphone 3g', 1),
#               ('apple iphone 3gs', 1),
#               ('samsung s8003 jet', 1),
#               ('samsung e250 cep', 1),
#               ('sony ericsson w995', 1),
#               ('samsung m620 cep', 1),
#               ('nokia 5630 xpressmusic', 1),
#               ('sony ericsson w810i', 1),
#               ('blackberry storm 9530', 1),
#               ('nokia 6300 cep', 1)],
#              'cikolata': [('samsung i560 cep', 1),
#               ('nokia e65 cep', 1),
#               ('nokia n76 cep', 1),
#               ('nokia 5300 xpressmusic', 1),
#               ('samsung u800 cep', 1)],
#              '???????????????? ??????????????': [('philips xenium w732',
#                8.595129061900579),
#               ('lenovo k900 32gb', 7.598115698278482),
#               ('nokia asha 210', 7.104404665575782),
#               ('samsung galaxy pocket', 6.655329010511656),
#               ('samsung c3322', 6.549486921375141),
#               ('sony xperia miro', 6.0946418838422245),
#               ('sony xperia e', 5.47056162034795)],
#              'jr': [('sony ericsson cedar', 9.639391650245358),
#               ('samsung b5722 handy', 9.264779929981916),
#               ('apple iphone 5s', 8.860716017936936),
#               ('samsung galaxy s3', 8.799628059354207),
#               ('huawei p8 lite', 8.607576269445238),
#               ('blu studio x', 8.415955285657255),
#               ('samsung galaxy s7', 8.011163293894722),
#               ('samsung galaxy s5', 7.151892260155821)],
#              'ozer1299': [('nokia n81 8gb', 1),
#               ('samsung d900i 1gb', 1),
#               ('nokia n70 cep', 1),
#               ('nokia x6 cep', 1),
#               ('samsung m620 cep', 1),
#               ('nokia 6500 slide', 1),
#               ('samsung i8000 omnia', 1)],
#              'george': [('samsung ativ s', 8.858153075361898),
#               ('huawei p9 lite', 8.589074333706417),
#               ('motorola moto g', 8.402912362859269),
#               ('motorola moto g', 8.402912362859269),
#               ('sim free motorola', 8.370559396763271),
#               ('nokia 6310i mobile', 8.087319015690204),
#               ('apple iphone 5s', 8.049839509651024),
#               ('samsung g920 galaxy', 8.016004638935264),
#               ('asus zenfone max', 7.562993076108565),
#               ('samsung galaxy s7', 7.4424041463636375)],
#              'mustafa': [('samsung i9190 galaxy', 9.461819225231476),
#               ('iphone 5s 16gb', 8.131107555773198),
#               ('samsung s7580 galaxy', 6.792303769729655),
#               ('samsung galaxy j1', 5.893426140958913)],
#              'xxx': [('sony ericsson xperia', 8.730296827933966),
#               ('doogee x5 pro', 8.68591312229503),
#               ('sony ericsson w395', 7.958423788723067),
#               ('huawei ascend y300', 7.642996542174251)],
#              'emre': [('lg g4 us991', 6.3427959670116225),
#               ('nokia 5800 xpressmusic', 5.973662051482516),
#               ('sony xperia z', 5.836480254609196),
#               ('motorola razr v3', 4.771872304497073)],
#              'anja': [('htc one max', 9.676378717506058),
#               ('htc desire c', 9.005814559357642),
#               ('microsoft nokia 2760', 8.814657829220748),
#               ('samsung galaxy y', 8.471802660458405),
#               ('huawei p8lite zwart', 8.153836019188008),
#               ('sony xperia sp', 7.153793789194242),
#               ('htc desire 310', 7.127133564978374),
#               ('vodafone smart 4', 7.086416755062569),
#               ('samsung galaxy ace', 6.429518513385682),
#               ('samsung galaxy s4', 6.054451838510669)],
#              '????????????????': [('samsung c3782 onyx', 9.17273558739957),
#               ('apple iphone 4s', 8.948422253443178),
#               ('htc desire c', 8.864884363878136),
#               ('nokia n9', 8.551632416883585),
#               ('huawei u8860 honor', 8.424903242513267),
#               ('nokia asha 210', 8.201412006849633),
#               ('sony xperia v', 7.68468668729793)],
#              'me': [('lg electronics leon', 8.96287868690549),
#               ('doro phoneeasy 410gsm', 8.836624863642854),
#               ('samsung c5212 duos', 8.456860675403483),
#               ('samsung galaxy s7', 7.979839125936876),
#               ('samsung galaxy note', 7.784124834230033),
#               ('samsung gt s5260', 7.746527073832079),
#               ('microsoft nokia lumia', 7.498164306029318),
#               ('sony xperia z', 7.441282989736839),
#               ('apple iphone 3gs', 7.015140526363392),
#               ('alcatel onetouch onetouch', 6.859554894479773)],
#              'dolunay': [('samsung galaxy mini', 1),
#               ('samsung s5233w star', 1),
#               ('nokia n73 cep', 1),
#               ('nokia n72 cep', 1),
#               ('samsung d900i 1gb', 1)],
#              'sezenm': [('nokia n95 cep', 1),
#               ('samsung p520 armani', 1),
#               ('nokia n72 cep', 1),
#               ('nokia 6131 cep', 1),
#               ('nokia 5500 sport', 1)],
#              'damien': [('samsung galaxy s6', 9.42417758677485),
#               ('lg g2 mini', 9.416328777186186),
#               ('motorola defy', 8.734539015984206),
#               ('microsoft lumia 535', 8.504528847326503),
#               ('lg nexus 5', 8.35870150919093),
#               ('nokia e63', 7.791573872760755)],
#              'ram': [('microsoft lumia 640', 7.385483506076643),
#               ('microsoft lumia 640', 7.385483506076643),
#               ('htc evo 3d', 6.5708942237969055),
#               ('apple iphone 6', 6.028418792085721)],
#              'tuvok': [('samsung galaxy express', 8.14481529030913)],
#              'tobias': [('samsung galaxy s4', 8.333974758511996),
#               ('huawei mate 9', 8.290304531998085),
#               ('samsung galaxy s', 8.097668811278096),
#               ('asus padfone 2', 7.825524731034964),
#               ('lenovo motorola moto', 7.775901013961787),
#               ('microsoft nokia 108', 7.387233282965488),
#               ('htc mozart 7', 7.054941484525244),
#               ('lg electronics google', 6.685516974578574),
#               ('nokia 6220 classic', 6.6678892264861105),
#               ('microsoft lumia 650', 5.687872393788069)],
#              'alice': [('samsung a5 2016', 9.359109553090526),
#               ('samsung galaxy a3', 9.110755029673786),
#               ('doro phoneeasy 612', 9.059605731915452),
#               ('huawei ascend mate', 8.89361975310796),
#               ('asus ze550kl zenfone', 8.858814400326034),
#               ('smartphone samsung galaxy', 8.717190279907387),
#               ('oukitel u7 plus', 8.499428580370024),
#               ('doro phone easy', 8.253511903237092),
#               ('samsung galaxy s4', 7.7147978605382965),
#               ('samsung galaxy y', 7.30464503093009)],
#              'zehrabalta': [('nokia e90 cep', 1),
#               ('nokia n97 mini', 1),
#               ('sony ericsson z310i', 1),
#               ('apple iphone 4', 1),
#               ('nokia n95 cep', 1)],
#              '???????\x80????': [('apple iphone 4s', 9.488880215579513),
#               ('samsung c3782 onyx', 9.227103464237183),
#               ('nokia 603', 9.219774074701327),
#               ('sony xperia v', 8.518454319039492),
#               ('htc sensation xl', 8.293992769497716),
#               ('nokia asha 311', 7.869641930069612)],
#              'louis': [('nokia lumia 830', 9.712938904349873),
#               ('sony xperia t', 9.652582098095134),
#               ('sony ericsson xperia', 9.075550441035272),
#               ('samsung galaxy s6', 8.923022576264792),
#               ('sony ericsson w580', 8.751137103893575),
#               ('samsung galaxy s7', 8.58239946829213),
#               ('apple iphone 4s', 8.453038543791209),
#               ('htc desire sim', 8.407702279557066),
#               ('doogee x5 pro', 8.240991150520333),
#               ('nokia microsoft lumia', 7.754420099877482)],
#              'bert': [('sim free motorola', 9.523651419056703),
#               ('huawei p8 champagne', 9.03606312572432),
#               ('huawei p8 grijs', 8.970767008261971),
#               ('apple iphone 5s', 8.937628680587839),
#               ('samsung b2710 solid', 8.681508911196206),
#               ('apple iphone se', 8.091139685939506)],
#              'narn3049': [('sony ericsson xperia', 9.971027228465225),
#               ('pearl 8100', 7.367704076286283),
#               ('v300', 7.367704076286283)],
#              'sue': [('sim free apple', 10),
#               ('huawei p9 lite', 9.46097091647567),
#               ('samsung s3350 chat', 8.43826580717394),
#               ('samsung galaxy s', 8.200096334972738),
#               ('samsung e1270 uk', 7.830419031905121),
#               ('blackberry dtek50 unlocked', 7.8183187828847895),
#               ('lg electronics ks360', 5.2382727599904335)],
#              'sunny': [('apple iphone 6s', 8.898468836091169),
#               ('doro phoneeasy 622', 7.8444358041377145),
#               ('samsung galaxy a3', 7.5558545237728625),
#               ('sony xperia s', 7.532887117166254),
#               ('huawei p8 lite', 7.324780005883115),
#               ('lg electronics e610', 5.4765677340942664),
#               ('karbonn titanium octane', 5.392986338814651),
#               ('apple iphone 3g', 3.850260650929419)],
#              'raquel': [('samsung galaxy s6', 8.567158864001899),
#               ('motorola moto g', 8.561725501514129),
#               ('apple iphone 5', 7.346878709557859),
#               ('smartphone lg optimus', 6.970417118830774),
#               ('blackberry torch 9810', 6.659915340604724),
#               ('htc one', 5.812958417372274)],
#              'aksisey': [('nokia 6500 slide', 1),
#               ('nokia n70 cep', 1),
#               ('nokia e65 cep', 1)]})

# %%
### validating
prod_listdf=df_final1[df_final1['author']=='alexander'][['prod_details','score']].sort_values('score', ascending=False)
prod_list=prod_listdf['prod_details'][0:10]
print('user has given high rating to below products')
print(prod_listdf[0:10])
u1=pred[pred['uid']=='alexander'][['uid','iid','r_ui','est']].sort_values(['r_ui','est'], ascending=False)
recom= u1[~u1['iid'].isin(prod_list)]
print(' ')
print('recommended products for user')
recom[0:5]
# Out:
# user has given high rating to below products
#                 prod_details  score
# 8497     sony ericsson k750i   10.0
# 52070       sony xperia tipo   10.0
# 85396         sprint lg volt   10.0
# 244829        sony xperia sp   10.0
# 91564   samsung s7582 galaxy   10.0
# 93964      samsung galaxy j5   10.0
# 69493         htc wildfire s   10.0
# 367736         huawei mate 2   10.0
# 144259     samsung galaxy a5   10.0
# 156158       lg google nexus   10.0
#
# recommended products for user
#              uid                 iid  r_ui        est
# 11762  alexander  huawei ascend g600  10.0  10.000000
# 5272   alexander  htc one smartphone  10.0   9.556021
# 5006   alexander  huawei ascend mate  10.0   9.425919
# 20044  alexander  honor 7 smartphone  10.0   8.639873
# 0      alexander           htc one x  10.0   8.534794

# %%
### same analysis for readable data
reader = Reader(rating_scale=(1, 10))
data1 = Dataset.load_from_df(df_final_v1[['author', 'prod_details1', 'score']], reader)

# Split data to train and test
from surprise.model_selection import train_test_split
trainset1, testset1 = train_test_split(data1, test_size=.25,random_state=123)

print(trainset.to_raw_iid(0))

svd_model = SVD(n_factors=5,biased=False)
svd_model.fit(trainset1)

test_pred1= svd_model.test(testset1)

# compute RMSE
print(accuracy.rmse(test_pred1))

pred = pd.DataFrame(test_pred1)
top_n = get_top_n(test_pred1, n=10)
top_n
# Out:
# htc incredible s
# RMSE: 2.9341
# 2.934079326909404
# defaultdict(list,
#             {'ivan': [('sim free apple', 9.849520331227229),
#               ('huawei ascend g300', 9.746287445747132),
#               ('sony xperia z3', 9.677772880088678),
#               ('lg google nexus', 9.622053758080268),
#               ('sim free lg', 9.518425465063867),
#               ('apple iphone 6s', 9.489873393209338),
#               ('smartphone sony xperia', 9.398736164751838),
#               ('motorola moto e', 9.208653663742641),
#               ('lg h340 leon', 9.12702213803825),
#               ('samsung n9005 galaxy', 9.077084783747063)],
#              'karthik': [('motorola moto z', 9.126515551035514),
#               ('lenovo vibe x3', 9.08239032349194),
#               ('apple iphone 6s', 8.853761728133719),
#               ('samsung galaxy s7', 8.812557048020615),
#               ('blu vivo air', 8.768879703522025),
#               ('sony xperia xa', 8.68173984215288),
#               ('meizu m1 note', 8.651091885854106),
#               ('lg g2 d802', 8.500407655990585),
#               ('motorola moto e', 7.935462786731176),
#               ('lenovo used lenovo', 7.894846007060217)],
#              'luca': [('apple iphone 5c', 9.29122755188985),
#               ('apple iphone 5c', 9.29122755188985),
#               ('nokia lumia 635', 8.95553424384744),
#               ('huawei ascend mate', 8.789187290303571),
#               ('htc desire 820', 8.723576637028724),
#               ('samsung a500 galaxy', 8.561650374852746),
#               ('lg optimus l5', 8.5098001178354),
#               ('lg optimus l5', 8.5098001178354),
#               ('nokia 105 telefono', 8.426174299393647),
#               ('huawei ascend g620s', 8.365352574058171)],
#              'jeff': [('sony ericsson w810i', 9.188034970990651),
#               ('sony ericsson arc', 8.93293423977247),
#               ('samsung e1150 flip', 8.547174286891002),
#               ('blu win jr', 8.366708792343925),
#               ('nokia lumia 640', 8.31445129932441),
#               ('samsung g890a unlocked', 8.13652443936764),
#               ('samsung s5230 star', 7.493199448005006),
#               ('leagoo easysmx leagoo', 6.703754702680678),
#               ('samsung galaxy s5', 6.388036622130703),
#               ('apple iphone 3gs', 6.077569870841767)],
#              'amazon customer': [('lg g2 smartphone', 9.745484574000425),
#               ('blackberry z10 uk', 9.564954672858397),
#               ('sony xperia xcompact', 9.379958790685418),
#               ('micromax canvas doodle', 9.33836389794062),
#               ('nokia lumia 1320', 9.33776025934408),
#               ('nokia lumia 1320', 9.33776025934408),
#               ('nokia lumia 1320', 9.33776025934408),
#               ('nokia lumia 1320', 9.33776025934408),
#               ('nokia lumia 1320', 9.33776025934408),
#               ('lg g6 fullvision', 9.335552083511832)],
#              'b': [('samsung guru e1200', 9.864539466037723),
#               ('acer liquid e2', 8.46078297024283),
#               ('sony xperia z', 8.315685307045875),
#               ('huawei honor 5x', 8.126605694574298),
#               ('motorola moto e', 8.084143055712383),
#               ('apple iphone 5c', 7.534046938558974),
#               ('blu vivo xl', 7.170793441221998),
#               ('lg electronics g4', 7.038984143376262),
#               ('samsung galaxy s4', 6.702789507180991),
#               ('lg electronics hb', 6.431097028778979)],
#              'mar': [('huawei ascend g610', 8.524949648785087),
#               ('huawei p8 lite', 8.245049159094929),
#               ('huawei p8 lite', 8.245049159094929),
#               ('htc evo 4g', 8.155594111561044),
#               ('motorola moto g', 8.06631742738329),
#               ('htc radar', 8.065322850342298),
#               ('samsung galaxy a5', 7.838544118070945),
#               ('samsung galaxy core', 7.750080729104899),
#               ('elephone p6000 pro', 7.693557893134528),
#               ('bq aquaris e5', 7.556907435769879)],
#              'javier': [('lg nexus 5x', 9.66205799149072),
#               ('samsung galaxy j5', 9.645083492833392),
#               ('bq aquaris 5', 9.332616317409265),
#               ('htc desire eye', 9.31986580021592),
#               ('lenovo motorola moto', 9.183103731417317),
#               ('lenovo motorola moto', 9.183103731417317),
#               ('lenovo motorola moto', 9.183103731417317),
#               ('sony xperia z3', 9.13304441315266),
#               ('sony xperia z3', 9.13304441315266),
#               ('sony xperia z3', 9.13304441315266)],
#              'no captured': [('nokia n800 portable', 10),
#               ('microsoft nokia 5140i', 10),
#               ('motorola atrix 2', 10),
#               ('microsoft nokia 5310', 9.874223414092205),
#               ('htc p3450 touch', 9.69568090881072),
#               ('htc p3450 touch', 9.69568090881072),
#               ('palm germany gmbh', 9.648821110999465),
#               ('siemens c45', 9.401142595597062),
#               ('huawei ascend p8', 9.39118919893836),
#               ('sony ericsson k530i', 9.372839857141734)],
#              'ruben': [('motorola moto e', 8.969019408759813),
#               ('lg g2 mini', 8.846416561808098),
#               ('lg l fino', 8.590091121633431),
#               ('lenovo motorola moto', 8.558933985492892),
#               ('samsung galaxy sii', 8.458533984133657),
#               ('samsung galaxy note', 8.40830583343177),
#               ('samsung i8190 galaxy', 8.295412306083318),
#               ('motorola moto g', 7.7453742376500525),
#               ('alcatel onetouch idol', 7.6557089793602895),
#               ('huawei ascend y330', 7.632261723406595)],
#              'martin': [('samsung galaxy note', 10),
#               ('microsoft lumia 650', 9.730518870568176),
#               ('huawei mate 7', 9.38602971727646),
#               ('huawei mate 7', 9.38602971727646),
#               ('sony xperia z1', 9.141120455910851),
#               ('lg electronics g2', 9.08906091938204),
#               ('galaxy samsung galaxy', 9.071661667601695),
#               ('lg electronics l40', 8.957260615129),
#               ('sony ericsson xperia', 8.89379164283173),
#               ('sony ericsson xperia', 8.89379164283173)],
#              'christine': [('acer liquid z5', 9.800232261396363),
#               ('nokia lumia 635', 9.639380341151345),
#               ('samsung galaxy young', 9.42439004092406),
#               ('motorola moto g', 9.248987869433911),
#               ('apple iphone 5s', 8.370782223484062),
#               ('samsung galaxy a5', 8.09245583093637),
#               ('sony xperia z1', 8.075598774365464),
#               ('samsung c3050 handy', 7.928388009157557),
#               ('blackberry curve 9320', 7.534926149842766),
#               ('sony xperia z3', 7.339400202223327)],
#              'sebastian': [('samsung galaxy s4', 9.981884142110875),
#               ('microsoft nokia e51', 9.836828990232517),
#               ('microsoft nokia 2760', 9.51089634699258),
#               ('sony xperia z5', 9.285354483555954),
#               ('sony ericsson k550i', 9.01808673671574),
#               ('htc sensation xe', 8.823327805590813),
#               ('lg g3 d855', 8.773980082485117),
#               ('samsung galaxy mini', 8.648141951888363),
#               ('htc desire smartphone', 8.511990218906966),
#               ('samsung wave 533', 8.426264875893187)],
#              'marco': [('huawei mate 8', 10),
#               ('samsung galaxy note', 9.90117805684616),
#               ('nokia lumia 635', 9.622046432906892),
#               ('lg d802 g2', 9.562237459110355),
#               ('samsung s5620 smartphone', 9.509863117910438),
#               ('samsung g900 galaxy', 9.485281490903933),
#               ('samsung galaxy s8', 9.340241533160219),
#               ('samsung i9082 galaxy', 9.32647815550135),
#               ('meizu m2 note', 9.17657932897961),
#               ('acer liquid e2', 9.131427451497478)],
#              'markus': [('samsung i9301 galaxy', 9.35790297156269),
#               ('samsung s5620 smartphone', 9.009595685463987),
#               ('microsoft nokia 2730', 8.580092812123393),
#               ('microsoft lumia 532', 8.410667942983395),
#               ('lg electronics g4', 8.391426096936762),
#               ('microsoft nokia n8', 8.017882461828394),
#               ('microsoft nokia 5230', 7.975348069416057),
#               ('honor 6 smartphone', 7.934060102048483),
#               ('samsung galaxy mini', 7.887567201532711),
#               ('samsung galaxy mini', 7.887567201532711)],
#              'laura': [('lg g5 h860', 9.505141026705239),
#               ('sim free apple', 9.46572867086114),
#               ('honor 6x smartphone', 9.287127787464744),
#               ('apple iphone 6s', 9.21520598022542),
#               ('samsung i9082 galaxy', 9.13973271701154),
#               ('samsung galaxy mini', 9.132069545557),
#               ('asus zenfone max', 9.002238735162885),
#               ('huawei honor 6', 8.972950019772428),
#               ('nokia lumia 720', 8.948235178413155),
#               ('samsung g357 galaxy', 8.917416105085332)],
#              "client d'amazon": [('doogee y6 max', 8.648702574518254),
#               ('meizu m2 note', 8.635116058733992),
#               ('samsung galaxy note', 8.437061611674388),
#               ('easyacc coque samsung', 8.320577307467646),
#               ('easyacc coque samsung', 8.320577307467646),
#               ('wiko fever smartphone', 8.160019050668348),
#               ('wiko fever smartphone', 8.160019050668348),
#               ('wiko fever smartphone', 8.160019050668348),
#               ('wiko fever smartphone', 8.160019050668348),
#               ('meizu pro 5', 8.136751575785606)],
#              'carlos': [('iphone 4s apple', 10),
#               ('lg g3 d855', 9.979592594653852),
#               ('lg nexus 5x', 9.924165715380946),
#               ('sony xperia u', 9.918618051789657),
#               ('apple iphone 5c', 9.874399262654098),
#               ('samsung galaxy s5', 9.754204718075759),
#               ('samsung galaxy s7', 9.735228919211792),
#               ('samsung galaxy s7', 9.735228919211792),
#               ('samsung galaxy s7', 9.735228919211792),
#               ('smartphone asus zenfone', 9.66446735815263)],
#              'federico': [('samsung n9005 galaxy', 9.848641428095156),
#               ('samsung galaxy note', 9.809782090204209),
#               ('huawei ascend g7', 9.638006460730942),
#               ('samsung g900 galaxy', 9.419369075280011),
#               ('samsung b2710 telefono', 9.20643952437476),
#               ('meizu m2 note', 9.184742650248833),
#               ('honor 6 smartphone', 9.0532297295458),
#               ('huawei ascend p8', 8.930431641839432),
#               ('sony xperia x', 8.797455436133175),
#               ('lenovo motorola moto', 8.765467574966522)],
#              'alessio': [('lg d802 g2', 9.503799887508467),
#               ('huawei ascend p6', 8.872654877505529),
#               ('meizu m2 note', 8.78280195261742),
#               ('lenovo motorola moto', 8.698110970315414),
#               ('lenovo motorola moto', 8.698110970315414),
#               ('lenovo motorola moto', 8.698110970315414),
#               ('lenovo motorola moto', 8.698110970315414),
#               ('lenovo motorola moto', 8.698110970315414),
#               ('samsung g925 galaxy', 8.631370115759612),
#               ('samsung ativ s', 8.452410014661604)],
#              'enrique': [('samsung galaxy j5', 9.82263331309724),
#               ('apple iphone 6s', 9.611308492796432),
#               ('blu vivo air', 9.47090719893156),
#               ('samsung s7582 galaxy', 9.429862988195481),
#               ('samsung galaxy note', 9.24783213017371),
#               ('samsung galaxy note', 9.24783213017371),
#               ('huawei p8 lite', 9.152151645325048),
#               ('alcatel onetouch 2004c', 8.85551412463223),
#               ('lg optimus g', 8.774352373033288),
#               ('nokia lumia 635', 8.709003306456227)],
#              'silvia': [('lg h410 wine', 9.647974755391092),
#               ('samsung galaxy sii', 9.36245343199889),
#               ('nokia 208 telefono', 9.299320402968052),
#               ('samsung galaxy j5', 9.277425607760895),
#               ('samsung galaxy j5', 9.277425607760895),
#               ('samsung g935 galaxy', 9.177453400311176),
#               ('samsung g935 galaxy', 9.177453400311176),
#               ('samsung c3590 telefono', 9.08336411328279),
#               ('samsung galaxy mini', 9.067313617537655),
#               ('microsoft lumia 640', 9.053848378009702)],
#              'rahul': [('samsung galaxy s4', 8.847616991303127),
#               ('microsoft lumia 540', 8.377621285112987),
#               ('apple iphone 6s', 8.169919017501625),
#               ('micromax canvas a1', 8.060000196131256),
#               ('samsung galaxy e7', 7.988656903660242),
#               ('asus zenfone 5', 7.902754277769059),
#               ('asus zenfone 5', 7.902754277769059),
#               ('nokia lumia 1320', 7.837165395691201),
#               ('huawei nexus 6p', 7.786704423026356),
#               ('lenovo vibe k4', 7.744359995719558)],
#              'jackie': [('motorola rizr z3', 9.306912546789432),
#               ('nokia lumia 830', 8.989846859704913),
#               ('microsoft lumia 640', 8.894451072945941),
#               ('sony xperia xz', 8.488755307984386),
#               ('samsung galaxy s4', 8.429795051723332),
#               ('samsung galaxy s4', 8.429795051723332),
#               ('lg env3 vx9200', 8.41265972691156),
#               ('apple iphone 4s', 8.336031630212624),
#               ('apple iphone 5s', 7.730711751723862),
#               ('pantech breakout 8995', 4.790883610236039)],
#              'cliente amazon': [('asus ze550kl zenfone', 9.358344520342518),
#               ('samsung n9005 galaxy', 9.335524790132348),
#               ('huawei ascend mate', 8.932043114313746),
#               ('huawei ascend mate', 8.932043114313746),
#               ('huawei ascend mate', 8.932043114313746),
#               ('huawei ascend mate', 8.932043114313746),
#               ('motorola moto e', 8.441794425972702),
#               ('motorola moto e', 8.441794425972702),
#               ('huawei mate 8', 8.439736788315422),
#               ('huawei mate 8', 8.439736788315422)],
#              'j': [('sim free samsung', 9.08007122882813),
#               ('sim free samsung', 9.08007122882813),
#               ('samsung galaxy j5', 8.828641552248657),
#               ('honor 6 smartphone', 8.70881233981693),
#               ('samsung galaxy note', 8.236247523252493),
#               ('samsung galaxy note', 8.236247523252493),
#               ('samsung galaxy s6', 8.20695249597796),
#               ('sony xperia z2', 8.117327412660462),
#               ('blu life pure', 7.971912928189843),
#               ('lg optimus g', 7.63889154180293)],
#              'david': [('lg h410 wine', 10),
#               ('motorola moto e', 10),
#               ('motorola moto e', 10),
#               ('sony xperia pro', 10),
#               ('motorola moto e', 10),
#               ('samsung i9195 galaxy', 9.813506179572798),
#               ('huawei mate 8', 9.765755361233971),
#               ('samsung ativ s', 9.765590058586199),
#               ('apple iphone 4', 9.726076681722853),
#               ('apple iphone 5', 9.684004067997806)],
#              'sabrina': [('apple iphone 7', 9.714342701865576),
#               ('samsung galaxy y', 9.519369308995373),
#               ('samsung g355 galaxy', 9.508390110921908),
#               ('smartphone samsung galaxy', 9.401850193146858),
#               ('samsung galaxy s6', 9.338845331504734),
#               ('wiko lenny 3', 8.931425117060623),
#               ('lg e440 l4ii', 8.704504406023405),
#               ('sony ericsson w595', 8.698461500741097),
#               ('lg g3 8806084954985', 8.479465090236259),
#               ('smartphone motorola moto', 8.242333250344457)],
#              'black': [('doogee smartphone dual', 1.1017911744085356),
#               ('apple iphone 3gs', 1.0028118177383278),
#               ('nokia 2630 cep', 1),
#               ('nokia e51 cep', 1),
#               ('motorola razr2 v9', 1),
#               ('samsung p520 armani', 1),
#               ('nokia 6288 cep', 1),
#               ('sony ericsson m600i', 1),
#               ('motorola rokr z6', 1),
#               ('palm treo 750', 1)],
#              'xawi': [('samsung d900i 1gb', 1),
#               ('nokia e65 cep', 1),
#               ('samsung m620 cep', 1),
#               ('nokia 5300 xpressmusic', 1),
#               ('samsung g810 cep', 1),
#               ('nokia 3720 classic', 1),
#               ('samsung i8000 omnia', 1),
#               ('nokia 5610 cep', 1)],
#              'fabrizio': [('samsung galaxy note', 9.25617218304696),
#               ('honor 6 smartphone', 9.219257003283676),
#               ('honor 6 smartphone', 9.219257003283676),
#               ('lenovo motorola moto', 9.090274854795085),
#               ('samsung galaxy s7', 9.086806373785308),
#               ('huawei p9 lite', 8.698670417058057),
#               ('huawei p9 lite', 8.698670417058057),
#               ('motorola moto g', 8.599488389816552),
#               ('blu vivo 5r', 8.482263363541419),
#               ('lenovo k6 smartphone', 8.441857496497068)],
#              'eric': [('samsung galaxy s7', 9.599755901245452),
#               ('nokia lumia 830', 9.214569793577041),
#               ('nokia lumia 830', 9.214569793577041),
#               ('honor 6 smartphone', 9.037177702561982),
#               ('htc radar', 8.944110815570559),
#               ('motorola atrix hd', 8.833187211514145),
#               ('nokia 6600', 8.754347370345243),
#               ('motorola moto g', 8.720853094224804),
#               ('motorola moto g', 8.720853094224804),
#               ('motorola moto g', 8.720853094224804)],
#              'christian': [('samsung galaxy s4', 10),
#               ('samsung galaxy s4', 10),
#               ('sony xperia xa', 9.685829593056518),
#               ('samsung j510 galaxy', 9.172336078671865),
#               ('huawei ascend mate', 9.075043507342906),
#               ('samsung e1200 handy', 9.020061337482218),
#               ('microsoft nokia n95', 8.965785866769062),
#               ('honor 6 smartphone', 8.886240172036796),
#               ('sony xperia z5', 8.767929452238434),
#               ('lg electronics g4', 8.593039638159079)],
#              'emilio': [('huawei ascend mate', 9.96261451803453),
#               ('nokia lumia 520', 9.864964062739316),
#               ('lg optimus l5', 9.69864287309771),
#               ('lg nexus 5x', 9.190672038377407),
#               ('honor 8 smartphone', 9.187036485504716),
#               ('huawei ascend g610', 9.179400473850075),
#               ('nokia lumia 720', 9.137768451182895),
#               ('samsung galaxy core', 9.041770847536467),
#               ('asus zenfone 2', 8.876714511974702),
#               ('asus zenfone 2', 8.876714511974702)],
#              'dee': [('binatone the brick', 9.190617280635095),
#               ('samsung galaxy s4', 8.861268779999516),
#               ('lg optimus l90', 8.740090402583379),
#               ('samsung galaxy s5', 8.098198610061871),
#               ('cubot unlocked cubot', 7.91734039362583),
#               ('nokia asha 205', 7.5316337001704605),
#               ('lg electronics e460', 7.435288661834895),
#               ('samsung rugby 3', 6.994410773707429),
#               ('samsung galaxy s6', 6.957365624061974),
#               ('oppo find 5', 3.979851047880486)],
#              'vincenzo': [('asus zenfone 3', 9.242815128260656),
#               ('lg optimus g', 9.051521366666643),
#               ('xiaomi hongmi redmi', 8.96007757620041),
#               ('lg google nexus', 8.63249646208255),
#               ('nokia 101', 8.60711658498276),
#               ('samsung g800 galaxy', 8.525217877651333),
#               ('lenovo motorola moto', 8.459873606966894),
#               ('nokia 208 telefono', 8.374594297649011),
#               ('wiko fever 4g', 8.230055009212343),
#               ('alcatel onetouch pop', 8.19705549452341)],
#              'narn3049': [('htc incredible s', 10),
#               ('motorola droid x2', 8.586488207360583),
#               ('lg env3', 8.025112117139484)],
#              'andreas': [('samsung galaxy s4', 10),
#               ('wiko rainbow smartphone', 10),
#               ('honor 7 smartphone', 9.924475737607779),
#               ('honor 6 smartphone', 9.4032594094043),
#               ('lg gs290 cookie', 8.76751739989657),
#               ('microsoft lumia 640', 8.535140317269626),
#               ('microsoft nokia lumia', 8.48591060435672),
#               ('huawei ascend g525', 8.32408791747879),
#               ('lenovo motorola razr', 8.29211198712192),
#               ('samsung galaxy s3', 8.235973464588026)],
#              'alessandro': [('nokia lumia 1020', 9.942974009431715),
#               ('lg nexus 5', 9.588160706063077),
#               ('honor 6 smartphone', 9.573734937606027),
#               ('nokia lumia 800', 9.511400563484381),
#               ('microsoft lumia 640', 9.498250197823454),
#               ('iphone apple iphone', 9.372346687345827),
#               ('sony xperia z', 9.3077363349306),
#               ('samsung g3500 galaxy', 9.299774171230379),
#               ('asus zenfone 3', 9.299504833211298),
#               ('samsung n9005 galaxy', 9.218733970241681)],
#              'luigi': [('lg optimus g', 9.01135031199724),
#               ('apple iphone 6s', 8.766013571651749),
#               ('samsung g800 galaxy', 8.71771665949494),
#               ('nokia lumia 1020', 8.711089396243292),
#               ('sony xperia xa', 8.653703918619541),
#               ('samsung e1200 telefono', 8.511002538131963),
#               ('microsoft lumia 640', 8.504619302499751),
#               ('sony xperia z5', 8.43212416298863),
#               ('huawei ascend p7', 8.418338517116295),
#               ('samsung galaxy s7', 8.338536079068515)],
#              'alejandro': [('samsung galaxy s4', 8.974462229396032),
#               ('samsung galaxy s4', 8.974462229396032),
#               ('samsung galaxy s4', 8.974462229396032),
#               ('xiaomi redmi note', 8.889426235428035),
#               ('lg optimus l5', 8.886488037847718),
#               ('microsoft lumia 640', 8.601727215047692),
#               ('microsoft lumia 640', 8.601727215047692),
#               ('acer liquid e2', 8.503543954657196),
#               ('galaxy samsung galaxy', 8.443210586707405),
#               ('motorola moto g', 8.41883075615455)],
#              'gabriel': [('samsung galaxy j5', 9.355925848587278),
#               ('lg g5 smartphone', 9.301732013100365),
#               ('smartphone lg l90', 9.26303668416048),
#               ('nokia lumia 520', 9.090954850290563),
#               ('lenovo motorola moto', 9.068251849293125),
#               ('oukitel k6000 4g', 8.951220550947353),
#               ('motorola moto g', 8.947005137371733),
#               ('motorola moto g', 8.947005137371733),
#               ('lenovo vibe k4', 8.909442962692331),
#               ('nokia lumia 920', 8.804475375646614)],
#              'mauro': [('huawei p8 smartphone', 10),
#               ('smartphone sony xperia', 9.982662240938708),
#               ('samsung galaxy s7', 8.678745725593846),
#               ('huawei p8 lite', 8.4468385908293),
#               ('nokia lumia 1520', 8.338144228120466),
#               ('smartphone lg optimus', 8.302341934215814),
#               ('lenovo motorola moto', 8.13774404564399),
#               ('lenovo motorola moto', 8.13774404564399),
#               ('lenovo motorola moto', 8.13774404564399),
#               ('lenovo motorola moto', 8.13774404564399)],
#              'paul': [('lg g2 verizon', 9.975969056364248),
#               ('meizu pro 5', 9.796088343998736),
#               ('nokia 1208 sim', 9.699171236463506),
#               ('sony mobile xperia', 9.528096157996023),
#               ('samsung captivate glide', 9.47760553158316),
#               ('sim free samsung', 9.429662601677217),
#               ('htc desire x', 9.254003460998266),
#               ('honor huawei honor', 9.214977818793056),
#               ('meizu mx4 pro', 9.184319207005634),
#               ('lg electronics google', 9.18226580081888)],
#              'erkek': [('sony xperia z2', 9.337205642059835),
#               ('sony xperia z2', 9.337205642059835),
#               ('lg optimus l5', 9.258043676133036),
#               ('lg optimus 4x', 9.189445845264302),
#               ('lg optimus 4x', 9.189445845264302),
#               ('nokia lumia 1520', 9.027026338158693),
#               ('lg g2 d802', 9.01347412021664),
#               ('nokia lumia 720', 8.941086781050142),
#               ('lg g pro', 8.803639773876977),
#               ('nokia lumia 1320', 8.750328790602)],
#              'mike': [('sony xperia xcompact', 9.578453146771599),
#               ('sim free iphone', 9.407174852853588),
#               ('doro phoneeasy 610', 9.362003586899707),
#               ('apple iphone 7', 9.28271124711177),
#               ('doro phoneeasy 410gsm', 9.24194075386503),
#               ('huawei ascend g600', 9.218947212082291),
#               ('vodafone huawei ascend', 9.185528158493552),
#               ('samsung i8160 galaxy', 9.027208454783267),
#               ('samsung galaxy s7', 8.934196183502031),
#               ('samsung galaxy s7', 8.934196183502031)],
#              'roberto': [('iphone 4s apple', 10),
#               ('meizu pro 5', 9.87151183553102),
#               ('huawei ascend mate', 9.514557763664556),
#               ('samsung i9301 galaxy', 9.432890347366328),
#               ('doro phone easy', 9.373768766712914),
#               ('motorola moto e', 9.369359393275632),
#               ('microsoft lumia 532', 9.3130182112576),
#               ('samsung galaxy j5', 9.270617869815903),
#               ('samsung galaxy j5', 9.270617869815903),
#               ('sony e5823 xperia', 8.919249886727197)],
#              'anonymous': [('htc one mini', 10),
#               ('samsung galaxy note', 10),
#               ('microsoft lumia 650', 10),
#               ('huawei honor 8', 9.80902778418005),
#               ('huawei honor 8', 9.80902778418005),
#               ('iphone 6 16', 9.708920932948487),
#               ('htc sensation z710e', 9.612166402520646),
#               ('lg nexus 5x', 9.562757939469563),
#               ('lg nexus 5x', 9.562757939469563),
#               ('samsung galaxy s7', 9.493903822829653)],
#              'enrico': [('huawei ascend g620s', 10),
#               ('samsung galaxy j5', 9.919177297143017),
#               ('samsung g800 galaxy', 9.775105126411626),
#               ('samsung a5 2016', 9.1072647893323),
#               ('huawei p8 lite', 9.03602368454603),
#               ('huawei p8 lite', 9.03602368454603),
#               ('microsoft lumia 532', 8.993181542843498),
#               ('huawei ascend g525', 8.983586172337311),
#               ('asus zenfone 5', 8.860725722952122),
#               ('htc desire 310', 8.824635516311794)],
#              'amazon kunde': [('blackberry passport smartphone',
#                8.447121412767645),
#               ('blackberry passport smartphone', 8.447121412767645),
#               ('sony xperia xcompact', 8.439391689165983),
#               ('lg electronics d605', 8.088452776870472),
#               ('caterpillar b15 q', 8.00727374300416),
#               ('caterpillar b15 q', 8.00727374300416),
#               ('lenovo k6 smartphone', 8.000612948623624),
#               ('huawei mate s', 7.8244630305213905),
#               ('huawei mate s', 7.8244630305213905),
#               ('huawei g8 smartphone', 7.618924241740944)],
#              'e-bit': [('smartphone lg leon', 9.16381872789973),
#               ('samsung galaxy note', 8.828607536880945),
#               ('smartphone microsoft lumia', 8.726066241389384),
#               ('smartphone apple iphone', 8.57435420420026),
#               ('smartphone apple iphone', 8.57435420420026),
#               ('smartphone apple iphone', 8.57435420420026),
#               ('smartphone apple iphone', 8.57435420420026),
#               ('smartphone apple iphone', 8.57435420420026),
#               ('smartphone apple iphone', 8.57435420420026),
#               ('smartphone apple iphone', 8.57435420420026)],
#              'johannes': [('samsung e1150 handy', 9.573289720545445),
#               ('sonyericsson w760i silber', 9.271226558580064),
#               ('lg electronics google', 9.267689881692343),
#               ('honor 7 smartphone', 8.795971870834432),
#               ('samsung wave 723', 8.41109479813595),
#               ('microsoft nokia lumia', 8.382629716924932),
#               ('sony xperia acro', 7.662816108100409),
#               ('samsung galaxy ace', 7.305329982989261),
#               ('microsoft nokia x6', 7.218268180577),
#               ('sony xperia z3', 7.183000070563841)],
#              'francisco': [('samsung galaxy s7', 9.580259758680771),
#               ('bq aquaris e5', 9.377838792441517),
#               ('nokia lumia 830', 9.195168271386912),
#               ('samsung galaxy note', 9.14167262865968),
#               ('samsung galaxy note', 9.14167262865968),
#               ('lenovo motorola moto', 9.092883783867),
#               ('htc desire x', 9.026326340389296),
#               ('smartphone samsung galaxy', 8.797568559258808),
#               ('nokia 6600', 8.784493598180955),
#               ('huawei ascend g610', 8.752638244316818)],
#              'erik': [('sony xperia z5', 8.6810464911392),
#               ('sony xperia z5', 8.6810464911392),
#               ('apple iphone 7', 8.554142115124591),
#               ('sony xperia tipo', 8.471733222652567),
#               ('motorola moto g', 8.42220980453251),
#               ('motorola moto g', 8.42220980453251),
#               ('samsung galaxy s4', 8.335042821650783),
#               ('samsung i9060 galaxy', 8.241036542167532),
#               ('samsung galaxy s7', 8.229094337356491),
#               ('google lg nexus', 8.019349984407256)],
#              'valeria': [('htc desire eye', 9.503890193498965),
#               ('asus zenfone 3', 8.781275647307162),
#               ('samsung n9005 galaxy', 8.767779165736805),
#               ('apple iphone 6s', 8.57425347092434),
#               ('lg g5 smartphone', 8.244234428594945),
#               ('samsung galaxy mini', 8.034797044134338),
#               ('cubot x9 smartphone', 7.868960622210834),
#               ('lenovo k6 note', 7.767092057764397),
#               ('oukitel u7 plus', 7.460412948307853),
#               ('htc one m7', 7.263437711924738)],
#              'alice': [('nokia n95', 8.911160530066022),
#               ('samsung galaxy s7', 8.756798371785512),
#               ('samsung j510 galaxy', 8.688049446221472),
#               ('samsung g935 galaxy', 8.565070897958865),
#               ('smartphone samsung galaxy', 8.47894888982957),
#               ('lg nexus 4', 8.47643038197169),
#               ('huawei p8 lite', 8.438612941493357),
#               ('sony xperia x', 8.360207958792168),
#               ('huawei p9 lite', 8.187654803207357),
#               ('huawei smartphone huawei', 8.16722544591566)],
#              'eduardo': [('samsung galaxy note', 9.744841385709835),
#               ('sony xperia pro', 9.447196832788153),
#               ('microsoft lumia 532', 8.918986849564849),
#               ('samsung galaxy mega', 8.712302758444121),
#               ('samsung galaxy j7', 8.65372889308885),
#               ('desconocido xiaomi redmi', 8.436627254341369),
#               ('lenovo motorola moto', 8.274876503353982),
#               ('samsung galaxy j5', 8.162770535385391),
#               ('microsoft lumia 640', 8.00984328833023),
#               ('samsung galaxy s7', 7.971578410840612)],
#              'paolo': [('sony xperia z3', 9.977311199852172),
#               ('samsung galaxy j5', 9.967119493408612),
#               ('samsung n9005 galaxy', 9.649676768833023),
#               ('honor 6 smartphone', 9.582894425438184),
#               ('wiko lenny 3', 9.552915754109971),
#               ('lg x screen', 9.501715361679988),
#               ('samsung e1200 telefono', 9.478053686703142),
#               ('samsung a5 2016', 9.39280996568884),
#               ('lg h340 leon', 9.372978238272395),
#               ('huawei ascend g700', 9.37162346902165)],
#              'antonio': [('lg d802 g2', 10),
#               ('huawei ascend mate', 10),
#               ('honor 6 smartphone', 10),
#               ('huawei ascend g620s', 10),
#               ('samsung ativ s', 9.930722994753841),
#               ('motorola nexus 6', 9.92635632773466),
#               ('samsung s7580 galaxy', 9.739867826817454),
#               ('samsung g3500 galaxy', 9.709643588531954),
#               ('smartphone motorola moto', 9.663879082516841),
#               ('blackberry z10 4g', 9.662454179040724)],
#              'mario': [('apple iphone 5c', 9.43745645176875),
#               ('huawei ascend mate', 9.41599468172409),
#               ('microsoft nokia 2710', 9.319018348023297),
#               ('honor 6 smartphone', 9.136263394249635),
#               ('samsung e1200 handy', 9.02834211495903),
#               ('sony xperia zl', 9.00182612069147),
#               ('sim free apple', 8.871063441397263),
#               ('samsung galaxy s4', 8.825347802155832),
#               ('lg electronics google', 8.797721937654327),
#               ('honor 7 smartphone', 8.747688374891803)],
#              'helen': [('apple iphone 7', 9.820502006664551),
#               ('apple iphone 7', 9.820502006664551),
#               ('apple iphone 7', 9.820502006664551),
#               ('apple iphone 7', 9.820502006664551),
#               ('huawei p9 lite', 9.649459462703954),
#               ('samsung galaxy s4', 9.588849837469443),
#               ('sim free alcatel', 9.28033325119026),
#               ('nokia 2720 fold', 7.707347293084299)],
#              'mary': [('htc evo 4g', 9.353098924063115),
#               ('huawei ascend w1', 9.350430034839572),
#               ('binatone the brick', 9.253021662772253),
#               ('apple iphone 6s', 9.208079186241692),
#               ('nokia lumia 730', 9.113116757413597),
#               ('nokia lumia 520', 8.999222525287351),
#               ('samsung galaxy j7', 8.772357952306933),
#               ('samsung galaxy s3', 8.720940981890614),
#               ('samsung galaxy s3', 8.720940981890614),
#               ('samsung galaxy s3', 8.720940981890614)],
#              'julia': [('huawei ascend g600', 8.401192126504558),
#               ('smartphone apple iphone', 8.377017267918452),
#               ('samsung b5722 handy', 8.126912059390376),
#               ('microsoft nokia lumia', 8.106883178094291),
#               ('microsoft nokia 6303i', 8.105517400987624),
#               ('huawei ascend p7', 8.096966213581894),
#               ('samsung wave 723', 7.93901044005499),
#               ('huawei p8 champagne', 7.910137064285072),
#               ('samsung galaxy s5', 7.6154631531961074),
#               ('samsung galaxy s5', 7.6154631531961074)],
#              'ramesh': [('samsung galaxy s6', 6.704660609546238),
#               ('htc one m8', 6.475472374142249),
#               ('asus zenfone max', 6.1895829837902685),
#               ('samsung c5212', 6.008494460898918)],
#              'julien': [('blackberry passport', 9.835506661052063),
#               ('motorola moto x', 8.963133657850326),
#               ('samsung galaxy a3', 8.915152203485565),
#               ('motorola moto g', 8.794006479455856),
#               ('samsung galaxy core', 8.752863372326793),
#               ('sony ericsson xperia', 8.589209387044932),
#               ('sony ericsson xperia', 8.589209387044932),
#               ('htc one v', 8.557488301939003),
#               ('samsung gt s5830', 8.482603643013151),
#               ('samsung galaxy s3', 8.375408712663553)],
#              'wendy': [('samsung galaxy note', 8.846243120493403),
#               ('apple iphone 7', 8.452119597550459),
#               ('apple iphone 7', 8.452119597550459),
#               ('sony xperia z', 8.390440600110402),
#               ('microsoft nokia lumia', 8.356877145416284),
#               ('apple iphone 5c', 8.186979445093536),
#               ('samsung galaxy a3', 7.8527678644522),
#               ('samsung galaxy s5', 7.413795541567733),
#               ('samsung galaxy s5', 7.413795541567733),
#               ('huawei ascend y330', 7.381401878064838)],
#              'patrick': [('honor 6 smartphone', 10),
#               ('htc desire x', 9.917029118433012),
#               ('samsung s4 mini', 9.752291773230183),
#               ('lg electronics g2', 9.705921356877393),
#               ('sony xperia s', 9.703891682707514),
#               ('honor 8 smartphone', 9.698269653131854),
#               ('huawei p8lite zwart', 9.48243210709463),
#               ('microsoft nokia 6303i', 9.472989223539702),
#               ('microsoft nokia 3720', 9.237981418740986),
#               ('samsung galaxy s7', 9.196756708682747)],
#              'lisa': [('samsung galaxy j5', 9.15910259123368),
#               ('samsung galaxy note', 9.033528380047521),
#               ('samsung galaxy note', 9.033528380047521),
#               ('vodafone smart 4', 8.77532694058462),
#               ('huawei p8 lite', 8.76138331764749),
#               ('huawei p8 lite', 8.76138331764749),
#               ('sim free samsung', 8.720941777201322),
#               ('htc one mini', 8.636025068756854),
#               ('samsung galaxy s6', 8.607623057222394),
#               ('apple smartphone iphone', 8.604187735595355)],
#              'leonardo': [('smartphone asus zenfone', 9.666973105344859),
#               ('lg g2 d800', 9.382188666878617),
#               ('samsung galaxy sii', 9.187569421123388),
#               ('smartphone motorola moto', 9.023389993503864),
#               ('huawei p8 lite', 9.004980283299611),
#               ('smartphone lg l90', 8.990378017694173),
#               ('smartphone samsung galaxy', 8.961705179340077),
#               ('smartphone samsung galaxy', 8.961705179340077),
#               ('smartphone samsung galaxy', 8.961705179340077),
#               ('samsung j710 galaxy', 8.943188405377589)],
#              'jose': [('smartphone asus zenfone', 9.426817669226322),
#               ('smartphone asus zenfone', 9.426817669226322),
#               ('huawei ascend g300', 9.346633710012917),
#               ('samsung galaxy s7', 9.035920352536035),
#               ('samsung galaxy mini', 9.032401070522864),
#               ('smartphone samsung galaxy', 8.910748204331906),
#               ('bq aquaris e5', 8.910331366470377),
#               ('motorola moto e', 8.691452907533797),
#               ('blackberry z10 4g', 8.64579877531505),
#               ('sony xperia z3', 8.632953554225377)],
#              'anã´nimo': [('smartphone asus zenfone', 10),
#               ('smartphone asus zenfone', 10),
#               ('nokia smartphone nokia', 9.141902451896412),
#               ('nokia smartphone nokia', 9.141902451896412),
#               ('smartphone samsung galaxy', 8.815147225219262),
#               ('smartphone samsung galaxy', 8.815147225219262),
#               ('smartphone samsung galaxy', 8.815147225219262),
#               ('smartphone samsung galaxy', 8.815147225219262),
#               ('smartphone samsung galaxy', 8.815147225219262),
#               ('smartphone samsung galaxy', 8.815147225219262)],
#              'joshua': [('huawei mate 8', 8.925906075059075),
#               ('sim free samsung', 8.575753372128977),
#               ('sony xperia x', 8.27294993382984),
#               ('apple iphone 5', 7.979497717024552),
#               ('tech armor samsung', 7.850100505890563),
#               ('apple iphone 6s', 7.816084184985226),
#               ('lg electronics e440', 7.318241155141408),
#               ('samsung galaxy siii', 7.30520135954667),
#               ('microsoft lumia 950', 7.2607352444834055),
#               ('asus zenfone 2', 6.965557763513779)],
#              'valerio': [('samsung a500 galaxy', 8.56390028186067),
#               ('lenovo motorola moto', 8.401291255139865),
#               ('huawei p8 lite', 8.356097131929971),
#               ('asus zenfone max', 8.245361832862441),
#               ('oukitel u7 plus', 8.222248968166026),
#               ('samsung galaxy a3', 8.198619832082198),
#               ('honor 7 smartphone', 8.068626864135709),
#               ('meizu m2 note', 8.062917211980203),
#               ('microsoft lumia 435', 8.039825180958701),
#               ('thl 2015a 4g', 7.990617740826553)],
#              'albert': [('lenovo motorola moto', 9.575022037838583),
#               ('samsung galaxy a3', 9.192250266621999),
#               ('microsoft lumia 950', 9.112625335959558),
#               ('sony ericsson xperia', 8.985468190594041),
#               ('zte blade s6', 8.936529048673327),
#               ('htc one mini', 8.816060276898348),
#               ('htc one m8', 8.641680639657103),
#               ('blackberry 9800 torch', 8.445379731251181),
#               ('sony xperia miro', 8.21488903130896),
#               ('samsung galaxy grand', 8.081264148438077)],
#              'susana': [('samsung galaxy mini', 8.61366717791756),
#               ('smartphone samsung galaxy', 8.486263696007839),
#               ('smartphone samsung galaxy', 8.486263696007839),
#               ('microsoft lumia 950', 8.180005593472265),
#               ('samsung galaxy s6', 7.809404363264533),
#               ('doogee x5 pro', 7.6901773429312215),
#               ('zte axon 7', 7.280326237418648),
#               ('doogee x5 max', 7.280080829624155),
#               ('samsung galaxy trend', 6.984034228656152),
#               ('samsung e 1270', 6.898286002766333)],
#              'd': [('sim free samsung', 9.28507378496752),
#               ('samsung galaxy note', 8.8776678216763),
#               ('samsung galaxy mini', 8.264533608291208),
#               ('microsoft nokia lumia', 8.252179619843677),
#               ('htc one m8', 8.062120870215542),
#               ('sony ericsson xperia', 7.934055124965256),
#               ('samsung galaxy s3', 7.663368560253713),
#               ('htc one sv', 7.352561996264714),
#               ('blu studio x', 7.019938963060638),
#               ('samsung t139 unlocked', 6.604355652685742)],
#              'mandy': [('nokia n95', 10),
#               ('apple iphone 7', 9.432144026381744),
#               ('apple iphone 7', 9.432144026381744),
#               ('nokia lumia 710', 8.824969081630044),
#               ('blackberry curve 8520', 8.523364258911435),
#               ('samsung galaxy grand', 8.479334479994629),
#               ('samsung galaxy s', 7.442546541788354),
#               ('apple iphone 5', 7.295786635450222),
#               ('apple iphone 4', 7.20498881299123),
#               ('microsoft nokia 515', 4.780247453474028)],
#              'tobias': [('microsoft nokia 3310', 8.980397430323361),
#               ('honor 6x smartphone', 8.719217578554634),
#               ('meizu m3 note', 8.44826801098672),
#               ('huawei p8 lite', 8.052942796313287),
#               ('huawei mate 9', 7.94495618063552),
#               ('sony xperia z', 7.881454452318051),
#               ('sony xperia z', 7.881454452318051),
#               ('sony ericsson w995', 7.434548376506672),
#               ('huawei p9 lite', 7.415650392252356),
#               ('asus zenfone 2', 7.355146836285053)],
#              'anand': [('motorola moto e', 6.980435302252467),
#               ('samsung galaxy s7', 6.773872648812958),
#               ('samsung galaxy s7', 6.773872648812958),
#               ('lenovo vibe x3', 6.75922722839262),
#               ('lenovo vibe k4', 6.6025180093620515),
#               ('zte nubia z9', 6.536915178937605),
#               ('apple iphone 5s', 6.224443652069536),
#               ('lenovo zuk z1', 6.188506493589037),
#               ('nokia 206', 6.091118991603191),
#               ('samsung galaxy j3', 6.049426122757865)],
#              'sam': [('sim free apple', 9.002217059277386),
#               ('sim free samsung', 8.98544613385236),
#               ('nokia 6303i classic', 8.942264052398208),
#               ('huawei w1 stainless', 8.87345892780809),
#               ('lg electronics d605', 8.83424448748769),
#               ('samsung galaxy s6', 8.814558792615719),
#               ('samsung galaxy s6', 8.814558792615719),
#               ('samsung galaxy s6', 8.814558792615719),
#               ('sony ericsson k550i', 8.771860094119948),
#               ('samsung galaxy s7', 8.742463864573882)],
#              'alicia': [('lg nexus 5', 7.913913730783686),
#               ('lg nexus 5', 7.913913730783686),
#               ('xiaomi redmi note', 7.383626059048853),
#               ('samsung straight talk', 7.093624113631766),
#               ('doogee 4g 64bit', 6.228889865442002),
#               ('pantech p7040 link', 6.182190925075015),
#               ('samsung galaxy j7', 6.106894617053551),
#               ('samsung galaxy note', 5.5723984722499065),
#               ('sony xperia c5', 5.442266135337836),
#               ('samsung wave y', 5.265286666123331)],
#              'charles': [('huawei ascend mate', 9.778569363837367),
#               ('lg optimus g', 9.372117486854238),
#               ('samsung galaxy note', 9.160809336946748),
#               ('microsoft nokia lumia', 8.889538547117063),
#               ('htc desire 626', 8.391529924609719),
#               ('samsung galaxy s6', 8.375230910634011),
#               ('samsung galaxy grand', 8.271740693631925),
#               ('apple iphone 4', 7.756112304933495),
#               ('samsung galaxy s', 7.322581027585526),
#               ('samsung galaxy s', 7.322581027585526)],
#              'eva': [('samsung korea galaxy', 8.565663818312562),
#               ('bq aquaris e5', 8.191109227893987),
#               ('alcatel onetouch 2004g', 7.953487093852857),
#               ('samsung galaxy j5', 7.852751414778073),
#               ('alcatel onetouch idol', 7.5198867437445305),
#               ('htc desire 500', 7.360820741784928),
#               ('apple iphone 5s', 7.232896078647577),
#               ('huawei p8 lite', 7.225362674223502),
#               ('huawei sonic u8650', 7.20734154777089),
#               ('sony mobile xperia', 7.171436738617071)],
#              'andrea': [('sim free motorola', 9.920301605346836),
#               ('apple iphone 5c', 9.861879692912227),
#               ('honor 6 smartphone', 9.698558777129552),
#               ('huawei ascend g615', 9.696925496933641),
#               ('doro phoneeasy 612', 9.680156306935302),
#               ('nokia lumia 635', 9.573827528429964),
#               ('lg electronics google', 9.540711542324262),
#               ('huawei ascend mate', 9.401882685313117),
#               ('lg leon h320', 9.39524396653175),
#               ('lg d855 g3', 9.376025336248595)],
#              'giacomo': [('lg d802 g2', 10),
#               ('lg h410 wine', 10),
#               ('samsung s6 edge', 9.95289417041582),
#               ('samsung galaxy sii', 9.431598205850916),
#               ('lg g5 smartphone', 9.274015942093264),
#               ('doro liberto 820', 9.23991860790462),
#               ('sony xperia z3', 9.22999792997415),
#               ('samsung g900 galaxy', 9.204544444641614),
#               ('huawei p8 lite', 9.029310134210979),
#               ('sony c2105 xperia', 9.011574388155436)],
#              'federica': [('samsung galaxy j5', 9.735519755593963),
#               ('samsung g800 galaxy', 9.57624976913299),
#               ('samsung a500 galaxy', 9.37873705547117),
#               ('lenovo motorola moto', 8.860567365391805),
#               ('htc desire 310', 8.776606739620002),
#               ('lg g4 smartphone', 8.509351874223979),
#               ('samsung g310 galaxy', 8.244889944052954),
#               ('sony mobile xperia', 8.112044723125255),
#               ('huawei ascend y5', 8.003624140572404),
#               ('alcatel one touch', 7.554739718595855)],
#              'filippo': [('samsung n9005 galaxy', 10),
#               ('lg electronics k8', 8.930530686235295),
#               ('cubot x9 smartphone', 8.898346938403385),
#               ('honor 4x smartphone', 8.897440058004511),
#               ('samsung galaxy s4', 8.895610979454517),
#               ('lenovo motorola moto', 8.618366757220267),
#               ('lenovo motorola moto', 8.618366757220267),
#               ('lenovo motorola moto', 8.618366757220267),
#               ('lenovo motorola moto', 8.618366757220267),
#               ('huawei p9 lite', 8.53863251630309)],
#              'sarah': [('htc desire x', 9.638053940355904),
#               ('huawei ascend g750', 9.591770910098159),
#               ('htc desire 500', 9.490462101031726),
#               ('sim free apple', 9.424208503844559),
#               ('sim free apple', 9.424208503844559),
# ...
#               ('ee alcatel one', 8.113740271590645),
#               ('sony xperia xa', 7.989770121219644),
#               ('samsung galaxy prevail', 6.885180538903564),
#               ('samsung galaxy ace', 6.4534066385400815),
#               ('motorola pebl u6', 6.013155697454153)],
#              'nik': [('lg g3 d855', 8.370562012145694),
#               ('lg optimus g', 8.368773408555493),
#               ('samsung galaxy mini', 8.166100564084722),
#               ('google nexus 5', 7.893919768374521),
#               ('apple iphone 4', 7.6242564591545054),
#               ('apple iphone 5s', 7.596698016491062),
#               ('htc one s', 7.285242897090803),
#               ('microsoft nokia c5', 6.641713347497782),
#               ('samsung galaxy s5', 6.270176916858725)],
#              'schreef': [('apple iphone 6s', 9.319188183535218),
#               ('apple iphone 7', 8.957329411626118),
#               ('apple iphone se', 8.88905856546471),
#               ('huawei y6 ii', 8.604586312748712),
#               ('samsung galaxy s6', 8.298905506139983)],
#              'robin': [('samsung galaxy note', 9.076261352176397),
#               ('sony xperia z5', 8.75006282834822),
#               ('microsoft lumia 950', 8.641801226406603),
#               ('samsung galaxy nexus', 8.3583335627347),
#               ('microsoft lumia 640', 7.950664563153687),
#               ('vodafone smart prime', 7.725506922213224),
#               ('sony ericsson w595', 7.664950197095594),
#               ('nokia 6280', 7.339252183057557),
#               ('apple iphone 4s', 7.1125500881095),
#               ('samsung galaxy j1', 6.450363062275588)],
#              'simona': [('samsung i9060i galaxy', 8.109802577292145),
#               ('samsung j320 galaxy', 8.095126157156994),
#               ('huawei p9 lite', 7.909480683283789),
#               ('huawei p9 lite', 7.909480683283789),
#               ('samsung galaxy ace', 7.645575109494085),
#               ('lg p700 l7', 7.311772732145746)],
#              'will': [('sim free sony', 9.93296581815539),
#               ('samsung galaxy note', 9.694322540516435),
#               ('samsung galaxy note', 9.694322540516435),
#               ('nokia lumia 800', 9.273743630129289),
#               ('lg optimus g', 9.255304901265912),
#               ('nokia lumia 1020', 9.055770902763053),
#               ('htc one m8', 8.964886894887066),
#               ('apple iphone 5', 8.748864387602412),
#               ('apple iphone 4', 8.629717278275521),
#               ('apple iphone 6', 8.259412211073213)],
#              'isa': [('samsung galaxy note', 8.69645842907485),
#               ('samsung galaxy j5', 8.33793391002158),
#               ('nokia lumia 630', 8.280269214728131),
#               ('sony xperia m2', 7.771822423307198),
#               ('sony ericsson aino', 7.479526116481036),
#               ('doogee x5 max', 6.848214378889355)],
#              'mm reviews': [('samsung j710 galaxy', 9.014995724490568),
#               ('huawei p9 smartphone', 8.563283446277248),
#               ('apple iphone se', 8.371050019466093),
#               ('apple iphone se', 8.371050019466093),
#               ('huawei mate s', 8.207465755365636),
#               ('zte blade v6', 7.939185657380561),
#               ('htc one a9', 7.845166726367072),
#               ('apple iphone 6', 7.633950365620802),
#               ('doogee x5 max', 7.283240016236671)],
#              'rene': [('samsung galaxy s7', 8.986386222311168),
#               ('sony xperia z2', 8.849384303312466),
#               ('huawei p8 lite', 8.833265694646128),
#               ('huawei p8 lite', 8.833265694646128),
#               ('apple iphone 7', 8.756577991580743),
#               ('samsung galaxy s3', 8.378311062495825),
#               ('nokia 8800 sirocco', 8.105650400043348),
#               ('nokia nokia lumia', 7.814537863783908),
#               ('pantech pocket p9060', 7.614149008250611),
#               ('samsung galaxy s4', 7.031584753855383)],
#              'daniela': [('sim free samsung', 9.107533143405496),
#               ('sony xperia e3', 8.645944380310661),
#               ('samsung galaxy s4', 8.545200636733444),
#               ('smartphone lg g4', 8.522719862585696),
#               ('microsoft nokia 3720', 8.420044207149608),
#               ('lg p710 l7ii', 8.24882158314607),
#               ('huawei ascend g525', 8.188334750978614),
#               ('huawei p8 lite', 8.056080213549908),
#               ('huawei p8 lite', 8.056080213549908),
#               ('samsung galaxy s7', 8.042750051384433)],
#              'kardelen': [('apple iphone 3gs', 1),
#               ('nokia 8800 arte', 1),
#               ('motorola rizr z3', 1),
#               ('nokia 2630 cep', 1),
#               ('sony ericsson k790i', 1),
#               ('nokia 6300 cep', 1),
#               ('samsung s5620 monte', 1),
#               ('nokia 5630 xpressmusic', 1),
#               ('nokia n76 cep', 1),
#               ('nokia 6500 slide', 1)],
#              'retkit': [('nokia 6131 cep', 1),
#               ('nokia 6500 slide', 1),
#               ('nokia x6 cep', 1),
#               ('apple iphone 4s', 1),
#               ('nokia 2310 cep', 1),
#               ('nokia 5800 xpressmusic', 1),
#               ('nokia n96 cep', 1),
#               ('samsung f250 cep', 1)],
#              'roman': [('microsoft nokia x7', 9.2765433925527),
#               ('blu life one', 8.695937235103479),
#               ('alcatel one touch', 8.555383194819035),
#               ('samsung g935 galaxy', 8.413231052199167),
#               ('sony xperia z', 8.187178188436155),
#               ('htc desire c', 7.6478020602109575),
#               ('samsung galaxy ace', 7.568516022623665),
#               ('sony xperia z1', 7.199632099309094),
#               ('sony xperia j', 6.960927623212764),
#               ('htc sensation smartphone', 6.5519962838053285)],
#              'sozer': [('nokia e51 cep', 1),
#               ('nokia 5800 xpressmusic', 1),
#               ('nokia 6131 cep', 1),
#               ('apple iphone 4', 1)],
#              'manuela': [('samsung e2370 handy', 10),
#               ('huawei u8860 smartphone', 10),
#               ('lenovo motorola moto', 9.12246808891406),
#               ('wiko fever 4g', 9.089511177349381),
#               ('huawei p8 lite', 9.084384753134602),
#               ('samsung i8190 galaxy', 9.010522764024033),
#               ('desconocido xiaomi redmi', 8.99922306859372),
#               ('doogee valencia2 y100', 8.706304416281684),
#               ('samsung galaxy s3', 8.563790673093745),
#               ('sony mobile xperia', 8.308426448889486)],
#              'xxx': [('samsung galaxy j5', 9.177747136175512),
#               ('samsung e1270 klapphandy', 8.395070148485134),
#               ('doogee x5 pro', 8.16757394008308),
#               ('lg g3 beat', 4.9005175341718585)],
#              'vito': [('zuk z1 smartphone', 9.641211181140465),
#               ('huawei p9 lite', 9.181430083048424),
#               ('samsung galaxy s3', 8.878031754116797),
#               ('samsung galaxy s5', 8.041914242902864),
#               ('samsung galaxy s4', 7.48939529199378),
#               ('apple iphone', 6.23032059883034)],
#              'streghe_1965': [('samsung gt e1150', 8.294338002816584),
#               ('lg optimus l3', 7.886157568272212),
#               ('apple iphone 5', 7.665051172425782),
#               ('samsung gt e1190', 7.390186457311089),
#               ('nokia 3710 fold', 5.525004667584218),
#               ('samsung b5722', 4.105083872188407)],
#              'carol': [('sony xperia z3', 10),
#               ('asus zenfone 3', 9.955461766726225),
#               ('smartphone samsung galaxy', 9.21696464103779),
#               ('samsung s5570 galaxy', 8.885711526583014),
#               ('nokia lumia 625', 8.817959761454844),
#               ('sony ericsson xperia', 8.4438083434753),
#               ('samsung galaxy s3', 7.735408849993651),
#               ('samsung galaxy s3', 7.735408849993651),
#               ('samsung t404g prepaid', 7.528092535380844),
#               ('nokia 500', 7.25665937701814)],
#              'damien': [('aicek coque samsung', 9.288044295397878),
#               ('huawei ascend g7', 9.189901025745199),
#               ('lg g2 mini', 9.082222087920655),
#               ('blackview bv6000 4g', 8.878967875828017),
#               ('acer liquid z200', 8.68543505832806),
#               ('nokia lumia 820', 8.593202230408952),
#               ('lg optimus g', 8.517014553391316),
#               ('nokia lumia 920', 8.374106523574783),
#               ('sony xperia m2', 8.330190937647822),
#               ('samsung galaxy a5', 8.168783685310018)],
#              'ronald': [('huawei p8 champagne', 9.140067021634541),
#               ('samsung galaxy exhibit', 8.97824769816437),
#               ('samsung galaxy s7', 8.614572982716108),
#               ('sony xperia s', 8.572494141142501),
#               ('blackberry torch 9860', 8.484250687994916),
#               ('motorola moto x', 8.151244357604579),
#               ('samsung galaxy a3', 8.124113961475269),
#               ('samsung galaxy s', 8.000641443471213),
#               ('huawei mate s', 7.408140804384374),
#               ('moto g plus', 7.105062312583826)],
#              'ken': [('samsung galaxy s4', 8.551514085474558),
#               ('tech armor galaxy', 8.39818248500769),
#               ('sony xperia m2', 8.249094967682286),
#               ('doro phoneeasy 410gsm', 8.06751910410446),
#               ('apple iphone 7', 8.012956462212745),
#               ('apple iphone 7', 8.012956462212745),
#               ('htc one m8', 7.95234648913286),
#               ('samsung galaxy s5', 7.705709726764284),
#               ('samsung galaxy s6', 7.702286559209143),
#               ('apple iphone 6', 7.414441196882742)],
#              'nathalie': [('huawei p10 zilver', 8.948625347491197),
#               ('lg g2 mini', 8.900637534090192),
#               ('samsung galaxy j5', 8.825900941288188),
#               ('htc one 2014', 8.675565769958142),
#               ('microsoft lumia 950', 8.521776660714947),
#               ('samsung galaxy a3', 8.250830624530556),
#               ('samsung galaxy a3', 8.250830624530556),
#               ('nokia lumia 1320', 8.206608328763325),
#               ('acer liquid z4', 7.820192046723805)],
#              'henk': [('huawei p8 champagne', 9.442647625039244),
#               ('huawei p8 champagne', 9.442647625039244),
#               ('huawei p8lite zwart', 9.2451753022479),
#               ('apple iphone 7', 9.217357390439764),
#               ('sony xperia x', 9.129826342169215),
#               ('nokia lumia 800', 9.09687658917419),
#               ('nokia lumia 800', 9.09687658917419),
#               ('sony xperia z5', 8.935188209016662),
#               ('sony xperia z5', 8.935188209016662),
#               ('huawei p8 lite', 8.705516678610053)],
#              'dolunay': [('samsung i9000 galaxy', 1),
#               ('palm treo 750', 1),
#               ('samsung galaxy fit', 1),
#               ('nokia n73 cep', 1),
#               ('nokia 6131 cep', 1),
#               ('nokia 2310 cep', 1)],
#              'mo': [('lg electronics g2', 9.235507496591174),
#               ('sony xperia z3', 9.104721776388667),
#               ('samsung galaxy s5', 7.4340272111973675),
#               ('htc one mini', 7.139548951781446)],
#              'pepe': [('motorola moto e', 8.90069682256251),
#               ('nokia lumia 925', 8.787848330411386),
#               ('huawei p8 lite', 8.766234315237934),
#               ('sony ericsson xperia', 8.629425899625208),
#               ('samsung galaxy s3', 8.327389768297007),
#               ('samsung galaxy s4', 7.937087365905753),
#               ('samsung galaxy s4', 7.937087365905753),
#               ('doogee x5 max', 7.717605041211595),
#               ('samsung galaxy ace', 7.495365860223949)],
#              'dunya': [('nokia 8800 arte', 1),
#               ('sony ericsson t715', 1),
#               ('sony ericsson c903', 1),
#               ('apple iphone 3gs', 1),
#               ('nokia e51 cep', 1)],
#              'mac reviews': [('sony xperia l', 7.3090682462133465),
#               ('samsung galaxy core', 6.829177363777487),
#               ('htc desire 310', 6.693535014196437),
#               ('samsung galaxy trend', 6.371231251160133),
#               ('samsung galaxy star', 5.89081193647174),
#               ('samsung galaxy star', 5.89081193647174),
#               ('samsung galaxy j1', 5.83264251481518),
#               ('sony xperia c', 5.726712223140568)],
#              'adriano': [('smartphone lg g2', 9.571259023376836),
#               ('huawei p8 lite', 9.102118531075869),
#               ('iphone apple iphone', 9.025528629782373),
#               ('samsung a500 galaxy', 8.771921320665962),
#               ('smartphone motorola razr', 8.62903873766464),
#               ('huawei honor 7', 8.555847813556547),
#               ('smartphone samsung galaxy', 8.544047687623321),
#               ('apple iphone 6', 8.421285233737162),
#               ('samsung galaxy ace', 8.284514565218341),
#               ('smartphone lg l70', 8.083968541746493)],
#              'santiago': [('samsung korea galaxy', 10),
#               ('nokia lumia 520', 9.842245927464695),
#               ('sony ericsson xperia', 9.104824283775862),
#               ('sony xperia l', 9.070337130133598),
#               ('motorola moto g', 9.042128180866365),
#               ('nokia lumia 630', 8.945156822274088),
#               ('huawei ascend y330', 8.184553448069378),
#               ('nokia lumia 1320', 7.761860848847227),
#               ('microsoft lumia 535', 7.524898560588104),
#               ('blackberry bold 9000', 4.002259052013455)],
#              'jr': [('sim free apple', 10),
#               ('blackberry q10 smartphone', 8.421931776959639),
#               ('zte blade s6', 8.390798476340443),
#               ('samsung galaxy s3', 7.831055659944075),
#               ('samsung galaxy s', 7.397791886245091),
#               ('samsung galaxy s', 7.397791886245091),
#               ('htc evo design', 6.947937669748167)],
#              'osmntyr': [('samsung b7722 duos', 1),
#               ('nokia 5500 sport', 1),
#               ('nokia n70 cep', 1),
#               ('nokia 5300 xpressmusic', 1),
#               ('nokia lumia 900', 1),
#               ('samsung s5233w star', 1)],
#              'tuvok': [('samsung galaxy express', 8.681280310669441),
#               ('motorola cd930', 4.0433017376048594)],
#              'karadag60': [('sony ericsson w810i', 1),
#               ('sony ericsson c903', 1),
#               ('sony ericsson w995', 1),
#               ('sony ericsson w910i', 1)],
#              'mrgreg': [('lg a290', 7.881415209559156),
#               ('samsung sgh l760', 7.390186457311089),
#               ('nokia 6120 classic', 7.319689521573168),
#               ('alcatel one touch', 7.308202938280932),
#               ('nokia asha 300', 7.2650926828513285),
#               ('nokia 105', 6.383190484310116),
#               ('motorola c650', 6.209043699465396)],
#              'kay': [('motcb moto g', 8.743432088779414),
#               ('microsoft nokia 2330', 8.44106642747834),
#               ('motorola moto g', 8.34792483952927),
#               ('lg nexus 5x', 8.202309089940105),
#               ('sony xperia z1', 7.2365582520848655),
#               ('huawei ascend y300', 6.774098757897683)],
#              'prashant': [('lenovo vibe x3', 7.460015449882464),
#               ('samsung galaxy core', 6.810316259957179),
#               ('samsung galaxy s7', 6.621030955884242),
#               ('asus zenfone max', 6.46435826923922),
#               ('microsoft lumia 535', 5.830309249299747)],
#              'naveen': [('sony xperia t2', 7.839008375618409),
#               ('lenovo vibe k4', 7.288321689982657),
#               ('lenovo vibe k4', 7.288321689982657),
#               ('google nexus 5', 7.267386681317436),
#               ('lava iris x1', 7.2258771900898235),
#               ('lg g2 d802', 7.212400442409714),
#               ('meizu m2 note', 7.181262117285021),
#               ('nokia lumia 630', 7.125057162025639),
#               ('apple iphone 5s', 6.372200016642637),
#               ('lenovo k3 note', 5.795084506990591)],
#              'mehmet': [('huawei p8 lite', 8.241036513377567)]})

# %%
## KNNWithMeans- userbased

# %%
algo_i = KNNWithMeans(k=10, sim_options={ 'user_based': True})
algo_i.fit(trainset)

test_pred=algo_i.test(testset)
print(accuracy.rmse(test_pred))

pred = pd.DataFrame(test_pred)
# pred[['uid','iid', 'r_ui','est']].sort_values(by = ['uid','r_ui','est'],ascending = False).head(10)
print("top recommended products for user based on KNN")
top_n = get_top_n(test_pred, n=10)
top_n
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 3.0518
# 3.0517901953414484
# top recommended products for user based on KNN
# defaultdict(list,
#             {'alexander': [('lg l90 d410', 9.733740710156896),
#               ('samsung nexus s', 9.503452651795786),
#               ('sony xperia s', 9.432499241267998),
#               ('blackberry bold 9780', 9.104632564370364),
#               ('htc one x', 8.98343533966499),
#               ('htc one smartphone', 8.818571683081387),
#               ('huawei ascend mate', 8.795993695797284),
#               ('honor 7 smartphone', 8.78480218022114),
#               ('nokia lumia 920', 8.644115005366027),
#               ('lenovo motorola moto', 8.541184706339369)],
#              'juan carlos': [('samsung galaxy ace', 10),
#               ('samsung galaxy ace', 10),
#               ('huawei p9 lite', 9.719324902175472),
#               ('galaxy samsung galaxy', 9.588578566735277),
#               ('samsung galaxy note', 9.424349377772906),
#               ('samsung galaxy s3', 9.267188121610644),
#               ('samsung galaxy s3', 9.267188121610644),
#               ('sony xperia p', 9.088970839805302),
#               ('lg l bello', 9.08212493628093),
#               ('bq aquaris e5', 9.019588498705852)],
#              'maria': [('sim free apple', 9.78865325806066),
#               ('sim free samsung', 9.68805967663914),
#               ('apple iphone 5', 9.596193575537027),
#               ('samsung korea samsung', 9.35315539546604),
#               ('huawei p8 lite', 9.329556823181788),
#               ('huawei p8 lite', 9.329556823181788),
#               ('samsung galaxy s3', 9.278309731657243),
#               ('samsung galaxy s3', 9.278309731657243),
#               ('samsung galaxy s3', 9.278309731657243),
#               ('doro phoneeasy 622', 9.207689566845803)],
#              'alex': [('apple iphone 4s', 10),
#               ('lg electronics p500', 10),
#               ('samsung s5360 galaxy', 10),
#               ('vodafone e1200 pay', 10),
#               ('apple iphone 4s', 10),
#               ('lg p500 optimus', 10),
#               ('huawei honor 8', 9.983380719445604),
#               ('microsoft nokia 100', 9.902218387866547),
#               ('sony xperia tx', 9.853335642687195),
#               ('apple iphone 5', 9.802899154767715)],
#              'francesco': [('huawei ascend mate', 10),
#               ('doogee smartphone dual', 10),
#               ('lg nexus 4', 9.878421733802712),
#               ('samsung galaxy ace', 9.845552082381577),
#               ('samsung j510 galaxy', 9.83219893396166),
#               ('lg k10 smartphone', 9.789529383525517),
#               ('nokia lumia 625', 9.747051807353756),
#               ('microsoft lumia 640', 9.744302639970284),
#               ('oukitel k10000 smartphone', 9.62339268730933),
#               ('lenovo moto z', 9.611777695228731)],
#              'ð\x98ñ\x80ð¸ð½ð°': [('nokia 5230 navigation', 9.926347726295793),
#               ('sony xperia z', 9.891875608232034),
#               ('sony xperia z1', 9.64988416671304),
#               ('sony xperia z1', 9.64988416671304),
#               ('samsung i9082 galaxy', 9.544253503755566),
#               ('samsung i9082 galaxy', 9.544253503755566),
#               ('samsung i9082 galaxy', 9.544253503755566),
#               ('samsung galaxy s5', 9.322899227400399),
#               ('samsung galaxy s5', 9.322899227400399),
#               ('samsung galaxy s5', 9.322899227400399)],
#              'anna': [('nokia 2310', 9.776681886627482),
#               ('samsung galaxy s5', 9.256804526829866),
#               ('samsung galaxy s5', 9.256804526829866),
#               ('htc desire 816', 9.225840479432184),
#               ('huawei ascend p7', 9.077578264351521),
#               ('huawei smartphone honor', 9.022233793493246),
#               ('huawei p9 lite', 8.859321246504038),
#               ('motorola moto g', 8.74830280696731),
#               ('motorola moto g', 8.74830280696731),
#               ('huawei p8 lite', 8.742826425588882)],
#              'kim': [('microsoft lumia 650', 10),
#               ('sony xperia z1', 9.39281036168133),
#               ('ee alcatel one', 9.294732562083048),
#               ('samsung galaxy j7', 9.200151493213435),
#               ('samsung galaxy grand', 9.193707667679588),
#               ('apple iphone 5s', 8.980456441669405),
#               ('htc flyer 7', 8.915239176312484),
#               ('huawei p8lite zwart', 8.618663003383984),
#               ('huawei p8lite zwart', 8.618663003383984),
#               ('apple iphone 6', 8.438729084520647)],
#              'ð\x92ð°ð»ðµñ\x80ð¸ð¹': [('sony xperia c', 8.16633501647346),
#               ('sony xperia c', 8.16633501647346),
#               ('htc nexus one', 8.050433600073141),
#               ('sony xperia sp', 7.691309680772545),
#               ('samsung i8150 galaxy', 7.487899766434493),
#               ('samsung galaxy s4', 6.6856045529736035),
#               ('samsung galaxy s7', 6.46069172792568),
#               ('samsung galaxy s5', 5.047569513787733),
#               ('apple iphone 5s', 4.320686222327422)],
#              'chris': [('sim free apple', 10),
#               ('lg electronics g2', 9.782498291241465),
#               ('sony xperia z3', 9.69907686760252),
#               ('htc one 32gb', 9.601541822233711),
#               ('microsoft nokia 808', 9.601015226300039),
#               ('samsung galaxy j5', 9.567176822021082),
#               ('blackberry classic smartphone', 9.450379634695313),
#               ('alcatel onetouch idol', 9.449801927594505),
#               ('apple iphone 5s', 9.445146652274119),
#               ('apple iphone 5s', 9.445146652274119)],
#              'kevin': [('sim free apple', 9.918322200515862),
#               ('sony ericsson arc', 9.909282397075035),
#               ('ringke asus zenfone', 9.805448801475467),
#               ('lenovo s8 s898t', 9.756706681764232),
#               ('huawei ascend p7', 9.730924171168043),
#               ('samsung galaxy s4', 9.58820245957465),
#               ('samsung galaxy s4', 9.58820245957465),
#               ('sony xperia z3', 9.255206212811489),
#               ('lenovo moto g4', 9.018355842419501),
#               ('lg optimus g', 8.941144413007992)],
#              'markus': [('lg electronics p500', 10),
#               ('samsung galaxy s', 9.554717832943544),
#               ('samsung galaxy s', 9.554717832943544),
#               ('samsung galaxy ace', 9.359906156940683),
#               ('sony ericsson w595', 9.35262714180202),
#               ('motorola nexus 6', 9.240298180062892),
#               ('sony xperia z1', 9.118715597925839),
#               ('sony xperia z5', 9.082980178814081),
#               ('microsoft nokia 2220', 8.999852098842272),
#               ('samsung galaxy s4', 8.967691009615715)],
#              'silvia': [('lenovo motorola k1', 10),
#               ('asus zenfone 2', 9.874716484101578),
#               ('asus zenfone 2', 9.874716484101578),
#               ('alcatel one touch', 9.22205373318208),
#               ('huawei p9 lite', 8.992626194577188),
#               ('huawei p9 lite', 8.992626194577188),
#               ('samsung ativ s', 8.963267702233132),
#               ('zte axon 7', 8.772570154052662),
#               ('htc one m8', 8.461214975216132),
#               ('samsung galaxy j5', 8.415767322226914)],
#              'david': [('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('lg 530g prepaid', 10),
#               ('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('nokia 6210', 10),
#               ('lg electronics l7', 10),
#               ('samsung galaxy s6', 10),
#               ('motorola moto e', 9.932343366267705),
#               ('motorola moto e', 9.932343366267705)],
#              'ð\x93ð¾ñ\x81ñ\x82ñ\x8c': [('nokia c6', 9.311852117411881),
#               ('nokia 5130 xpressmusic', 8.943384721018163),
#               ('sony ericsson xperia', 8.827282263109165),
#               ('sony ericsson x10', 8.566373429103598),
#               ('samsung galaxy j7', 8.267024834164017),
#               ('apple iphone 3gs', 7.541479238928887),
#               ('htc windows phone', 7.410068534029094),
#               ('nokia 5530 xpressmusic', 6.956394353857215),
#               ('nokia 6303i classic', 6.423305024208396),
#               ('nokia 6303i classic', 6.423305024208396)],
#              'salvatore': [('huawei p9 lite', 10),
#               ('sony xperia z1', 9.766141962378521),
#               ('huawei ascend g6', 9.685414260424409),
#               ('lg h410 wine', 9.656783346624888),
#               ('huawei ascend g700', 9.6463882300563),
#               ('nokia lumia 735', 9.579571231977495),
#               ('lenovo motorola moto', 9.547483951865424),
#               ('huawei mate 8', 9.531387200228775),
#               ('doogee x6 pro', 9.527658810835005),
#               ('huawei ascend y550', 9.461426577324914)],
#              'no captured': [('lenovo s860', 10),
#               ('nokia 7210', 10),
#               ('nokia 6125', 10),
#               ('lenovo s860', 10),
#               ('lenovo s860', 10),
#               ('siemens s45', 10),
#               ('siemens a55', 10),
#               ('sony ericsson p800', 10),
#               ('lenovo s860', 10),
#               ('samsung e2120', 10)],
#              'amazon customer': [('motorola tundra va76r', 9.877741592928686),
#               ('motorola tundra va76r', 9.877741592928686),
#               ('doogee dagger dg550', 9.845491671921977),
#               ('nokia 1208 sim', 9.831802955290929),
#               ('samsung galaxy gs7', 9.815866300755705),
#               ('samsung galaxy gs7', 9.815866300755705),
#               ('lg electronics p710', 9.764563942846964),
#               ('motorola v197 unlocked', 9.668917531524768),
#               ('motorola v197 unlocked', 9.668917531524768),
#               ('samsung galaxy nexus', 9.668700593336801)],
#              'marie': [('samsung galaxy j7', 9.426583925710576),
#               ('htc incredible s', 9.379760743065475),
#               ('motorola moto e', 9.185358255058148),
#               ('apple iphone 6s', 9.175009389100842),
#               ('apple iphone 6s', 9.175009389100842),
#               ('samsung galaxy a3', 9.149865337077891),
#               ('samsung galaxy grand', 9.06795689150897),
#               ('apple iphone 7', 9.057632270455212),
#               ('samsung galaxy y', 8.995912479384987),
#               ('samsung galaxy y', 8.995912479384987)],
#              'james': [('sim free apple', 9.922795835839754),
#               ('samsung galaxy note', 9.240863255747145),
#               ('huawei honor 8', 9.139468531149218),
#               ('sim free motorola', 9.10020563923678),
#               ('samsung galaxy j7', 9.060286602872905),
#               ('huawei p8 lite', 8.88019376573587),
#               ('samsung galaxy s3', 8.843510765590855),
#               ('htc droid dna', 8.768348161962429),
#               ('zte axon 7', 8.720921904473002),
#               ('samsung galaxy s', 8.687473001161276)],
#              'pascal': [('samsung e1190 sim', 10),
#               ('samsung galaxy j5', 9.75836419425561),
#               ('sony mobile xperia', 9.691006909240725),
#               ('tech armor samsung', 9.530151858188269),
#               ('nokia lumia 625', 9.319867898688273),
#               ('lg gt540', 9.197402597402597),
#               ('lg ku990 viewty', 9.18568386556726),
#               ('samsung galaxy s7', 8.91715767513502),
#               ('samsung galaxy s7', 8.91715767513502),
#               ('htc one m8s', 8.784581719441476)],
#              'valentina': [('samsung a500 galaxy', 10),
#               ('samsung a300 galaxy', 10),
#               ('samsung s7580 galaxy', 10),
#               ('lenovo motorola moto', 10),
#               ('huawei p8 lite', 10),
#               ('huawei p9 lite', 10),
#               ('samsung galaxy j5', 10),
#               ('samsung galaxy s7', 10),
#               ('lg g4 smartphone', 9.5706624668941),
#               ('samsung g800 galaxy', 9.553387552010706)],
#              'sabrina': [('apple iphone 4s', 10),
#               ('motorola moto g', 9.52276511226891),
#               ('samsung i9301 galaxy', 9.522062106989624),
#               ('lg d722 g3', 9.364031707371566),
#               ('samsung galaxy s5', 9.1744103256232),
#               ('smartphone asus zenfone', 8.99261541301288),
#               ('huawei ascend p6', 8.831237142697644),
#               ('sony ericsson k770i', 8.10060341017661),
#               ('samsung galaxy trend', 7.817680377210108),
#               ('samsung galaxy y', 7.773942249314648)],
#              'simone': [('wiko fever 4g', 9.866389918217298),
#               ('microsoft nokia 7230', 9.697549775188254),
#               ('asus zenfone 2', 9.652022679932783),
#               ('asus zenfone 3', 9.602226766263133),
#               ('huawei ascend p1', 9.583868260188488),
#               ('samsung galaxy w', 9.56129045180204),
#               ('asus zenfone 5', 9.481300304801989),
#               ('asus zenfone 5', 9.481300304801989),
#               ('huawei ascend g7', 9.447684493813178),
#               ('lenovo motorola moto', 9.444843751011975)],
#              'amazon kunde': [('cat b15 smartphone', 9.896273944116016),
#               ('honor 6x smartphone', 9.571880781354132),
#               ('honor 6x smartphone', 9.571880781354132),
#               ('honor 6x smartphone', 9.571880781354132),
#               ('honor 6x smartphone', 9.571880781354132),
#               ('yota yotaphone 2', 9.450404227606509),
#               ('honor 6 plus', 9.35611820262151),
#               ('sony xperia x', 9.20628542206951),
#               ('zte axon 7', 9.106412181484442),
#               ('zte axon 7', 9.106412181484442)],
#              'jean': [('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('samsung galaxy mini', 10),
#               ('lg optimus l7', 9.627972960203696),
#               ('samsung galaxy s7', 9.530890594999056),
#               ('htc sensation sim', 9.359089785233762),
#               ('nokia lumia 625', 9.071585433314263),
#               ('smartphone alcatel one', 9.034858994161201),
#               ('lg optimus g', 8.827289719742447)],
#              'valerio': [('samsung galaxy a3', 10),
#               ('samsung ativ s', 9.864281374706705),
#               ('lenovo motorola moto', 9.756014387406683),
#               ('huawei p8 lite', 9.554879410042453),
#               ('samsung galaxy j5', 9.244861735565076),
#               ('samsung galaxy note', 9.060577931001847),
#               ('huawei p9 plus', 8.883727932188489),
#               ('xiaomi hongmi 1s', 8.566668293739696),
#               ('sony xperia x', 7.858019075349567),
#               ('samsung galaxy sii', 7.705879725132139)],
#              'zã¡kaznã\xadk': [('samsung galaxy s5', 10),
#               ('nokia lumia 630', 10),
#               ('samsung galaxy s5', 10),
#               ('samsung galaxy s5', 10),
#               ('samsung galaxy s6', 9.986416152205056),
#               ('samsung galaxy s6', 9.986416152205056),
#               ('samsung galaxy s6', 9.986416152205056),
#               ('samsung galaxy s6', 9.986416152205056),
#               ('samsung galaxy s6', 9.986416152205056),
#               ('nokia lumia 625', 9.943902435604118)],
#              'john': [('doogee dagger dg550', 10),
#               ('samsung korea samsung', 9.675388058701655),
#               ('microsoft nokia lumia', 9.671986083953229),
#               ('sim free apple', 9.65634565832151),
#               ('sony xperia e3', 9.614941011680534),
#               ('asus zenfone max', 9.482798846832068),
#               ('apple iphone 4', 9.476586911968065),
#               ('apple iphone 4', 9.476586911968065),
#               ('apple iphone 4', 9.476586911968065),
#               ('apple iphone 6', 9.355714627238974)],
#              'manish': [('huawei nexus 6p', 8.851652922664877),
#               ('apple iphone 5s', 8.601334333208174),
#               ('huawei honor 8', 8.359791335811272),
#               ('motorola moto g', 8.239647605321181),
#               ('micromax canvas turbo', 7.963527477166853),
#               ('nokia lumia 530', 7.950457723836034),
#               ('lenovo k900 32gb', 7.732074043490228),
#               ('samsung galaxy a8', 7.583643342844389),
#               ('apple iphone 6', 7.127215680378005),
#               ('apple iphone 6', 7.127215680378005)],
#              'angel': [('samsung galaxy ace', 9.889758411280098),
#               ('samsung galaxy ace', 9.889758411280098),
#               ('nokia lumia 625', 9.501306153050912),
#               ('microsoft lumia 640', 9.391308568407586),
#               ('lg optimus g', 9.281347855924531),
#               ('sony ericsson xperia', 9.26228645601462),
#               ('apple iphone 5c', 9.10298928145487),
#               ('lg g3 d855', 8.82177865064365),
#               ('bq aquaris 5', 8.753069900603768),
#               ('samsung galaxy core', 8.70904044534411)],
#              'sandy': [('microsoft nokia 6303i', 8.913540571826157),
#               ('samsung galaxy centura', 8.868086282190015),
#               ('nokia n9 unlocked', 8.858837347470882),
#               ('samsung galaxy s7', 8.772522286531744),
#               ('tech armor galaxy', 8.705268492359487),
#               ('lg google nexus', 8.615756766062425),
#               ('nokia lumia 520', 8.480427071337402),
#               ('tudia zenfone 3', 8.389282520716678),
#               ('lenovo vibe k4', 8.19424754511383),
#               ('samsung galaxy alpha', 8.146593724397462)],
#              'angelo': [('samsung galaxy note', 10),
#               ('apple iphone 5c', 10),
#               ('sony xperia z3', 9.751721874309496),
#               ('sony xperia z3', 9.751721874309496),
#               ('lg h410 wine', 9.733125034034975),
#               ('samsung n9005 galaxy', 9.713069769889701),
#               ('wiko fever 4g', 9.673546693765926),
#               ('motorola v3 sim', 9.645238956138543),
#               ('lg k10 smartphone', 9.638269397206473),
#               ('samsung g920 galaxy', 9.30038779372814)],
#              'prashant': [('lenovo vibe x3', 8.054897396845242),
#               ('htc desire 816', 7.6882887668639865),
#               ('asus zenfone max', 7.657395887709118),
#               ('meizu m1 note', 7.367727832947753),
#               ('google nexus 5', 7.212707736240126),
#               ('asus zenfone 2', 7.0611910337888055),
#               ('samsung galaxy s6', 6.780199415175274),
#               ('blackberry bold 9790', 6.757276181577029),
#               ('sony xperia t2', 6.7148562374144065),
#               ('samsung galaxy j7', 6.669769029471701)],
#              'ð\x92ð¸ðºñ\x82ð¾ñ\x80ð¸ñ\x8f': [('sony xperia m',
#                9.382820663253467),
#               ('sony xperia l', 8.99001182898941),
#               ('samsung galaxy s4', 8.636788860823273),
#               ('apple iphone se', 8.454346176567825),
#               ('samsung galaxy s5', 8.409565596328553),
#               ('samsung galaxy s5', 8.409565596328553),
#               ('samsung galaxy s5', 8.409565596328553),
#               ('samsung galaxy s5', 8.409565596328553),
#               ('nokia 5230 xpressmusic', 7.725715019280948),
#               ('htc desire 620g', 7.68855533660777)],
#              'eli': [('doogee dagger dg550', 10),
#               ('samsung galaxy s7', 9.645850221762355),
#               ('huawei p8 lite', 8.803615048847146),
#               ('smartphone lg l90', 8.742165355358287),
#               ('nokia lumia 800', 8.474150221941791),
#               ('samsung galaxy core', 7.922976914250446),
#               ('samsung t404g prepaid', 7.831716299929294),
#               ('motorola verizon motorola', 6.576438998130997),
#               ('asus zenfone 2', 6.029002564811075)],
#              'andrea': [('lenovo motorola k1', 10),
#               ('doro phoneeasy 612', 9.839328945722217),
#               ('apple iphone 7', 9.6290065222206),
#               ('wiko fever 4g', 9.523378186013876),
#               ('wiko fever 4g', 9.523378186013876),
#               ('tudia zenfone 3', 9.472708203232179),
#               ('asus zenfone 3', 9.435530097482468),
#               ('nokia lumia 735', 9.434563927986234),
#               ('samsung j510 galaxy', 9.424740434487777),
#               ('huawei ascend g750', 9.410982118199483)],
#              'ð\x90ð»ðµðºñ\x81ð°ð½ð´ñ\x80': [('samsung i8190 galaxy',
#                9.746426597933567),
#               ('samsung i8190 galaxy', 9.746426597933567),
#               ('sony xperia m', 9.474805400201687),
#               ('sony xperia m', 9.474805400201687),
#               ('samsung galaxy a7', 9.453359642412615),
#               ('nokia n95', 9.22179539012559),
#               ('samsung s5570 galaxy', 9.22102176291372),
#               ('sony xperia sp', 9.069177752233106),
#               ('sony xperia tx', 8.92668741112043),
#               ('lg optimus l7', 8.533126873022086)],
#              'anonymous': [('iphone 5s 16', 10),
#               ('iphone 5s 16', 10),
#               ('nokia n900 black', 10),
#               ('nokia 2690', 9.934653600517548),
#               ('motorola rokr e1', 9.91832560739594),
#               ('apple iphone 7', 9.8),
#               ('apple iphone 7', 9.8),
#               ('apple iphone 7', 9.8),
#               ('samsung galaxy s7', 9.8),
#               ('apple iphone 7', 9.8)],
#              'alexandre': [('lg a290', 9.933776536054161),
#               ('nokia lumia 520', 9.800562001316953),
#               ('smartphone lg l90', 9.405874145180123),
#               ('microsoft lumia 435', 9.047696856334088),
#               ('samsung wave m', 8.988951879560858),
#               ('celular desbloqueado samsung', 8.957544936328041),
#               ('smartphone samsung galaxy', 8.295375003139219),
#               ('nokia lumia 530', 8.063571958783546),
#               ('samsung galaxy s6', 8.063543300407138),
#               ('samsung galaxy s', 7.927371241654497)],
#              'eva': [('samsung galaxy note', 9.338235113524917),
#               ('htc desire 500', 8.510391753910621),
#               ('microsoft lumia 640', 8.373967121232532),
#               ('htc windows phone', 8.187963878768056),
#               ('smartphone lg optimus', 8.122870784727377),
#               ('samsung galaxy s5', 8.106263984945905),
#               ('huawei ascend y201', 7.753131223337499),
#               ('samsung galaxy s7', 7.714807480080959),
#               ('samsung j320 galaxy', 7.471614069109636),
#               ('asus zenfone go', 7.322739852220487)],
#              'cliente amazon': [('lenovo motorola k1', 10),
#               ('acer liquid z520', 9.751439432296618),
#               ('acer liquid z520', 9.751439432296618),
#               ('lg g3 s', 9.453286288797145),
#               ('motorola nexus 6', 9.39034564638128),
#               ('acer liquid jade', 9.37966826986545),
#               ('desconocido xiaomi red', 9.309312479419948),
#               ('desconocido xiaomi red', 9.309312479419948),
#               ('alcatel pop c7', 9.279158286831638),
#               ('lg x screen', 9.267226779277602)],
#              'nicolas': [('htc 8x unlocked', 9.727796243351946),
#               ('nokia lumia 930', 9.702483066003385),
#               ('sony ericsson xperia', 9.496202352328941),
#               ('apple iphone 4s', 9.474526839275551),
#               ('samsung galaxy j7', 9.413761075519295),
#               ('sony ericsson z610i', 9.40835609477228),
#               ('htc one m8', 9.305605420460063),
#               ('samsung galaxy mega', 9.228869590231412),
#               ('sony xperia z3', 9.070635556660674),
#               ('samsung galaxy a5', 9.057478749662698)],
#              'mike': [('htc one 32gb', 10),
#               ('motorola moto g', 9.989091758486316),
#               ('samsung galaxy j5', 9.98313956399161),
#               ('samsung galaxy j5', 9.98313956399161),
#               ('sim free apple', 9.98276763182164),
#               ('sim free apple', 9.98276763182164),
#               ('spigen neo hybrid', 9.956257600730405),
#               ('motorola moto x', 9.733394569862197),
#               ('sony xperia z', 9.6937617124191),
#               ('samsung galaxy note', 9.604345320971284)],
#              'andreas': [('nokia 3230', 10),
#               ('htc one dual', 10),
#               ('lg electronics g', 9.571778679343218),
#               ('sony xperia z1', 9.261916149303214),
#               ('sony xperia z1', 9.261916149303214),
#               ('sony xperia z2', 9.158636331885177),
#               ('samsung galaxy s7', 8.964259554468148),
#               ('samsung galaxy s7', 8.964259554468148),
#               ('sony ericsson xperia', 8.862164817221405),
#               ('sony ericsson xperia', 8.862164817221405)],
#              'stefan': [('microsoft lumia 650', 10),
#               ('microsoft lumia 640', 9.877659525826063),
#               ('samsung galaxy note', 9.749581300502715),
#               ('sony xperia xz', 9.746531841699964),
#               ('microsoft nokia 100', 9.591777483448096),
#               ('lenovo motorola razr', 9.579661640207156),
#               ('sony xperia xcompact', 9.536903033194722),
#               ('lg electronics e400', 9.48481676145795),
#               ('samsung galaxy s3', 9.410166827964606),
#               ('blackberry classic smartphone', 9.320505420325027)],
#              'ð\x9fð¾ð»ñ\x8cð·ð¾ð²ð°ñ\x82ðµð»ñ\x8c ñ\x81ðºñ\x80ñ\x8bð» ñ\x81ð²ð¾ð¸ ð´ð°ð½ð½ñ\x8bðµ': [('microsoft lumia 650',
#                10),
#               ('blackberry passport', 9.764439348132461),
#               ('asus zenfone 3', 9.694927577585387),
#               ('apple iphone 6', 9.468107722452382),
#               ('apple iphone 6', 9.468107722452382),
#               ('samsung galaxy j5', 9.273548961096138),
#               ('apple iphone 7', 9.125622875471906),
#               ('apple iphone 7', 9.125622875471906),
#               ('huawei honor 4x', 9.054299669785426),
#               ('microsoft lumia 950', 8.987299535618327)],
#              'jose': [('sony xperia p', 9.710038740697982),
#               ('smartphone samsung galaxy', 9.580724120346762),
#               ('smartphone samsung galaxy', 9.580724120346762),
#               ('smartphone samsung galaxy', 9.580724120346762),
#               ('motorola moto x', 9.513303929359184),
#               ('asus zenfone 2', 9.475048538763893),
#               ('lenovo motorola moto', 9.4487169359935),
#               ('lenovo motorola moto', 9.4487169359935),
#               ('blackberry bold 9900', 9.381588787460704),
#               ('samsung galaxy s6', 9.275028885734098)],
#              'antonio': [('microsoft lumia 640', 9.927645050820914),
#               ('microsoft lumia 640', 9.927645050820914),
#               ('doro phoneeasy 612', 9.886733094187461),
#               ('apple iphone 5', 9.866281601009227),
#               ('nokia lumia 520', 9.722383258983902),
#               ('nokia lumia 520', 9.722383258983902),
#               ('nokia lumia 520', 9.722383258983902),
#               ('samsung s7580 galaxy', 9.616124687697587),
#               ('samsung ativ s', 9.600408565390243),
#               ('samsung a5 2016', 9.593561083774098)],
#              'anonieme bezoeker': [('lg e610 optimus', 9.052560358076624),
#               ('nokia lumia 920', 8.944535018132152),
#               ('htc desire c', 8.465875216725625),
#               ('htc desire c', 8.465875216725625),
#               ('htc desire c', 8.465875216725625),
#               ('htc desire c', 8.465875216725625),
#               ('blackberry bold 9900', 8.0649376041397),
#               ('htc desire x', 8.022512695103742),
#               ('samsung galaxy s', 7.994180285932523),
#               ('samsung galaxy s4', 7.9)],
#              'toni': [('samsung i9301 galaxy', 10),
#               ('samsung galaxy note', 10),
#               ('sim free samsung', 9.816974870485234),
#               ('microsoft lumia 640', 9.768300414201926),
#               ('asus zenfone selfie', 9.3238898621405),
#               ('nokia lumia 625', 9.281971987582978),
#               ('zte axon 7', 9.250740820268897),
#               ('lg spirit 4g', 8.79084958895731),
#               ('samsung galaxy s4', 8.480483027615799),
#               ('apple iphone 5s', 8.44354950149329)],
#              'lukas': [('samsung galaxy s5', 9.755145415977484),
#               ('htc one smartphone', 9.293355361442773),
#               ('microsoft nokia lumia', 9.255433441469615),
#               ('samsung galaxy note', 9.092192266213434),
#               ('samsung galaxy note', 9.092192266213434),
#               ('microsoft lumia 640', 8.8244769109053),
#               ('huawei u8860 smartphone', 8.64437282162743),
#               ('huawei p8 champagne', 8.374454068910639),
#               ('samsung galaxy s6', 8.20129892576634),
#               ('samsung b2100 outdoor', 8.09759753466004)],
#              'anthony': [('apple iphone 7', 9.503343970092839),
#               ('apple iphone 7', 9.503343970092839),
#               ('apple iphone 7', 9.503343970092839),
#               ('apple iphone 7', 9.503343970092839),
#               ('apple iphone 7', 9.503343970092839),
#               ('apple iphone 6s', 9.470410792709494),
#               ('samsung galaxy a5', 9.407428273590737),
#               ('lg optimus g', 9.288361124731413),
#               ('sony xperia x', 9.286485746896517),
#               ('sony mobile xperia', 9.091370809252863)],
#              'pedro': [('htc one m8', 9.740033271801055),
#               ('alcatel pop c7', 9.494171817583648),
#               ('sony xperia z3', 9.351195337286551),
#               ('motorola moto g', 9.335858786752166),
#               ('motorola moto g', 9.335858786752166),
#               ('motorola moto g', 9.335858786752166),
#               ('blackberry z10 uk', 9.102169912388607),
#               ('huawei p8 lite', 9.038167879195695),
#               ('smartphone lg g2', 9.011076727465921),
#               ('sony xperia z1', 8.933550265970686)],
#              'ð\xa0ð¾ð¼ð°ð½': [('sony xperia tx', 9.579988060796467),
#               ('nokia lumia 720', 8.656019864966819),
#               ('motorola defy', 8.507939000633746),
#               ('xiaomi mi4i 16gb', 8.429447156594035),
#               ('nokia 101 premium', 8.375037100720833),
#               ('sony xperia z1', 8.350679196673013),
#               ('sony xperia z1', 8.350679196673013),
#               ('sony xperia z1', 8.350679196673013),
#               ('sony xperia z1', 8.350679196673013),
#               ('sony xperia z', 8.229567000000552)],
#              'jack': [('sony ericsson p900', 10),
#               ('samsung galaxy j5', 9.492747191337806),
#               ('sony sony xperia', 9.375066072582644),
#               ('samsung galaxy j2', 9.255386073026235),
#               ('lg g5 h850', 9.182958612283649),
#               ('samsung galaxy s7', 8.763727631413076),
#               ('samsung galaxy s7', 8.763727631413076),
#               ('samsung galaxy s7', 8.763727631413076),
#               ('samsung galaxy s7', 8.763727631413076),
#               ('nokia 808 pureview', 8.669988820601237)],
#              'pasquale': [('lg d802 g2', 10),
#               ('nokia lumia 520', 10),
#               ('lenovo motorola moto', 10),
#               ('huawei p8 lite', 9.811593925545539),
#               ('huawei ascend y550', 9.437491286429916),
#               ('motorola moto g', 9.086803231624366),
#               ('samsung a700 galaxy', 8.936109744800454),
#               ('alcatel one touch', 8.930167546506357),
#               ('asus zenfone 2', 8.7844334230244),
#               ('huawei ascend y5', 8.604002136510712)],
#              'mar': [('motorola moto g', 9.111178134392185),
#               ('huawei p8 lite', 8.562754798145704),
#               ('samsung galaxy j5', 8.445134155565603),
#               ('htc evo 4g', 7.7149459771615945),
#               ('huawei ascend g730', 7.676920833779781),
#               ('lg optimus hub', 7.366498993385772),
#               ('lg optimus f3', 6.820113103080437),
#               ('samsung galaxy s7', 6.464347399748957),
#               ('nokia 6500 slide', 6.313937798249223),
#               ('motorola droid 3', 6.238560927024535)],
#              'philipp': [('samsung galaxy s5', 8.957943745985657),
#               ('nokia 3250', 8.720644956904197),
#               ('sony ericsson s500i', 8.445645148216308),
#               ('huawei ascend p6', 8.160789508496116),
#               ('blackberry q5 smartphone', 8.057243146534107),
#               ('acer liquid e1', 8.032065493634583),
#               ('sony ericsson xperia', 7.892070219283738),
#               ('honor 7 smartphone', 7.862716375178307),
#               ('apple iphone 4', 7.313025798284038),
#               ('microsoft lumia 550', 3.6521420173911054)],
#              'paul': [('asus padfone x', 10),
#               ('sim free iphone', 10),
#               ('microsoft nokia 100', 10),
#               ('samsung galaxy s5', 9.917921970332182),
#               ('samsung galaxy s5', 9.917921970332182),
#               ('nokia 1208 sim', 9.82804862431702),
#               ('motorola moto x', 9.729195177997006),
#               ('sim free apple', 9.676376225999674),
#               ('sim free apple', 9.676376225999674),
#               ('zte axon 7', 9.501176588471171)],
#              'roberto': [('samsung galaxy gs7', 10),
#               ('apple iphone 4s', 10),
#               ('huawei p9 plus', 9.757785522035693),
#               ('motorola moto x', 9.738267590810505),
#               ('motorola moto g', 9.653321346454346),
#               ('huawei ascend mate', 9.599202676639933),
#               ('meizu pro 5', 9.535749134319996),
#               ('microsoft lumia 550', 9.472186721751648),
#               ('nokia lumia 520', 9.464170473202135),
#               ('nokia lumia 735', 9.453889760449627)],
#              'wendy': [('samsung galaxy s', 9.546689895379945),
#               ('samsung tocco lite', 9.545134111650702),
#               ('sony xperia z', 9.495407363726514),
#               ('samsung galaxy note', 9.491079605828464),
#               ('samsung galaxy note', 9.491079605828464),
#               ('samsung galaxy note', 9.491079605828464),
#               ('lenovo motorola razr', 9.008549945876169),
#               ('huawei p8 lite', 8.860726106305934),
#               ('htc wildfire s', 8.696809770241318),
#               ('samsung galaxy ace', 8.124151985428528)],
#              'ð\x90ð½ð´ñ\x80ðµð¹': [('sony xperia zr', 9.319001095731243),
#               ('samsung n9000 galaxy', 9.059640428729734),
#               ('huawei ascend p6', 8.934346323643405),
#               ('lg optimus l7', 8.796053945060002),
#               ('sony xperia tx', 8.594693879224799),
#               ('samsung galaxy s7', 8.532107127322439),
#               ('lg nexus 4', 8.479167929752528),
#               ('samsung galaxy a5', 8.340116469889097),
#               ('samsung galaxy a5', 8.340116469889097),
#               ('lg optimus l4', 8.270535006518417)],
#              'fernando': [('smartphone asus zenfone', 9.898018332414619),
#               ('zte axon 7', 9.837055775391223),
#               ('lg electronics g2', 9.673011016936819),
#               ('samsung galaxy s7', 9.630413419314047),
#               ('nokia lumia 625', 9.445708701488154),
#               ('huawei ascend g300', 9.301310448527122),
#               ('bq aquaris e5', 9.263193579643653),
#               ('asus zenfone 2', 9.177815446586418),
#               ('samsung galaxy grand', 9.094637883744996),
#               ('apple iphone 5', 9.045570112161673)],
#              'mark': [('samsung galaxy note', 9.770825760652233),
#               ('samsung galaxy note', 9.770825760652233),
#               ('apple iphone 5s', 9.568042836573328),
#               ('zte axon 7', 9.554737517733805),
#               ('zte axon 7', 9.554737517733805),
#               ('lenovo motorola moto', 9.551596944754703),
#               ('motorola google nexus', 9.376502744155129),
#               ('samsung galaxy a3', 9.268858556665972),
#               ('huawei honor 8', 9.260288986975127),
#               ('sim free sony', 9.231012265362466)],
#              'rachel': [('apple iphone 6s', 9.472280243383139),
#               ('apple iphone 6', 9.428214896261307),
#               ('sim free iphone', 9.204741592952297),
#               ('samsung galaxy j7', 9.180437648094037),
#               ('asus zenfone max', 9.03819113563755),
#               ('samsung galaxy grand', 8.967429574230483),
#               ('htc desire 816', 8.709570579361253),
#               ('lenovo motorola moto', 8.158516982110449),
#               ('lg vx9200 env3', 8.10106732989456),
#               ('samsung galaxy s5', 7.950113378684807)],
#              'laura': [('apple iphone 4s', 10),
#               ('apple iphone 4s', 10),
#               ('lenovo motorola moto', 9.516886543251152),
#               ('apple iphone 6', 9.424026952874643),
#               ('samsung galaxy s5', 9.377068717256922),
#               ('samsung galaxy s5', 9.377068717256922),
#               ('sim free samsung', 9.33500079797461),
#               ('asus zenfone max', 9.293379488902355),
#               ('asus zenfone max', 9.293379488902355),
#               ('samsung galaxy a5', 9.184860121417252)],
#              'incesaz': [('nokia n97 mini', 1),
#               ('apple iphone 3g', 1),
#               ('nokia 2630 cep', 1),
#               ('nokia 6500 slide', 1),
#               ('sony ericsson k850i', 1),
#               ('sony ericsson w995', 1),
#               ('samsung e250 cep', 1)],
#              'wolfgang': [('blackberry passport smartphone',
#                8.710930103112553),
#               ('microsoft nokia lumia', 8.397938905188234),
#               ('htc one mini', 8.174972655921689),
#               ('samsung galaxy s', 7.982963003831378),
#               ('samsung galaxy s', 7.982963003831378),
#               ('apple iphone 6', 7.911359360807201),
#               ('microsoft nokia e51', 7.876163073049845),
#               ('honor 6 smartphone', 7.863747730248216),
#               ('lg electronics l40', 7.842135915331875),
#               ('huawei ascend g750', 7.37166914904533)],
#              'manu': [('samsung galaxy j5', 9.621817451787017),
#               ('microsoft lumia 640', 9.546463300552315),
#               ('microsoft lumia 640', 9.546463300552315),
#               ('sony xperia s', 9.364306048248674),
#               ('samsung galaxy s3', 9.357634705764433),
#               ('samsung galaxy s3', 9.357634705764433),
#               ('lg nexus 5x', 9.159904120375096),
#               ('wiko fever 4g', 9.075388351510853),
#               ('lenovo motorola moto', 8.72417944302152),
#               ('nokia 5130 xpressmusic', 8.64786656424138)],
#              'rick2809': [('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone microsoft lumia', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone motorola moto', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone samsung galaxy', 10)],
#              'gianfranco': [('huawei p9 lite', 10),
#               ('huawei p9 lite', 10),
#               ('alcatel one touch', 10),
#               ('honor 7 smartphone', 10),
#               ('alcatel pixi 4', 9.801060797277723),
#               ('alcatel pixi 4', 9.801060797277723),
#               ('sony e5603 xperia', 9.73019564616068),
#               ('nokia asha 305', 8.495976217741498),
#               ('nokia asha 501', 8.463554880545221),
#               ('lenovo zuk z1', 8.44350609355325)],
#              "client d'amazon": [('blackberry priv smartphone',
#                9.719601172309288),
#               ('meizu pro 5', 9.334373271879294),
#               ('apple iphone se', 9.303817096344744),
#               ('apple iphone se', 9.303817096344744),
#               ('apple iphone se', 9.303817096344744),
#               ('huawei mate 9', 9.252981283307244),
#               ('huawei mate 9', 9.252981283307244),
#               ('samsung galaxy j7', 9.1284883240579),
#               ('nokia microsoft lumia', 9.123624491368645),
#               ('nokia microsoft lumia', 9.123624491368645)],
#              'juan': [('samsung galaxy s3', 9.4775409384897),
#               ('lg nexus 5x', 9.355714795204829),
#               ('lg nexus 5x', 9.355714795204829),
#               ('nokia lumia 520', 9.22698322505999),
#               ('htc one m8', 8.977976737409705),
#               ('motorola moto g', 8.749937520934417),
#               ('samsung galaxy s6', 8.733357089258753),
#               ('lenovo motorola moto', 8.608657272434673),
#               ('samsung galaxy j7', 8.578269296044848),
#               ('sony xperia tipo', 8.385288159209416)],
#              'sergio': [('lenovo moto g4', 9.838232323211649),
#               ('samsung galaxy s5', 9.83788744380122),
#               ('motorola moto g', 9.795687911420625),
#               ('huawei ascend p7', 9.787735110888125),
#               ('huawei ascend y550', 9.65810750115192),
#               ('huawei nexus 6p', 9.64008518933974),
#               ('sony xperia s', 9.39655562582297),
#               ('smartphone samsung galaxy', 9.206807046979645),
#               ('smartphone samsung galaxy', 9.206807046979645),
#               ('lg d802 g2', 9.102205974648385)],
#              'charlie': [('motorola moto g', 10),
#               ('lg 530g prepaid', 10),
#               ('apple iphone 6', 10),
#               ('samsung galaxy j7', 9.26690886626109),
#               ('lg ku990 viewty', 8.905074598430096),
#               ('nokia asha 302', 8.536002727724725),
#               ('lg electronics nexus', 8.457704548053693),
#               ('apple iphone 5s', 8.425329491022941),
#               ('samsung galaxy y', 8.413446300853778),
#               ('samsung galaxy s4', 7.9934019603466115)],
#              'nicole': [('huawei nexus 6p', 9.021847225404098),
#               ('archos 50 helium', 9.000892556768054),
#               ('apple iphone 5c', 8.935733366212837),
#               ('samsung galaxy alpha', 8.930565712208544),
#               ('lenovo motorola moto', 8.562639440934793),
#               ('samsung galaxy j7', 7.948808509205664),
#               ('sony xperia zl', 7.9478346745655495),
#               ('samsung galaxy j1', 7.836883765859338),
#               ('lg electronics t385', 7.756268836146667),
#               ('nokia 7373', 6.270237020764368)],
#              'ð\x95ð²ð³ðµð½ð¸ñ\x8f': [('sony xperia m', 9.875721340271358),
#               ('sony xperia l', 9.631734256326062),
#               ('sony xperia z1', 9.518906151170146),
#               ('sony xperia z1', 9.518906151170146),
#               ('samsung s7270 galaxy', 9.360056646532112),
#               ('samsung n7100 galaxy', 9.223154931114479),
#               ('samsung galaxy s4', 9.044945814337847),
#               ('samsung galaxy s4', 9.044945814337847),
#               ('samsung galaxy note', 8.450865661221389),
#               ('samsung galaxy j1', 7.959833860223649)],
#              'ð\x94ð¸ð¼ð°': [('samsung galaxy s4', 10),
#               ('samsung i8190 galaxy', 10),
#               ('sony xperia z1', 10),
#               ('htc desire s', 10),
#               ('sony xperia l', 9.987509062213714),
#               ('sony xperia l', 9.987509062213714),
#               ('samsung galaxy a3', 8.91025847081124),
#               ('samsung i5800 galaxy', 8.578248031823447),
#               ('samsung galaxy ace', 7.422452247223514),
#               ('htc desire v', 5.666777897489888)],
#              'rpv': [('samsung galaxy s4', 10),
#               ('samsung galaxy note', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 920', 10),
#               ('samsung galaxy note', 10),
#               ('nokia lumia 720', 10),
#               ('samsung galaxy note', 10),
#               ('nokia lumia 920', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 920', 10)],
#              'ana': [('apple iphone 5s', 9.460956118099785),
#               ('motorola moto x', 9.400508106239311),
#               ('motorola moto x', 9.400508106239311),
#               ('motorola cd930', 9.367777407404603),
#               ('smartphone moto e', 9.296025345649445),
#               ('huawei ascend p6', 9.083195073478006),
#               ('lg optimus l5', 8.969500680826757),
#               ('lg google nexus', 8.944493114986058),
#               ('samsung galaxy grand', 8.939734359351839),
#               ('samsung galaxy s5', 8.80299175682928)],
#              'ð\x90ð½ð°ñ\x81ñ\x82ð°ñ\x81ð¸ñ\x8f': [('apple iphone se',
#                8.95534586225396),
#               ('samsung i9082 galaxy', 8.732967860737215),
#               ('sony xperia z1', 8.502994177790404),
#               ('asus zenfone 2', 8.451412972612445),
#               ('sony xperia z', 8.44847156894218),
#               ('sony xperia m', 8.330371869694334),
#               ('sony xperia m', 8.330371869694334),
#               ('samsung galaxy a3', 7.703891866060221),
#               ('samsung galaxy s4', 7.644659297225961),
#               ('apple iphone 5s', 7.591846416339675)],
#              'gary': [('samsung galaxy j5', 10),
#               ('lg g2 sprint', 9.840445362017006),
#               ('samsung i9100 galaxy', 9.732149208187064),
#               ('samsung galaxy a3', 9.127242305723247),
#               ('lg g2 mini', 9.069039148513781),
#               ('huawei mate 9', 9.051300840675582),
#               ('lg verizon lg', 8.674847076455437),
#               ('nokia lumia 635', 8.535678887627109),
#               ('samsung note 2', 8.12113446306914),
#               ('apple iphone se', 7.779138102007504)],
#              'mary': [('samsung galaxy s3', 9.327363992557325),
#               ('motorola moto g', 9.110639710859308),
#               ('lg nexus 5x', 8.960480589839722),
#               ('samsung knack u310', 8.842956500330047),
#               ('nokia lumia 1320', 8.733473686549491),
#               ('samsung a157 gophone', 8.713386891505847),
#               ('samsung galaxy s4', 8.635618272734977),
#               ('samsung galaxy j7', 8.616632099086376),
#               ('samsung galaxy j3', 8.570965536843234),
#               ('wiko cink slim', 8.549911044971532)],
#              'mario': [('sim free apple', 10),
#               ('microsoft nokia lumia', 9.81366427407021),
#               ('smartphone lg l90', 9.727713090312548),
#               ('htc one m8', 9.708873748006203),
#               ('lg google nexus', 9.689749688586005),
#               ('samsung galaxy s4', 9.586766246058687),
#               ('wiko fever 4g', 9.54877797056923),
#               ('nokia asha 309', 9.471402786181145),
#               ('nokia lumia 620', 9.443160348166213),
#               ('asus zenfone 2', 9.41559131462003)],
#              'caroline': [('samsung galaxy j5', 9.505434464358062),
#               ('samsung galaxy j5', 9.505434464358062),
#               ('apple iphone 7', 9.449829539628887),
#               ('ringke asus zenfone', 9.445069222124692),
#               ('sim free apple', 9.39243960539983),
#               ('smartphone asus zenfone', 9.370319059109486),
#               ('microsoft lumia 640', 9.103801633963712),
#               ('lenovo moto g4', 8.525107439949542),
#               ('samsung galaxy ace', 8.314035536643406),
#               ('sony xperia z5', 8.30330782591653)],
#              'kindle customer': [('samsung galaxy j7', 9.522201471024172),
#               ('htc one 32gb', 9.511076704754409),
#               ('motorola nexus 6', 9.200861544790065),
#               ('huawei honor 8', 9.148792207049732),
#               ('samsung s425g prepaid', 9.007603894174268),
#               ('samsung s425g prepaid', 9.007603894174268),
#               ('motorola droid razr', 8.950884643565898),
#               ('samsung galaxy siii', 8.878837204603546),
#               ('nokia lumia 735', 8.83316368014337),
#               ('motorola moto g', 8.825074999337998)],
#              'frank': [('huawei ascend p7', 9.587528865525144),
#               ('apple iphone 5', 9.576342301729948),
#               ('blackberry q5 smartphone', 9.38826993963195),
#               ('asus zenfone 2', 9.29397420230193),
#               ('huawei honor 3c', 9.248059144753057),
#               ('microsoft nokia lumia', 9.241362598552469),
#               ('microsoft nokia lumia', 9.241362598552469),
#               ('samsung e2550 monte', 9.230845159839227),
#               ('samsung galaxy s7', 9.18671951176835),
#               ('samsung galaxy s3', 8.937123513021309)],
#              '????????': [('sony xperia p', 9.71309897532171),
#               ('apple iphone 5', 9.69515436615552),
# ...
#              'dunya': [('samsung s8003 jet', 1),
#               ('nokia 8800 arte', 1),
#               ('nokia 6500 slide', 1),
#               ('motorola rokr z6', 1),
#               ('samsung i8000 omnia', 1),
#               ('motorola razr2 v9', 1)],
#              'pankaj': [('samsung galaxy note', 9.616565713871955),
#               ('micromax canvas hd', 9.428294534832967),
#               ('asus zenfone 5', 7.725751535066137),
#               ('samsung galaxy a9', 7.59305363822413),
#               ('sony xperia c3', 7.396811851217871)],
#              'natalia': [('ee alcatel one', 10),
#               ('samsung galaxy s6', 9.780492376151008),
#               ('huawei ascend g510', 9.518679018758984),
#               ('sony xperia s', 9.374964222709997),
#               ('lenovo motorola moto', 8.711651120046126),
#               ('sony xperia tipo', 8.175284792688492),
#               ('sony xperia z3', 7.696452929496185),
#               ('alcatel one touch', 7.3037895401925175),
#               ('samsung galaxy star', 6.220905573200394)],
#              'ciklet': [('nokia e90 cep', 1),
#               ('nokia 5310 cep', 1),
#               ('nokia n70 cep', 1)],
#              'thierry': [('samsung galaxy s5', 10),
#               ('zte axon 7', 10),
#               ('nokia microsoft lumia', 10),
#               ('zte axon 7', 10),
#               ('nokia lumia 830', 10),
#               ('samsung galaxy core', 10),
#               ('zte axon 7', 10),
#               ('honor 4x smartphone', 9.340013000679631),
#               ('samsung galaxy y', 8.704131100131736),
#               ('samsung galaxy a5', 8.4807412301019)],
#              'mel': [('motorola rokr e1', 9.604216029066757),
#               ('huawei ascend mate', 9.149951960823874),
#               ('microsoft lumia 640', 8.344731169782822),
#               ('tech armor galaxy', 4.209727150139175),
#               ('motorola mb300 backflip', 3.8368333813364055)],
#              'bianca': [('huawei p8 grijs', 9.023437278048105),
#               ('samsung galaxy s4', 8.99167316878577),
#               ('samsung galaxy s6', 8.398376681630662),
#               ('smartphone motorola defy', 8.36049697017324),
#               ('apple iphone 5c', 8.078095331237076),
#               ('sony xperia z5', 7.624382501103402),
#               ('sony ericsson s500i', 7.42881619959584),
#               ('sony ericsson c', 6.868561610977091)],
#              'marion': [('apple iphone 7', 10),
#               ('emporia elegance handy', 9.30189402724762),
#               ('buyus etui housse', 8.943462715906115),
#               ('lenovo motorola moto', 8.195556726442025),
#               ('doro matra phone', 7.942211532210055),
#               ('sony xperia m4', 4.727987695087687)],
#              'simona': [('huawei p8 lite', 10),
#               ('asus ze550kl zenfone', 9.870829269474047),
#               ('huawei ascend p7', 9.85965997107755),
#               ('samsung galaxy j5', 9.507759741544252),
#               ('lg g2 mini', 9.32395551559794),
#               ('blackberry curve 9320', 8.988967281530678),
#               ('huawei ascend g7', 8.876591914289799),
#               ('htc desire 816', 8.210357851288489),
#               ('apple iphone 5s', 8.094694868541938),
#               ('homtom ht7 3g', 8.065853329694392)],
#              'enzo': [('apple iphone 5s', 9.536541133076085),
#               ('lenovo motorola moto', 9.33108702316273),
#               ('lenovo motorola moto', 9.33108702316273),
#               ('lg k10 smartphone', 9.260250612381757),
#               ('huawei p8 lite', 8.891380259453655),
#               ('doogee valencia2 y100', 8.687772121159894),
#               ('huawei p9 lite', 8.529496242054115),
#               ('sony e6653 xperia', 8.315067556521887),
#               ('samsung g355 galaxy', 8.117451771078438),
#               ('samsung smartphone galaxy', 7.482420386997789)],
#              'karadag60': [('sony ericsson w610i', 1),
#               ('sony ericsson w910i', 1),
#               ('sony ericsson c903', 1),
#               ('sony ericsson w995', 1),
#               ('palm treo pro', 1),
#               ('sony ericsson z310i', 1)],
#              'adriana': [('samsung galaxy note', 7.86083391258916),
#               ('smartphone motorola moto', 7.500306359793621),
#               ('samsung galaxy y', 7.1047538538893695),
#               ('samsung i9060i galaxy', 6.8189253355667105),
#               ('huawei ascend y300', 6.468998748150839),
#               ('sony xperia l', 5.633194824000054),
#               ('blackberry bold 9000', 3.0234591634714088),
#               ('motorola xt390', 2.9245885203587365),
#               ('palm pre plus', 2.750760867829082)],
#              'francis': [('apple iphone 7', 8.478777232833966),
#               ('lg gt540', 8.064069264069264),
#               ('motorola moto g', 7.872397013789477),
#               ('apple iphone 5', 7.447749244651308),
#               ('samsung galaxy grand', 7.4379006340171845),
#               ('samsung galaxy s7', 7.097408032237891),
#               ('samsung galaxy s7', 7.097408032237891),
#               ('doogee x5 max', 6.8836176190911305),
#               ('samsung s5230 player', 4.895217568835502),
#               ('lg neon', 4.3452176845278)],
#              'delicate': [('nokia 2730 classic', 1),
#               ('palm treo 750', 1),
#               ('nokia 6600i slide', 1),
#               ('apple iphone 3gs', 1),
#               ('palm treo 650', 1),
#               ('nokia e52', 1)],
#              'flavio': [('smartphone lg optimus', 9.42057866969116),
#               ('asus zenfone 2', 8.917431585858544),
#               ('apple iphone 5s', 8.912306324158177),
#               ('lg d855 g3', 8.898942422354136),
#               ('huawei ascend y530', 8.880592089714202),
#               ('huawei nexus 6p', 8.853217541076793),
#               ('lg optimus l5', 8.794012675729624),
#               ('alcatel one touch', 7.46985333365045),
#               ('huawei ascend p8', 6.741900719720119),
#               ('motorola xt390', 5.890509543190642)],
#              'santiago': [('samsung galaxy s6', 10),
#               ('huawei smartphone huawei', 10),
#               ('microsoft lumia 640', 9.375886586795144),
#               ('sony xperia p', 9.32128770126242),
#               ('lenovo motorola moto', 9.253752005648291),
#               ('nokia lumia 1320', 8.658384305724995),
#               ('motorola moto e', 8.21053703645426),
#               ('bq aquaris x5', 8.02752827685322),
#               ('sony xperia z', 7.1371357858652225),
#               ('samsung galaxy s', 6.620661312579419)],
#              'emanetcan': [('apple iphone 3g', 1),
#               ('apple iphone 3gs', 1),
#               ('samsung s8003 jet', 1),
#               ('samsung e250 cep', 1),
#               ('sony ericsson w995', 1),
#               ('samsung m620 cep', 1),
#               ('nokia 5630 xpressmusic', 1),
#               ('sony ericsson w810i', 1),
#               ('blackberry storm 9530', 1),
#               ('nokia 6300 cep', 1)],
#              'cikolata': [('samsung i560 cep', 1),
#               ('nokia e65 cep', 1),
#               ('nokia n76 cep', 1),
#               ('nokia 5300 xpressmusic', 1),
#               ('samsung u800 cep', 1)],
#              '???????????????? ??????????????': [('philips xenium w732',
#                9.622159186990675),
#               ('sony xperia e', 8.740158299372727),
#               ('nokia asha 210', 8.18018524280032),
#               ('lenovo k900 32gb', 8.064539241495222),
#               ('samsung galaxy pocket', 7.511704124418779),
#               ('samsung c3322', 6.5979414777885665),
#               ('sony xperia miro', 4.469278778509961)],
#              'jr': [('samsung galaxy s3', 10),
#               ('apple iphone 5s', 10),
#               ('sony ericsson cedar', 10),
#               ('blu studio x', 9.919332909807844),
#               ('huawei p8 lite', 9.860546761143585),
#               ('samsung b5722 handy', 9.70125789915466),
#               ('samsung galaxy s7', 8.532562741312741),
#               ('samsung galaxy s5', 8.476304113986238)],
#              'ozer1299': [('nokia n81 8gb', 1),
#               ('samsung d900i 1gb', 1),
#               ('nokia n70 cep', 1),
#               ('nokia x6 cep', 1),
#               ('samsung m620 cep', 1),
#               ('nokia 6500 slide', 1),
#               ('samsung i8000 omnia', 1)],
#              'george': [('samsung galaxy s7', 9.677916705698602),
#               ('huawei p9 lite', 9.398995069392655),
#               ('samsung ativ s', 9.377406538952147),
#               ('apple iphone 6', 9.329074780328352),
#               ('nokia 6310i mobile', 9.301458396451036),
#               ('asus zenfone max', 8.627935535757812),
#               ('sim free motorola', 8.62237737209104),
#               ('samsung g920 galaxy', 8.56186158756337),
#               ('lg g flex', 8.471344300938314),
#               ('apple iphone 5s', 8.236787319622064)],
#              'mustafa': [('iphone 5s 16gb', 9.20032461170537),
#               ('samsung i9190 galaxy', 8.891623417657629),
#               ('samsung s7580 galaxy', 6.852754619804518),
#               ('samsung galaxy j1', 6.29001787781936)],
#              'xxx': [('sony ericsson xperia', 10),
#               ('doogee x5 pro', 8.6676671976842),
#               ('huawei ascend y300', 7.481747393787237),
#               ('sony ericsson w395', 5.795968043523609)],
#              'emre': [('lg g4 us991', 7.998270099271311),
#               ('motorola razr v3', 5.263528601162883),
#               ('nokia 5800 xpressmusic', 5.074914910049449),
#               ('sony xperia z', 1)],
#              'anja': [('microsoft nokia 2760', 9.607628185668528),
#               ('sony xperia sp', 8.349674386821494),
#               ('htc one max', 8.336640277161),
#               ('htc desire c', 8.330176610822718),
#               ('vodafone smart 4', 8.077114831335274),
#               ('samsung galaxy y', 7.751573113323771),
#               ('huawei p8lite zwart', 7.699811620911076),
#               ('samsung galaxy ace', 7.32724930072037),
#               ('htc desire 310', 7.221743021725347),
#               ('samsung galaxy s4', 6.583000715946197)],
#              '????????????????': [('samsung c3782 onyx', 9.606029837316893),
#               ('apple iphone 4s', 8.934949122698745),
#               ('nokia n9', 8.33269331975193),
#               ('htc desire c', 8.316132289145736),
#               ('huawei u8860 honor', 8.205389146405066),
#               ('sony xperia v', 7.974969720660179),
#               ('nokia asha 210', 6.040389314511698)],
#              'me': [('lg electronics leon', 8.988527320579252),
#               ('samsung c5212 duos', 8.229147036116565),
#               ('samsung galaxy note', 8.16762295861535),
#               ('microsoft nokia lumia', 8.153301608416307),
#               ('alcatel onetouch onetouch', 8.123441570998798),
#               ('samsung galaxy s7', 8.000170443559147),
#               ('htc one m8', 7.498988373465341),
#               ('doro phoneeasy 410gsm', 6.935521458530524),
#               ('samsung gt s5260', 6.8547648892218325),
#               ('lg env touch', 6.439048276313176)],
#              'dolunay': [('samsung galaxy mini', 1),
#               ('samsung s5233w star', 1),
#               ('nokia n73 cep', 1),
#               ('nokia n72 cep', 1),
#               ('samsung d900i 1gb', 1)],
#              'sezenm': [('nokia n95 cep', 1),
#               ('samsung p520 armani', 1),
#               ('nokia n72 cep', 1),
#               ('nokia 6131 cep', 1),
#               ('nokia 5500 sport', 1)],
#              'damien': [('microsoft lumia 535', 10),
#               ('lg g2 mini', 9.917747969164461),
#               ('motorola defy', 9.795244998716965),
#               ('nokia e63', 9.435637949815955),
#               ('samsung galaxy s6', 9.208629065248676),
#               ('lg nexus 5', 8.230637145015766)],
#              'ram': [('microsoft lumia 640', 7.857172255971566),
#               ('microsoft lumia 640', 7.857172255971566),
#               ('htc evo 3d', 6.778019648492061),
#               ('apple iphone 6', 6.693944943760878)],
#              'tuvok': [('samsung galaxy express', 10)],
#              'tobias': [('samsung galaxy s4', 8.574076572477981),
#               ('samsung galaxy s', 8.356451424750086),
#               ('huawei mate 9', 8.32240683016351),
#               ('lenovo motorola moto', 8.196076197838856),
#               ('microsoft nokia 108', 7.109018083861424),
#               ('nokia 6220 classic', 6.886389494952232),
#               ('lg electronics google', 6.745177151968743),
#               ('asus padfone 2', 6.624924370414072),
#               ('htc mozart 7', 6.135803985631324),
#               ('apple iphone 6', 5.8563097302451395)],
#              'alice': [('huawei ascend mate', 10),
#               ('doro phoneeasy 612', 9.282450168254156),
#               ('asus ze550kl zenfone', 9.27991049556383),
#               ('samsung a5 2016', 9.2140132233868),
#               ('oukitel u7 plus', 8.311560221434023),
#               ('doro phone easy', 8.12941594438819),
#               ('samsung galaxy a3', 8.09597177711493),
#               ('microsoft lumia 650', 8.082768290402266),
#               ('smartphone samsung galaxy', 8.082608695652175),
#               ('samsung galaxy y', 7.429297111370417)],
#              'zehrabalta': [('nokia e90 cep', 1),
#               ('nokia n97 mini', 1),
#               ('sony ericsson z310i', 1),
#               ('apple iphone 4', 1),
#               ('nokia n95 cep', 1)],
#              '???????\x80????': [('samsung c3782 onyx', 9.85830056313765),
#               ('apple iphone 4s', 9.35093638185201),
#               ('htc sensation xl', 9.153020358774535),
#               ('nokia 603', 9.069809115641593),
#               ('sony xperia v', 8.882970046278905),
#               ('nokia asha 311', 7.098373624802347)],
#              'louis': [('samsung galaxy s7', 9.954153496700432),
#               ('nokia lumia 830', 9.891481406641198),
#               ('nokia microsoft lumia', 9.743432516587196),
#               ('htc desire sim', 9.084853272460254),
#               ('doogee x5 pro', 8.962971079214181),
#               ('sony ericsson w580', 8.822611232642153),
#               ('apple iphone 4s', 8.634362642794226),
#               ('sony ericsson xperia', 8.606401832043149),
#               ('samsung galaxy s6', 8.485320957999326),
#               ('samsung galaxy s5', 8.453499744827921)],
#              'bert': [('sim free motorola', 10),
#               ('huawei p8 champagne', 9.188618349260025),
#               ('huawei p8 grijs', 8.892417316211606),
#               ('samsung b2710 solid', 8.837878269978322),
#               ('apple iphone 5s', 8.613550022500231),
#               ('apple iphone se', 8.489295564323323)],
#              'narn3049': [('sony ericsson xperia', 7.521850585013812),
#               ('pearl 8100', 7.367704076286283),
#               ('v300', 7.367704076286283)],
#              'sue': [('sim free apple', 10),
#               ('samsung galaxy s', 9.554213271784027),
#               ('blackberry dtek50 unlocked', 9.412157196299635),
#               ('huawei p9 lite', 9.181090955174373),
#               ('samsung s3350 chat', 8.690242068574205),
#               ('samsung e1270 uk', 7.012807795736804),
#               ('lg electronics ks360', 5.443387252688738)],
#              'sunny': [('sony xperia s', 9.202815217011405),
#               ('doro phoneeasy 622', 8.972128279002948),
#               ('apple iphone 6s', 8.688055937927064),
#               ('samsung galaxy a3', 8.48932741838636),
#               ('huawei p8 lite', 7.558810620275636),
#               ('karbonn titanium octane', 7.364103996093479),
#               ('lg electronics e610', 7.202348089767716),
#               ('apple iphone 3g', 4.319212801725373)],
#              'raquel': [('samsung galaxy s6', 8.995159783369868),
#               ('blackberry torch 9810', 7.541410194145223),
#               ('htc one', 7.136882155307468),
#               ('smartphone lg optimus', 7.0802850762674545),
#               ('motorola moto g', 7.074009856150661),
#               ('apple iphone 5', 6.193445253280771)],
#              'aksisey': [('nokia 6500 slide', 1),
#               ('nokia n70 cep', 1),
#               ('nokia e65 cep', 1)]})

# %%
# algo_i = KNNWithMeans(k=10, sim_options={ 'user_based': True})
# algo_i.fit(trainset1)

# test_pred=algo_i.test(testset1)
# print(accuracy.rmse(test_pred))

# pred = pd.DataFrame(test_pred)
# pred[['uid','iid', 'r_ui','est']].sort_values(by = ['uid','r_ui','est'],ascending = False).head(10)

# %%
algo_i = KNNWithMeans(k=10, sim_options={ 'user_based': False})
algo_i.fit(trainset)

test_pred=algo_i.test(testset)
print(accuracy.rmse(test_pred))

print("top recommended products for Item based on KNN")
top_n = get_top_n(test_pred, n=10)
top_n
# pred = pd.DataFrame(test_pred)
# pred[['uid','iid', 'r_ui','est']].sort_values(by = ['uid','r_ui'],ascending = False).head(10)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 3.0940
# 3.0939967304435956
# top recommended products for Item based on KNN
# defaultdict(list,
#             {'alexander': [('huawei ascend mate', 10),
#               ('sony xperia s', 10),
#               ('huawei ascend g600', 9.994287461368568),
#               ('lenovo motorola moto', 9.835957156113393),
#               ('htc one smartphone', 9.73597788675107),
#               ('nokia c6 unlocked', 9.302562236082824),
#               ('lg l90 d410', 9.151245433819657),
#               ('samsung nexus s', 9.134897828863346),
#               ('honor 7 smartphone', 8.92399103324069),
#               ('lg g flex', 8.780911711633735)],
#              'juan carlos': [('samsung galaxy ace', 9.526617680618426),
#               ('samsung galaxy ace', 9.526617680618426),
#               ('lg l bello', 9.40518861981026),
#               ('huawei p9 lite', 9.330970872040398),
#               ('samsung galaxy s3', 8.974208642382083),
#               ('samsung galaxy s3', 8.974208642382083),
#               ('samsung galaxy note', 8.909815424939193),
#               ('bq aquaris e5', 8.699290082101463),
#               ('blackberry bold 9790', 8.277363282134443),
#               ('meizu m3s 16gb', 8.163561437884304)],
#              'maria': [('nokia 6310i', 10),
#               ('sim free samsung', 10),
#               ('sim free apple', 10),
#               ('samsung korea samsung', 9.661533498996963),
#               ('huawei p8 lite', 9.660132458815214),
#               ('huawei p8 lite', 9.660132458815214),
#               ('samsung galaxy s3', 9.571468644687535),
#               ('samsung galaxy s3', 9.571468644687535),
#               ('samsung galaxy s3', 9.571468644687535),
#               ('microsoft mobile nokia', 9.475697223656116)],
#              'alex': [('smartphone moto e', 10),
#               ('microsoft nokia 100', 10),
#               ('lg electronics p500', 10),
#               ('sim free samsung', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone apple iphone', 10),
#               ('vodafone e1200 pay', 10),
#               ('samsung ativ s', 10),
#               ('samsung c3520i telefono', 10),
#               ('samsung i9060 galaxy', 9.932015538929676)],
#              'francesco': [('lg nexus 4', 10),
#               ('oukitel k10000 smartphone', 10),
#               ('huawei ascend g615', 10),
#               ('lg k10 smartphone', 10),
#               ('nokia lumia 625', 10),
#               ('samsung j510 galaxy', 10),
#               ('lg e610 l5', 10),
#               ('nokia lumia 925', 9.93805160511409),
#               ('meizu m3 note', 9.884159701351752),
#               ('samsung g900 galaxy', 9.87975834681062)],
#              'ð\x98ñ\x80ð¸ð½ð°': [('nokia 5230 navigation', 10),
#               ('sony xperia z1', 9.515724923939041),
#               ('sony xperia z1', 9.515724923939041),
#               ('sony xperia sp', 9.50842457547439),
#               ('sony xperia sp', 9.50842457547439),
#               ('apple iphone se', 9.506217560976504),
#               ('samsung i9082 galaxy', 9.459809258922457),
#               ('samsung i9082 galaxy', 9.459809258922457),
#               ('samsung i9082 galaxy', 9.459809258922457),
#               ('sony xperia z', 9.454655152537981)],
#              'anna': [('huawei smartphone honor', 10),
#               ('nokia 105 telefono', 9.846996223837378),
#               ('huawei ascend p7', 9.645040285693447),
#               ('samsung e1270 telefono', 9.427461880981511),
#               ('samsung galaxy s5', 9.355568537559101),
#               ('samsung galaxy s5', 9.355568537559101),
#               ('huawei p9 lite', 9.24504105192796),
#               ('samsung galaxy s4', 8.988519017298115),
#               ('samsung galaxy s4', 8.988519017298115),
#               ('huawei p8 lite', 8.803979978061639)],
#              'kim': [('microsoft nokia lumia', 10),
#               ('htc flyer 7', 9.703960753593988),
#               ('sony xperia z1', 9.672871311617833),
#               ('huawei p8 grijs', 9.251848184241833),
#               ('samsung galaxy grand', 9.158060162033554),
#               ('ee alcatel one', 9.144547814855862),
#               ('microsoft lumia 650', 9.013880574837126),
#               ('huawei p8lite zwart', 8.48254008882356),
#               ('huawei p8lite zwart', 8.48254008882356),
#               ('samsung galaxy prevail', 8.343013954759584)],
#              'ð\x92ð°ð»ðµñ\x80ð¸ð¹': [('htc nexus one', 9.18477502038988),
#               ('sony xperia c', 8.295003451625975),
#               ('sony xperia c', 8.295003451625975),
#               ('sony xperia sp', 7.784217588150218),
#               ('samsung galaxy s7', 6.90890134628078),
#               ('samsung galaxy s4', 6.747301249033658),
#               ('samsung galaxy s5', 6.1485681756662816),
#               ('samsung i8150 galaxy', 5.859724326720392),
#               ('apple iphone 5s', 5.670983713799686)],
#              'chris': [('samsung rugby 2', 10),
#               ('blu vivo xl', 10),
#               ('sim free apple', 10),
#               ('blu vivo xl', 10),
#               ('sony xperia z2', 9.99320245645827),
#               ('lg electronics g2', 9.956480613163814),
#               ('huawei ascend p6', 9.94727867683448),
#               ('sony xperia z3', 9.702713831217489),
#               ('nokia lumia 925', 9.694810323522727),
#               ('sim free motorola', 9.571153426153426)],
#              'kevin': [('sim free apple', 10),
#               ('lg optimus g', 9.508186899172687),
#               ('samsung galaxy s4', 9.335720977356374),
#               ('samsung galaxy s4', 9.335720977356374),
#               ('lenovo moto g4', 8.990386978756442),
#               ('ringke asus zenfone', 8.933110778953708),
#               ('honor 7 smartphone', 8.894532661680987),
#               ('honor 7 smartphone', 8.894532661680987),
#               ('lg google nexus', 8.840340264762357),
#               ('lenovo s8 s898t', 8.83266900021007)],
#              'markus': [('microsoft nokia n8', 10),
#               ('lg electronics p500', 10),
#               ('sony ericsson w595', 9.509410972710372),
#               ('sony xperia z1', 9.32343424320275),
#               ('samsung galaxy s', 9.252841856222716),
#               ('samsung galaxy s', 9.252841856222716),
#               ('motorola nexus 6', 9.087889176630307),
#               ('samsung galaxy nexus', 8.762112042879156),
#               ('lg ku990 viewty', 8.696263708627086),
#               ('blackberry pearl 3g', 8.677691014590277)],
#              'silvia': [('lenovo motorola k1', 10),
#               ('huawei p9 lite', 9.153103610476578),
#               ('huawei p9 lite', 9.153103610476578),
#               ('asus zenfone 2', 8.996339834719203),
#               ('asus zenfone 2', 8.996339834719203),
#               ('alcatel one touch', 8.930204870275238),
#               ('samsung i8200 galaxy', 8.631242368510467),
#               ('samsung galaxy j5', 8.059302735986563),
#               ('smartphone blackberry curve', 7.8239834613033645),
#               ('bq aquaris e5', 7.721235626685852)],
#              'david': [('lg optimus g', 10),
#               ('huawei mate 9', 10),
#               ('htc desire 816', 10),
#               ('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('archos 50 helium', 10),
#               ('huawei p8 grijs', 10),
#               ('motorola google nexus', 10),
#               ('lg voyager', 10),
#               ('samsung galaxy s6', 10)],
#              'ð\x93ð¾ñ\x81ñ\x82ñ\x8c': [('htc windows phone', 10),
#               ('nokia c6', 9.493305433542051),
#               ('sony ericsson x10', 9.467752513860637),
#               ('sony ericsson xperia', 9.276108544969698),
#               ('nokia 5130 xpressmusic', 9.235997344200742),
#               ('nokia 6303i classic', 8.382419604657734),
#               ('nokia 6303i classic', 8.382419604657734),
#               ('nokia e72', 8.363231470255105),
#               ('samsung galaxy j7', 7.8061195830186865),
#               ('apple iphone 3gs', 7.732660315672058)],
#              'salvatore': [('lg g2 smartphone', 10),
#               ('nokia 105 telefono', 10),
#               ('lg h410 wine', 10),
#               ('huawei ascend g700', 9.856828437961008),
#               ('huawei ascend g6', 9.692162178924956),
#               ('huawei p9 lite', 9.677428195036054),
#               ('nokia lumia 735', 9.673222619575505),
#               ('huawei ascend y550', 9.58217742228167),
#               ('sony xperia z1', 9.51419471634624),
#               ('lenovo motorola moto', 9.462208642683674)],
#              'no captured': [('lenovo s860', 10),
#               ('nokia 7210', 10),
#               ('sony ericsson w700i', 10),
#               ('acer liquid e3', 10),
#               ('siemens s35i', 10),
#               ('htc one dual', 10),
#               ('nokia 6125', 10),
#               ('lenovo s860', 10),
#               ('doogee smartphone android', 10),
#               ('samsung c3050', 10)],
#              'amazon customer': [('acer liquid z630s', 10),
#               ('doogee dagger dg550', 10),
#               ('blackberry pearl flip', 10),
#               ('nokia 1208 sim', 10),
#               ('motorola v197 unlocked', 10),
#               ('lg electronics d605', 10),
#               ('cubot p9 unlocked', 10),
#               ('samsung galaxy gs7', 10),
#               ('nokia lumia 720', 10),
#               ('samsung s5570 galaxy', 10)],
#              'marie': [('htc incredible s', 9.846725024580538),
#               ('huawei p8lite zwart', 9.770154090003565),
#               ('lg electronics gd880', 9.318098764102299),
#               ('samsung galaxy y', 9.055536339118673),
#               ('samsung galaxy y', 9.055536339118673),
#               ('wiko rainbow smartphone', 8.900262387673123),
#               ('kit me out', 8.876748099953408),
#               ('samsung galaxy s3', 8.869340088692732),
#               ('samsung galaxy mega', 8.785854403730713),
#               ('samsung galaxy a3', 8.64813161558331)],
#              'james': [('sim free apple', 10),
#               ('sim free motorola', 9.444903357903357),
#               ('samsung galaxy note', 9.29884868058409),
#               ('htc droid dna', 8.944752282142922),
#               ('nokia lumia 635', 8.87900819240152),
#               ('huawei ascend w1', 8.757199174268628),
#               ('samsung galaxy s', 8.734996271724986),
#               ('zte axon 7', 8.712697995806389),
#               ('huawei p8 lite', 8.683498793635811),
#               ('samsung galaxy s3', 8.597131197882554)],
#              'pascal': [('samsung e1190 sim', 10),
#               ('nokia lumia 625', 9.011559712015075),
#               ('lg gt540', 8.990496645982477),
#               ('samsung galaxy s7', 8.889134439334882),
#               ('samsung galaxy s7', 8.889134439334882),
#               ('sony mobile xperia', 8.883775907985774),
#               ('tech armor samsung', 8.348978123261181),
#               ('lg ku990 viewty', 8.122317278997723),
#               ('alcatel one touch', 8.024010689865804),
#               ('alcatel one touch', 8.024010689865804)],
#              'valentina': [('samsung a300 galaxy', 10),
#               ('samsung a500 galaxy', 9.970083066846241),
#               ('huawei p9 lite', 9.842537564004566),
#               ('huawei p8 lite', 9.808208696674003),
#               ('samsung galaxy s7', 9.785959918549644),
#               ('samsung s7580 galaxy', 9.783153387360482),
#               ('samsung galaxy j5', 9.750720572975442),
#               ('lenovo motorola moto', 9.598623951938015),
#               ('samsung e1270 telefono', 9.306167715213174),
#               ('samsung g800 galaxy', 9.228361799645269)],
#              'sabrina': [('samsung i9301 galaxy', 9.981739110658344),
#               ('motorola moto g', 9.616804307358553),
#               ('smartphone asus zenfone', 9.028056310199704),
#               ('samsung galaxy s5', 9.017205507687963),
#               ('lg d722 g3', 8.934582121565724),
#               ('sony ericsson k770i', 8.516423816885467),
#               ('samsung i9060 galaxy', 8.302519237337268),
#               ('samsung star s5230', 8.054109343064132),
#               ('huawei ascend p6', 7.841209055294206),
#               ('motorola flipout', 7.719835290263685)],
#              'simone': [('sony smartphone sony', 10),
#               ('honor 6x smartphone', 9.767858702277557),
#               ('microsoft nokia 7230', 9.718375546562552),
#               ('huawei y3 smartphone', 9.588554968173481),
#               ('wiko fever 4g', 9.588032329135926),
#               ('huawei ascend g7', 9.573953385875221),
#               ('smartphone samsung galaxy', 9.571217516487291),
#               ('htc desire 500', 9.494036075040881),
#               ('lenovo motorola moto', 9.454237981862036),
#               ('lenovo motorola moto', 9.454237981862036)],
#              'amazon kunde': [('honor 6x smartphone', 10),
#               ('honor 6x smartphone', 10),
#               ('lenovo motorola nexus', 10),
#               ('honor 8 smartphone', 10),
#               ('yota yotaphone 2', 10),
#               ('cat b15 smartphone', 10),
#               ('honor 6x smartphone', 10),
#               ('honor 6x smartphone', 10),
#               ('blackberry q5 smartphone', 9.93767445369276),
#               ('huawei ascend g525', 9.680242204809446)],
#              'jean': [('smartphone samsung galaxy', 10),
#               ('lg optimus g', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone motorola moto', 9.653102203722707),
#               ('samsung galaxy s7', 9.516281834982683),
#               ('htc sensation sim', 9.376151171252838),
#               ('nokia asha 302', 9.207441054718846),
#               ('celular lg t375', 9.175927516888482),
#               ('nokia lumia 625', 9.04077496941762)],
#              'valerio': [('lenovo motorola moto', 9.623031300002024),
#               ('samsung galaxy a3', 9.600486976247428),
#               ('huawei p8 lite', 9.25257574599435),
#               ('samsung galaxy j5', 8.942190236856044),
#               ('samsung ativ s', 8.776253163574502),
#               ('xiaomi hongmi 1s', 8.724943198483363),
#               ('sony xperia x', 8.610456370872804),
#               ('huawei p9 plus', 8.503776356181424),
#               ('thl 2015a 4g', 8.230813028424375),
#               ('samsung galaxy note', 8.093620756389127)],
#              'zã¡kaznã\xadk': [('lg g2 32gb', 9.867795495643596),
#               ('lg g2 32gb', 9.867795495643596),
#               ('iphone 5s 16gb', 9.678018566953122),
#               ('nokia lumia 625', 9.610076075143612),
#               ('nokia lumia 625', 9.610076075143612),
#               ('htc desire 820', 9.60321640176808),
#               ('samsung galaxy s6', 9.471189729810419),
#               ('samsung galaxy s6', 9.471189729810419),
#               ('samsung galaxy s6', 9.471189729810419),
#               ('samsung galaxy s6', 9.471189729810419)],
#              'john': [('sim free samsung', 10),
#               ('blackberry z10 smartphone', 10),
#               ('sim free apple', 10),
#               ('sim free sony', 10),
#               ('motorola x style', 10),
#               ('microsoft nokia lumia', 10),
#               ('sim free samsung', 10),
#               ('sony xperia z1', 9.578553467081171),
#               ('motorola moto g4', 9.410236095515847),
#               ('apple iphone 6', 9.388127221318582)],
#              'manish': [('apple iphone 5s', 9.709179334922569),
#               ('huawei honor 5x', 9.605802390090007),
#               ('samsung galaxy a8', 9.454263538357544),
#               ('huawei honor 8', 9.206291224694933),
#               ('motorola moto g', 9.122161958631242),
#               ('apple iphone 6', 9.058274637813495),
#               ('apple iphone 6', 9.058274637813495),
#               ('huawei nexus 6p', 8.70294969823082),
#               ('samsung galaxy j2', 8.580381663106513),
#               ('nokia lumia 530', 8.222784637204755)],
#              'angel': [('samsung galaxy ace', 9.590092377704465),
#               ('samsung galaxy ace', 9.590092377704465),
#               ('lg optimus g', 9.20524490130628),
#               ('nokia lumia 625', 9.127250542455736),
#               ('apple iphone 5c', 8.812636041773509),
#               ('sony xperia xz', 8.644012677634894),
#               ('microsoft lumia 640', 8.008044718771881),
#               ('sony xperia go', 7.865365326035477),
#               ('sony ericsson xperia', 7.807985440172477),
#               ('lg voyager', 7.668458443626419)],
#              'sandy': [('microsoft nokia 6303i', 9.599737458342366),
#               ('sony xperia z5', 8.98416510991592),
#               ('samsung galaxy centura', 8.926871923308214),
#               ('nokia n9 unlocked', 8.807335210120941),
#               ('nokia lumia 520', 8.72921287931342),
#               ('samsung galaxy s3', 8.664684962622289),
#               ('samsung galaxy s3', 8.664684962622289),
#               ('tudia zenfone 3', 8.629956657397228),
#               ('samsung galaxy alpha', 8.383822014577138),
#               ('lg google nexus', 8.35955009880096)],
#              'angelo': [('lg h410 wine', 10),
#               ('samsung g920 galaxy', 9.964648275493218),
#               ('samsung n9005 galaxy', 9.812945491026666),
#               ('wiko fever 4g', 9.63539164236977),
#               ('thl 5000 smartphone', 9.416193750471342),
#               ('samsung c3590 telefono', 9.190604103571674),
#               ('apple iphone 5c', 9.1328759725048),
#               ('samsung galaxy note', 8.972796220515328),
#               ('doogee x5 max', 8.960801351466115),
#               ('sony xperia z3', 8.916729981939541)],
#              'prashant': [('samsung galaxy s6', 7.3051104816527),
#               ('lenovo vibe x3', 7.251475686436047),
#               ('samsung galaxy j7', 5.839648593477426),
#               ('asus zenfone max', 5.716314613043984),
#               ('meizu m1 note', 5.612349528844149),
#               ('htc desire 816', 5.60941961265104),
#               ('motorola moto g', 5.2948506914462),
#               ('asus zenfone 2', 5.206186695189764),
#               ('sony xperia t2', 5.000475592405278),
#               ('blackberry bold 9790', 4.797737090274289)],
#              'ð\x92ð¸ðºñ\x82ð¾ñ\x80ð¸ñ\x8f': [('sony xperia m',
#                9.756520620968724),
#               ('sony xperia l', 9.370103787144885),
#               ('samsung galaxy s5', 9.10938179893891),
#               ('samsung galaxy s5', 9.10938179893891),
#               ('samsung galaxy s5', 9.10938179893891),
#               ('samsung galaxy s5', 9.10938179893891),
#               ('samsung galaxy s4', 9.046011152488376),
#               ('apple iphone se', 8.91796809759235),
#               ('samsung s7270 galaxy', 7.543233019780345),
#               ('htc desire 620g', 7.385204214339572)],
#              'eli': [('doogee dagger dg550', 9.826827184396175),
#               ('samsung galaxy s7', 9.681923483390925),
#               ('smartphone lg l90', 9.072935647077342),
#               ('huawei p8 lite', 9.008519436823931),
#               ('nokia lumia 800', 8.675711034009199),
#               ('asus zenfone 2', 8.162894087634713),
#               ('samsung galaxy core', 7.749788595804851),
#               ('samsung t404g prepaid', 6.989073338200854),
#               ('motorola verizon motorola', 6.623798267729868)],
#              'andrea': [('wiko fever 4g', 10),
#               ('wiko fever 4g', 10),
#               ('lenovo motorola k1', 10),
#               ('huawei ascend g525', 9.968576196964598),
#               ('samsung galaxy sii', 9.814855902110803),
#               ('nokia lumia 720', 9.68129003251201),
#               ('nokia lumia 720', 9.68129003251201),
#               ('lg d802 g2', 9.573392898958007),
#               ('honor 7 smartphone', 9.532900121056723),
#               ('honor 7 smartphone', 9.532900121056723)],
#              'ð\x90ð»ðµðºñ\x81ð°ð½ð´ñ\x80': [('samsung s5570 galaxy', 10),
#               ('acer liquid e1', 9.731428758787906),
#               ('lenovo p780', 9.62444172715588),
#               ('sony xperia m', 9.587253009439026),
#               ('sony xperia m', 9.587253009439026),
#               ('samsung galaxy core', 9.575104286316579),
#               ('nokia 101 premium', 9.557336761281558),
#               ('samsung i8190 galaxy', 9.376342611835923),
#               ('samsung i8190 galaxy', 9.376342611835923),
#               ('sony xperia z2', 9.294513120247286)],
#              'anonymous': [('lg a340', 10),
#               ('iphone 5s 16', 10),
#               ('lg a340', 10),
#               ('nokia 6630', 10),
#               ('lg g2 sprint', 10),
#               ('sim free iphone', 10),
#               ('iphone 5s 16', 10),
#               ('lg g2 verizon', 10),
#               ('nokia 2690', 10),
#               ('motorola rokr e1', 10)],
#              'alexandre': [('smartphone lg l90', 10),
#               ('nokia lumia 520', 9.651767215369508),
#               ('nokia lumia 530', 9.398798617840495),
#               ('lg a290', 9.259470837112918),
#               ('celular desbloqueado samsung', 9.178272648904981),
#               ('microsoft lumia 435', 8.891799587320552),
#               ('samsung galaxy s', 8.840556816909794),
#               ('samsung wave m', 8.743084858717653),
#               ('samsung galaxy s6', 8.524311918609259),
#               ('smartphone samsung galaxy', 8.324242272817388)],
#              'eva': [('microsoft lumia 640', 9.391468558522405),
#               ('asus zenfone go', 9.112284645359047),
#               ('motorola moto g', 8.68703605857144),
#               ('htc desire 500', 8.637803906180434),
#               ('samsung galaxy note', 8.369779029574362),
#               ('alcatel onetouch idol', 8.265663119515805),
#               ('samsung galaxy j1', 8.14653807250625),
#               ('htc windows phone', 8.095250658050984),
#               ('samsung galaxy s5', 8.086868690759577),
#               ('samsung galaxy s7', 7.613186435815637)],
#              'cliente amazon': [('blackberry z30 smartphone', 10),
#               ('samsung g355 galaxy', 10),
#               ('huawei ascend g620s', 10),
#               ('samsung i9060 galaxy', 10),
#               ('samsung n9005 galaxy', 10),
#               ('lg x screen', 10),
#               ('samsung n9005 galaxy', 10),
#               ('alcatel pop c7', 10),
#               ('samsung n9005 galaxy', 10),
#               ('samsung i9060 galaxy', 10)],
#              'nicolas': [('sony xperia m', 10),
#               ('nokia lumia 930', 9.83659677705632),
#               ('htc 8x unlocked', 9.668559116770098),
#               ('htc one m8', 9.653552447332032),
#               ('lg optimus l5', 9.00826389565081),
#               ('samsung i9105p galaxy', 8.759011749747392),
#               ('huawei p8 lite', 8.756518301346158),
#               ('huawei p8 lite', 8.756518301346158),
#               ('samsung galaxy mega', 8.701491244548517),
#               ('microsoft lumia 535', 8.581107290210106)],
#              'mike': [('sim free apple', 10),
#               ('sim free apple', 10),
#               ('motorola moto g', 9.7746574493865),
#               ('samsung rugby 2', 9.71443910649836),
#               ('samsung galaxy note', 9.471485682026524),
#               ('tech armor samsung', 9.278592307354218),
#               ('tech armor samsung', 9.278592307354218),
#               ('huawei honor 5x', 9.275375925576316),
#               ('sony xperia z', 9.254052793690223),
#               ('samsung galaxy j5', 9.20831204473474)],
#              'andreas': [('nokia 3230', 10),
#               ('htc one dual', 10),
#               ('sony xperia z2', 9.739799178180332),
#               ('honor 6 smartphone', 9.56089377933318),
#               ('acer liquid e2', 9.436062413592772),
#               ('lg electronics g', 9.401706112655388),
#               ('sony xperia z1', 9.198923541662731),
#               ('sony xperia z1', 9.198923541662731),
#               ('htc desire', 8.795375318003162),
#               ('microsoft lumia 550', 8.74688140595012)],
#              'stefan': [('huawei p8 grijs', 10),
#               ('lenovo motorola razr', 9.67032511494112),
#               ('huawei p8 champagne', 9.594510534772867),
#               ('asus zenfone 2', 9.37291912363159),
#               ('nokia lumia 925', 9.370988595624638),
#               ('microsoft lumia 640', 9.347361735533998),
#               ('sony xperia xcompact', 9.299284826757031),
#               ('microsoft nokia 100', 9.240144521829073),
#               ('sony xperia xz', 9.200461198555473),
#               ('samsung galaxy s3', 9.174443044646736)],
#              'ð\x9fð¾ð»ñ\x8cð·ð¾ð²ð°ñ\x82ðµð»ñ\x8c ñ\x81ðºñ\x80ñ\x8bð» ñ\x81ð²ð¾ð¸ ð´ð°ð½ð½ñ\x8bðµ': [('huawei ascend y600',
#                10),
#               ('huawei p8', 10),
#               ('blackberry passport', 10),
#               ('asus zenfone 3', 9.443777713621937),
#               ('samsung galaxy j5', 9.044683001767776),
#               ('sony xperia z2', 9.023508012204022),
#               ('microsoft lumia 650', 8.917869482628124),
#               ('apple iphone se', 8.812691609781606),
#               ('apple iphone 6', 8.76427734064589),
#               ('apple iphone 6', 8.76427734064589)],
#              'jose': [('sim free motorola', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('tracfone motorola moto', 9.979866334670858),
#               ('lenovo motorola moto', 9.949221916862946),
#               ('lenovo motorola moto', 9.949221916862946),
#               ('motorola nexus 6', 9.9168064719764),
#               ('samsung galaxy s3', 9.797631385366833),
#               ('samsung galaxy s3', 9.797631385366833)],
#              'antonio': [('samsung s7580 galaxy', 10),
#               ('smartphone moto e', 9.962464303249863),
#               ('smartphone moto e', 9.962464303249863),
#               ('samsung n9005 galaxy', 9.924659202336873),
#               ('blackberry z30 smartphone', 9.788111189679146),
#               ('huawei ascend y5', 9.786888461656755),
#               ('microsoft lumia 640', 9.778059979592342),
#               ('microsoft lumia 640', 9.778059979592342),
#               ('smartphone lg g2', 9.715455301477235),
#               ('doro phoneeasy 612', 9.707337514342507)],
#              'anonieme bezoeker': [('lg e610 optimus', 10),
#               ('nokia lumia 920', 8.76903144969459),
#               ('htc desire c', 8.582127484592197),
#               ('htc desire c', 8.582127484592197),
#               ('htc desire c', 8.582127484592197),
#               ('htc desire c', 8.582127484592197),
#               ('blackberry bold 9900', 8.557374456593218),
#               ('htc desire x', 8.103138299401323),
#               ('nokia lumia 820', 7.980387272437016),
#               ('nokia lumia 820', 7.980387272437016)],
#              'toni': [('sim free samsung', 10),
#               ('nokia lumia 625', 9.16984065552003),
#               ('motorola smartphone motorola', 9.156852264881461),
#               ('huawei ascend mate', 8.904239903958985),
#               ('samsung galaxy note', 8.901646675578274),
#               ('microsoft lumia 640', 8.87902138506302),
#               ('motorola moto x', 7.83205939616389),
#               ('htc one x', 7.686846629410009),
#               ('lg spirit 4g', 7.665408491598335),
#               ('samsung galaxy s4', 7.621535453990741)],
#              'lukas': [('huawei p8 champagne', 9.891118440217621),
#               ('microsoft nokia lumia', 9.355936594805556),
#               ('samsung galaxy note', 9.341423244410612),
#               ('samsung galaxy note', 9.341423244410612),
#               ('samsung galaxy s5', 9.234187127846251),
#               ('microsoft lumia 640', 8.904715063061817),
#               ('motorola moto g', 8.884513482147756),
#               ('samsung galaxy s6', 8.617513859716405),
#               ('samsung galaxy a5', 8.573156323741129),
#               ('htc one smartphone', 8.428539375332505)],
#              'anthony': [('apple iphone 7', 10),
#               ('apple iphone 7', 10),
#               ('sony mobile xperia', 10),
#               ('apple iphone 7', 10),
#               ('apple iphone 7', 10),
#               ('apple iphone 7', 10),
#               ('samsung galaxy a5', 10),
#               ('apple iphone 6s', 9.878841705007089),
#               ('apple iphone 5s', 9.740914622176588),
#               ('htc flyer 7', 9.506574970006076)],
#              'pedro': [('blackberry z10 uk', 9.84481101930891),
#               ('huawei y6 ii', 9.817652283680498),
#               ('sony xperia z3', 9.462562282978663),
#               ('smartphone apple iphone', 9.352463251500582),
#               ('alcatel pop c7', 9.31688668119307),
#               ('sony xperia z1', 9.243701167923032),
#               ('sony xperia z1', 9.243701167923032),
#               ('huawei p8 lite', 9.217932163959052),
#               ('motorola moto g', 9.216518901451021),
#               ('motorola moto g', 9.216518901451021)],
#              'ð\xa0ð¾ð¼ð°ð½': [('lg nexus 4', 9.762750207718346),
#               ('nokia 101 premium', 9.523320597469255),
#               ('sony xperia tx', 9.467792123046605),
#               ('motorola defy', 9.267210472830383),
#               ('samsung galaxy s7', 9.179225146640295),
#               ('huawei ascend g750', 9.174282329933028),
#               ('samsung n9000 galaxy', 9.083638422133102),
#               ('nokia lumia 720', 9.024005564862591),
#               ('samsung galaxy j3', 8.606229701577547),
#               ('sony xperia z1', 8.461045491405539)],
#              'jack': [('huawei p8 grijs', 9.763378055327923),
#               ('sony ericsson p900', 9.554974117306497),
#               ('lg g5 h850', 9.443516939322196),
#               ('sony sony xperia', 9.148184510854794),
#               ('samsung galaxy j5', 9.110398902390486),
#               ('huawei ascend mate', 8.773823555556138),
#               ('kazam wileyfox swift', 8.597714290719228),
#               ('samsung galaxy s7', 8.565010670247895),
#               ('samsung galaxy s7', 8.565010670247895),
#               ('samsung galaxy s7', 8.565010670247895)],
#              'pasquale': [('lg d802 g2', 10),
#               ('lenovo motorola moto', 9.916977179449836),
#               ('huawei ascend y550', 9.822740462482988),
#               ('nokia lumia 520', 9.50649904198691),
#               ('alcatel one touch', 8.96001522072703),
#               ('huawei ascend y5', 8.853616377736525),
#               ('huawei p8 lite', 8.764116077134434),
#               ('samsung a700 galaxy', 8.591549727039592),
#               ('asus zenfone 2', 8.466548129553972),
#               ('motorola moto g', 8.32417002386123)],
#              'mar': [('motorola moto g', 8.777900299897585),
#               ('huawei p8 lite', 8.423299523755938),
#               ('lg optimus f3', 8.368709711128615),
#               ('sony xperia zr', 8.07453644321778),
#               ('bq aquaris x5', 7.750195525618531),
#               ('motorola droid 3', 7.687256678887018),
#               ('samsung galaxy j5', 7.662901325662544),
#               ('lg optimus hub', 7.0240957970275995),
#               ('huawei ascend g730', 6.95155871083356),
#               ('samsung galaxy s7', 6.15988059780945)],
#              'philipp': [('blackberry q5 smartphone', 8.85250815944277),
#               ('honor 7 smartphone', 8.736850791389855),
#               ('huawei ascend p6', 8.478208354950286),
#               ('acer liquid e1', 7.70005971114184),
#               ('sony ericsson xperia', 7.608194958453026),
#               ('samsung galaxy s5', 7.355015355589994),
#               ('sony ericsson s500i', 7.347312444909361),
#               ('nokia 3250', 7.076855559605752),
#               ('apple iphone 4', 6.453593328972628),
#               ('microsoft lumia 550', 3.984428620860671)],
#              'paul': [('apple iphone 4s', 10),
#               ('nokia 1208 sim', 10),
#               ('samsung galaxy s5', 10),
#               ('sim free iphone', 10),
#               ('samsung galaxy s5', 10),
#               ('apple iphone 4s', 10),
#               ('samsung galaxy j3', 10),
#               ('microsoft nokia 100', 10),
#               ('sim free apple', 9.648883142298015),
#               ('sim free apple', 9.648883142298015)],
#              'roberto': [('huawei p9 plus', 10),
#               ('huawei p8lite zwart', 9.973750879662209),
#               ('samsung n7505 galaxy', 9.941915254205872),
#               ('nokia e72 unlocked', 9.793588661161255),
#               ('samsung a500 galaxy', 9.671009367602464),
#               ('samsung a500 galaxy', 9.671009367602464),
#               ('samsung g3500 galaxy', 9.534955887863966),
#               ('huawei mate 9', 9.533012134375621),
#               ('nokia lumia 735', 9.505065274231717),
#               ('nokia lumia 735', 9.505065274231717)],
#              'wendy': [('sony xperia z', 9.560581662457318),
#               ('htc wildfire s', 9.528345369255558),
#               ('samsung galaxy note', 9.422814461636603),
#               ('samsung galaxy note', 9.422814461636603),
#               ('samsung galaxy note', 9.422814461636603),
#               ('samsung galaxy s', 9.061114300783228),
#               ('huawei p8 lite', 8.82659946443126),
#               ('vodafone smart 4', 8.61898940496799),
#               ('samsung tocco lite', 8.448324745191092),
#               ('verizon lg octane', 8.406276737368094)],
#              'ð\x90ð½ð´ñ\x80ðµð¹': [('lg optimus l4', 9.921539929415765),
#               ('huawei ascend p6', 9.726241048937688),
#               ('htc desire s', 9.688018053671394),
#               ('samsung n9000 galaxy', 9.679375295992905),
#               ('samsung galaxy a5', 9.592978285936752),
#               ('samsung galaxy a5', 9.592978285936752),
#               ('sony xperia zr', 9.445146692931282),
#               ('lg optimus l7', 9.323973896192134),
#               ('htc wildfire s', 9.281671825664713),
#               ('lg nexus 4', 9.22414464904453)],
#              'fernando': [('smartphone asus zenfone', 10),
#               ('zte axon 7', 9.608645133747395),
#               ('samsung galaxy s7', 9.394079166717926),
#               ('smartphone samsung galaxy', 9.103985375105852),
#               ('smartphone samsung galaxy', 9.103985375105852),
#               ('smartphone samsung galaxy', 9.103985375105852),
#               ('nokia lumia 625', 8.910958637319295),
#               ('bq aquaris e5', 8.883825597746204),
#               ('asus zenfone 2', 8.487591231851258),
#               ('microsoft lumia 640', 8.329082400151927)],
#              'mark': [('lenovo motorola moto', 10),
#               ('microsoft nokia 2720', 10),
#               ('zte axon 7', 10),
#               ('zte axon 7', 10),
#               ('motorola google nexus', 9.930302061303843),
#               ('sim free sony', 9.62077051186093),
#               ('blackberry passport factory', 9.571088619140207),
#               ('apple iphone 5s', 9.4894878892854),
#               ('wiko rainbow smartphone', 9.34668955121443),
#               ('samsung galaxy a3', 9.14235081189083)],
#              'rachel': [('smartphone lg l90', 10),
#               ('sim free iphone', 10),
#               ('apple iphone 6', 9.730605523669974),
#               ('apple iphone 6s', 9.51102343313018),
#               ('lenovo motorola moto', 9.452872355413483),
#               ('samsung galaxy grand', 9.450051261202391),
#               ('samsung galaxy reverb', 9.28387198221041),
#               ('wiko smartphone wiko', 9.24341663666478),
#               ('microsoft lumia 435', 9.019769044559158),
#               ('meizu m3s 16gb', 8.857571679651864)],
#              'laura': [('huawei ascend p8', 10),
#               ('sim free samsung', 9.984649859943978),
#               ('lenovo motorola moto', 9.793273215786625),
#               ('lg g5 h860', 9.655208805421829),
#               ('samsung smartphone samsung', 9.619783724447847),
#               ('huawei p9 lite', 9.53254400587697),
#               ('samsung galaxy a5', 9.474753318563135),
#               ('samsung galaxy a5', 9.474753318563135),
#               ('samsung galaxy a5', 9.474753318563135),
#               ('lg k10 smartphone', 9.44137317171)],
#              'incesaz': [('sony ericsson w995', 5.645803367233692),
#               ('apple iphone 3g', 4.99873418170114),
#               ('nokia n97 mini', 3.383979930355297),
#               ('nokia 6500 slide', 2.951599901795381),
#               ('sony ericsson k850i', 2.221200557864654),
#               ('nokia 2630 cep', 1),
#               ('samsung e250 cep', 1)],
#              'wolfgang': [('microsoft nokia e51', 9.415284657271567),
#               ('blackberry passport smartphone', 9.11879107419722),
#               ('honor 6 smartphone', 9.104672823325767),
#               ('htc one s', 8.691550882615438),
#               ('samsung galaxy s3', 8.636987060549455),
#               ('samsung galaxy s3', 8.636987060549455),
#               ('microsoft nokia lumia', 8.481836167323811),
#               ('microsoft nokia 5230', 7.98806325980385),
#               ('lenovo moto z', 7.755076861431201),
#               ('samsung galaxy j5', 7.632368232384033)],
#              'manu': [('samsung galaxy s3', 9.535843553424566),
#               ('samsung galaxy s3', 9.535843553424566),
#               ('samsung galaxy j5', 9.325768002390015),
#               ('blu vivo xl', 9.244537474849784),
#               ('sony ericsson k800i', 8.849318904243216),
#               ('lenovo motorola moto', 8.726259850941398),
#               ('wiko fever 4g', 8.553608547749887),
#               ('lg nexus 5x', 8.54654280043059),
#               ('microsoft lumia 640', 8.470377195613022),
#               ('microsoft lumia 640', 8.470377195613022)],
#              'rick2809': [('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone microsoft lumia', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone motorola moto', 9.93553736718727)],
#              'gianfranco': [('huawei p9 lite', 9.685465507356996),
#               ('huawei p9 lite', 9.685465507356996),
#               ('sony e5603 xperia', 9.568863806629029),
#               ('alcatel one touch', 9.162397660659815),
#               ('honor 7 smartphone', 9.01936097472961),
#               ('lenovo zuk z1', 8.626373652454948),
#               ('lenovo zuk z1', 8.626373652454948),
#               ('nokia asha 305', 8.503324677768559),
#               ('nokia asha 501', 7.931178712488116),
#               ('alcatel pixi 4', 7.2349116060179925)],
#              "client d'amazon": [('blackberry priv smartphone', 10),
#               ('baas nokia lumia', 10),
#               ('huawei mate 9', 10),
#               ('meizu pro 5', 10),
#               ('huawei mate 9', 10),
#               ('wiko robby smartphone', 9.354542124542125),
#               ('lg g2 smartphone', 9.32926021347074),
#               ('oukitel k6000 4g', 9.16101101457532),
#               ('lenovo motorola moto', 9.154166813045924),
#               ('apple iphone se', 9.145702389143583)],
#              'juan': [('samsung galaxy s3', 9.855931520870465),
#               ('nokia lumia 520', 9.235210732632655),
#               ('sony xperia tipo', 9.061930260853378),
#               ('lenovo motorola moto', 9.029410116366817),
#               ('lg nexus 5x', 8.907583367019896),
#               ('lg nexus 5x', 8.907583367019896),
#               ('samsung galaxy s6', 8.862989616128223),
#               ('motorola moto g', 8.663791263535149),
#               ('samsung galaxy young', 8.36655697601423),
#               ('htc one x', 8.292561776264337)],
#              'sergio': [('lg d802 g2', 10),
#               ('huawei ascend y550', 10),
#               ('motorola moto g', 9.927010356465354),
#               ('huawei nexus 6p', 9.919357850436624),
#               ('samsung galaxy s5', 9.777173159001913),
#               ('huawei ascend p7', 9.767081178758563),
#               ('samsung s7582 galaxy', 9.70134629424233),
#               ('apple smartphone iphone', 9.693170154544989),
#               ('lenovo moto g4', 9.520776007106722),
#               ('nokia lumia 925', 9.421541815904565)],
#              'charlie': [('motorola moto g', 9.592045237165152),
#               ('lg 530g prepaid', 9.457369379144765),
#               ('apple iphone 6', 9.26542381793304),
#               ('nokia asha 302', 8.614227082214684),
#               ('samsung galaxy a3', 8.361506252766695),
#               ('samsung galaxy s4', 8.097157033407711),
#               ('samsung galaxy y', 7.953766061169889),
#               ('samsung galaxy j7', 7.79985313949906),
#               ('apple iphone 5s', 7.612800425240838),
#               ('lg ku990 viewty', 7.4413838383243975)],
#              'nicole': [('apple iphone 5c', 10),
#               ('lenovo motorola moto', 9.933316029960935),
#               ('huawei nexus 6p', 9.485134580623718),
#               ('samsung galaxy alpha', 9.278325733824433),
#               ('sony xperia zl', 9.219007798613431),
#               ('archos 50 helium', 8.657912436590493),
#               ('lg electronics t385', 7.574881858511198),
#               ('nokia 7373', 7.296745840727717),
#               ('samsung galaxy s4', 6.475158089359986),
#               ('samsung galaxy j1', 6.4071469284846305)],
#              'ð\x95ð²ð³ðµð½ð¸ñ\x8f': [('samsung n7100 galaxy',
#                9.84074914955184),
#               ('samsung s7270 galaxy', 9.711740597580336),
#               ('sony xperia z1', 9.61423520876878),
#               ('sony xperia z1', 9.61423520876878),
#               ('sony xperia l', 9.605721424567335),
#               ('sony xperia m', 9.462600406377852),
#               ('samsung galaxy a5', 9.166860583917137),
#               ('samsung galaxy s4', 9.118299868325359),
#               ('samsung galaxy s4', 9.118299868325359),
#               ('samsung galaxy note', 8.236090655926603)],
#              'ð\x94ð¸ð¼ð°': [('sony xperia z1', 10),
#               ('samsung i8190 galaxy', 9.828936081917062),
#               ('samsung galaxy s4', 9.824844906681422),
#               ('samsung galaxy ace', 9.265503672845004),
#               ('sony xperia l', 9.052515259511324),
#               ('sony xperia l', 9.052515259511324),
#               ('samsung i5800 galaxy', 8.868410018713975),
#               ('samsung galaxy a3', 8.62970372084243),
#               ('htc desire v', 8.50841014155694),
#               ('htc desire s', 8.231396446033598)],
#              'rpv': [('nokia lumia 720', 10),
#               ('nokia lumia 920', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 920', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 920', 10),
#               ('htc nexus one', 10),
#               ('samsung galaxy s4', 9.965778165664757),
#               ('samsung galaxy s4', 9.965778165664757),
#               ('samsung galaxy s4', 9.965778165664757)],
#              'ana': [('smartphone moto e', 10),
#               ('huawei ascend p6', 10),
#               ('lg nexus 5', 10),
#               ('lg optimus l5', 9.85492756389069),
#               ('motorola cd930', 9.854421524663238),
#               ('smartphone lg optimus', 9.727455705419104),
#               ('samsung galaxy grand', 9.682076563563049),
#               ('samsung galaxy s5', 9.401825438294548),
#               ('apple iphone 5s', 9.154530953745846),
#               ('smartphone samsung galaxy', 9.083650919255112)],
#              'ð\x90ð½ð°ñ\x81ñ\x82ð°ñ\x81ð¸ñ\x8f': [('samsung galaxy s4',
#                9.766354494644208),
#               ('apple iphone se', 9.594754222870247),
#               ('samsung i9082 galaxy', 9.265199838869325),
#               ('asus zenfone 2', 9.236528148200433),
#               ('sony xperia m', 8.819147850448552),
#               ('sony xperia m', 8.819147850448552),
#               ('samsung galaxy a3', 8.782092975593201),
#               ('sony xperia z1', 8.619219308407432),
#               ('sony xperia z', 8.604805375750185),
#               ('samsung s5660 galaxy', 8.406682857741949)],
#              'gary': [('lg g2 sprint', 10),
#               ('huawei mate 9', 9.989352782447455),
#               ('samsung galaxy j5', 9.891749223767064),
#               ('samsung galaxy a3', 9.173780994069755),
#               ('lg g2 mini', 9.095060559656009),
#               ('samsung galaxy s5', 8.618606603687308),
#               ('apple iphone se', 8.455565819698563),
#               ('samsung i9100 galaxy', 8.219186674408583),
#               ('lg verizon lg', 7.8777915141825785),
#               ('nokia lumia 635', 7.2786980604294715)],
#              'mary': [('samsung i9082 galaxy', 9.928567380675961),
#               ('huawei p8 grijs', 9.804158960408808),
#               ('huawei smartphone honor', 9.60899475532867),
#               ('samsung galaxy s3', 9.248840133001094),
#               ('motorola moto g', 9.216787113279304),
#               ('samsung galaxy ace', 9.019196074666784),
#               ('samsung galaxy s4', 8.843257713542547),
#               ('tracfone motorola moto', 8.76959674006276),
#               ('huawei p8 lite', 8.600208590777282),
#               ('samsung factory unlocked', 8.582994167774913)],
#              'mario': [('wiko fever 4g', 10),
#               ('sim free apple', 10),
#               ('samsung 903 galaxy', 10),
#               ('smartphone motorola razr', 10),
#               ('nokia asha 309', 10),
#               ('lg electronics g3', 9.746910978295062),
#               ('huawei ascend g7', 9.718272965892591),
#               ('microsoft lumia 640', 9.582393550086195),
#               ('samsung galaxy mega', 9.31884713590596),
#               ('huawei ascend p8', 9.283945119530541)],
#              'caroline': [('smartphone asus zenfone', 10),
#               ('sim free apple', 9.923474080747386),
#               ('htc desire 310', 9.739269418083952),
#               ('apple iphone 7', 9.229963163256379),
#               ('samsung galaxy j5', 9.225154033380287),
#               ('samsung galaxy j5', 9.225154033380287),
#               ('lenovo moto g4', 8.960516870911446),
#               ('ringke asus zenfone', 8.959420463188678),
#               ('microsoft lumia 640', 8.846193948270034),
#               ('sony ericsson w395', 8.791632845372192)],
#              'kindle customer': [('htc one 32gb', 10),
#               ('nokia lumia 735', 9.566607272885225),
#               ('samsung galaxy siii', 9.52343507107454),
#               ('samsung galaxy j7', 9.227399916583387),
#               ('motorola nexus 6', 8.968288559104057),
#               ('samsung galaxy centura', 8.846803102888195),
#               ('samsung galaxy centura', 8.846803102888195),
#               ('motorola moto g', 8.836941964793333),
#               ('samsung s3350 chat', 8.738312049529549),
#               ('samsung s425g prepaid', 8.672542960915054)],
#              'frank': [('samsung galaxy 3', 10),
#               ('huawei p8 champagne', 10),
#               ('lg electronics nexus', 10),
#               ('wiko rainbow smartphone', 10),
#               ('blackberry q5 smartphone', 9.934066430407894),
#               ('lg g4 us991', 9.883423829317449),
#               ('asus zenfone 2', 9.624426874255132),
#               ('huawei honor 3c', 9.278338318030924),
#               ('samsung galaxy s7', 9.21208726609881),
#               ('nokia lumia 830', 9.191506180834399)],
#              '????????': [('samsung c3782 onyx', 9.74401317192432),
#               ('apple iphone 5', 9.560288378912695),
#               ('apple iphone 5', 9.560288378912695),
#               ('apple iphone 5', 9.560288378912695),
#               ('sony xperia s', 9.493291336339036),
#               ('nokia lumia 820', 9.42249987238811),
#               ('samsung galaxy note', 9.247725389247279),
#               ('samsung galaxy note', 9.247725389247279),
#               ('nokia asha 309', 8.973804785569921),
#               ('caterpillar cat b15', 8.879095837937928)],
#              'claire': [('apple iphone 7', 9.400952346815668),
#               ('apple iphone 7', 9.400952346815668),
#               ('apple iphone 7', 9.400952346815668),
#               ('sim free apple', 8.791094414944585),
#               ('microsoft lumia 640', 8.232651844223042),
#               ('samsung galaxy s4', 7.641424082491237),
#               ('sony ericsson k700i', 7.599355573963077),
#               ('blackberry bold 9900', 7.455723688471896),
# ...
#               ('lenovo motorola moto', 8.74194238326142),
#               ('huawei ascend g510', 8.138294182369593),
#               ('alcatel one touch', 8.054977427534608),
#               ('sony xperia s', 7.77120569706212),
#               ('sony xperia z3', 7.255438147505164),
#               ('samsung galaxy s6', 6.940809635465074),
#               ('samsung galaxy star', 6.51951886952008)],
#              'ciklet': [('nokia e90 cep', 1),
#               ('nokia 5310 cep', 1),
#               ('nokia n70 cep', 1)],
#              'thierry': [('nokia lumia 830', 9.916409592038592),
#               ('zte axon 7', 9.396625047594872),
#               ('zte axon 7', 9.396625047594872),
#               ('zte axon 7', 9.396625047594872),
#               ('nokia microsoft lumia', 9.041902931594368),
#               ('samsung galaxy core', 8.903600422343926),
#               ('samsung galaxy s', 8.76451349869835),
#               ('samsung galaxy s', 8.76451349869835),
#               ('alcatel one touch', 8.101526524741795),
#               ('honor 4x smartphone', 8.015002749812064)],
#              'mel': [('motorola rokr e1', 9.71583849667487),
#               ('huawei ascend mate', 8.788212028514502),
#               ('microsoft lumia 640', 8.632136938538247),
#               ('tech armor galaxy', 6.780105625198238),
#               ('motorola mb300 backflip', 4.9041130351061595)],
#              'bianca': [('smartphone motorola defy', 9.284707674803753),
#               ('huawei p8 grijs', 8.813749568486957),
#               ('sony xperia z5', 8.09602262411619),
#               ('samsung galaxy s6', 7.948181072916167),
#               ('sony ericsson c', 7.923645433138227),
#               ('sony ericsson s500i', 7.873381681614495),
#               ('apple iphone 5c', 3.958850944714164),
#               ('samsung galaxy s4', 3.899613525654565)],
#              'marion': [('apple iphone 7', 8.750236769515453),
#               ('emporia elegance handy', 8.73616506800877),
#               ('doro matra phone', 7.674854984971624),
#               ('lenovo motorola moto', 7.425847460571455),
#               ('sony xperia m4', 6.478262092020971),
#               ('buyus etui housse', 6.335595509998071)],
#              'simona': [('huawei ascend p7', 9.602133766128452),
#               ('asus ze550kl zenfone', 9.158007278567188),
#               ('huawei p8 lite', 8.991346020803018),
#               ('lg g2 mini', 8.25740288043794),
#               ('huawei ascend g7', 8.251535870976294),
#               ('htc desire 816', 8.184785837776356),
#               ('samsung galaxy j5', 7.904925250134868),
#               ('apple iphone 5s', 7.889792578612976),
#               ('blackberry curve 9320', 6.771122974120384),
#               ('homtom ht7 3g', 6.261991307365002)],
#              'enzo': [('lenovo motorola moto', 9.850616936102437),
#               ('lenovo motorola moto', 9.850616936102437),
#               ('huawei p8 lite', 9.563226580335145),
#               ('lg k10 smartphone', 9.542986229092115),
#               ('sony e6653 xperia', 9.441013134592529),
#               ('doogee valencia2 y100', 9.300316531358227),
#               ('apple iphone 5s', 8.913134782080316),
#               ('huawei p9 lite', 8.539765208645752),
#               ('samsung smartphone galaxy', 8.264650291125045),
#               ('samsung g355 galaxy', 7.729040099714672)],
#              'karadag60': [('sony ericsson w995', 2.8147288801605597),
#               ('sony ericsson w910i', 2.195069089519745),
#               ('palm treo pro', 1.838582530017756),
#               ('sony ericsson w610i', 1),
#               ('sony ericsson c903', 1),
#               ('sony ericsson z310i', 1)],
#              'adriana': [('samsung i9060i galaxy', 7.993385163160642),
#               ('sony xperia l', 7.747915548420943),
#               ('smartphone motorola moto', 7.553323660457874),
#               ('samsung galaxy note', 7.024363581119748),
#               ('huawei ascend y300', 6.7943130299415),
#               ('samsung galaxy y', 5.992949444526674),
#               ('motorola xt390', 4.553183797114824),
#               ('palm pre plus', 4.170519403335142),
#               ('blackberry bold 9000', 3.3524033088330274)],
#              'francis': [('samsung galaxy s7', 8.403006140837602),
#               ('samsung galaxy s7', 8.403006140837602),
#               ('motorola moto g', 8.35204994174135),
#               ('samsung galaxy grand', 8.041329899636981),
#               ('apple iphone 7', 7.960657818322577),
#               ('doogee x5 max', 7.178606390076587),
#               ('apple iphone 5', 7.1597471351879864),
#               ('samsung s5230 player', 6.597434957604015),
#               ('lg gt540', 5.87019080583805),
#               ('blackberry bold 9900', 4.067517096321939)],
#              'delicate': [('apple iphone 3gs', 5.145483875155795),
#               ('nokia e52', 3.098034242232086),
#               ('nokia 2730 classic', 3.0799999999999996),
#               ('palm treo 750', 2.991774891774892),
#               ('palm treo 650', 2.5237619450268145),
#               ('nokia 6600i slide', 1.993548387096774)],
#              'flavio': [('huawei nexus 6p', 9.387968974979781),
#               ('lg d855 g3', 8.81441892854442),
#               ('smartphone lg optimus', 8.530913688878847),
#               ('apple iphone 5s', 8.362599360300173),
#               ('asus zenfone 2', 7.962011980678975),
#               ('alcatel one touch', 7.834872704524072),
#               ('lg optimus l5', 7.7768720561780444),
#               ('doogee x5 max', 6.990696738511914),
#               ('huawei ascend y530', 6.846299250262089),
#               ('huawei ascend p8', 5.85767409748081)],
#              'santiago': [('huawei smartphone huawei', 9.434307097289404),
#               ('samsung galaxy s6', 9.07528203458638),
#               ('lenovo motorola moto', 8.541700052177474),
#               ('bq aquaris x5', 7.824789558178765),
#               ('sony xperia p', 7.823056463877498),
#               ('microsoft lumia 640', 7.763604206040039),
#               ('nokia lumia 1320', 7.6449132189359625),
#               ('motorola moto e', 7.441027842899495),
#               ('samsung galaxy s', 7.408790876618271),
#               ('sony xperia z', 7.228339926469667)],
#              'emanetcan': [('sony ericsson w995', 5.147916666666667),
#               ('sony ericsson w810i', 4.962731481481482),
#               ('apple iphone 3g', 4.526704545454546),
#               ('apple iphone 3gs', 4.116792168674699),
#               ('nokia n97 mini', 3.4186046511627906),
#               ('blackberry storm 9530', 2.1479166666666663),
#               ('sony ericsson z320i', 1.3636029411764705),
#               ('nokia 5630 xpressmusic', 1.0464673913043478),
#               ('samsung s8003 jet', 1),
#               ('samsung e250 cep', 1)],
#              'cikolata': [('nokia 5300 xpressmusic', 2.4776683087027918),
#               ('samsung i560 cep', 1),
#               ('nokia e65 cep', 1),
#               ('nokia n76 cep', 1),
#               ('samsung u800 cep', 1)],
#              '???????????????? ??????????????': [('philips xenium w732',
#                9.570597356370161),
#               ('nokia asha 210', 8.834008347338095),
#               ('sony xperia e', 8.736793625228593),
#               ('lenovo k900 32gb', 7.887982809477757),
#               ('samsung galaxy pocket', 7.1114959744596185),
#               ('samsung c3322', 6.0928716719402),
#               ('sony xperia miro', 4.958767302591525)],
#              'jr': [('sony ericsson cedar', 10),
#               ('samsung b5722 handy', 9.782485889803832),
#               ('apple iphone 5s', 9.295474191850813),
#               ('samsung galaxy s3', 9.069220066367642),
#               ('samsung galaxy s7', 8.932701234066405),
#               ('huawei p8 lite', 8.898167992203811),
#               ('blu studio x', 8.799405005131279),
#               ('samsung galaxy s5', 8.006064033233791)],
#              'ozer1299': [('nokia 6500 slide', 2.7835189093486856),
#               ('nokia n81 8gb', 1.3667014672176352),
#               ('samsung d900i 1gb', 1),
#               ('nokia n70 cep', 1),
#               ('nokia x6 cep', 1),
#               ('samsung m620 cep', 1),
#               ('samsung i8000 omnia', 1)],
#              'george': [('samsung galaxy s7', 9.083190301827893),
#               ('samsung g920 galaxy', 9.048414541860444),
#               ('sim free motorola', 8.882090891121603),
#               ('pantech pocket p9060', 8.859228010095016),
#               ('samsung ativ s', 8.715238776552694),
#               ('huawei p9 lite', 8.492050376091145),
#               ('nokia 6310i mobile', 8.147005624724676),
#               ('apple iphone 6', 8.035122779392928),
#               ('lg g flex', 8.024341231137612),
#               ('lg p990 optimus', 7.9945179689265125)],
#              'mustafa': [('samsung i9190 galaxy', 10),
#               ('iphone 5s 16gb', 9.088542033283753),
#               ('samsung s7580 galaxy', 7.493865481442181),
#               ('samsung galaxy j1', 6.3445852295305825)],
#              'xxx': [('sony ericsson xperia', 9.292834011317508),
#               ('doogee x5 pro', 9.192001388987062),
#               ('huawei ascend y300', 9.11714890735296),
#               ('sony ericsson w395', 6.298744423106163)],
#              'emre': [('lg g4 us991', 7.387662765246615),
#               ('motorola razr v3', 4.547530831488144),
#               ('sony xperia z', 3.0503632750807874),
#               ('nokia 5800 xpressmusic', 2.9136572906360136)],
#              'anja': [('microsoft nokia 2760', 9.480843885547904),
#               ('htc desire c', 8.384147481404604),
#               ('huawei p8lite zwart', 8.345173920106932),
#               ('vodafone smart 4', 7.61039369406897),
#               ('sony ericsson c902', 7.483111554812638),
#               ('htc one max', 7.195208358750312),
#               ('sony xperia sp', 6.953693701084832),
#               ('htc desire 310', 6.90801390330095),
#               ('samsung galaxy ace', 6.747154020638287),
#               ('samsung galaxy y', 6.6804831265447255)],
#              '????????????????': [('samsung c3782 onyx', 10),
#               ('huawei u8860 honor', 9.861843379153514),
#               ('nokia n9', 8.572498317046213),
#               ('nokia asha 210', 8.246607510541452),
#               ('htc desire c', 8.228103553127541),
#               ('apple iphone 4s', 8.089350874064241),
#               ('sony xperia v', 7.7281383252413605)],
#              'me': [('samsung c5212 duos', 9.63533395929272),
#               ('lg env touch', 8.525539950416066),
#               ('samsung gt s5260', 8.405766416107381),
#               ('lg electronics leon', 8.102073073508414),
#               ('doro phoneeasy 410gsm', 6.989119791241418),
#               ('microsoft nokia lumia', 6.93847462489076),
#               ('sony xperia z', 6.870574498674762),
#               ('alcatel onetouch onetouch', 6.841142759366822),
#               ('htc one m8', 6.656307079191064),
#               ('samsung galaxy note', 6.411083497061238)],
#              'dolunay': [('samsung galaxy mini', 7.557390075469344),
#               ('samsung s5233w star', 1),
#               ('nokia n73 cep', 1),
#               ('nokia n72 cep', 1),
#               ('samsung d900i 1gb', 1)],
#              'sezenm': [('nokia 5500 sport', 1.347595356464064),
#               ('nokia n95 cep', 1),
#               ('samsung p520 armani', 1),
#               ('nokia n72 cep', 1),
#               ('nokia 6131 cep', 1)],
#              'damien': [('lg g2 mini', 9.467591785848708),
#               ('microsoft lumia 535', 8.88486963311085),
#               ('motorola defy', 8.401394144652292),
#               ('lg nexus 5', 8.035936087035083),
#               ('samsung galaxy s6', 7.913373495375872),
#               ('nokia e63', 7.5393134014787995)],
#              'ram': [('microsoft lumia 640', 7.991949652744115),
#               ('microsoft lumia 640', 7.991949652744115),
#               ('apple iphone 6', 6.4797545667187695),
#               ('htc evo 3d', 5.160409259953463)],
#              'tuvok': [('samsung galaxy express', 8.924232745123062)],
#              'tobias': [('htc mozart 7', 10),
#               ('samsung galaxy s', 9.365771428000755),
#               ('huawei mate 9', 9.078640471196419),
#               ('microsoft nokia 108', 8.785995802444935),
#               ('lg electronics google', 8.692807613868991),
#               ('samsung galaxy s4', 8.331835094575464),
#               ('lenovo motorola moto', 8.263339757567337),
#               ('asus padfone 2', 7.122573577761844),
#               ('microsoft lumia 650', 6.720431737868688),
#               ('apple iphone 6', 5.993709595485038)],
#              'alice': [('huawei ascend mate', 9.818685852408708),
#               ('samsung a5 2016', 9.567976509810546),
#               ('asus ze550kl zenfone', 9.46874278232641),
#               ('smartphone samsung galaxy', 9.462891378750877),
#               ('doro phoneeasy 612', 8.744767169149677),
#               ('samsung galaxy a3', 8.68313971690562),
#               ('doro phone easy', 8.555427802389948),
#               ('asus zenfone 2', 8.08458656309722),
#               ('samsung galaxy s4', 7.698840136512942),
#               ('microsoft lumia 650', 7.0975980008001125)],
#              'zehrabalta': [('apple iphone 4', 6.101063829787234),
#               ('nokia n97 mini', 3.4186046511627906),
#               ('sony ericsson z310i', 3.0),
#               ('nokia e90 cep', 1),
#               ('nokia n95 cep', 1)],
#              '???????\x80????': [('samsung c3782 onyx', 10),
#               ('sony xperia v', 9.435705041394193),
#               ('nokia 603', 8.483217710307924),
#               ('htc sensation xl', 8.256843622621245),
#               ('apple iphone 4s', 7.451543792648856),
#               ('nokia asha 311', 6.917423792829233)],
#              'louis': [('htc desire sim', 10),
#               ('nokia lumia 830', 10),
#               ('samsung galaxy s7', 9.770120844328654),
#               ('sony ericsson w580', 9.754831049520226),
#               ('doogee x5 pro', 9.607839235201295),
#               ('nokia microsoft lumia', 9.541999017276758),
#               ('sony ericsson xperia', 9.070406185249922),
#               ('sony xperia t', 8.998805610407578),
#               ('apple iphone 4s', 8.45034058003127),
#               ('archos 28 internet', 8.425228674349647)],
#              'bert': [('sim free motorola', 9.695617605832515),
#               ('huawei p8 grijs', 9.471997227515796),
#               ('huawei p8 champagne', 9.226862914927839),
#               ('samsung b2710 solid', 9.175234691895925),
#               ('apple iphone se', 8.008474842506274),
#               ('apple iphone 5s', 7.7178821358316565)],
#              'narn3049': [('pearl 8100', 7.367704076286283),
#               ('v300', 7.367704076286283),
#               ('sony ericsson xperia', 5.9163344512989156)],
#              'sue': [('sim free apple', 10),
#               ('samsung s3350 chat', 9.754727407306788),
#               ('samsung galaxy s', 8.859331791013496),
#               ('blackberry dtek50 unlocked', 8.706640319953665),
#               ('huawei p9 lite', 8.524148734678988),
#               ('samsung e1270 uk', 7.565706982271431),
#               ('lg electronics ks360', 6.394946978227544)],
#              'sunny': [('sony xperia s', 9.807947793850039),
#               ('doro phoneeasy 622', 9.590153903457695),
#               ('apple iphone 6s', 8.810340710079618),
#               ('samsung galaxy a3', 8.544063627249882),
#               ('huawei p8 lite', 8.504542329974482),
#               ('lg electronics e610', 7.418549407046377),
#               ('karbonn titanium octane', 5.509253042427766),
#               ('apple iphone 3g', 4.894881806186739)],
#              'raquel': [('blackberry torch 9810', 8.313335489363809),
#               ('motorola moto g', 8.189549914755764),
#               ('samsung galaxy s6', 7.871634143574594),
#               ('htc one', 7.157592163958396),
#               ('smartphone lg optimus', 6.583479814537388),
#               ('apple iphone 5', 6.448334962192763)],
#              'aksisey': [('nokia 6500 slide', 3.0),
#               ('nokia n70 cep', 1),
#               ('nokia e65 cep', 1)]})

# %%
### Cross validate

# %%
from surprise.model_selection import cross_validate

# %%
algo_user = KNNWithMeans(k=10, sim_options={ 'user_based': True})
cross_validate(algo_user, data1, measures=['RMSE', 'MAE'], cv=5, verbose=True)
test_pred=algo_user.test(testset)
print(accuracy.rmse(test_pred))
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.0025  3.0105  2.9840  3.0126  3.0126  3.0044  0.0109
# MAE (testset)     2.3690  2.3802  2.3507  2.3779  2.3717  2.3699  0.0104
# Fit time          1.19    1.19    1.19    1.01    1.22    1.16    0.07
# Test time         4.29    4.21    4.13    4.34    4.21    4.24    0.07
# RMSE: 2.3860
# 2.38600805666108

# %%
top_cv = get_top_n(test_pred, n=10)
top_cv
# Out:
# defaultdict(list,
#             {'alexander': [('huawei ascend mate', 10),
#               ('htc one x', 9.763126622869105),
#               ('sony ericsson k750i', 9.586751027820915),
#               ('samsung galaxy s3', 9.530019967925494),
#               ('huawei ascend g600', 9.449439889797251),
#               ('htc one smartphone', 9.199174390110715),
#               ('nokia c6 unlocked', 8.978927974770249),
#               ('sony xperia m4', 8.902603289372875),
#               ('lenovo motorola moto', 8.836198570468838),
#               ('sony ericsson txt', 8.73360017338344)],
#              'juan carlos': [('huawei p9 lite', 10),
#               ('apple iphone 5s', 10),
#               ('sony xperia z5', 9.737967435330516),
#               ('samsung galaxy s3', 9.52399959197863),
#               ('samsung galaxy s3', 9.52399959197863),
#               ('samsung galaxy ace', 9.417568737623087),
#               ('samsung galaxy ace', 9.417568737623087),
#               ('galaxy samsung galaxy', 9.377393093787685),
#               ('sony xperia p', 9.309147894646102),
#               ('blackberry bold 9790', 9.065855420033389)],
#              'maria': [('samsung galaxy j5', 9.93410864737917),
#               ('samsung galaxy j5', 9.93410864737917),
#               ('samsung korea samsung', 9.851755929077926),
#               ('doro phoneeasy 612', 9.817637525942553),
#               ('sim free samsung', 9.791947812322366),
#               ('samsung galaxy s3', 9.791550993704119),
#               ('samsung galaxy s3', 9.791550993704119),
#               ('samsung galaxy s3', 9.791550993704119),
#               ('huawei ascend g750', 9.71944427147846),
#               ('lenovo moto g4', 9.697756287857949)],
#              'alex': [('sim free samsung', 10),
#               ('lg p500 optimus', 10),
#               ('samsung i9500 galaxy', 9.996884141920445),
#               ('vodafone e1200 pay', 9.985157909778575),
#               ('huawei honor 8', 9.976795181123897),
#               ('htc desire s', 9.916665852487712),
#               ('apple iphone 5', 9.914980576919124),
#               ('nokia n91', 9.858033443439057),
#               ('lg electronics p500', 9.831525883004932),
#               ('nokia lumia 830', 9.7643548243959)],
#              'francesco': [('samsung j510 galaxy', 10),
#               ('doogee smartphone dual', 10),
#               ('asus zenfone max', 10),
#               ('doogee x5 max', 9.958377973929265),
#               ('lg nexus 4', 9.957117413991956),
#               ('lg k10 smartphone', 9.909218869955545),
#               ('microsoft lumia 640', 9.896099601832145),
#               ('lenovo k3 note', 9.843814804788625),
#               ('huawei ascend g615', 9.840908423330905),
#               ('oukitel k10000 smartphone', 9.793726473599742)],
#              'ð\x98ñ\x80ð¸ð½ð°': [('nokia 5230 navigation', 7.384568204121688),
#               ('sony xperia sp', 7.384568204121688),
#               ('samsung galaxy a3', 7.384568204121688),
#               ('samsung galaxy core', 7.384568204121688),
#               ('samsung galaxy s5', 7.384568204121688),
#               ('apple iphone 4', 7.384568204121688),
#               ('samsung galaxy a3', 7.384568204121688),
#               ('apple iphone 5s', 7.384568204121688),
#               ('sony xperia c', 7.384568204121688),
#               ('samsung i9082 galaxy', 7.384568204121688)],
#              'anna': [('huawei ascend p7', 9.648761601732433),
#               ('htc desire 816', 9.596405269428264),
#               ('samsung galaxy s5', 9.586615943848603),
#               ('samsung galaxy s5', 9.586615943848603),
#               ('huawei p9 lite', 9.585335756402127),
#               ('huawei smartphone honor', 9.380646142303947),
#               ('htc one s', 9.276727228094911),
#               ('samsung galaxy j5', 9.22646348412801),
#               ('lg electronics optimus', 9.223158895830284),
#               ('samsung e1270 telefono', 9.088227661045597)],
#              'kim': [('ee alcatel one', 9.940258532408258),
#               ('apple iphone 5c', 9.77232633311382),
#               ('samsung galaxy grand', 9.537570521945877),
#               ('samsung galaxy j7', 9.398252004241417),
#               ('samsung galaxy s', 9.299822151289025),
#               ('samsung wave 525', 9.052371872954268),
#               ('htc flyer 7', 8.943340186592692),
#               ('microsoft lumia 650', 8.166598176731803),
#               ('samsung galaxy prevail', 8.100171901887176),
#               ('huawei p8 grijs', 8.098665170342597)],
#              'ð\x92ð°ð»ðµñ\x80ð¸ð¹': [('sony xperia c', 7.384568204121688),
#               ('samsung galaxy s5', 7.384568204121688),
#               ('sony xperia c', 7.384568204121688),
#               ('htc nexus one', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('apple iphone 5s', 7.384568204121688),
#               ('samsung galaxy s7', 7.384568204121688),
#               ('samsung i8150 galaxy', 7.384568204121688),
#               ('sony xperia sp', 7.384568204121688)],
#              'chris': [('sim free apple', 9.963311505832555),
#               ('lg electronics g2', 9.935833816146854),
#               ('htc one 32gb', 9.797122138772536),
#               ('samsung rugby 2', 9.75352032986281),
#               ('lg g2 d800', 9.677596771551434),
#               ('lg electronics g5', 9.592097501105764),
#               ('sony xperia z3', 9.565576755834998),
#               ('cubot note s', 9.478859021948558),
#               ('cubot note s', 9.478859021948558),
#               ('sony ericsson w995', 9.427635494750602)],
#              'kevin': [('sony ericsson arc', 9.94411370893997),
#               ('htc mozart 7', 9.923519563415779),
#               ('just 1 j509', 9.88022106112442),
#               ('sim free apple', 9.87539593588046),
#               ('ringke asus zenfone', 9.769653801658418),
#               ('lenovo moto g4', 9.58463287364062),
#               ('htc 7 trophy', 9.55592194468903),
#               ('apple iphone 6s', 9.434322110667171),
#               ('sony xperia z3', 9.364655928953669),
#               ('honor 7 smartphone', 9.309051873176514)],
#              'markus': [('honor 6 smartphone', 9.596780108730876),
#               ('sony xperia z5', 9.595074866372379),
#               ('samsung galaxy nexus', 9.551636191951053),
#               ('motorola nexus 6', 9.310010925117675),
#               ('sony ericsson c905', 9.189652348637356),
#               ('sony xperia z1', 9.188344539531988),
#               ('cubot note s', 9.072509436772927),
#               ('microsoft lumia 640', 8.975231394692361),
#               ('microsoft lumia 640', 8.975231394692361),
#               ('samsung galaxy ace', 8.78417873774291)],
#              'silvia': [('lenovo motorola k1', 10),
#               ('nokia lumia 630', 9.570746989265816),
#               ('nokia lumia 630', 9.570746989265816),
#               ('alcatel one touch', 9.523412428408825),
#               ('samsung i9105p galaxy', 9.449885467983608),
#               ('htc one m8', 9.445012257164727),
#               ('huawei p9 lite', 9.35208965348935),
#               ('huawei p9 lite', 9.35208965348935),
#               ('samsung ativ s', 9.347073173223986),
#               ('asus zenfone 2', 9.230307695590604)],
#              'david': [('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('samsung galaxy s6', 10),
#               ('nokia 6210', 10),
#               ('lg electronics l7', 10),
#               ('samsung galaxy s6', 10),
#               ('samsung i9250 galaxy', 9.914784059460203),
#               ('sony xperia zl', 9.903577912614342),
#               ('huawei mate 9', 9.80892251801535)],
#              'ð\x93ð¾ñ\x81ñ\x82ñ\x8c': [('nokia 6303i classic',
#                7.384568204121688),
#               ('nokia 6700 classic', 7.384568204121688),
#               ('nokia 6303i classic', 7.384568204121688),
#               ('nokia n97 mini', 7.384568204121688),
#               ('nokia e72', 7.384568204121688),
#               ('htc windows phone', 7.384568204121688),
#               ('nokia 6300', 7.384568204121688),
#               ('apple iphone 3gs', 7.384568204121688),
#               ('apple iphone 4', 7.384568204121688),
#               ('nokia 5530 xpressmusic', 7.384568204121688)],
#              'salvatore': [('huawei p9 lite', 10),
#               ('huawei mate 8', 9.628705709183743),
#               ('lg h410 wine', 9.556536429589043),
#               ('samsung e1270 telefono', 9.37028262007414),
#               ('sony xperia z1', 9.331024646478607),
#               ('doogee x5 max', 9.301279559694647),
#               ('huawei ascend g700', 9.149050732974418),
#               ('nokia asha 200', 9.005654359696596),
#               ('huawei ascend g6', 8.836502335785319),
#               ('alcatel one touch', 8.492909124005525)],
#              'no captured': [('lg p698 optimus', 10),
#               ('lenovo s820 8gb', 10),
#               ('sony ericsson w900i', 10),
#               ('htc butterfly s', 10),
#               ('motorola timeport p7389', 10),
#               ('sony ericsson w900i', 10),
#               ('lenovo s820 8gb', 10),
#               ('sony ericsson w900i', 10),
#               ('motorola timeport p7389', 10),
#               ('lenovo a859', 10)],
#              'amazon customer': [('lg l70 d320n', 10),
#               ('vodafone 155 big', 9.927716218508879),
#               ('vodafone 155 big', 9.927716218508879),
#               ('motorola v70', 9.862781071793622),
#               ('nokia 113 handy', 9.833527564174787),
#               ('nokia e71 unlocked', 9.81209690544581),
#               ('lg electronics d605', 9.777588668355648),
#               ('sony ericsson z610i', 9.761447079406874),
#               ('zte unlocked zte', 9.741049733890462),
#               ('lg g2 smartphone', 9.730730274431135)],
#              'marie': [('samsung galaxy a3', 9.703896304014192),
#               ('samsung galaxy s3', 9.699681123556278),
#               ('lg electronics gd880', 9.469682930116585),
#               ('palm germany gmbh', 9.42930883122032),
#               ('samsung galaxy j7', 9.294451963321638),
#               ('sony xperia tipo', 9.272584681810388),
#               ('huawei ascend g510', 9.04400354092733),
#               ('apple iphone 4s', 8.962218114977595),
#               ('apple iphone 6s', 8.95742291211666),
#               ('apple iphone 6s', 8.95742291211666)],
#              'james': [('sim free apple', 9.993947317896811),
#               ('apple iphone 5', 9.868951091828778),
#               ('apple iphone 5', 9.868951091828778),
#               ('huawei ascend p6', 9.664382289743163),
#               ('blackberry classic', 9.652091216689529),
#               ('samsung galaxy grand', 9.589319446062888),
#               ('microsoft lumia 430', 9.500758476133305),
#               ('htc one x', 9.429718879555526),
#               ('zte axon 7', 9.400027055039173),
#               ('lg g2 d801', 9.248541913582166)],
#              'pascal': [('apple iphone 5s', 10),
#               ('htc one a9', 10),
#               ('samsung e1190 sim', 10),
#               ('apple iphone 5s', 10),
#               ('alcatel one touch', 9.915117902589335),
#               ('alcatel one touch', 9.915117902589335),
#               ('samsung galaxy j5', 9.812657061082508),
#               ('htc one m8s', 9.800723610807784),
#               ('tech armor samsung', 9.70016870077793),
#               ('sony mobile xperia', 9.544908537155727)],
#              'valentina': [('samsung galaxy ace', 10),
#               ('huawei p9 lite', 10),
#               ('samsung galaxy j5', 10),
#               ('samsung galaxy s7', 10),
#               ('lenovo motorola moto', 9.966135216284714),
#               ('microsoft lumia 535', 9.939709668028993),
#               ('samsung a300 galaxy', 9.825446836288553),
#               ('huawei p8 lite', 9.8107031840512),
#               ('lg g4 smartphone', 9.680961601175566),
#               ('samsung i9082 galaxy', 9.61532551320554)],
#              'sabrina': [('sony xperia z3', 9.955472149412353),
#               ('motorola moto g', 9.927507189678652),
#               ('samsung galaxy s5', 9.83108908146676),
#               ('smartphone asus zenfone', 9.54574319687025),
#               ('sony ericsson k770i', 9.501134150850728),
#               ('samsung galaxy y', 9.480764744286105),
#               ('samsung i9301 galaxy', 9.328786820276616),
#               ('huawei ascend p6', 9.283265525674224),
#               ('samsung galaxy trend', 9.018135877077935),
#               ('apple iphone 4s', 8.940856206563415)],
#              'simone': [('motorola moto g', 10),
#               ('microsoft lumia 640', 9.936548816470761),
#               ('microsoft nokia 7230', 9.884717696266309),
#               ('asus zenfone 5', 9.858091657331599),
#               ('asus zenfone 5', 9.858091657331599),
#               ('honor 6x smartphone', 9.75151486385581),
#               ('asus zenfone 3', 9.708671171328257),
#               ('asus zenfone 2', 9.666850245231807),
#               ('htc desire 500', 9.599320733351341),
#               ('oukitel u7 plus', 9.519217441550177)],
#              'amazon kunde': [('microsoft nokia 5310', 9.56144134980499),
#               ('alcatel one touch', 9.514172976949965),
#               ('nokia 6310i silver', 9.400701110158497),
#               ('oukitel k6000 pro', 9.331825989066402),
#               ('microsoft nokia 7230', 9.288139394724558),
#               ('sony xperia xcompact', 9.257716453428163),
#               ('sony xperia xcompact', 9.257716453428163),
#               ('sony xperia zl', 9.150839275286497),
#               ('microsoft nokia e72', 8.99553233827492),
#               ('motorola moto e', 8.93130544071653)],
#              'jean': [('htc sensation sim', 9.584943054645302),
#               ('sony xperia z2', 9.387432423383697),
#               ('smartphone samsung galaxy', 9.272501107322535),
#               ('smartphone samsung galaxy', 9.272501107322535),
#               ('smartphone samsung galaxy', 9.272501107322535),
#               ('nokia lumia 625', 8.697739707417947),
#               ('samsung galaxy s7', 8.55544277129976),
#               ('samsung instinct', 8.429128442719561),
#               ('smartphone alcatel one', 8.288184487120331),
#               ('buyus etui housse', 8.252669655326406)],
#              'valerio': [('lenovo motorola moto', 10),
#               ('samsung galaxy a3', 10),
#               ('samsung galaxy note', 10),
#               ('samsung ativ s', 9.895919125734128),
#               ('microsoft lumia 950', 9.69518491108646),
#               ('sony xperia x', 9.554075062739727),
#               ('huawei p8 lite', 9.534507304085285),
#               ('samsung galaxy sii', 8.984529912944083),
#               ('xiaomi hongmi 1s', 8.918616790902204),
#               ('huawei p9 plus', 8.854689758279143)],
#              'zã¡kaznã\xadk': [('sony xperia z1', 10),
#               ('samsung galaxy s5', 10),
#               ('samsung galaxy s4', 10),
#               ('samsung galaxy s5', 10),
#               ('samsung galaxy s5', 10),
#               ('htc desire 820', 10),
#               ('samsung galaxy s3', 9.961085310099374),
#               ('samsung galaxy s3', 9.961085310099374),
#               ('htc desire 510', 9.8745507315861),
#               ('nokia lumia 630', 9.85956667842784)],
#              'john': [('sim free apple', 9.892792723416312),
#               ('nokia 2760 sim', 9.857532395737666),
#               ('nokia lumia 1020', 9.70999267109882),
#               ('nokia lumia 1020', 9.70999267109882),
#               ('motorola razri uk', 9.661439161251199),
#               ('sony ericsson w810i', 9.644736717638201),
#               ('sony xperia e3', 9.585606896186846),
#               ('samsung galaxy j5', 9.555309831382036),
#               ('blackberry z10 smartphone', 9.517636898571302),
#               ('tech armor samsung', 9.492276220764046)],
#              'manish': [('micromax canvas turbo', 9.559453761551843),
#               ('huawei honor 5x', 9.414563350975525),
#               ('huawei honor 8', 9.339987839655972),
#               ('samsung galaxy j2', 8.89241651279233),
#               ('micromax unite 2', 8.785300406134615),
#               ('nokia lumia 530', 8.42596979805842),
#               ('apple iphone 5s', 7.767572741423975),
#               ('samsung galaxy a8', 6.870941915301559),
#               ('huawei nexus 6p', 6.426454424018626),
#               ('apple iphone 6', 6.184817529093702)],
#              'angel': [('lg g3 d855', 10),
#               ('samsung galaxy core', 9.328881797194128),
#               ('lg optimus g', 9.276208749299053),
#               ('sony xperia z3', 9.239912725493898),
#               ('sony xperia z3', 9.239912725493898),
#               ('microsoft lumia 640', 9.128818373790018),
#               ('lg voyager', 8.94100334923218),
#               ('sony ericsson xperia', 8.932972646626531),
#               ('samsung galaxy ace', 8.55084895285236),
#               ('samsung galaxy ace', 8.55084895285236)],
#              'sandy': [('nokia n9 unlocked', 9.88572008414091),
#               ('tech armor galaxy', 9.718112588728514),
#               ('microsoft nokia 6303i', 9.606607328396274),
#               ('nokia lumia 520', 9.59858368333468),
#               ('lg google nexus', 9.591370496791951),
#               ('huawei ascend y300', 9.57783506431812),
#               ('samsung galaxy s7', 9.295238180626043),
#               ('tudia zenfone 3', 9.25345565696102),
#               ('lg 800g prepaid', 9.086098251023266),
#               ('apple iphone 4', 8.886616551491391)],
#              'angelo': [('apple iphone 5c', 10),
#               ('lg k10 smartphone', 9.851110232340439),
#               ('wiko fever 4g', 9.769792101033715),
#               ('sony xperia z3', 9.730045614183911),
#               ('sony xperia z3', 9.730045614183911),
#               ('samsung galaxy note', 9.720231833853589),
#               ('samsung c3590 telefono', 9.571460959195699),
#               ('huawei p8 lite', 9.40656740127264),
#               ('asus zenfone 2', 9.231762954097553),
#               ('lg h410 wine', 9.207580134807404)],
#              'prashant': [('sony xperia t2', 8.938737490111825),
#               ('htc desire 816', 8.779828830456164),
#               ('meizu m1 note', 8.362745691331574),
#               ('asus zenfone max', 8.23651416408423),
#               ('google nexus 5', 7.984421458310285),
#               ('lenovo vibe x3', 7.692557068754738),
#               ('hp slate 6', 6.762423668914721),
#               ('blackberry bold 9790', 6.40679998835814),
#               ('motorola moto g', 6.368623221111674),
#               ('lenovo vibe p1m', 6.122599352131907)],
#              'ð\x92ð¸ðºñ\x82ð¾ñ\x80ð¸ñ\x8f': [('samsung galaxy s5',
#                7.384568204121688),
#               ('sony xperia m', 7.384568204121688),
#               ('htc desire 620g', 7.384568204121688),
#               ('apple iphone se', 7.384568204121688),
#               ('sony xperia sp', 7.384568204121688),
#               ('nokia 5230 xpressmusic', 7.384568204121688),
#               ('samsung n7100 galaxy', 7.384568204121688),
#               ('sony xperia sp', 7.384568204121688),
#               ('samsung galaxy s5', 7.384568204121688),
#               ('sony xperia l', 7.384568204121688)],
#              'eli': [('samsung galaxy core', 9.584730841003877),
#               ('huawei p8 lite', 9.277612538895559),
#               ('nokia lumia 800', 8.612945206315304),
#               ('doogee dagger dg550', 8.214951295299379),
#               ('asus zenfone 2', 7.580249428613678),
#               ('samsung galaxy s7', 7.262579333254375),
#               ('smartphone lg l90', 7.005862842312563),
#               ('samsung t404g prepaid', 6.182414388207683),
#               ('motorola verizon motorola', 2.888642005785548)],
#              'andrea': [('lenovo motorola k1', 10),
#               ('samsung j510 galaxy', 9.816474396536519),
#               ('tudia zenfone 3', 9.811520000736904),
#               ('lenovo moto g4', 9.80865023000781),
#               ('doro phoneeasy 612', 9.803283124159082),
#               ('samsung galaxy s3', 9.799307687846714),
#               ('samsung galaxy s3', 9.799307687846714),
#               ('huawei ascend g750', 9.758059493178207),
#               ('nokia lumia 735', 9.704590541615211),
#               ('meizu m2 note', 9.701315927714822)],
#              'ð\x90ð»ðµðºñ\x81ð°ð½ð´ñ\x80': [('sony xperia z1',
#                7.384568204121688),
#               ('sony xperia l', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('samsung s5570 galaxy', 7.384568204121688),
#               ('samsung galaxy note', 7.384568204121688),
#               ('xiaomi mi4i 16gb', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('sony xperia zr', 7.384568204121688),
#               ('lg optimus l9', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688)],
#              'anonymous': [('lg none none', 10),
#               ('apple iphone 4s', 9.93365777727955),
#               ('samsung galaxy j5', 9.882415482358297),
#               ('apple iphone 6', 9.836108838428018),
#               ('apple iphone 7', 9.8),
#               ('apple iphone 7', 9.8),
#               ('apple iphone 7', 9.8),
#               ('samsung galaxy s7', 9.8),
#               ('apple iphone 7', 9.8),
#               ('apple iphone 7', 9.8)],
#              'alexandre': [('samsung galaxy s6', 10),
#               ('lg a290', 9.658294108641346),
#               ('samsung wave m', 9.596596372110396),
#               ('microsoft lumia 435', 9.527920292047119),
#               ('celular desbloqueado samsung', 9.297272498424183),
#               ('nokia lumia 520', 9.250844173467563),
#               ('smartphone lg l90', 9.112576005879745),
#               ('smartphone samsung galaxy', 9.07136640557006),
#               ('nokia lumia 530', 7.615686089780051),
#               ('samsung galaxy s', 6.515881872627009)],
#              'eva': [('blackberry curve 9360', 9.09691560739443),
#               ('samsung galaxy s5', 9.018444273761464),
#               ('meizu m3s 16gb', 8.973208585162563),
#               ('samsung galaxy note', 8.40611550024649),
#               ('samsung galaxy s7', 7.9514371484018325),
#               ('samsung j320 galaxy', 7.897236490144367),
#               ('smartphone lg optimus', 7.660079967742608),
#               ('huawei ascend y201', 7.625350143009009),
#               ('htc windows phone', 7.548414191048076),
#               ('htc desire 500', 7.4995497489120675)],
#              'cliente amazon': [('lenovo motorola k1', 9.968863561349751),
#               ('htc desire 530', 9.845061803225883),
#               ('motorola nexus 6', 9.810834590011263),
#               ('blackberry priv smartphone', 9.748942402865486),
#               ('sony xperia z2', 9.738053385941292),
#               ('sony xperia z2', 9.738053385941292),
#               ('sony xperia z2', 9.738053385941292),
#               ('sony xperia e4', 9.531940319577044),
#               ('doro phone easy', 9.52192279800341),
#               ('samsung ativ s', 9.465697824286192)],
#              'nicolas': [('htc one m8s', 10),
#               ('sony ericsson xperia', 9.904916003218498),
#               ('htc one m8', 9.846399515040325),
#               ('samsung galaxy mega', 9.824316796781023),
#               ('sony xperia m', 9.7367610793792),
#               ('apple iphone 4s', 9.62706421715766),
#               ('nokia lumia 930', 9.546492131185033),
#               ('huawei p8 lite', 9.405638958970702),
#               ('huawei p8 lite', 9.405638958970702),
#               ('samsung i9105p galaxy', 9.383844739896368)],
#              'mike': [('samsung galaxy note', 9.99768063203063),
#               ('sim free apple', 9.96759646867),
#               ('sim free apple', 9.96759646867),
#               ('motorola moto g', 9.871758419210927),
#               ('htc one m8', 9.830894902829803),
#               ('motorola moto x', 9.800143972436782),
#               ('htc one 32gb', 9.793780082528452),
#               ('microsoft nokia 2710', 9.750427462934557),
#               ('samsung galaxy s8', 9.653792531769822),
#               ('lenovo moto g4', 9.57771634426392)],
#              'andreas': [('honor 8 smartphone', 9.59320072342367),
#               ('acer liquid e2', 9.53974678675752),
#               ('honor 6 smartphone', 9.519464274518725),
#               ('samsung galaxy a5', 9.398007266792606),
#               ('sony xperia s', 9.322873666134823),
#               ('sony xperia z1', 9.220602814656422),
#               ('sony xperia z1', 9.220602814656422),
#               ('sony xperia z2', 9.040196387549836),
#               ('lg electronics g', 8.954860231332606),
#               ('samsung galaxy s4', 8.756168223989382)],
#              'stefan': [('lenovo motorola razr', 9.98465840571128),
#               ('microsoft lumia 640', 9.910351701614251),
#               ('just 1 j509', 9.867127587786547),
#               ('sony xperia xcompact', 9.76843087794733),
#               ('lenovo moto g4', 9.716702330864699),
#               ('microsoft nokia 100', 9.655248589705966),
#               ('apple iphone 6s', 9.598881745195216),
#               ('samsung m8800 pixon', 9.515020819515797),
#               ('samsung galaxy s3', 9.48761217356725),
#               ('sony xperia xz', 9.351653835017437)],
#              'ð\x9fð¾ð»ñ\x8cð·ð¾ð²ð°ñ\x82ðµð»ñ\x8c ñ\x81ðºñ\x80ñ\x8bð» ñ\x81ð²ð¾ð¸ ð´ð°ð½ð½ñ\x8bðµ': [('sony xperia z3',
#                7.384568204121688),
#               ('microsoft lumia 640', 7.384568204121688),
#               ('asus zenfone 2', 7.384568204121688),
#               ('asus zenfone 2', 7.384568204121688),
#               ('huawei honor 4x', 7.384568204121688),
#               ('asus zenfone 3', 7.384568204121688),
#               ('microsoft lumia 650', 7.384568204121688),
#               ('lenovo vibe p1', 7.384568204121688),
#               ('microsoft lumia 950', 7.384568204121688),
#               ('samsung galaxy s5', 7.384568204121688)],
#              'jose': [('sony xperia z2', 9.807524419223745),
#               ('sim free motorola', 9.593214821800363),
#               ('lenovo motorola moto', 9.582439358722212),
#               ('lenovo motorola moto', 9.582439358722212),
#               ('asus zenfone 2', 9.574388168785688),
#               ('smartphone samsung galaxy', 9.513209342560554),
#               ('smartphone samsung galaxy', 9.513209342560554),
#               ('smartphone samsung galaxy', 9.513209342560554),
#               ('microsoft lumia 640', 9.488298584511867),
#               ('microsoft lumia 640', 9.488298584511867)],
#              'antonio': [('samsung g920 galaxy', 9.825694758488147),
#               ('samsung g920 galaxy', 9.825694758488147),
#               ('microsoft lumia 640', 9.711357112495147),
#               ('microsoft lumia 640', 9.711357112495147),
#               ('samsung a5 2016', 9.65004759011215),
#               ('apple iphone 5', 9.641951154735315),
#               ('samsung ativ s', 9.630602942952777),
#               ('samsung galaxy j7', 9.627156963584891),
#               ('apple iphone 6s', 9.605488650822998),
#               ('huawei ascend y330', 9.500568921342468)],
#              'anonieme bezoeker': [('nokia lumia 920', 8.68997043219644),
#               ('huawei ascend g510', 8.549173357034512),
#               ('blackberry bold 9900', 8.505986853963648),
#               ('nokia asha 200', 8.295383047065922),
#               ('lg optimus l3', 8.191189270484132),
#               ('samsung galaxy s4', 8.154953696518184),
#               ('samsung galaxy s4', 8.154953696518184),
#               ('sony xperia t', 8.109968413240427),
#               ('samsung galaxy s', 8.00516080448164),
#               ('apple iphone 5', 7.963754056971086)],
#              'toni': [('sim free samsung', 10),
#               ('samsung galaxy note', 10),
#               ('motorola moto x', 9.627692449796216),
#               ('desconocido xiaomi redmi', 9.594586285041103),
#               ('apple iphone 5s', 9.349220945024204),
#               ('samsung i9301 galaxy', 9.309477791921493),
#               ('zte axon 7', 9.267327677782582),
#               ('nokia lumia 625', 9.245499991616722),
#               ('microsoft lumia 640', 9.220966350977488),
#               ('asus zenfone selfie', 9.097995881464431)],
#              'lukas': [('huawei u8860 smartphone', 9.33128710407224),
#               ('htc one smartphone', 9.267989946925013),
#               ('motorola moto g', 9.203600259670829),
#               ('lenovo moto x', 9.19461727824935),
#               ('zte blade v7', 9.157921683859962),
#               ('microsoft lumia 640', 9.142196327791373),
#               ('samsung galaxy s6', 9.1023466920169),
#               ('samsung smartphone dual', 8.822359346642468),
#               ('xiaomi redmi note', 8.699788761305308),
#               ('huawei p8 champagne', 8.68926340108904)],
#              'anthony': [('lg optimus g', 10),
#               ('apple iphone 5s', 9.695492290329632),
#               ('htc flyer 7', 9.585055219577217),
#               ('samsung galaxy note', 9.469979259837082),
#               ('samsung galaxy note', 9.469979259837082),
#               ('samsung galaxy note', 9.469979259837082),
#               ('samsung galaxy s7', 9.424430301865799),
#               ('samsung galaxy s7', 9.424430301865799),
#               ('apple iphone 7', 9.162751498379405),
#               ('apple iphone 7', 9.162751498379405)],
#              'pedro': [('lenovo p780', 9.6927864699285),
#               ('alcatel pop c7', 9.480093590598639),
#               ('samsung galaxy s5', 9.246571279618305),
#               ('samsung galaxy alpha', 9.235406038316759),
#               ('meizu mx4 pro', 9.146927026525788),
#               ('htc one m8', 9.142893501987928),
#               ('asus zenfone 2', 8.961975285670812),
#               ('sony xperia z1', 8.95765556657176),
#               ('sony xperia z1', 8.95765556657176),
#               ('smartphone samsung galaxy', 8.79379256155055)],
#              'ð\xa0ð¾ð¼ð°ð½': [('samsung i9082 galaxy', 7.384568204121688),
#               ('xiaomi mi4i 16gb', 7.384568204121688),
#               ('sony xperia sp', 7.384568204121688),
#               ('apple iphone 5s', 7.384568204121688),
#               ('samsung n9000 galaxy', 7.384568204121688),
#               ('motorola defy', 7.384568204121688),
#               ('nokia lumia 720', 7.384568204121688),
#               ('huawei ascend g750', 7.384568204121688),
#               ('samsung galaxy s7', 7.384568204121688),
#               ('samsung galaxy s5', 7.384568204121688)],
#              'jack': [('nokia 808 pureview', 9.724192918717497),
#               ('samsung galaxy j5', 9.575782347548676),
#               ('apple iphone 7', 9.532402409006842),
#               ('sony xperia m', 9.407887855331182),
#               ('huawei ascend mate', 9.350470787191373),
#               ('nokia lumia 520', 9.257076497834014),
#               ('lg g5 h850', 9.217684639685567),
#               ('samsung galaxy s7', 9.197286926732193),
#               ('samsung galaxy s7', 9.197286926732193),
#               ('samsung galaxy s7', 9.197286926732193)],
#              'pasquale': [('asus zenfone 3', 10),
#               ('lenovo motorola moto', 10),
#               ('huawei ascend y5', 10),
#               ('alcatel one touch', 10),
#               ('asus zenfone 2', 10),
#               ('lg d802 g2', 9.934361602512881),
#               ('huawei ascend y550', 9.8258791603807),
#               ('nokia lumia 520', 9.75469879176867),
#               ('motorola moto g', 9.648673943189182),
#               ('nokia asha 306', 9.486051591707685)],
#              'mar': [('motorola moto g', 10),
#               ('huawei p8 lite', 9.281247461770747),
#               ('lg optimus f3', 9.204151145055036),
#               ('samsung galaxy j5', 8.932964560493145),
#               ('huawei ascend g730', 8.865001732819849),
#               ('sony xperia zr', 8.845607195250164),
#               ('htc evo 4g', 8.063305389851767),
#               ('lg optimus hub', 7.944462441854007),
#               ('motorola droid 3', 7.793348863734709),
#               ('nokia 6500 slide', 6.55970565574988)],
#              'philipp': [('apple iphone 4', 10),
#               ('acer liquid e1', 9.81371271641516),
#               ('blackberry q5 smartphone', 9.7129523373383),
#               ('huawei ascend p6', 9.489482144468012),
#               ('sony ericsson s500i', 9.12596801931911),
#               ('sony ericsson xperia', 8.598614183567898),
#               ('nokia 3250', 8.440730730610621),
#               ('honor 7 smartphone', 7.950564579029329),
#               ('samsung galaxy s5', 7.774017736204127),
#               ('microsoft lumia 550', 3.6189842984038583)],
#              'paul': [('apple iphone 4s', 10),
#               ('nokia 1208 sim', 10),
#               ('sim free iphone', 10),
#               ('apple iphone 4s', 10),
#               ('htc one s', 10),
#               ('sim free apple', 9.94469490767864),
#               ('sim free apple', 9.94469490767864),
#               ('motorola moto x', 9.913952743047714),
#               ('nokia e90 communicator', 9.906012380409438),
#               ('samsung galaxy s5', 9.832219216822939)],
#              'roberto': [('apple iphone 4s', 10),
#               ('motorola moto x', 10),
#               ('huawei ascend mate', 9.911399162393685),
#               ('nokia lumia 930', 9.884706468515326),
#               ('samsung galaxy note', 9.87664661505586),
#               ('meizu pro 5', 9.733438994838298),
#               ('honor 6x smartphone', 9.726808325319462),
#               ('samsung galaxy gs7', 9.696659179150128),
#               ('huawei smartphone huawei', 9.686509922438173),
#               ('alcatel pop c7', 9.561449944279785)],
#              'wendy': [('apple iphone 5c', 9.81517265774753),
#               ('apple iphone 5c', 9.81517265774753),
#               ('lenovo motorola razr', 9.55880812991225),
#               ('verizon lg octane', 9.510618891252925),
#               ('htc wildfire s', 9.475173425478246),
#               ('samsung galaxy note', 9.301599279366839),
#               ('samsung galaxy note', 9.301599279366839),
#               ('samsung galaxy note', 9.301599279366839),
#               ('samsung galaxy s', 9.031694912413716),
#               ('apple straight talk', 8.85968019034157)],
#              'ð\x90ð½ð´ñ\x80ðµð¹': [('samsung i9082 galaxy',
#                7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('sony xperia sp', 7.384568204121688),
#               ('sony xperia c', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('lg gs290 cookie', 7.384568204121688),
#               ('samsung i9000 galaxy', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('nokia 500', 7.384568204121688),
#               ('samsung galaxy ace', 7.384568204121688)],
#              'fernando': [('htc google nexus', 9.707580504832375),
#               ('smartphone asus zenfone', 9.563552382675889),
#               ('microsoft nokia lumia', 9.391560487513997),
#               ('apple iphone 7', 9.368200187161213),
#               ('lg electronics g2', 9.352830648304538),
#               ('samsung galaxy grand', 9.182914399253217),
#               ('zte axon 7', 9.159980189781352),
#               ('samsung galaxy s7', 9.070736698868137),
#               ('smartphone samsung galaxy', 9.032363052473393),
#               ('smartphone samsung galaxy', 9.032363052473393)],
#              'mark': [('blackberry passport factory', 9.855857587621184),
#               ('huawei honor 8', 9.799562919668613),
#               ('wileyfox swift 4g', 9.720466301263478),
#               ('huawei mate 9', 9.557851391555001),
#               ('ttfone pluto big', 9.499611925843192),
#               ('samsung galaxy s5', 9.491288232314187),
#               ('samsung galaxy s5', 9.491288232314187),
#               ('samsung galaxy s5', 9.491288232314187),
#               ('samsung b2100 unlocked', 9.40485820559835),
#               ('zte axon 7', 9.382960546482249)],
#              'rachel': [('wiko smartphone wiko', 9.90997117047857),
#               ('sim free iphone', 9.753452310522633),
#               ('lg 840g prepaid', 9.562149097584996),
#               ('asus zenfone max', 9.507843976852145),
#               ('apple iphone 6', 9.419203210079955),
#               ('samsung galaxy s5', 9.418301642038351),
#               ('samsung galaxy s5', 9.418301642038351),
#               ('microsoft lumia 435', 9.157909642958645),
#               ('smartphone lg l90', 9.140422552674963),
#               ('xperia sony xperia', 8.860333812175314)],
#              'laura': [('apple iphone 6', 9.901430033166106),
#               ('sim free samsung', 9.900767564574338),
#               ('lenovo motorola moto', 9.61115536406667),
#               ('huawei p8 grace', 9.558108397835692),
#               ('sony xperia tipo', 9.48225673635884),
#               ('htc one x', 9.397755119467474),
#               ('samsung galaxy a3', 9.334231130386751),
#               ('huawei p9 lite', 9.313752004687721),
#               ('samsung galaxy a8', 9.310546876140156),
#               ('lg k10 smartphone', 9.27684327086263)],
#              'incesaz': [('nokia n97 mini', 1),
#               ('apple iphone 3g', 1),
#               ('nokia 2630 cep', 1),
#               ('nokia 6500 slide', 1),
#               ('sony ericsson k850i', 1),
#               ('sony ericsson w995', 1),
#               ('samsung e250 cep', 1)],
#              'wolfgang': [('htc one mini', 9.740024007299658),
#               ('samsung galaxy mega', 9.656590221198389),
#               ('blackberry passport smartphone', 9.634843269245158),
#               ('htc one s', 9.532835116685582),
#               ('lenovo moto z', 9.421843609412095),
#               ('lg electronics l40', 9.321278945568043),
#               ('lenovo razr v3', 9.126889971986671),
#               ('samsung galaxy s3', 9.034283947745767),
#               ('samsung galaxy s3', 9.034283947745767),
#               ('samsung galaxy ace', 8.899554095522106)],
#              'manu': [('lg nexus 5x', 9.834345392962433),
#               ('samsung galaxy s3', 9.507899684211402),
#               ('samsung galaxy s3', 9.507899684211402),
#               ('samsung galaxy j5', 9.334906802990783),
#               ('micromax unite 2', 9.147622884716993),
#               ('blackberry q10 smartphone', 8.904377294636872),
#               ('desconocido xiaomi redmi', 8.541759203730232),
#               ('sony ericsson k800i', 8.396072195797371),
#               ('sony xperia s', 8.098162931981298),
#               ('celular desbloqueado nokia', 8.092477920117334)],
#              'rick2809': [('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone microsoft lumia', 10),
#               ('smartphone lg x', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone motorola moto', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10)],
#              'gianfranco': [('lenovo zuk z1', 10),
#               ('huawei p9 lite', 10),
#               ('huawei p9 lite', 10),
#               ('alcatel one touch', 10),
#               ('lenovo zuk z1', 10),
#               ('sony e5603 xperia', 9.994253072032098),
#               ('alcatel pixi 4', 9.587015264472317),
#               ('alcatel pixi 4', 9.587015264472317),
#               ('honor 7 smartphone', 9.412224302776087),
#               ('nokia asha 305', 8.867364338557106)],
#              "client d'amazon": [('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6),
#               ('sony mobile xperia', 9.6)],
#              'juan': [('apple iphone 4s', 10),
#               ('samsung galaxy j7', 9.653481730835361),
#               ('htc one m8', 9.622551226106847),
#               ('motorola moto g', 9.55801162019645),
#               ('samsung galaxy young', 9.483353312558128),
#               ('sony xperia e', 9.225477667702387),
#               ('samsung galaxy s6', 9.141968966741315),
#               ('doogee voyager2 dg310', 9.141215652030617),
#               ('nokia lumia 520', 9.119330197642533),
#               ('samsung galaxy grand', 9.117889902015456)],
#              'sergio': [('lenovo moto g4', 9.90811913599109),
#               ('samsung galaxy s5', 9.840909383105078),
#               ('asus zenfone selfie', 9.783896620362343),
#               ('samsung galaxy s4', 9.7654556717771),
#               ('samsung galaxy s4', 9.7654556717771),
#               ('huawei ascend g615', 9.760667861365103),
#               ('huawei nexus 6p', 9.735636309455556),
#               ('motorola moto g', 9.691907345772913),
#               ('motorola nexus 6', 9.61885821419802),
#               ('samsung gt b2100', 9.447313314288182)],
#              'charlie': [('apple iphone 5s', 10),
#               ('apple iphone 6', 10),
#               ('lg electronics nexus', 9.592253942298713),
#               ('samsung galaxy j7', 9.4220715876272),
#               ('lg ku990 viewty', 9.206665320358509),
#               ('samsung galaxy s4', 8.681083991474612),
#               ('samsung galaxy a3', 8.63551677890584),
#               ('doogee x5 max', 8.379119748857946),
#               ('apple iphone 7', 8.257820176034574),
#               ('lg 530g prepaid', 8.17034657979571)],
#              'nicole': [('lenovo motorola moto', 9.213208989132712),
#               ('samsung galaxy j7', 9.123755763938576),
#               ('lg electronics t385', 9.039262848645079),
#               ('huawei nexus 6p', 8.795188894692945),
#               ('samsung galaxy s4', 8.777785911870215),
#               ('archos 50 helium', 8.610547181904222),
#               ('apple iphone 5c', 8.195105015068725),
#               ('sony xperia zl', 8.11140837116451),
#               ('samsung galaxy j1', 8.004952395504308),
#               ('samsung galaxy alpha', 7.303853409123812)],
#              'ð\x95ð²ð³ðµð½ð¸ñ\x8f': [('sony xperia l', 7.384568204121688),
#               ('samsung galaxy j1', 7.384568204121688),
#               ('samsung galaxy s5', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('samsung galaxy a5', 7.384568204121688),
#               ('samsung galaxy note', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('samsung s7270 galaxy', 7.384568204121688),
#               ('sony xperia m', 7.384568204121688),
#               ('sony xperia e1', 7.384568204121688)],
#              'ð\x94ð¸ð¼ð°': [('samsung n7100 galaxy', 7.384568204121688),
#               ('samsung galaxy s4', 7.384568204121688),
#               ('samsung galaxy a3', 7.384568204121688),
#               ('samsung i8190 galaxy', 7.384568204121688),
#               ('htc desire v', 7.384568204121688),
#               ('samsung i5800 galaxy', 7.384568204121688),
#               ('sony xperia l', 7.384568204121688),
#               ('sony xperia z1', 7.384568204121688),
#               ('samsung galaxy ace', 7.384568204121688),
#               ('sony xperia l', 7.384568204121688)],
#              'rpv': [('samsung galaxy s4', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 920', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 920', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 920', 10),
#               ('samsung galaxy s4', 10),
#               ('samsung galaxy s4', 10),
#               ('samsung galaxy note', 9.804563112369872)],
#              'ana': [('apple iphone 4s', 10),
#               ('motorola moto x', 9.811503851913542),
#               ('motorola moto x', 9.811503851913542),
#               ('apple iphone 5s', 9.802974029899577),
#               ('samsung galaxy grand', 9.35622295627839),
#               ('smartphone samsung galaxy', 9.176005073328785),
#               ('smartphone samsung galaxy', 9.176005073328785),
#               ('smartphone samsung galaxy', 9.176005073328785),
#               ('smartphone samsung galaxy', 9.176005073328785),
#               ('lg google nexus', 9.129825932151684)],
#              'ð\x90ð½ð°ñ\x81ñ\x82ð°ñ\x81ð¸ñ\x8f': [('apple iphone 5s',
#                7.384568204121688),
#               ('apple iphone se', 7.384568204121688),
#               ('sony xperia sp', 7.384568204121688),
#               ('sony xperia tx', 7.384568204121688),
#               ('nokia asha 206', 7.384568204121688),
#               ('nokia x6 8gb', 7.384568204121688),
#               ('sony xperia m', 7.384568204121688),
#               ('htc desire 828', 7.384568204121688),
#               ('sony xperia j', 7.384568204121688),
#               ('sony xperia j', 7.384568204121688)],
#              'gary': [('samsung note 2', 10),
#               ('samsung galaxy s5', 9.894356792315412),
#               ('samsung galaxy j5', 9.675557294261731),
#               ('huawei mate 9', 9.587844594863025),
#               ('nokia lumia 635', 9.522963986394135),
#               ('apple iphone se', 9.512315168826326),
#               ('samsung galaxy a3', 8.986545225170318),
#               ('samsung i9100 galaxy', 8.685386221300782),
#               ('lg g2 sprint', 8.357449616173307),
#               ('lg verizon lg', 8.200239463112595)],
#              'mary': [('samsung galaxy j7', 9.8010658489105),
#               ('wiko cink slim', 9.682278831526094),
#               ('huawei smartphone honor', 9.480574179545314),
#               ('verizon lg octane', 9.462390190400638),
#               ('samsung i9082 galaxy', 9.370730218302633),
#               ('samsung galaxy s3', 9.35926284355553),
#               ('samsung galaxy s4', 9.340169143802735),
#               ('tracfone motorola moto', 9.255787644255701),
#               ('samsung wave y', 9.255729490367596),
#               ('huawei p8 lite', 9.202173670543324)],
#              'mario': [('microsoft lumia 640', 9.999500179785551),
#               ('sim free apple', 9.934869826947),
#               ('samsung galaxy mega', 9.90527305473585),
#               ('lg google nexus', 9.776401213867867),
#               ('sony xperia t', 9.74327144009223),
#               ('samsung galaxy j5', 9.696526732566024),
#               ('motcb moto g', 9.655299337453194),
#               ('wiko fever 4g', 9.599712896308525),
#               ('samsung galaxy s4', 9.589569751128778),
#               ('sony e6653 xperia', 9.493958665638923)],
#              'caroline': [('sim free apple', 10),
#               ('ringke asus zenfone', 9.915026045720845),
#               ('samsung galaxy s5', 9.884557305079593),
#               ('samsung galaxy s5', 9.884557305079593),
#               ('microsoft lumia 640', 9.605891966853207),
#               ('smartphone asus zenfone', 9.604152775226435),
#               ('lenovo moto g4', 9.596735297632716),
#               ('samsung galaxy j5', 9.573798875009636),
#               ('samsung galaxy j5', 9.573798875009636),
#               ('samsung galaxy ace', 9.526355698110706)],
#              'kindle customer': [('lg optimus g', 9.986937974107182),
#               ('lg optimus g', 9.986937974107182),
#               ('htc one 32gb', 9.728388941827816),
#               ('vodafone smart 4', 9.383667752893977),
#               ('samsung s3350 chat', 9.36852512027153),
#               ('vodafone smart prime', 9.250080980178122),
#               ('nokia lumia 735', 9.225475401132702),
#               ('samsung epic 4g', 9.145859190435033),
#               ('nokia microsoft lumia', 9.144935381682366),
#               ('samsung galaxy j7', 9.125570952469316)],
#              'frank': [('lg google nexus', 9.85294762962046),
#               ('huawei honor 3c', 9.649108483305131),
#               ('huawei ascend p7', 9.53981992935881),
#               ('blackberry q5 smartphone', 9.53966101504994),
#               ('apple iphone 5', 9.37949536218988),
#               ('wiko rainbow smartphone', 9.371847453680378),
#               ('lenovo motorola moto', 9.3563158433018),
#               ('huawei ascend g7', 9.32422636039763),
#               ('samsung galaxy s3', 9.204380671207552),
#               ('samsung galaxy s3', 9.204380671207552)],
#              '????????': [('apple iphone 5', 7.384568204121688),
# ...
#               ('lenovo k900 16gb', 7.384568204121688),
#               ('samsung galaxy s', 7.384568204121688)],
#              'dunya': [('samsung s8003 jet', 1),
#               ('nokia 8800 arte', 1),
#               ('nokia 6500 slide', 1),
#               ('motorola rokr z6', 1),
#               ('samsung i8000 omnia', 1),
#               ('motorola razr2 v9', 1)],
#              'pankaj': [('samsung galaxy note', 9.804051770836034),
#               ('micromax canvas hd', 9.165851751798987),
#               ('samsung galaxy a9', 8.945991120559224),
#               ('asus zenfone 5', 8.21178466437945),
#               ('sony xperia c3', 5.496813516445309)],
#              'natalia': [('alcatel one touch', 10),
#               ('sony xperia z3', 10),
#               ('sony xperia tipo', 9.884225700123025),
#               ('huawei ascend g510', 9.48714351007176),
#               ('ee alcatel one', 9.350958811114163),
#               ('sony xperia s', 9.186892341191292),
#               ('samsung galaxy star', 7.810870788680453),
#               ('samsung galaxy s6', 7.319650932756511),
#               ('lenovo motorola moto', 3.736251379288948)],
#              'ciklet': [('nokia e90 cep', 1),
#               ('nokia 5310 cep', 1),
#               ('nokia n70 cep', 1)],
#              'thierry': [('samsung galaxy core', 9.975749252379792),
#               ('honor 4x smartphone', 9.588198109325765),
#               ('nokia lumia 830', 9.475208492642937),
#               ('samsung galaxy y', 9.307544944244938),
#               ('lg g3 smartphone', 9.160630722558992),
#               ('samsung galaxy s5', 9.010813828852807),
#               ('samsung galaxy a5', 8.524491711153415),
#               ('samsung galaxy s4', 7.917368584293216),
#               ('zte axon 7', 7.8879363031271055),
#               ('zte axon 7', 7.8879363031271055)],
#              'mel': [('tech armor galaxy', 9.07401199091546),
#               ('microsoft lumia 640', 9.040900934223094),
#               ('huawei ascend mate', 8.45331061369287),
#               ('motorola mb300 backflip', 7.157802454704851),
#               ('motorola rokr e1', 6.309347326053551)],
#              'bianca': [('apple iphone 5c', 10),
#               ('samsung galaxy s6', 9.934579834552864),
#               ('sony xperia z5', 9.832980521325554),
#               ('huawei p8 grijs', 9.402418250966596),
#               ('sony ericsson s500i', 9.401226355246227),
#               ('samsung galaxy s4', 9.045424984970394),
#               ('smartphone motorola defy', 8.510449861041726),
#               ('sony ericsson c', 5.089299277732097)],
#              'marion': [('emporia elegance handy', 9.531137698128479),
#               ('apple iphone 7', 8.489230561051269),
#               ('buyus etui housse', 8.365705198411776),
#               ('doro matra phone', 8.271071367377948),
#               ('sony xperia m4', 7.791057170002082),
#               ('lenovo motorola moto', 2.7124245559547537)],
#              'simona': [('lg g2 mini', 10),
#               ('samsung galaxy j5', 9.879799083538094),
#               ('huawei ascend g7', 9.829659610276199),
#               ('huawei ascend p7', 9.792088674167498),
#               ('huawei p8 lite', 9.717584299238094),
#               ('asus ze550kl zenfone', 9.672841196439553),
#               ('htc desire 816', 9.332262321026603),
#               ('apple iphone 5s', 7.619199662098862),
#               ('lenovo motorola moto', 7.321486777458131),
#               ('blackberry curve 9320', 5.486183224597492)],
#              'enzo': [('apple iphone 5s', 10),
#               ('lenovo motorola moto', 9.82983690682881),
#               ('lenovo motorola moto', 9.82983690682881),
#               ('huawei p9 lite', 9.803508953258978),
#               ('sony e6653 xperia', 9.218398592782952),
#               ('samsung smartphone galaxy', 9.042622877305003),
#               ('lg k10 smartphone', 8.19167976753619),
#               ('samsung g355 galaxy', 7.321464967736986),
#               ('doogee valencia2 y100', 4.735997584928867),
#               ('huawei p8 lite', 4.498011368052657)],
#              'karadag60': [('sony ericsson w610i', 1),
#               ('sony ericsson w910i', 1),
#               ('sony ericsson c903', 1),
#               ('sony ericsson w995', 1),
#               ('palm treo pro', 1),
#               ('sony ericsson z310i', 1)],
#              'adriana': [('samsung galaxy note', 10),
#               ('samsung galaxy y', 9.11030875966866),
#               ('smartphone motorola moto', 9.053510899360251),
#               ('huawei ascend y300', 8.13838999325893),
#               ('samsung i9060i galaxy', 7.700788271855214),
#               ('sony xperia l', 7.109224768044877),
#               ('palm pre plus', 5.306897840461561),
#               ('blackberry bold 9000', 3.7816153048544505),
#               ('motorola xt390', 2.037915977011658)],
#              'francis': [('apple iphone 5', 9.143349287983797),
#               ('apple iphone 7', 8.2781006990311),
#               ('lg neon', 7.792780905576934),
#               ('lg gt540', 7.545463678493504),
#               ('samsung galaxy s7', 7.525875420875421),
#               ('samsung galaxy s7', 7.525875420875421),
#               ('samsung galaxy grand', 7.272736604409656),
#               ('samsung s5230 player', 6.900579645144713),
#               ('blackberry bold 9900', 6.661975814472221),
#               ('motorola moto g', 6.4884234900830275)],
#              'delicate': [('nokia 2730 classic', 1),
#               ('palm treo 750', 1),
#               ('nokia 6600i slide', 1),
#               ('apple iphone 3gs', 1),
#               ('palm treo 650', 1),
#               ('nokia e52', 1)],
#              'flavio': [('alcatel one touch', 10),
#               ('asus zenfone 2', 10),
#               ('apple iphone 5s', 9.987990326666797),
#               ('lg d855 g3', 9.611275011703603),
#               ('smartphone lg optimus', 8.824881948925958),
#               ('lg optimus l5', 8.417897247761072),
#               ('doogee x5 max', 7.202788357746087),
#               ('huawei ascend y530', 7.148239911977435),
#               ('huawei ascend p8', 5.370624390738948),
#               ('huawei nexus 6p', 4.900272190024227)],
#              'santiago': [('sony xperia p', 10),
#               ('samsung galaxy s6', 10),
#               ('lenovo motorola moto', 10),
#               ('huawei smartphone huawei', 10),
#               ('motorola moto e', 10),
#               ('sony xperia z', 10),
#               ('microsoft lumia 640', 10),
#               ('nokia lumia 1320', 10),
#               ('bq aquaris x5', 9.836715005020706),
#               ('samsung galaxy s', 8.751056891612395)],
#              'emanetcan': [('apple iphone 3g', 1),
#               ('apple iphone 3gs', 1),
#               ('samsung s8003 jet', 1),
#               ('samsung e250 cep', 1),
#               ('sony ericsson w995', 1),
#               ('samsung m620 cep', 1),
#               ('nokia 5630 xpressmusic', 1),
#               ('sony ericsson w810i', 1),
#               ('blackberry storm 9530', 1),
#               ('nokia 6300 cep', 1)],
#              'cikolata': [('samsung i560 cep', 1),
#               ('nokia e65 cep', 1),
#               ('nokia n76 cep', 1),
#               ('nokia 5300 xpressmusic', 1),
#               ('samsung u800 cep', 1)],
#              '???????????????? ??????????????': [('philips xenium w732',
#                7.384568204121688),
#               ('lenovo k900 32gb', 7.384568204121688),
#               ('sony xperia e', 7.384568204121688),
#               ('samsung c3322', 7.384568204121688),
#               ('samsung galaxy pocket', 7.384568204121688),
#               ('nokia asha 210', 7.384568204121688),
#               ('sony xperia miro', 7.384568204121688)],
#              'jr': [('samsung galaxy s7', 10),
#               ('samsung galaxy s3', 10),
#               ('huawei p8 lite', 10),
#               ('samsung b5722 handy', 9.864323429359976),
#               ('blu studio x', 9.792669660798987),
#               ('samsung galaxy s5', 9.463390153896857),
#               ('sony ericsson cedar', 8.612960629215795),
#               ('apple iphone 5s', 7.3520613189538295)],
#              'ozer1299': [('nokia n81 8gb', 1),
#               ('samsung d900i 1gb', 1),
#               ('nokia n70 cep', 1),
#               ('nokia x6 cep', 1),
#               ('samsung m620 cep', 1),
#               ('nokia 6500 slide', 1),
#               ('samsung i8000 omnia', 1)],
#              'george': [('lg g flex', 9.826455550385834),
#               ('samsung ativ s', 9.517737359403611),
#               ('asus zenfone max', 9.504084296870795),
#               ('samsung g920 galaxy', 9.406184533050613),
#               ('pantech pocket p9060', 9.373800012820332),
#               ('apple iphone 6', 9.353131050339012),
#               ('nokia 230 dual', 9.35051279127041),
#               ('motorola photon q', 9.137418398570665),
#               ('huawei p9 lite', 9.047311589204819),
#               ('asus zenfone 3', 8.98876158795122)],
#              'mustafa': [('iphone 5s 16gb', 9.243514079447385),
#               ('samsung i9190 galaxy', 9.157104062276508),
#               ('samsung galaxy j1', 7.900279051415979),
#               ('samsung s7580 galaxy', 6.578345359748876)],
#              'xxx': [('sony ericsson xperia', 9.464725377924838),
#               ('huawei ascend y300', 9.013638463084945),
#               ('doogee x5 pro', 8.510729327640163),
#               ('sony ericsson w395', 3.334028681189711)],
#              'emre': [('lg g4 us991', 10),
#               ('nokia 5800 xpressmusic', 9.444892008942027),
#               ('sony xperia z', 8.930304941735098),
#               ('motorola razr v3', 8.885510147648732)],
#              'anja': [('sony xperia sp', 9.378977569085503),
#               ('vodafone smart 4', 9.12000595535325),
#               ('htc desire c', 8.852919343471505),
#               ('htc desire 310', 8.687905681903597),
#               ('microsoft nokia 2760', 8.206723772117005),
#               ('htc one max', 7.970876315210397),
#               ('huawei p8lite zwart', 7.381693069926239),
#               ('samsung star ii', 6.637441929925368),
#               ('samsung galaxy y', 6.40928466895766),
#               ('sony ericsson c902', 4.687454202606736)],
#              '????????????????': [('samsung c3782 onyx', 7.384568204121688),
#               ('sony xperia v', 7.384568204121688),
#               ('nokia n9', 7.384568204121688),
#               ('huawei u8860 honor', 7.384568204121688),
#               ('nokia asha 210', 7.384568204121688),
#               ('htc desire c', 7.384568204121688),
#               ('apple iphone 4s', 7.384568204121688)],
#              'me': [('lg electronics leon', 9.305597937973186),
#               ('samsung c5212 duos', 9.142819465662832),
#               ('samsung galaxy note', 9.036662656240406),
#               ('htc one m8', 8.938320652594754),
#               ('apple iphone 3gs', 8.906614552959391),
#               ('microsoft nokia lumia', 8.62435071610662),
#               ('sony xperia z', 8.359744126486042),
#               ('samsung galaxy s7', 7.017007697815968),
#               ('samsung gt s5260', 6.195148077522589),
#               ('samsung galaxy s4', 5.195286531775002)],
#              'dolunay': [('samsung galaxy mini', 1),
#               ('samsung s5233w star', 1),
#               ('nokia n73 cep', 1),
#               ('nokia n72 cep', 1),
#               ('samsung d900i 1gb', 1)],
#              'sezenm': [('nokia n95 cep', 1),
#               ('samsung p520 armani', 1),
#               ('nokia n72 cep', 1),
#               ('nokia 6131 cep', 1),
#               ('nokia 5500 sport', 1)],
#              'damien': [('microsoft lumia 535', 10),
#               ('lg g2 mini', 10),
#               ('nokia e63', 8.813112768953951),
#               ('samsung galaxy s6', 8.332238453112442),
#               ('lg nexus 5', 7.830670467491799),
#               ('motorola defy', 7.722294000718079)],
#              'ram': [('microsoft lumia 640', 9.078630708119992),
#               ('microsoft lumia 640', 9.078630708119992),
#               ('htc evo 3d', 2.4672571724512737),
#               ('apple iphone 6', 2.075410553960112)],
#              'tuvok': [('samsung galaxy express', 4.99347973916471)],
#              'tobias': [('apple iphone 6', 9.569421768326812),
#               ('microsoft nokia 108', 9.316190909560946),
#               ('microsoft lumia 650', 9.005022816305388),
#               ('lg electronics google', 8.997053482461416),
#               ('samsung galaxy s4', 8.685383217412145),
#               ('htc mozart 7', 8.174251409787244),
#               ('samsung galaxy s', 8.103659929370101),
#               ('asus padfone 2', 8.071053013998295),
#               ('huawei mate 9', 7.813606531185707),
#               ('lenovo motorola moto', 7.761694666516684)],
#              'alice': [('asus zenfone 2', 9.507789279568035),
#               ('huawei ascend mate', 9.27170585081307),
#               ('samsung a5 2016', 9.002499542249637),
#               ('doro phoneeasy 612', 8.755100391852684),
#               ('oukitel u7 plus', 8.389094762082175),
#               ('asus ze550kl zenfone', 8.368039615229241),
#               ('samsung galaxy y', 8.278059143314861),
#               ('microsoft lumia 650', 8.270328382127765),
#               ('smartphone samsung galaxy', 7.986639306885545),
#               ('samsung galaxy a3', 7.841325662354118)],
#              'zehrabalta': [('nokia e90 cep', 1),
#               ('nokia n97 mini', 1),
#               ('sony ericsson z310i', 1),
#               ('apple iphone 4', 1),
#               ('nokia n95 cep', 1)],
#              '???????\x80????': [('sony xperia v', 7.384568204121688),
#               ('nokia 603', 7.384568204121688),
#               ('nokia asha 311', 7.384568204121688),
#               ('htc sensation xl', 7.384568204121688),
#               ('apple iphone 4s', 7.384568204121688),
#               ('samsung c3782 onyx', 7.384568204121688)],
#              'louis': [('samsung galaxy s7', 10),
#               ('nokia lumia 830', 9.86962276666118),
#               ('samsung galaxy s5', 9.79138201504999),
#               ('sony xperia t', 9.79126429999613),
#               ('htc desire sim', 9.75339107313226),
#               ('apple iphone 4s', 9.6175245494982),
#               ('sony ericsson w580', 9.296596445201326),
#               ('nokia microsoft lumia', 9.184104850928582),
#               ('archos 28 internet', 9.022175622199216),
#               ('samsung galaxy s6', 8.530807995494323)],
#              'bert': [('sim free motorola', 10),
#               ('huawei p8 grijs', 9.28054550585879),
#               ('apple iphone 5s', 9.27584419326558),
#               ('huawei p8 champagne', 9.03906356241306),
#               ('apple iphone se', 8.90415457093226),
#               ('samsung b2710 solid', 8.234778654994066)],
#              'narn3049': [('pearl 8100', 10),
#               ('sony ericsson xperia', 9.576543246910202),
#               ('v300', 7.0)],
#              'sue': [('huawei p9 lite', 10),
#               ('sim free apple', 10),
#               ('blackberry dtek50 unlocked', 9.628330720922886),
#               ('samsung e1270 uk', 9.547612693061003),
#               ('samsung s3350 chat', 9.496443920755459),
#               ('samsung galaxy s', 8.204008415504541),
#               ('lg electronics ks360', 4.838991574133308)],
#              'sunny': [('doro phoneeasy 622', 9.723497169370242),
#               ('sony xperia s', 9.673305444645635),
#               ('apple iphone 6s', 9.291673711468986),
#               ('samsung galaxy a3', 8.938825108995),
#               ('lg electronics e610', 8.072480109300232),
#               ('karbonn titanium octane', 7.136182301481784),
#               ('huawei p8 lite', 5.99835216559481),
#               ('apple iphone 3g', 3.399230953008418)],
#              'raquel': [('blackberry torch 9810', 9.111856021643971),
#               ('samsung galaxy s6', 7.340338654954064),
#               ('apple iphone 5', 7.189221772186261),
#               ('smartphone lg optimus', 7.185243187595005),
#               ('motorola moto g', 7.050244154970643),
#               ('htc one', 4.498284521090335)],
#              'aksisey': [('nokia 6500 slide', 1),
#               ('nokia n70 cep', 1),
#               ('nokia e65 cep', 1)]})

# %%
algo_item = KNNWithMeans(k=10, sim_options={ 'user_based': False})
cross_validate(algo_i, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
test_pred=algo_i.test(testset)
print(accuracy.rmse(test_pred))
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.0973  3.0773  3.0927  3.0952  3.1083  3.0941  0.0100
# MAE (testset)     2.4582  2.4415  2.4543  2.4533  2.4714  2.4557  0.0096
# Fit time          11.57   9.74    11.02   10.75   11.61   10.94   0.68
# Test time         21.24   22.64   22.85   23.72   24.05   22.90   0.98
# RMSE: 2.2945
# 2.2945428292895196

# %%
top_cv = get_top_n(test_pred, n=10)
top_cv
# Out:
# defaultdict(list,
#             {'alexander': [('htc one smartphone', 10),
#               ('huawei ascend g600', 10),
#               ('lenovo motorola moto', 10),
#               ('honor 7 smartphone', 10),
#               ('huawei ascend mate', 9.698431250001432),
#               ('htc one x', 9.364739418483428),
#               ('lg l90 d410', 9.032467027374937),
#               ('samsung nexus s', 9.025320230181341),
#               ('nokia c6 unlocked', 9.012462537462538),
#               ('sony xperia s', 8.974523019874384)],
#              'juan carlos': [('samsung galaxy note', 9.580253844168851),
#               ('sony xperia z5', 9.576841237471939),
#               ('huawei p9 lite', 9.558952050727974),
#               ('sony xperia p', 9.459104393555748),
#               ('samsung galaxy ace', 9.40092013898581),
#               ('samsung galaxy ace', 9.40092013898581),
#               ('apple iphone 5s', 9.38138981350631),
#               ('blackberry bold 9790', 9.209568717403231),
#               ('samsung galaxy s3', 9.158561211663653),
#               ('samsung galaxy s3', 9.158561211663653)],
#              'maria': [('motorola milestone 2', 10),
#               ('smartphone motorola razr', 10),
#               ('samsung korea samsung', 10),
#               ('lenovo moto g4', 10),
#               ('sim free samsung', 10),
#               ('smartphone lg optimus', 10),
#               ('lg g flex', 10),
#               ('samsung s5620 smartphone', 10),
#               ('sim free apple', 10),
#               ('lg optimus l9', 9.968677841361503)],
#              'alex': [('samsung i9060 galaxy', 10),
#               ('lg g4 us991', 10),
#               ('honor holly smartphone', 10),
#               ('lg electronics p500', 10),
#               ('blackberry z30 smartphone', 10),
#               ('nokia n91', 10),
#               ('sim free samsung', 10),
#               ('honor 8 smartphone', 10),
#               ('nokia lumia 830', 10),
#               ('samsung i9500 galaxy', 10)],
#              'francesco': [('samsung smartphone galaxy', 10),
#               ('huawei ascend g615', 10),
#               ('lg k10 smartphone', 10),
#               ('samsung j510 galaxy', 10),
#               ('doogee smartphone dual', 9.946633279793412),
#               ('huawei ascend g700', 9.894412993891246),
#               ('microsoft lumia 640', 9.806165044161737),
#               ('lg d855 g3', 9.750715035841015),
#               ('lg d802 g2', 9.708187094064883),
#               ('samsung g355 galaxy', 9.70114650571278)],
#              'ð\x98ñ\x80ð¸ð½ð°': [('samsung galaxy s4', 9.786760618127227),
#               ('nokia 5230 navigation', 9.643579074839995),
#               ('sony xperia z1', 9.43445220243132),
#               ('sony xperia z1', 9.43445220243132),
#               ('apple iphone se', 9.399632293835825),
#               ('samsung s8500 wave', 9.387391887803874),
#               ('samsung galaxy s5', 9.3),
#               ('samsung galaxy s5', 9.3),
#               ('samsung galaxy s5', 9.3),
#               ('samsung galaxy s5', 9.3)],
#              'anna': [('nokia 105 telefono', 10),
#               ('samsung e1270 telefono', 9.934723006462137),
#               ('lg electronics optimus', 9.91155422145988),
#               ('huawei ascend p7', 9.802294705123964),
#               ('samsung galaxy s5', 9.400307924020732),
#               ('samsung galaxy s5', 9.400307924020732),
#               ('huawei smartphone honor', 9.399821336688557),
#               ('huawei p9 lite', 9.329035606801737),
#               ('samsung n9005 galaxy', 9.027666916639735),
#               ('samsung galaxy s4', 8.846549870129945)],
#              'kim': [('htc flyer 7', 10),
#               ('ee alcatel one', 10),
#               ('samsung wave 525', 9.790770233778918),
#               ('huawei p8lite zwart', 9.75718953403285),
#               ('huawei p8lite zwart', 9.75718953403285),
#               ('samsung galaxy grand', 9.224900327727921),
#               ('huawei p8 grijs', 9.02319197624784),
#               ('microsoft lumia 650', 8.942165573353028),
#               ('apple iphone 5c', 8.781032102619552),
#               ('microsoft nokia lumia', 8.554714061646727)],
#              'ð\x92ð°ð»ðµñ\x80ð¸ð¹': [('samsung galaxy s7', 9.055549766989968),
#               ('samsung i8150 galaxy', 8.567754242898099),
#               ('sony xperia sp', 8.41681153695983),
#               ('apple iphone 5s', 7.3957981595792015),
#               ('samsung galaxy s4', 6.476836827493668),
#               ('samsung galaxy s5', 6.346247201744052),
#               ('sony xperia c', 5.103529877966868),
#               ('sony xperia c', 5.103529877966868),
#               ('htc nexus one', 2.7241360939853134)],
#              'chris': [('sim free motorola', 10),
#               ('sim free motorola', 10),
#               ('apple apple iphone', 10),
#               ('lenovo moto g4', 10),
#               ('nokia c3', 10),
#               ('samsung rugby 2', 10),
#               ('huawei smartphone honor', 10),
#               ('lg g2 d800', 10),
#               ('doro phoneeasy 410gsm', 10),
#               ('nokia lumia 820', 10)],
#              'kevin': [('sim free apple', 10),
#               ('just 1 j509', 10),
#               ('sony ericsson arc', 10),
#               ('ringke asus zenfone', 10),
#               ('htc mozart 7', 9.63353545821198),
#               ('sony xperia z3', 9.436469261220664),
#               ('honor 7 smartphone', 9.362879346477802),
#               ('honor 7 smartphone', 9.362879346477802),
#               ('honor 4x smartphone', 9.324037667631735),
#               ('lenovo moto g4', 9.289975852945123)],
#              'markus': [('honor 6 smartphone', 10),
#               ('lg electronics p500', 9.45229936520764),
#               ('sony ericsson c905', 9.281803028645134),
#               ('samsung galaxy s', 9.19490424843354),
#               ('samsung galaxy s', 9.19490424843354),
#               ('cubot note s', 8.761532844139065),
#               ('microsoft nokia n8', 8.758613497851972),
#               ('sony xperia z1', 8.655891780176583),
#               ('microsoft lumia 640', 8.609373571013323),
#               ('microsoft lumia 640', 8.609373571013323)],
#              'silvia': [('samsung ativ s', 9.897173783860415),
#               ('huawei p9 lite', 9.609035216954029),
#               ('huawei p9 lite', 9.609035216954029),
#               ('samsung galaxy s7', 9.404982746840446),
#               ('asus zenfone 2', 9.239843274657638),
#               ('asus zenfone 2', 9.239843274657638),
#               ('lenovo motorola k1', 9.116547355927898),
#               ('alcatel one touch', 8.99580997744389),
#               ('samsung galaxy a3', 8.672490719516512),
#               ('nokia lumia 630', 8.633847239682803)],
#              'david': [('huawei mate 9', 10),
#               ('lg 530g prepaid', 10),
#               ('archos 50 helium', 10),
#               ('motorola google nexus', 10),
#               ('nokia 6210', 10),
#               ('huawei mate 9', 10),
#               ('huawei smartphone huawei', 10),
#               ('sim free motorola', 10),
#               ('lg electronics l7', 10),
#               ('huawei ascend g300', 9.989256795835743)],
#              'ð\x93ð¾ñ\x81ñ\x82ñ\x8c': [('htc windows phone',
#                9.924661903285237),
#               ('samsung galaxy j7', 9.75379462863863),
#               ('nokia 6303i classic', 9.73576017877856),
#               ('nokia 6303i classic', 9.73576017877856),
#               ('sony ericsson x10', 9.683203721705318),
#               ('nokia c6', 9.29661723619716),
#               ('sony ericsson xperia', 8.939615035447172),
#               ('nokia e72', 8.808401305082585),
#               ('apple iphone 3gs', 8.771973851652074),
#               ('nokia 5130 xpressmusic', 8.343547633856572)],
#              'salvatore': [('lg h410 wine', 10),
#               ('nokia asha 200', 9.950357549759016),
#               ('huawei p9 lite', 9.74889673900518),
#               ('lg electronics e610', 9.548876047363272),
#               ('sony xperia z1', 9.519969755043467),
#               ('nokia lumia 735', 9.313315789294196),
#               ('huawei ascend g6', 9.283932124692882),
#               ('huawei mate 8', 9.044158394009658),
#               ('doogee x5 max', 8.967379900077487),
#               ('samsung g935 galaxy', 8.914190862753635)],
#              'no captured': [('huawei ascend p7', 10),
#               ('apple smartphone iphone', 10),
#               ('blu studio c', 10),
#               ('htc butterfly', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone apple iphone', 10),
#               ('sony ericsson w900i', 10),
#               ('nokia 9300', 10),
#               ('nokia 9300', 10),
#               ('blackberry pearl 8120', 10)],
#              'amazon customer': [('samsung rugby 2', 10),
#               ('nokia 1208 sim', 10),
#               ('aicek coque asus', 10),
#               ('lg electronics d605', 10),
#               ('ringke asus zenfone', 10),
#               ('nokia lumia 720', 10),
#               ('samsung ativ s', 10),
#               ('htc one 2014', 10),
#               ('huawei mate s', 10),
#               ('samsung s5610 handy', 10)],
#              'marie': [('motorola moto e', 10),
#               ('samsung galaxy mega', 10),
#               ('palm germany gmbh', 9.901624970000244),
#               ('huawei p8lite zwart', 9.775382692908465),
#               ('wiko rainbow smartphone', 9.675973988075011),
#               ('samsung galaxy grand', 9.430267509747463),
#               ('apple iphone 4s', 9.33626222334966),
#               ('samsung galaxy a3', 9.2867239336807),
#               ('samsung galaxy s3', 9.228293995357657),
#               ('samsung galaxy j7', 9.225364885702078)],
#              'james': [('sim free motorola', 10),
#               ('sim free apple', 10),
#               ('lg g2 d801', 9.698333333333332),
#               ('microsoft nokia lumia', 9.146353804654154),
#               ('lg nexus 5', 9.041251086038129),
#               ('nokia lumia 930', 9.039970485225941),
#               ('samsung galaxy note', 9.001645982614976),
#               ('htc one x', 8.929770167332379),
#               ('apple iphone 5s', 8.92146617392704),
#               ('samsung galaxy j7', 8.846802306335308)],
#              'pascal': [('samsung e1190 sim', 10),
#               ('sony mobile station', 9.338568861922115),
#               ('tech armor samsung', 9.288669578726381),
#               ('samsung galaxy j5', 9.248273997724878),
#               ('htc one m8s', 9.005176342261043),
#               ('nokia lumia 625', 8.78438138982706),
#               ('sony mobile xperia', 8.755279076661912),
#               ('samsung galaxy s7', 8.752096601507223),
#               ('samsung galaxy s7', 8.752096601507223),
#               ('apple iphone 5s', 8.7196908541309)],
#              'valentina': [('nokia 105 telefono', 10),
#               ('samsung g800 galaxy', 10),
#               ('samsung e1270 telefono', 9.953693513492459),
#               ('samsung galaxy s7', 9.894102434274169),
#               ('samsung galaxy j5', 9.848245785804854),
#               ('huawei p8 lite', 9.805783839766837),
#               ('lenovo motorola moto', 9.658471221401973),
#               ('samsung g355 galaxy', 9.476376081436117),
#               ('samsung s7580 galaxy', 9.360187186426487),
#               ('samsung a500 galaxy', 9.183441411360787)],
#              'sabrina': [('smartphone asus zenfone', 10),
#               ('samsung i9060 galaxy', 10),
#               ('motorola moto g', 9.717631003776132),
#               ('samsung i9301 galaxy', 9.606093461574899),
#               ('samsung galaxy s5', 9.569005760715015),
#               ('sony ericsson k770i', 9.555114641456104),
#               ('huawei ascend p6', 9.459157799478206),
#               ('samsung galaxy trend', 9.439880186625643),
#               ('samsung galaxy y', 9.314244594538268),
#               ('apple iphone 4s', 8.717911732409279)],
#              'simone': [('nokia 215 telefono', 10),
#               ('samsung c115 galaxy', 10),
#               ('huawei mate s', 9.997892287531533),
#               ('wiko fever 4g', 9.84395368446043),
#               ('samsung a300 galaxy', 9.7561504926077),
#               ('smartphone samsung galaxy', 9.429781078867808),
#               ('samsung g355 galaxy', 9.400461777397021),
#               ('htc desire 500', 9.383636039298004),
#               ('honor 6x smartphone', 9.337507380520043),
#               ('huawei ascend p1', 9.327815680459873)],
#              'amazon kunde': [('samsung j710 galaxy', 10),
#               ('microsoft nokia 5310', 10),
#               ('sony xperia xcompact', 10),
#               ('sony xperia xcompact', 10),
#               ('honor 6 smartphone', 10),
#               ('honor 6 smartphone', 10),
#               ('honor 8 smartphone', 10),
#               ('microsoft nokia 7230', 10),
#               ('huawei ideos x3', 10),
#               ('nokia 6310i silver', 10)],
#              'jean': [('sony xperia z2', 9.896210908852243),
#               ('smartphone samsung galaxy', 9.724840623444443),
#               ('smartphone samsung galaxy', 9.724840623444443),
#               ('smartphone samsung galaxy', 9.724840623444443),
#               ('smartphone motorola moto', 9.417281219477195),
#               ('nokia lumia 625', 8.942179079756837),
#               ('nokia asha 302', 8.652085441018444),
#               ('nokia 108 dual', 8.593814848099365),
#               ('lg optimus l7', 8.494871375010796),
#               ('samsung instinct', 8.042514740309615)],
#              'valerio': [('samsung ativ s', 9.981960114665972),
#               ('lenovo motorola moto', 9.610708917979156),
#               ('samsung galaxy a3', 9.525755112083257),
#               ('samsung galaxy note', 9.301695251841535),
#               ('xiaomi hongmi 1s', 8.891585147088191),
#               ('samsung galaxy j5', 8.055712104536621),
#               ('samsung galaxy sii', 8.03325115192915),
#               ('microsoft lumia 950', 7.988747064649461),
#               ('huawei p9 plus', 7.983256661637079),
#               ('asus zenfone 2', 7.939525686732669)],
#              'zã¡kaznã\xadk': [('htc desire 820', 10),
#               ('iphone 5s 16gb', 10),
#               ('lg g2 32gb', 9.853147472819604),
#               ('lg g2 32gb', 9.853147472819604),
#               ('nokia lumia 630', 9.710942083361756),
#               ('nokia lumia 625', 9.684344313670868),
#               ('nokia lumia 625', 9.684344313670868),
#               ('samsung galaxy s6', 9.6),
#               ('samsung galaxy s6', 9.6),
#               ('samsung galaxy s6', 9.6)],
#              'john': [('huawei p8 grijs', 10),
#               ('blackberry z10 smartphone', 10),
#               ('sim free apple', 10),
#               ('nokia 2760 sim', 10),
#               ('sim free samsung', 9.988130823146879),
#               ('sim free samsung', 9.988130823146879),
#               ('huawei ascend y330', 9.799832627608808),
#               ('tech armor samsung', 9.731319668651206),
#               ('blackberry z30 unlocked', 9.713864468864468),
#               ('lg electronics nexus', 9.684722454747789)],
#              'manish': [('samsung galaxy a8', 9.525945368474458),
#               ('micromax canvas turbo', 9.332560625932748),
#               ('huawei honor 5x', 9.187143151654745),
#               ('huawei honor 8', 9.156396202090049),
#               ('nokia lumia 530', 9.082973535533723),
#               ('samsung galaxy j2', 8.88446897336419),
#               ('micromax unite 2', 8.826267827103424),
#               ('apple iphone 5s', 7.9973587198387),
#               ('huawei nexus 6p', 6.315506921053958),
#               ('apple iphone 6', 6.165853739103415)],
#              'angel': [('sony xperia xz', 9.740583617307157),
#               ('motcb moto g', 9.71274848746759),
#               ('sony xperia z3', 9.634221901890559),
#               ('sony xperia z3', 9.634221901890559),
#               ('samsung galaxy ace', 9.622705817678938),
#               ('samsung galaxy ace', 9.622705817678938),
#               ('microsoft lumia 640', 9.302235917470599),
#               ('lg g3 d855', 9.273711085975673),
#               ('lg optimus g', 9.009674340740883),
#               ('sony xperia go', 8.77257245487096)],
#              'sandy': [('lg google nexus', 9.180088210427815),
#               ('microsoft nokia 6303i', 9.170949220284413),
#               ('samsung galaxy s7', 9.12693488797976),
#               ('nokia lumia 520', 8.870518228000016),
#               ('nokia n9 unlocked', 8.69633577254067),
#               ('huawei ascend y300', 8.657417916376604),
#               ('sony xperia z5', 8.63182936168378),
#               ('tech armor galaxy', 8.603611097728592),
#               ('tudia zenfone 3', 8.440046102573913),
#               ('meizu m1 note', 8.42229578928613)],
#              'angelo': [('lg k10 smartphone', 10),
#               ('lg e610 l5', 10),
#               ('samsung c3590 telefono', 10),
#               ('samsung n9005 galaxy', 10),
#               ('wiko fever 4g', 9.879249322824915),
#               ('sony xperia z3', 9.74825560587938),
#               ('sony xperia z3', 9.74825560587938),
#               ('samsung galaxy note', 9.59973801506029),
#               ('apple iphone 5c', 9.562994664306757),
#               ('thl 5000 smartphone', 9.502141956230535)],
#              'prashant': [('htc desire 816', 9.348643215980646),
#               ('blackberry bold 9790', 9.258357753348195),
#               ('meizu m1 note', 8.781763117868758),
#               ('sony xperia t2', 8.45819697458105),
#               ('lenovo vibe x3', 7.563389340088872),
#               ('asus zenfone max', 7.354154745780275),
#               ('google nexus 5', 7.087246424285812),
#               ('motorola moto g', 6.115633403669099),
#               ('hp slate 6', 5.725578855388175),
#               ('lenovo vibe p1m', 5.311922491621215)],
#              'ð\x92ð¸ðºñ\x82ð¾ñ\x80ð¸ñ\x8f': [('samsung galaxy s5',
#                9.941449303895174),
#               ('samsung galaxy s5', 9.941449303895174),
#               ('samsung galaxy s5', 9.941449303895174),
#               ('samsung galaxy s5', 9.941449303895174),
#               ('nokia 5230 xpressmusic', 9.753106437508526),
#               ('sony xperia l', 9.606348781350517),
#               ('apple iphone se', 9.584414952611338),
#               ('sony xperia m', 9.567129477959872),
#               ('samsung galaxy s4', 9.108079825975818),
#               ('sony xperia sp', 8.90130413413562)],
#              'eli': [('huawei p8 lite', 9.322878942351705),
#               ('asus zenfone 2', 9.19718708498842),
#               ('samsung galaxy core', 9.112128246191048),
#               ('doogee dagger dg550', 8.975270648578865),
#               ('nokia lumia 800', 8.551859126523109),
#               ('smartphone lg l90', 7.625468202958225),
#               ('samsung galaxy s7', 5.619411101526497),
#               ('samsung t404g prepaid', 5.018661256377291),
#               ('motorola verizon motorola', 3.176733049001117)],
#              'andrea': [('samsung g357 galaxy', 10),
#               ('huawei ascend g525', 10),
#               ('huawei ascend g750', 10),
#               ('sony e6653 xperia', 10),
#               ('smartphone moto e', 10),
#               ('nokia lumia 720', 10),
#               ('nokia lumia 720', 10),
#               ('samsung j510 galaxy', 10),
#               ('doogee x3 smartphone', 10),
#               ('samsung i9082 galaxy', 9.986843686534154)],
#              'ð\x90ð»ðµðºñ\x81ð°ð½ð´ñ\x80': [('acer liquid e1', 10),
#               ('lg e510 optimus', 10),
#               ('nokia lumia 730', 10),
#               ('nokia n95', 9.863573926073926),
#               ('sony xperia z2', 9.776737821565408),
#               ('samsung c5212 duos', 9.708478766724841),
#               ('motorola flipout', 9.639583333333334),
#               ('sony xperia m', 9.572980882690832),
#               ('sony xperia m', 9.572980882690832),
#               ('samsung galaxy j7', 9.557421270638699)],
#              'anonymous': [('apple iphone 7', 10),
#               ('apple iphone 7', 10),
#               ('iphone 5s 16', 10),
#               ('apple iphone 7', 10),
#               ('lg electronics g2', 10),
#               ('sim free iphone', 10),
#               ('lg unlocked lg', 10),
#               ('iphone 5s 16', 10),
#               ('apple iphone 7', 10),
#               ('lg g2 verizon', 10)],
#              'alexandre': [('microsoft lumia 435', 9.757606265463373),
#               ('celular desbloqueado samsung', 9.652598455903963),
#               ('lg a290', 9.610091725761807),
#               ('samsung galaxy s6', 9.304204066155322),
#               ('smartphone lg l90', 9.1029237003067),
#               ('nokia lumia 520', 9.045223267652402),
#               ('smartphone samsung galaxy', 8.765686280048694),
#               ('samsung wave m', 8.277640432200714),
#               ('nokia lumia 530', 7.363718744891676),
#               ('samsung galaxy s', 7.097642955572733)],
#              'eva': [('samsung j320 galaxy', 10),
#               ('samsung galaxy note', 9.16339140394376),
#               ('meizu m3s 16gb', 8.988285294666696),
#               ('samsung galaxy s5', 8.702199440760655),
#               ('htc desire 500', 8.394858515904657),
#               ('samsung galaxy s7', 7.976484681046606),
#               ('huawei ascend y201', 7.870973423678452),
#               ('sony xperia sp', 7.849602282457358),
#               ('htc windows phone', 7.796860064641412),
#               ('smartphone lg optimus', 7.787919004623307)],
#              'cliente amazon': [('huawei ascend g750', 10),
#               ('huawei mate 9', 10),
#               ('samsung ativ s', 10),
#               ('samsung ativ s', 10),
#               ('nokia cellulare nokia', 10),
#               ('xiaomi redmi 2', 10),
#               ('aicek coque samsung', 10),
#               ('xiaomi mi 3', 10),
#               ('xiaomi redmi 2', 10),
#               ('doro phone easy', 10)],
#              'nicolas': [('htc one m8', 9.795994798099827),
#               ('samsung galaxy mega', 9.602789151020682),
#               ('samsung i9105p galaxy', 9.590603712149296),
#               ('huawei p8 lite', 9.455223897694172),
#               ('huawei p8 lite', 9.455223897694172),
#               ('samsung s8500 wave', 9.402387809145505),
#               ('nokia lumia 925', 9.261209738177978),
#               ('apple iphone 6', 9.201648330066462),
#               ('samsung galaxy j7', 9.127897130797209),
#               ('sony ericsson xperia', 8.898630964840875)],
#              'mike': [('blackberry classic factory', 10),
#               ('sim free apple', 10),
#               ('htc one m8', 10),
#               ('microsoft nokia 2710', 10),
#               ('sim free apple', 10),
#               ('zte axon 7', 10),
#               ('motorola nexus 6', 10),
#               ('motorola moto x', 10),
#               ('honor 3c smartphone', 9.935475695475695),
#               ('htc one 32gb', 9.917489711934156)],
#              'andreas': [('honor 6 smartphone', 10),
#               ('honor 8 smartphone', 10),
#               ('acer liquid e2', 9.843836929165851),
#               ('sony xperia z1', 9.653735720585281),
#               ('sony xperia z1', 9.653735720585281),
#               ('lg electronics g', 9.64562839418291),
#               ('samsung galaxy a5', 9.509381984798964),
#               ('sony xperia z2', 9.453821493816163),
#               ('nokia 3230', 8.84743182262334),
#               ('sony ericsson xperia', 8.75558176981191)],
#              'stefan': [('samsung star 3', 10),
#               ('htc one sv', 10),
#               ('sony xperia xcompact', 10),
#               ('huawei p8 grijs', 10),
#               ('lenovo moto g4', 10),
#               ('htc 8x blauw', 10),
#               ('microsoft nokia 100', 10),
#               ('nokia lumia 925', 10),
#               ('just 1 j509', 10),
#               ('lenovo motorola razr', 9.920173047804456)],
#              'ð\x9fð¾ð»ñ\x8cð·ð¾ð²ð°ñ\x82ðµð»ñ\x8c ñ\x81ðºñ\x80ñ\x8bð» ñ\x81ð²ð¾ð¸ ð´ð°ð½ð½ñ\x8bðµ': [('dell venue pro',
#                10),
#               ('microsoft lumia 950', 9.960789401751857),
#               ('microsoft lumia 950', 9.960789401751857),
#               ('huawei ascend y600', 9.949932614555255),
#               ('alcatel idol 4', 9.90700808625337),
#               ('apple iphone 7', 9.865855012839368),
#               ('apple iphone 7', 9.865855012839368),
#               ('samsung galaxy note', 9.653163757264805),
#               ('blackberry passport', 9.648289022002352),
#               ('htc one x9', 9.555044716703325)],
#              'jose': [('sim free motorola', 10),
#               ('smartphone moto e', 10),
#               ('samsung galaxy a9', 10),
#               ('lg g5 h850', 9.95201104447776),
#               ('lenovo motorola moto', 9.944473073493228),
#               ('lenovo motorola moto', 9.944473073493228),
#               ('motorola moto x', 9.91666405845841),
#               ('smartphone samsung galaxy', 9.86841213085557),
#               ('smartphone samsung galaxy', 9.86841213085557),
#               ('smartphone samsung galaxy', 9.86841213085557)],
#              'antonio': [('apple smartphone iphone', 10),
#               ('samsung g3500 galaxy', 10),
#               ('samsung n9005 galaxy', 10),
#               ('samsung a5 2016', 10),
#               ('samsung ativ s', 9.99756515355009),
#               ('samsung a500 galaxy', 9.995764187972863),
#               ('smartphone moto e', 9.982738743814862),
#               ('smartphone moto e', 9.982738743814862),
#               ('samsung s7580 galaxy', 9.927790373186253),
#               ('samsung g920 galaxy', 9.64124759389894)],
#              'anonieme bezoeker': [('nokia lumia 820', 9.234007900815534),
#               ('nokia lumia 820', 9.234007900815534),
#               ('blackberry bold 9900', 8.953726481426196),
#               ('nokia lumia 920', 8.928482969747574),
#               ('lg e610 optimus', 8.660661629210743),
#               ('nokia asha 200', 8.24163982419322),
#               ('htc desire x', 8.193334013290412),
#               ('samsung galaxy s', 8.19239577572977),
#               ('samsung galaxy s4', 8.1),
#               ('samsung galaxy s4', 8.1)],
#              'toni': [('sim free samsung', 10),
#               ('motorola smartphone motorola', 9.861327198547261),
#               ('nokia lumia 625', 9.778261736711602),
#               ('samsung i9301 galaxy', 9.639656127168728),
#               ('samsung galaxy note', 9.307958837241172),
#               ('microsoft lumia 640', 9.011111171917365),
#               ('motorola moto x', 8.97398591726958),
#               ('htc one x', 8.813109921908023),
#               ('motorola razr i', 8.766858175675662),
#               ('motorola razr i', 8.766858175675662)],
#              'lukas': [('samsung smartphone dual', 10),
#               ('samsung b2100 outdoor', 9.400521097809444),
#               ('lenovo moto x', 9.39308842890346),
#               ('xiaomi redmi note', 9.378168400133617),
#               ('htc one smartphone', 9.358729916201447),
#               ('microsoft lumia 640', 9.340464750100914),
#               ('huawei u8860 smartphone', 9.26547532374974),
#               ('samsung galaxy s6', 9.17726714722112),
#               ('microsoft lumia 930', 9.003786787253215),
#               ('motorola moto g', 8.969468708156086)],
#              'anthony': [('htc flyer 7', 10),
#               ('samsung galaxy s7', 10),
#               ('samsung galaxy s7', 10),
#               ('samsung transform ultra', 10),
#               ('lg optimus g', 10),
#               ('blackberry curve 8520', 10),
#               ('sony mobile xperia', 9.500736275211908),
#               ('apple iphone 7', 9.476009464147422),
#               ('apple iphone 7', 9.476009464147422),
#               ('apple iphone 7', 9.476009464147422)],
#              'pedro': [('blackberry z10 uk', 10),
#               ('lenovo p780', 10),
#               ('smartphone lg g2', 9.753952983928032),
#               ('sony xperia z1', 9.497524461170695),
#               ('sony xperia z1', 9.497524461170695),
#               ('alcatel pop c7', 9.42404756806928),
#               ('samsung galaxy nexus', 9.354722439831184),
#               ('meizu mx4 pro', 9.298476056847521),
#               ('smartphone samsung galaxy', 9.267185916682426),
#               ('meizu m3 note', 9.255090161139222)],
#              'ð\xa0ð¾ð¼ð°ð½': [('huawei ascend g750', 9.915486464258406),
#               ('motorola defy', 9.79981685283436),
#               ('nokia 101 premium', 9.75687647619488),
#               ('samsung galaxy s7', 9.73791304958776),
#               ('sony xperia tx', 9.72933082473017),
#               ('nokia lumia 720', 9.706512744451011),
#               ('htc desire', 9.332071378050202),
#               ('samsung n9000 galaxy', 9.240529389131689),
#               ('samsung galaxy a5', 8.999532499664431),
#               ('sony ericsson vivaz', 8.845835053047647)],
#              'jack': [('huawei p8 grijs', 10),
#               ('lg g5 h850', 9.929779928140661),
#               ('huawei ascend mate', 9.639256319825952),
#               ('nokia 808 pureview', 9.558152785166037),
#               ('samsung galaxy s7', 9.361508996525506),
#               ('samsung galaxy s7', 9.361508996525506),
#               ('samsung galaxy s7', 9.361508996525506),
#               ('samsung galaxy s7', 9.361508996525506),
#               ('sony xperia m', 9.280935878928476),
#               ('samsung galaxy j5', 9.200020847444742)],
#              'pasquale': [('huawei ascend y5', 9.506860836708723),
#               ('asus zenfone 2', 9.40418422843343),
#               ('alcatel one touch', 9.29517027820325),
#               ('lg d802 g2', 9.273751858020617),
#               ('nokia asha 306', 8.893128164270731),
#               ('nokia lumia 520', 8.854425247932236),
#               ('samsung a700 galaxy', 8.764756306258441),
#               ('lenovo motorola moto', 8.740100423532557),
#               ('huawei ascend y550', 8.725306190409157),
#               ('asus zenfone 3', 8.593589861704142)],
#              'mar': [('motorola moto g', 9.060011531204287),
#               ('lg optimus f3', 8.933149576900854),
#               ('huawei p8 lite', 8.709200819691636),
#               ('lg optimus hub', 8.485128323274063),
#               ('htc evo 4g', 8.452901567785354),
#               ('sony xperia zr', 8.004080643098469),
#               ('huawei ascend g730', 7.745576813210356),
#               ('samsung galaxy j5', 7.133004845782428),
#               ('motorola droid 3', 7.080269243661039),
#               ('samsung galaxy s7', 6.399725372716592)],
#              'philipp': [('honor 7 smartphone', 9.944273542819037),
#               ('huawei ascend p6', 9.650550576796332),
#               ('nokia 3250', 9.584184860179468),
#               ('blackberry q5 smartphone', 9.507013110093192),
#               ('acer liquid e1', 9.436038595616619),
#               ('sony ericsson xperia', 8.8015662677029),
#               ('sony ericsson s500i', 8.580324804313369),
#               ('apple iphone 4', 8.045271636047042),
#               ('microsoft lumia 550', 5.650424054246624),
#               ('samsung galaxy s5', 3.610773740917958)],
#              'paul': [('sim free apple', 10),
#               ('sim free iphone', 10),
#               ('samsung s5570 galaxy', 10),
#               ('lg electronics google', 10),
#               ('sim free apple', 10),
#               ('htc one m9', 9.98550882475555),
#               ('nokia e90 communicator', 9.958988095238094),
#               ('samsung galaxy s5', 9.881140429226111),
#               ('samsung galaxy s5', 9.881140429226111),
#               ('lenovo motorola moto', 9.695022199784985)],
#              'roberto': [('samsung galaxy gs7', 10),
#               ('huawei smartphone huawei', 10),
#               ('honor 6x smartphone', 10),
#               ('samsung n7505 galaxy', 10),
#               ('huawei p8lite zwart', 9.891218723360875),
#               ('nokia e72 unlocked', 9.781130746110014),
#               ('cubot x16 smartphone', 9.771924952324783),
#               ('lg e430 l3ii', 9.71681714109106),
#               ('huawei ascend p8', 9.70899154227621),
#               ('huawei mate 9', 9.679652183337422)],
#              'wendy': [('samsung galaxy note', 9.74934766109857),
#               ('samsung galaxy note', 9.74934766109857),
#               ('samsung galaxy note', 9.74934766109857),
#               ('huawei p9 smartphone', 9.378931781045752),
#               ('samsung galaxy s', 9.368565619855469),
#               ('htc wildfire s', 9.320034089449887),
#               ('sony xperia z', 9.231287851372523),
#               ('samsung tocco lite', 9.187500066334053),
#               ('lenovo motorola razr', 9.185521209816534),
#               ('huawei p8 lite', 9.169667018645965)],
#              'ð\x90ð½ð´ñ\x80ðµð¹': [('lg optimus l4', 10),
#               ('samsung n9005 galaxy', 10),
#               ('htc desire s', 10),
#               ('samsung n7100 galaxy', 9.759450419882908),
#               ('samsung n7100 galaxy', 9.759450419882908),
#               ('sony xperia zr', 9.562517732236747),
#               ('samsung galaxy s7', 9.541113975186429),
#               ('samsung galaxy j7', 9.416554117222644),
#               ('samsung galaxy a5', 9.30153214034736),
#               ('samsung galaxy a5', 9.30153214034736)],
#              'fernando': [('smartphone asus zenfone', 10),
#               ('microsoft nokia lumia', 9.867615900093337),
#               ('asus zenfone 2', 9.605052382123423),
#               ('samsung galaxy grand', 9.326252155337059),
#               ('zte axon 7', 9.323712526693097),
#               ('sprint lg volt', 9.114187661850835),
#               ('huawei ascend g300', 8.865341963237055),
#               ('samsung galaxy j1', 8.744910955422693),
#               ('samsung galaxy s7', 8.73923273529432),
#               ('smartphone samsung galaxy', 8.735551272228154)],
#              'mark': [('lenovo motorola moto', 10),
#               ('wiko lenny 3', 10),
#               ('samsung galaxy mega', 10),
#               ('motorola google nexus', 10),
#               ('samsung galaxy mega', 10),
#               ('huawei mate 9', 10),
#               ('huawei honor 8', 10),
#               ('sim free sony', 10),
#               ('blackberry passport factory', 10),
#               ('lg electronics e460', 9.939629958012311)],
#              'rachel': [('smartphone lg l90', 10),
#               ('microsoft lumia 435', 10),
#               ('samsung galaxy reverb', 10),
#               ('lg 840g prepaid', 10),
#               ('samsung galaxy j7', 10),
#               ('sim free iphone', 9.979808088775835),
#               ('samsung galaxy s5', 9.785519405803004),
#               ('samsung galaxy s5', 9.785519405803004),
#               ('asus zenfone max', 9.659878680079942),
#               ('wiko smartphone wiko', 9.64645370725617)],
#              'laura': [('asus zenfone 5', 10),
#               ('lg optimus l7', 10),
#               ('sim free samsung', 10),
#               ('lg k10 smartphone', 10),
#               ('huawei ascend w1', 10),
#               ('sony xperia tipo', 10),
#               ('huawei p9 lite', 9.82382849138965),
#               ('lenovo motorola moto', 9.817971952793513),
#               ('apple iphone 4s', 9.524036319793495),
#               ('apple iphone 4s', 9.524036319793495)],
#              'incesaz': [('sony ericsson w995', 4.521118804615245),
#               ('apple iphone 3g', 4.03475363019809),
#               ('nokia n97 mini', 2.764881217755674),
#               ('sony ericsson k850i', 2.543796208307624),
#               ('nokia 6500 slide', 2.226289765080222),
#               ('nokia 2630 cep', 1),
#               ('samsung e250 cep', 1)],
#              'wolfgang': [('microsoft nokia e51', 10),
#               ('lg electronics l40', 10),
#               ('blackberry passport smartphone', 10),
#               ('samsung galaxy mega', 9.353168847799514),
#               ('htc one s', 8.898099944779457),
#               ('samsung galaxy ace', 8.756453855840292),
#               ('samsung galaxy j5', 8.724157956321594),
#               ('lenovo razr v3', 8.591638290870929),
#               ('samsung galaxy s3', 7.6952283222987194),
#               ('samsung galaxy s3', 7.6952283222987194)],
#              'manu': [('blackberry q10 smartphone', 10),
#               ('samsung galaxy s3', 9.764960839107383),
#               ('samsung galaxy s3', 9.764960839107383),
#               ('samsung galaxy j5', 9.526756266557607),
#               ('blu vivo xl', 9.192025894594689),
#               ('desconocido xiaomi redmi', 9.042709370227366),
#               ('celular desbloqueado nokia', 8.845463516800105),
#               ('lenovo motorola moto', 8.681394940558906),
#               ('sony ericsson k800i', 8.164348763828185),
#               ('htc wildfire s', 8.045532613513982)],
#              'rick2809': [('smartphone samsung galaxy', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone microsoft lumia', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone apple iphone', 10),
#               ('smartphone asus zenfone', 10),
#               ('smartphone samsung galaxy', 10),
#               ('smartphone motorola moto', 9.947318094136977)],
#              'gianfranco': [('alcatel one touch', 9.375843470735477),
#               ('lenovo zuk z1', 9.308398620170278),
#               ('lenovo zuk z1', 9.308398620170278),
#               ('huawei p9 lite', 9.306331685631152),
#               ('huawei p9 lite', 9.306331685631152),
#               ('sony e5603 xperia', 9.175385306925762),
#               ('alcatel pixi 4', 8.826191968798891),
#               ('alcatel pixi 4', 8.826191968798891),
#               ('honor 7 smartphone', 8.480984611238911),
#               ('nokia asha 305', 8.370166657645797)],
#              "client d'amazon": [('blackberry priv smartphone', 10),
#               ('nokia lumia 830', 9.827116887876677),
#               ('oukitel k6000 4g', 9.801692278088431),
#               ('lg g2 smartphone', 9.711033574510786),
#               ('lenovo motorola moto', 9.586969317532715),
#               ('lg nexus 5x', 9.501354962417548),
#               ('samsung gt b2100', 9.407127687543523),
#               ('alcatel onetouch pop', 9.338301758780856),
#               ('honor 4x smartphone', 9.316430943962285),
#               ('huawei mate 9', 9.228123724188315)],
#              'juan': [('doogee voyager2 dg310', 9.723260682231025),
#               ('sony xperia neo', 9.71569213912168),
#               ('sony xperia neo', 9.71569213912168),
#               ('motorola moto g', 9.626968824687657),
#               ('nokia lumia 520', 9.619510468066487),
#               ('samsung galaxy s6', 9.474898906994664),
#               ('huawei ascend p6', 9.466614961415324),
#               ('elephone p6000 pro', 9.331433947362001),
#               ('samsung galaxy j7', 9.259378658135182),
#               ('samsung galaxy young', 9.084620453394793)],
#              'sergio': [('apple smartphone iphone', 10),
#               ('huawei ascend y550', 10),
#               ('smartphone samsung galaxy', 10),
#               ('lenovo moto g4', 10),
#               ('nokia lumia 830', 10),
#               ('smartphone samsung galaxy', 10),
#               ('nokia microsoft lumia', 10),
#               ('samsung s7582 galaxy', 10),
#               ('motorola nexus 6', 10),
#               ('nokia lumia 925', 9.989302147055039)],
#              'charlie': [('lg 530g prepaid', 10),
#               ('lg electronics nexus', 9.47838029570653),
#               ('samsung galaxy j7', 8.958526709756786),
#               ('apple iphone 5s', 8.83915415047973),
#               ('apple iphone 6', 8.812702977770662),
#               ('doogee x5 max', 8.7926603878539),
#               ('lg ku990 viewty', 8.785014337645915),
#               ('samsung galaxy y', 8.707605207579668),
#               ('samsung e1080i sim', 8.603036780655994),
#               ('samsung galaxy a3', 8.363487105373705)],
#              'nicole': [('samsung galaxy s4', 10),
#               ('lg electronics t385', 10),
#               ('huawei nexus 6p', 10),
#               ('lenovo motorola moto', 9.924604240989456),
#               ('samsung galaxy j1', 9.770990949544803),
#               ('samsung galaxy j7', 9.44630215966994),
#               ('archos 50 helium', 8.719670636567093),
#               ('apple iphone 5c', 8.137217248496952),
#               ('samsung galaxy alpha', 6.609276328638024),
#               ('sony xperia zl', 5.956284883001086)],
#              'ð\x95ð²ð³ðµð½ð¸ñ\x8f': [('samsung galaxy a5', 9.670214183955109),
#               ('samsung n7100 galaxy', 9.62109434963506),
#               ('samsung s7270 galaxy', 9.584238986787241),
#               ('sony xperia z1', 9.523441168506455),
#               ('sony xperia z1', 9.523441168506455),
#               ('sony xperia l', 9.30380204889166),
#               ('samsung galaxy note', 9.053804908125354),
#               ('sony xperia m', 8.868996852857709),
#               ('samsung galaxy s4', 8.68816339333813),
#               ('samsung galaxy s4', 8.68816339333813)],
#              'ð\x94ð¸ð¼ð°': [('samsung i5800 galaxy', 10),
#               ('samsung galaxy s4', 9.963332022172162),
#               ('sony xperia z1', 9.942596689024771),
#               ('samsung i8190 galaxy', 9.613824423568346),
#               ('sony xperia l', 9.259802030381955),
#               ('sony xperia l', 9.259802030381955),
#               ('htc desire v', 9.184803448971767),
#               ('samsung galaxy ace', 8.96324891362002),
#               ('samsung galaxy a3', 8.940440531279165),
#               ('htc desire s', 4.9407654582152185)],
#              'rpv': [('samsung galaxy s4', 10),
#               ('samsung galaxy s4', 10),
#               ('samsung galaxy s4', 10),
#               ('nokia lumia 920', 9.975487459484553),
#               ('nokia lumia 920', 9.975487459484553),
#               ('nokia lumia 920', 9.975487459484553),
#               ('nokia lumia 720', 9.9408397086438),
#               ('nokia lumia 720', 9.9408397086438),
#               ('nokia lumia 720', 9.9408397086438),
#               ('samsung galaxy note', 9.137117836782384)],
#              'ana': [('motorola cd930', 10),
#               ('huawei p8 champagne', 10),
#               ('huawei smartphone huawei', 10),
#               ('smartphone nokia lumia', 9.87412872000799),
#               ('lg nexus 5', 9.759883420994978),
#               ('smartphone samsung galaxy', 9.62749766573296),
#               ('smartphone samsung galaxy', 9.62749766573296),
#               ('smartphone samsung galaxy', 9.62749766573296),
#               ('smartphone samsung galaxy', 9.62749766573296),
#               ('samsung galaxy s5', 9.50826668890472)],
#              'ð\x90ð½ð°ñ\x81ñ\x82ð°ñ\x81ð¸ñ\x8f': [('samsung galaxy s4',
#                9.696261339875514),
#               ('asus zenfone 2', 9.61474318245564),
#               ('samsung i9082 galaxy', 9.602364688319643),
#               ('sony xperia t2', 9.469837860934776),
#               ('nokia x6 8gb', 9.376855500299321),
#               ('samsung galaxy a3', 9.169089550844454),
#               ('sony xperia z', 8.77699750286455),
#               ('samsung s5660 galaxy', 8.524686675400137),
#               ('samsung n7100 galaxy', 8.465991336430614),
#               ('samsung n7100 galaxy', 8.465991336430614)],
#              'gary': [('huawei mate 9', 10),
#               ('samsung note 2', 10),
#               ('nokia lumia 635', 9.858496861366634),
#               ('samsung galaxy j5', 9.741237828379596),
#               ('apple iphone se', 9.692674999450997),
#               ('lg g2 mini', 9.15930321166973),
#               ('blu dash x', 9.0023551118189),
#               ('samsung i9100 galaxy', 8.944246330898306),
#               ('samsung galaxy a3', 8.934422223001269),
#               ('lg verizon lg', 8.567380364618488)],
#              'mary': [('tracfone motorola moto', 10),
#               ('huawei p8 grijs', 10),
#               ('wiko cink slim', 10),
#               ('samsung galaxy s3', 9.81363647035881),
#               ('samsung knack u310', 9.771151061178184),
#               ('huawei honor 5x', 9.624257029113874),
#               ('samsung galaxy s4', 9.592535225152218),
#               ('huawei ascend w1', 9.575508222481282),
#               ('nokia lumia 1320', 9.461943613015674),
#               ('huawei p8 lite', 9.449559991160477)],
#              'mario': [('sony e6653 xperia', 10),
#               ('huawei ascend p8', 10),
#               ('sim free apple', 10),
#               ('samsung galaxy mega', 9.749354553680227),
#               ('wiko fever 4g', 9.71325488250558),
#               ('lg optimus l90', 9.642601637826425),
#               ('microsoft lumia 640', 9.494926812768092),
#               ('smartphone lg l90', 9.452532046696726),
#               ('lenovo motorola moto', 9.4),
#               ('lenovo motorola moto', 9.4)],
#              'caroline': [('sim free apple', 10),
#               ('ringke asus zenfone', 10),
#               ('smartphone asus zenfone', 10),
#               ('lenovo moto g4', 9.586776961124245),
#               ('samsung galaxy s5', 9.41986341389381),
#               ('samsung galaxy s5', 9.41986341389381),
#               ('motorola moto g', 9.403640748115805),
#               ('microsoft lumia 640', 9.39627020999173),
#               ('smartphone alcatel one', 9.320366996755446),
#               ('samsung galaxy j5', 9.171222971091911)],
#              'kindle customer': [('nokia lumia 720', 10),
#               ('nokia lumia 720', 10),
#               ('samsung s425g prepaid', 10),
#               ('samsung s425g prepaid', 10),
#               ('samsung s3350 chat', 10),
#               ('nokia lumia 735', 9.851258617448588),
#               ('htc one 32gb', 9.70293880804148),
#               ('huawei y3 smartphone', 9.434252912036417),
#               ('zte axon pro', 9.403464557125236),
#               ('htc evo v', 9.394858544743562)],
#              'frank': [('huawei p8 champagne', 10),
#               ('huawei honor 3c', 10),
#               ('huawei ascend g610', 10),
#               ('lg google nexus', 10),
#               ('huawei p8 grijs', 10),
#               ('blackberry q5 smartphone', 10),
#               ('huawei ascend g7', 10),
#               ('apple iphone 5c', 9.983700459699238),
#               ('sony xperia z5', 9.980087928582535),
#               ('doogee voyager2 dg310', 9.942919570071833)],
#              '????????': [('sony xperia s', 9.404254870676883),
#               ('samsung galaxy note', 9.277305888938121),
#               ('samsung galaxy note', 9.277305888938121),
#               ('nokia asha 309', 9.228232572463577),
#               ('samsung galaxy s', 9.165720111276404),
#               ('htc radar', 9.09219961312856),
#               ('huawei ascend w1', 9.072531784615293),
#               ('lg optimus l5', 8.759995450353436),
#               ('lg optimus l5', 8.759995450353436),
#               ('caterpillar cat b15', 8.75824101904065)],
#              'claire': [('sim free apple', 10),
#               ('lg electronics spirit', 9.719662299683254),
#               ('blackberry bold 9900', 9.434827320805368),
#               ('lg env2', 8.42865317892461),
#               ('microsoft lumia 640', 8.28551587684053),
#               ('huawei nexus 6p', 8.190298576042492),
#               ('samsung galaxy s3', 8.092237475338582),
#               ('sony ericsson k700i', 7.941648374610174),
#               ('samsung galaxy y', 7.780141848881444),
#               ('apple iphone 7', 7.260112795745476)],
#              'william': [('huawei p8 grijs', 10),
#               ('huawei mate 7', 10),
#               ('nokia 6125', 9.785987674189222),
#               ('samsung galaxy s5', 9.779626063522308),
#               ('samsung galaxy s5', 9.779626063522308),
#               ('dell venue pro', 9.741358111673856),
#               ('apple iphone 6s', 9.718007643610305),
#               ('samsung galaxy s4', 9.659331482438459),
#               ('honor 7 smartphone', 9.551773526613779),
#               ('nokia lumia 920', 9.411149765177637)],
#              'ozer': [('sony ericsson w995', 5.282608695652174),
#               ('sony ericsson w910i', 5.21875),
#               ('motorola razr2 v9', 4.294117647058823),
#               ('sony ericsson w580i', 3.755769230769231),
#               ('sony ericsson c903', 2.7),
#               ('nokia 6303 classic', 2.5161290322580645),
#               ('sony ericsson k810i', 2.48),
#               ('sony ericsson k850i', 2.4),
#               ('motorola rokr e8', 2.353846153846154),
#               ('sony ericsson m600i', 1.5428571428571427)],
#              'giovanni': [('nokia 215 telefono', 9.609828893114924),
# ...
#               ('micromax canvas hd', 8.716496460930887),
#               ('asus zenfone 5', 7.833588077380904),
#               ('sony xperia c3', 4.15079001926663)],
#              'natalia': [('sony xperia s', 9.184952094475852),
#               ('sony xperia z3', 8.943302908907146),
#               ('samsung galaxy s6', 8.91058807427141),
#               ('alcatel one touch', 8.82784764781731),
#               ('ee alcatel one', 8.226462970088743),
#               ('huawei ascend g510', 7.6048794796709265),
#               ('samsung galaxy star', 6.999348522015234),
#               ('sony xperia tipo', 6.891430583049399),
#               ('lenovo motorola moto', 5.592956966163445)],
#              'ciklet': [('nokia e90 cep', 1),
#               ('nokia 5310 cep', 1),
#               ('nokia n70 cep', 1)],
#              'thierry': [('honor 4x smartphone', 9.44565389288702),
#               ('nokia lumia 830', 9.404311045375206),
#               ('alcatel one touch', 9.185737477775227),
#               ('samsung galaxy core', 8.754550264671748),
#               ('samsung galaxy a5', 8.42708489347006),
#               ('nokia microsoft lumia', 8.011499363269827),
#               ('samsung galaxy y', 7.879370816924837),
#               ('samsung galaxy s4', 7.878670844460792),
#               ('lg g3 smartphone', 7.877591048416306),
#               ('samsung galaxy s5', 7.834196828847035)],
#              'mel': [('tech armor galaxy', 10),
#               ('microsoft lumia 640', 9.35726464347768),
#               ('huawei ascend mate', 8.540467480702725),
#               ('motorola rokr e1', 5.879274252858191),
#               ('motorola mb300 backflip', 1)],
#              'bianca': [('huawei p8 grijs', 9.313934968233582),
#               ('apple iphone 5c', 9.14238108990349),
#               ('sony xperia z5', 8.785047451327529),
#               ('sony ericsson s500i', 8.40734743702781),
#               ('samsung galaxy s4', 8.181690922053154),
#               ('smartphone motorola defy', 8.13799147613549),
#               ('samsung galaxy s6', 7.751645928072033),
#               ('sony ericsson c', 3.9512098275145076)],
#              'marion': [('emporia elegance handy', 9.397512163344405),
#               ('doro matra phone', 7.901254310622325),
#               ('buyus etui housse', 7.6168188622012005),
#               ('sony xperia m4', 7.5107440996252866),
#               ('apple iphone 7', 7.456985364029468),
#               ('lenovo motorola moto', 5.214218459893889)],
#              'simona': [('asus ze550kl zenfone', 10),
#               ('huawei ascend g7', 9.650192719000987),
#               ('huawei ascend p7', 9.469935727557083),
#               ('lg g2 mini', 9.232059680634464),
#               ('huawei p8 lite', 9.151547630590258),
#               ('homtom ht7 3g', 9.015038327876834),
#               ('homtom ht7 3g', 9.015038327876834),
#               ('samsung galaxy j5', 8.23322461757608),
#               ('apple iphone 5s', 8.131448452311938),
#               ('lenovo motorola moto', 7.441961497541433)],
#              'enzo': [('lg k10 smartphone', 10),
#               ('sony e6653 xperia', 10),
#               ('lenovo motorola moto', 9.895612967652228),
#               ('lenovo motorola moto', 9.895612967652228),
#               ('samsung smartphone galaxy', 9.825073561777105),
#               ('huawei p9 lite', 9.58447769988447),
#               ('apple iphone 5s', 9.471074663410985),
#               ('samsung g355 galaxy', 8.892493361696745),
#               ('doogee valencia2 y100', 6.281484717542111),
#               ('huawei p8 lite', 6.132127436875525)],
#              'karadag60': [('sony ericsson w610i', 1),
#               ('sony ericsson w910i', 1),
#               ('sony ericsson c903', 1),
#               ('sony ericsson w995', 1),
#               ('palm treo pro', 1),
#               ('sony ericsson z310i', 1)],
#              'adriana': [('samsung galaxy note', 9.212003792927733),
#               ('samsung galaxy y', 8.856646892157443),
#               ('smartphone motorola moto', 8.746488282487201),
#               ('samsung i9060i galaxy', 7.897542593654873),
#               ('sony xperia l', 7.741909563736897),
#               ('huawei ascend y300', 6.374529631213897),
#               ('blackberry bold 9000', 5.297589270666314),
#               ('palm pre plus', 4.432228068915376),
#               ('motorola xt390', 1.2214607411374487)],
#              'francis': [('motorola moto g', 9.188732206987817),
#               ('apple iphone 5', 9.110648524221048),
#               ('apple iphone 7', 8.911120695626831),
#               ('samsung galaxy s7', 8.134049264713447),
#               ('samsung galaxy s7', 8.134049264713447),
#               ('samsung galaxy grand', 8.118754906929002),
#               ('samsung s5230 player', 7.512759706003681),
#               ('lg gt540', 7.329928823523585),
#               ('blackberry bold 9900', 4.684745336362304),
#               ('lg neon', 3.997174895619143)],
#              'delicate': [('apple iphone 3gs', 4.3471419470984065),
#               ('nokia e52', 3.059191259480406),
#               ('nokia 2730 classic', 2.6564248131485386),
#               ('palm treo 650', 1.807534115478676),
#               ('nokia 6600i slide', 1.7234353757641574),
#               ('palm treo 750', 1.464180793427281)],
#              'flavio': [('lg d855 g3', 9.936132399702307),
#               ('huawei ascend y530', 9.445263069671551),
#               ('apple iphone 5s', 9.341761137808675),
#               ('smartphone lg optimus', 9.327564542331178),
#               ('alcatel one touch', 9.27641991755699),
#               ('asus zenfone 2', 8.432587895743568),
#               ('lg optimus l5', 8.122506557148052),
#               ('doogee x5 max', 7.790271865324671),
#               ('motorola xt390', 5.778769209194321),
#               ('huawei nexus 6p', 4.3294879789789675)],
#              'santiago': [('huawei smartphone huawei', 9.69898169724745),
#               ('samsung galaxy s6', 9.131004423196421),
#               ('nokia lumia 1320', 9.129670932054676),
#               ('sony xperia p', 8.989887142604884),
#               ('motorola moto e', 8.914888438434575),
#               ('microsoft lumia 640', 8.656514906855449),
#               ('lenovo motorola moto', 8.303225767187485),
#               ('bq aquaris x5', 8.247825087617521),
#               ('samsung galaxy s', 7.8763682979634915),
#               ('sony xperia z', 7.455327445724268)],
#              'emanetcan': [('sony ericsson w995', 4.754347826086956),
#               ('sony ericsson w810i', 4.741428571428571),
#               ('apple iphone 3gs', 4.592307692307692),
#               ('apple iphone 3g', 4.271428571428571),
#               ('nokia n97 mini', 3.340909090909091),
#               ('blackberry storm 9530', 1.6997619047619048),
#               ('sony ericsson z320i', 1.1019548872180451),
#               ('nokia 5630 xpressmusic', 1.0214285714285714),
#               ('samsung s8003 jet', 1),
#               ('samsung e250 cep', 1)],
#              'cikolata': [('nokia 5300 xpressmusic', 2.1470588235294117),
#               ('samsung i560 cep', 1),
#               ('nokia e65 cep', 1),
#               ('nokia n76 cep', 1),
#               ('samsung u800 cep', 1)],
#              '???????????????? ??????????????': [('nokia asha 210',
#                8.989779325630312),
#               ('philips xenium w732', 8.685293392326672),
#               ('samsung galaxy pocket', 6.994069248435732),
#               ('sony xperia miro', 6.841444618113264),
#               ('sony xperia e', 6.737061519167431),
#               ('samsung c3322', 6.596105395424096),
#               ('lenovo k900 32gb', 6.428899955918174)],
#              'jr': [('samsung b5722 handy', 10),
#               ('samsung galaxy s7', 9.757418961144669),
#               ('samsung galaxy s3', 9.473216417929065),
#               ('sony ericsson cedar', 9.317029175726566),
#               ('huawei p8 lite', 8.940901299027676),
#               ('samsung galaxy s5', 8.043985654216758),
#               ('blu studio x', 7.750003856776778),
#               ('apple iphone 5s', 6.305760707617189)],
#              'ozer1299': [('nokia 6500 slide', 2.4604166666666667),
#               ('nokia n81 8gb', 1.004094827586207),
#               ('samsung d900i 1gb', 1),
#               ('nokia n70 cep', 1),
#               ('nokia x6 cep', 1),
#               ('samsung m620 cep', 1),
#               ('samsung i8000 omnia', 1)],
#              'george': [('samsung g920 galaxy', 10),
#               ('samsung ativ s', 10),
#               ('sim free motorola', 10),
#               ('huawei p9 lite', 9.971699609513506),
#               ('samsung galaxy s7', 9.699029301975607),
#               ('lg g flex', 9.699019128661094),
#               ('motorola photon q', 9.60064382029344),
#               ('apple iphone 6', 9.587276243400856),
#               ('asus zenfone max', 9.539825774580756),
#               ('samsung galaxy light', 9.286328488632735)],
#              'mustafa': [('samsung i9190 galaxy', 10),
#               ('iphone 5s 16gb', 9.891284787231339),
#               ('samsung s7580 galaxy', 6.236907229416016),
#               ('samsung galaxy j1', 6.056411760920557)],
#              'xxx': [('huawei ascend y300', 8.799285206522395),
#               ('sony ericsson xperia', 6.9169194935279785),
#               ('doogee x5 pro', 4.059790491816827),
#               ('sony ericsson w395', 3.2371638149425075)],
#              'emre': [('lg g4 us991', 9.612673841610256),
#               ('sony xperia z', 5.186862104325451),
#               ('motorola razr v3', 4.733070129576008),
#               ('nokia 5800 xpressmusic', 1)],
#              'anja': [('huawei p8lite zwart', 9.864438755189347),
#               ('vodafone smart 4', 9.834687521712821),
#               ('microsoft nokia 2760', 9.57635464406305),
#               ('htc desire c', 9.346310513242216),
#               ('htc desire 310', 9.249015104831994),
#               ('sony xperia sp', 8.93750336312057),
#               ('samsung star ii', 7.241755454467334),
#               ('samsung galaxy y', 6.950479138036832),
#               ('htc one max', 4.937370303383712),
#               ('sony ericsson c902', 4.776961559864637)],
#              '????????????????': [('huawei u8860 honor', 10),
#               ('nokia n9', 9.87953673463094),
#               ('nokia asha 210', 9.371401023358105),
#               ('apple iphone 4s', 9.323754892755709),
#               ('samsung c3782 onyx', 9.241463979597286),
#               ('htc desire c', 8.864710226122593),
#               ('sony xperia v', 8.608144973612788)],
#              'me': [('lg electronics leon', 9.857278782112274),
#               ('microsoft nokia lumia', 9.04641559495951),
#               ('samsung galaxy note', 8.177684113876172),
#               ('htc one m8', 8.165332348924752),
#               ('samsung c5212 duos', 8.115295373943388),
#               ('sony xperia z', 7.804570120436309),
#               ('samsung gt s5260', 7.29125712738809),
#               ('apple iphone 3gs', 7.120319197935455),
#               ('samsung galaxy s4', 5.353700988097343),
#               ('lg env touch', 4.51962078439017)],
#              'dolunay': [('samsung galaxy mini', 6.747095390654421),
#               ('samsung s5233w star', 1),
#               ('nokia n73 cep', 1),
#               ('nokia n72 cep', 1),
#               ('samsung d900i 1gb', 1)],
#              'sezenm': [('nokia n95 cep', 1),
#               ('samsung p520 armani', 1),
#               ('nokia n72 cep', 1),
#               ('nokia 6131 cep', 1),
#               ('nokia 5500 sport', 1)],
#              'damien': [('lg g2 mini', 9.29507567567718),
#               ('microsoft lumia 535', 9.252624562060138),
#               ('samsung galaxy s6', 9.111056864068638),
#               ('lg nexus 5', 8.110273334895387),
#               ('motorola defy', 8.089141921368917),
#               ('nokia e63', 7.992648903365423)],
#              'ram': [('microsoft lumia 640', 8.823404287965214),
#               ('microsoft lumia 640', 8.823404287965214),
#               ('apple iphone 6', 4.745233805918004),
#               ('htc evo 3d', 3.5132989857346777)],
#              'tuvok': [('samsung galaxy express', 6.068599504186317)],
#              'tobias': [('lg electronics google', 9.856217331680783),
#               ('huawei mate 9', 9.564600856797934),
#               ('samsung galaxy s', 9.562344240874944),
#               ('asus padfone 2', 9.525762216869865),
#               ('microsoft lumia 650', 9.502023296307677),
#               ('htc mozart 7', 9.219368462289811),
#               ('apple iphone 6', 9.212511855408327),
#               ('microsoft nokia 108', 9.208199042312476),
#               ('lenovo motorola moto', 8.351811617042525),
#               ('sony ericsson v630i', 8.02335222708244)],
#              'alice': [('asus ze550kl zenfone', 10),
#               ('samsung a5 2016', 9.96725382762336),
#               ('smartphone samsung galaxy', 9.91933158316918),
#               ('huawei ascend mate', 9.166378833100637),
#               ('doro phoneeasy 612', 8.805415817885704),
#               ('oukitel u7 plus', 8.669671513582633),
#               ('samsung galaxy a3', 8.443858766617852),
#               ('doro phone easy', 8.324636420689604),
#               ('samsung galaxy s4', 7.985028520900355),
#               ('asus zenfone 2', 7.546279452262863)],
#              'zehrabalta': [('apple iphone 4', 6.371501272264631),
#               ('nokia n97 mini', 3.340909090909091),
#               ('sony ericsson z310i', 2.0),
#               ('nokia e90 cep', 1),
#               ('nokia n95 cep', 1)],
#              '???????\x80????': [('apple iphone 4s', 9.170278647772157),
#               ('nokia 603', 9.143693379182057),
#               ('sony xperia v', 9.071100040938132),
#               ('htc sensation xl', 8.96360299370393),
#               ('nokia asha 311', 8.898926864477358),
#               ('samsung c3782 onyx', 6.669849090885178)],
#              'louis': [('htc desire sim', 10),
#               ('sony xperia t', 10),
#               ('nokia lumia 830', 10),
#               ('apple iphone 4s', 9.773570761384718),
#               ('sony ericsson w580', 9.72999963887548),
#               ('samsung galaxy s7', 9.628933342733456),
#               ('nokia microsoft lumia', 9.559005908462835),
#               ('samsung galaxy s5', 9.015595850044173),
#               ('doogee x5 pro', 8.746172117038062),
#               ('archos 28 internet', 8.57663373447831)],
#              'bert': [('sim free motorola', 10),
#               ('huawei p8 champagne', 9.50929663441091),
#               ('huawei p8 grijs', 9.396344924426506),
#               ('apple iphone se', 9.031002119714904),
#               ('apple iphone 5s', 8.235255452488355),
#               ('samsung b2710 solid', 8.078444675166505)],
#              'narn3049': [('sony ericsson xperia', 7.625090974158006),
#               ('pearl 8100', 7.3698074548108226),
#               ('v300', 7.131283593921645)],
#              'sue': [('sim free apple', 10),
#               ('samsung s3350 chat', 10),
#               ('huawei p9 lite', 9.458152188524465),
#               ('samsung e1270 uk', 8.22780763014993),
#               ('samsung galaxy s', 8.107206866009795),
#               ('blackberry dtek50 unlocked', 7.7456296720333935),
#               ('lg electronics ks360', 4.754139190681183)],
#              'sunny': [('doro phoneeasy 622', 10),
#               ('sony xperia s', 9.842302309962282),
#               ('karbonn titanium octane', 9.266121318571885),
#               ('lg electronics e610', 9.20698382935225),
#               ('apple iphone 6s', 9.096361779314067),
#               ('samsung galaxy a3', 7.435381495981122),
#               ('huawei p8 lite', 5.976952191583807),
#               ('apple iphone 3g', 4.832537783345794)],
#              'raquel': [('smartphone lg optimus', 9.288281418731607),
#               ('apple iphone 5', 9.111171968416384),
#               ('blackberry torch 9810', 8.80431034304058),
#               ('samsung galaxy s6', 8.089863355773348),
#               ('motorola moto g', 4.626233698849971),
#               ('htc one', 3.3249641563701267)],
#              'aksisey': [('nokia 6500 slide', 2.4),
#               ('nokia n70 cep', 1),
#               ('nokia e65 cep', 1)]})

# %% [markdown]
# Summary:
# 1. Tried SVD and Kmeans for user-user and item-item recommendations with and without cross validation
# 2. accuracy based on item-item cross validation is least. So products recommended from item-item with cV can be recommended to users
# 3. IT can be observed that SVD and KMeans produces slightly different recommendation. Sometime the recommended products are different and sometimes rank of the products.
# 4. So based on least RMSE products can be recommended to users

# %%
# 11. In what business scenario you should use popularity based Recommendation Systems ?
# 12. In what business scenario you should use CF based Recommendation Systems ?
# 13. What other possible methods can you think of which can further improve the recommendation for different users ?

# %% [markdown]
# ### Popularity based Recommendation :
# 1. Popularity based, is simplest way to build recommendation system.
# 2. It is based on popularity i.e average ratings or for item or products
# 3. Its easiest way to showcase the current trend in the market. So any songs, movie or products on ecommerce site which are popular in the industry, can be made avaiable to user for any exploration. For. example Netflix showing top 10 movies trending in India.
# 4. This does not provide any personalization, as it is just based on average ratings.
# 5. This type of recommondation system is useful for any business which wants to showcase current trend in their industry to users. It also helps to provide recommendation to new users for which there is no user history or profile. It helps in great way to new business who do not have any user base. they can still use this recommendation to show whats popular in the industry.
# 6. Few business which can get benifited from RS e-Commerce,Retail,Media,Banking,Telecom,Utilities
#
# ### CF based Recommendation Systems
# 1. Collaborative Filtering is a personalised recommender system, the recommendations are based on the past behavior of the user and it is not dependent on any additional information. This type of recommendations are useful in marketing campaigns, retail business and this can be used in upscalling and cross saling.
# 2. collaberative Recommendations is a personalised recommender system so it helps more to business which has a user base. so based on similarity in user profile, items can be recommended to new customers.
# 3. Item-item based CF can be useful a business to cater new users based on thier navigation similar items can be recommended to new customers.
# 4. simillary in collaberation with CF User-user and item-item, products can be suggested to user in same category or different adding more to cross sell and upscale
# 5. Few business which can get benifited from CF e-Commerce,Retail,Media,Banking,Telecom,Utilities
# 6. This can help business by Increased sales/conversion, Increased user satisfaction,Increased loyalty and Reduced churn
#
# ### Improvement in Recommendations
# 1. User-user/item-item based recommendations does provide recommendation based on similarity between user profile and item profile, but these recommendations are based on user-user similarity. but lacks to provide any personalizetion based on user preference
# 2. So this can be further improved based by considering other user informations like geogrphical information, age if possible, user’s dynamic information from social network, historical log and many more.
# 3. combining two or more recommendations systems for recommendations.
